# %% [markdown]
# # Frequent nouns WE

# %% [markdown]
# This notebook uses frequency sorting by the frequency of lemmas.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# We extracted a list of most frequently used nouns and we can merge them with the WE of FlauBERT.

# %%
top_freq_n = pd.read_csv('Most Frequent Words/top_frequent_NOUN.csv', index_col='Word')[:1000]

# %%
top_freq_n
# Out:
#               lemme cgram  freqlemlivres
# Word
# homme         homme   NOM        1398.85
# hommes        homme   NOM        1398.85
# jour           jour   NOM        1341.76
# jours          jour   NOM        1341.76
# temps         temps   NOM        1289.39
# ...             ...   ...            ...
# cesses        cesse   NOM          71.96
# flamme       flamme   NOM          71.82
# flammes      flamme   NOM          71.82
# pantalon   pantalon   NOM          71.76
# pantalons  pantalon   NOM          71.76
#
# [1000 rows x 3 columns]

# %%
all_n_we = pd.read_csv('all_nouns_we.csv', index_col=0)

# %% [markdown]
# Out of 1000 most popular nouns, 899 have their own embedding. We can merge them into one DataFrame.

# %%
freq_n_we = all_n_we.merge(top_freq_n, left_index=True, right_index=True)
freq_n_we
# Out:
#                    0         1         2         3         4         5  \
# absence     3.322297 -0.768149  3.555035 -0.685460  1.201102 -3.151831
# absences    3.295355 -0.794079  2.472845  3.223941  5.035848 -4.848855
# accord     -0.732188 -2.024965  1.674970 -4.194049 -2.528312 -2.400746
# accords     1.037610 -0.246123  3.333316 -4.094496  0.056898 -2.978131
# action      1.376720 -3.602622  0.270682 -7.004842  1.199668 -0.341319
# ...              ...       ...       ...       ...       ...       ...
# événements -1.245101 -0.820061  1.330310  5.786696  3.966537 -3.242018
# être        0.166950 -1.121742  3.855680  0.846314 -3.065409  0.577782
# êtres       3.589590 -4.551544  6.088149  2.847501  3.829500 -3.342109
# île        -0.489183 -3.752668 -2.676017  4.677486  1.093927 -5.670148
# îles       -2.838814 -3.576476 -1.082639  5.224788  1.871563 -5.175120
#
#                    6         7         8         9  ...       507       508  \
# absence    -3.592423  1.189369 -2.742928 -2.666739  ... -3.189504 -1.781391
# absences   -4.557629 -2.719433 -1.932022 -6.440993  ... -2.720232 -5.453354
# accord     -4.672920  0.374903  6.015941 -0.066068  ... -1.511964 -3.012614
# accords    -4.198946 -2.159259  3.082677  2.101236  ...  1.128479 -2.874813
# action      3.974475 -0.292309  2.597899  1.607074  ... -3.168099 -2.357484
# ...              ...       ...       ...       ...  ...       ...       ...
# événements -0.265572  2.159446  0.661078 -0.936386  ... -1.882473 -2.838502
# être        1.696410  0.962429  1.131322 -5.577701  ... -4.168539 -1.392100
# êtres       2.749030 -0.169812  1.994654  0.893699  ...  0.022459 -3.056951
# île        -0.456426  2.867334  2.531248 -2.738322  ... -4.173942 -3.766897
# îles        2.896314  1.005481  4.880717 -2.816181  ... -2.302102 -5.743091
#
#                  509       510       511        gn     gender      lemme  \
# absence    -1.852207  5.123568 -2.381779  singular   feminine    absence
# absences   -1.545623  5.919082  0.577700    plural   feminine    absence
# accord     -2.688764 -5.424189 -6.660925  singular  masculine     accord
# accords    -3.825052 -5.254343 -6.959417    plural  masculine     accord
# action     -0.797240  3.015040  0.167511  singular   feminine     action
# ...              ...       ...       ...       ...        ...        ...
# événements -6.080573  1.265242  1.124227    plural  masculine  événement
# être       -5.050613  1.669239 -4.337866  singular  masculine       être
# êtres      -1.911428  0.167977 -1.285041    plural  masculine       être
# île        -7.543975 -2.131077 -4.665631  singular   feminine        île
# îles       -6.689997  0.354014 -2.508205    plural   feminine        île
#
#             cgram  freqlemlivres
# absence       NOM          76.28
# absences      NOM          76.28
# accord        NOM         136.15
# accords       NOM         136.15
# action        NOM          87.43
# ...           ...            ...
# événements    NOM          84.59
# être          NOM         122.57
# êtres         NOM         122.57
# île           NOM         108.24
# îles          NOM         108.24
#
# [899 rows x 517 columns]

# %% [markdown]
# We can also create a dataframe with WE of all available nouns and their frequencies, having approximately 11K nouns WE available:

# %%
all_nouns_with_freq = pd.read_csv('Most Frequent Words/top_frequent_NOUN.csv', index_col='Word')
all_n_we_with_freq = all_n_we.merge(all_nouns_with_freq, left_index=True, right_index=True)
all_n_we_with_freq
# Out:
#                     0         1         2         3         4         5  \
# abaisse      4.652041 -4.028067  0.883202  4.782082 -2.294611 -3.894453
# abaissement  3.209496 -2.750259  2.293690  0.207780 -1.170953 -5.999461
# abandon      3.841302 -2.121901 -1.159175 -5.437495 -1.977204 -4.404269
# abat         7.341515 -1.911543 -3.165352  0.881856  1.255612 -2.573492
# abats        2.571915 -0.997795  2.213263  7.866621  5.011806 -1.280126
# ...               ...       ...       ...       ...       ...       ...
# êtres        3.589590 -4.551544  6.088149  2.847501  3.829500 -3.342109
# île         -0.489183 -3.752668 -2.676017  4.677486  1.093927 -5.670148
# îles        -2.838814 -3.576476 -1.082639  5.224788  1.871563 -5.175120
# îlot         5.139837 -7.427926  4.884292  1.064615  1.387612 -4.198579
# îlots        0.316387 -5.135355  3.555227  3.901632  0.842719 -6.265700
#
#                     6         7         8         9  ...       507       508  \
# abaisse     -0.810279 -0.713933  4.819906  4.090149  ... -5.865204 -7.542219
# abaissement -0.837151  4.209501  0.482295  2.926001  ... -3.568309 -7.705732
# abandon     -5.100209  2.764617 -2.829459 -1.417439  ... -7.677973 -4.133019
# abat        -0.540472 -2.959341  2.970956  1.989334  ... -2.878892 -6.178219
# abats       -1.463984 -5.969271 -0.341902 -3.891024  ... -0.574585 -5.538427
# ...               ...       ...       ...       ...  ...       ...       ...
# êtres        2.749030 -0.169812  1.994654  0.893699  ...  0.022459 -3.056951
# île         -0.456426  2.867334  2.531248 -2.738322  ... -4.173942 -3.766897
# îles         2.896314  1.005481  4.880717 -2.816181  ... -2.302102 -5.743091
# îlot        -1.997534  4.594993  2.311641  1.507236  ... -1.106573 -1.279163
# îlots       -2.832418  3.986920  2.747350  1.586111  ... -3.144311 -1.404029
#
#                   509       510       511        gn     gender        lemme  \
# abaisse     -4.662949 -0.546076 -1.836027  singular   feminine      abaisse
# abaissement -5.310164  1.347664 -4.607303  singular  masculine  abaissement
# abandon     -2.451917  3.346283 -3.959826  singular  masculine      abandon
# abat        -0.410775  0.161333  3.765968  singular  masculine         abat
# abats        2.004640  1.403861 -8.578702    plural  masculine         abat
# ...               ...       ...       ...       ...        ...          ...
# êtres       -1.911428  0.167977 -1.285041    plural  masculine         être
# île         -7.543975 -2.131077 -4.665631  singular   feminine          île
# îles        -6.689997  0.354014 -2.508205    plural   feminine          île
# îlot        -0.509667  1.712433 -3.325491  singular  masculine         îlot
# îlots       -1.362893 -0.495850  0.191013    plural  masculine         îlot
#
#              cgram  freqlemlivres
# abaisse        NOM           0.00
# abaissement    NOM           2.16
# abandon        NOM          27.36
# abat           NOM           1.01
# abats          NOM           1.01
# ...            ...            ...
# êtres          NOM         122.57
# île            NOM         108.24
# îles           NOM         108.24
# îlot           NOM          10.68
# îlots          NOM          10.68
#
# [11395 rows x 517 columns]

# %% [markdown]
# # Frequency dimension

# %% [markdown]
# There was an assumption that dimensions 371 and 52 can be correlated to frequency. We can look at the correlations of these dimensions with `freqlemlivres`:

# %%
all_n_we_with_freq.loc[:, [ '52', '371', 'freqlemlivres']].corr()
# Out:
#                      52       371  freqlemlivres
# 52             1.000000 -0.678549      -0.101934
# 371           -0.678549  1.000000       0.072126
# freqlemlivres -0.101934  0.072126       1.000000

# %% [markdown]
# The correlation between the dimension values and the frequency values is not strong. We can try to find a dimension with the strongest correlation with the values of the frequency column.

# %%
freq_corr_df = pd.DataFrame(columns=['corr_with_freq'])
freq_list = []

# Go through dimensions from 0 to 511
for i in range(512):
    # Find the correlation of the current column with "freqlemlivres" and add to the list
    freq_list.append(all_n_we_with_freq.loc[:, [str(i), 'freqlemlivres']].corr().iloc[0][-1])

# Use the list values as 
freq_corr_df['corr_with_freq'] = freq_list
freq_corr_df['sign'] = np.sign(freq_corr_df['corr_with_freq'])
freq_corr_df['abs'] = abs(freq_corr_df['corr_with_freq'])
freq_corr_df
# Out:
#      corr_with_freq  sign       abs
# 0         -0.056975  -1.0  0.056975
# 1          0.054485   1.0  0.054485
# 2         -0.014856  -1.0  0.014856
# 3         -0.053013  -1.0  0.053013
# 4         -0.020633  -1.0  0.020633
# ..              ...   ...       ...
# 507       -0.072089  -1.0  0.072089
# 508        0.013247   1.0  0.013247
# 509       -0.018811  -1.0  0.018811
# 510        0.049783   1.0  0.049783
# 511        0.026257   1.0  0.026257
#
# [512 rows x 3 columns]

# %%
freq_corr_df.sort_values('abs').iloc[-20:]
# Out:
#      corr_with_freq  sign       abs
# 148        0.099414   1.0  0.099414
# 487       -0.099493  -1.0  0.099493
# 186       -0.099986  -1.0  0.099986
# 338       -0.101221  -1.0  0.101221
# 24        -0.101487  -1.0  0.101487
# 52        -0.101934  -1.0  0.101934
# 228       -0.104339  -1.0  0.104339
# 366       -0.104582  -1.0  0.104582
# 119       -0.105853  -1.0  0.105853
# 484       -0.106097  -1.0  0.106097
# 208        0.106921   1.0  0.106921
# 469        0.108511   1.0  0.108511
# 113        0.108816   1.0  0.108816
# 91        -0.109126  -1.0  0.109126
# 43         0.109958   1.0  0.109958
# 143       -0.110892  -1.0  0.110892
# 314        0.125546   1.0  0.125546
# 324       -0.129692  -1.0  0.129692
# 224       -0.131444  -1.0  0.131444
# 146       -0.133998  -1.0  0.133998

# %% [markdown]
# We can see that even the dimensions with highest correlation to the frequency column are not that high, and dimension `52` is not far away from the values seen above.
#
# This experiment doesn't allow us to establish a strong correlation with frequency for any dimension.

# %% [markdown]
# # Dimensions with highest and lowest avg

# %% [markdown]
# We can make an assumption that dimensions that have highest or lowest values can be representative of noun-ness.
#
# For the experiment with dimensions we will take the most frequent nouns which as well *can't be interpreted as verb* (as seen above, one of the most common nouns is `être` which will potentially has dimensions both representing nouns and verbs).
#
# For this we will first the list of nouns and verbs and find the nouns that are uniquely in the list of nouns.

# %%
top_freq_v = pd.read_csv('Most Frequent Words/top1000_VERB.csv', index_col='Word')
top_freq_v
# Out:
#                  lemme cgram  freqlemlivres
# Word
# es                être   VER       15085.47
# est               être   VER       15085.47
# furent            être   VER       15085.47
# fus               être   VER       15085.47
# fusse             être   VER       15085.47
# ...                ...   ...            ...
# éliciter      éliciter   VER           0.00
# émuler          émuler   VER           0.00
# émulsifier  émulsifier   VER           0.00
# équeuter      équeuter   VER           0.00
# équivoquer  équivoquer   VER           0.00
#
# [64929 rows x 3 columns]

# %%
top1000_unique_nouns = all_nouns_with_freq[~all_nouns_with_freq.index.isin(top_freq_v.index)][:1000]
top1000_unique_nouns
# Out:
#             lemme cgram  freqlemlivres
# Word
# homme       homme   NOM        1398.85
# hommes      homme   NOM        1398.85
# jour         jour   NOM        1341.76
# jours        jour   NOM        1341.76
# temps       temps   NOM        1289.39
# ...           ...   ...            ...
# actes        acte   NOM          57.30
# paysan     paysan   NOM          57.30
# paysanne   paysan   NOM          57.30
# paysannes  paysan   NOM          57.30
# paysans    paysan   NOM          57.30
#
# [1000 rows x 3 columns]

# %% [markdown]
# Now we can find the WE for these nouns that can't be confused as verbs. We will also add PoS encoding for nouns as `1`:

# %%
unique_freq_n_we = all_n_we.merge(top1000_unique_nouns, left_index=True, right_index=True)
unique_freq_n_we['pos'] = 1

unique_freq_n_we
# Out:
#                    0         1         2         3         4         5  \
# absence     3.322297 -0.768149  3.555035 -0.685460  1.201102 -3.151831
# absences    3.295355 -0.794079  2.472845  3.223941  5.035848 -4.848855
# accord     -0.732188 -2.024965  1.674970 -4.194049 -2.528312 -2.400746
# accords     1.037610 -0.246123  3.333316 -4.094496  0.056898 -2.978131
# acte        5.714411 -3.455246  1.156246  0.894613 -2.072708  1.619847
# ...              ...       ...       ...       ...       ...       ...
# événement  -0.693584 -0.753810  0.124109  2.200120  1.585398 -2.354075
# événements -1.245101 -0.820061  1.330310  5.786696  3.966537 -3.242018
# êtres       3.589590 -4.551544  6.088149  2.847501  3.829500 -3.342109
# île        -0.489183 -3.752668 -2.676017  4.677486  1.093927 -5.670148
# îles       -2.838814 -3.576476 -1.082639  5.224788  1.871563 -5.175120
#
#                    6         7         8         9  ...       508       509  \
# absence    -3.592423  1.189369 -2.742928 -2.666739  ... -1.781391 -1.852207
# absences   -4.557629 -2.719433 -1.932022 -6.440993  ... -5.453354 -1.545623
# accord     -4.672920  0.374903  6.015941 -0.066068  ... -3.012614 -2.688764
# accords    -4.198946 -2.159259  3.082677  2.101236  ... -2.874813 -3.825052
# acte       -2.930497 -1.164060  1.456195 -3.298590  ... -1.903922 -1.031769
# ...              ...       ...       ...       ...  ...       ...       ...
# événement  -2.994415  1.552121  4.762497 -1.361055  ... -4.852169 -5.389591
# événements -0.265572  2.159446  0.661078 -0.936386  ... -2.838502 -6.080573
# êtres       2.749030 -0.169812  1.994654  0.893699  ... -3.056951 -1.911428
# île        -0.456426  2.867334  2.531248 -2.738322  ... -3.766897 -7.543975
# îles        2.896314  1.005481  4.880717 -2.816181  ... -5.743091 -6.689997
#
#                  510       511        gn     gender      lemme  cgram  \
# absence     5.123568 -2.381779  singular   feminine    absence    NOM
# absences    5.919082  0.577700    plural   feminine    absence    NOM
# accord     -5.424189 -6.660925  singular  masculine     accord    NOM
# accords    -5.254343 -6.959417    plural  masculine     accord    NOM
# acte        1.625798 -3.859723  singular  masculine       acte    NOM
# ...              ...       ...       ...        ...        ...    ...
# événement   0.740749 -3.701469  singular  masculine  événement    NOM
# événements  1.265242  1.124227    plural  masculine  événement    NOM
# êtres       0.167977 -1.285041    plural  masculine       être    NOM
# île        -2.131077 -4.665631  singular   feminine        île    NOM
# îles        0.354014 -2.508205    plural   feminine        île    NOM
#
#             freqlemlivres  pos
# absence             76.28    1
# absences            76.28    1
# accord             136.15    1
# accords            136.15    1
# acte                57.30    1
# ...                   ...  ...
# événement           84.59    1
# événements          84.59    1
# êtres              122.57    1
# île                108.24    1
# îles               108.24    1
#
# [885 rows x 518 columns]

# %% [markdown]
# ## Dimensions with the highest average

# %% [markdown]
# Now that we have a dataframe, containing words that serve as nouns only and are relatively frequent, we can analyse the dimensions. First, we can find top 5 dimensions with the highest values:

# %%
unique_freq_n_we.loc[:, :'511'].mean().sort_values()[-5:]
# Out:
# 195     5.924231
# 326     6.414400
# 44      7.174508
# 250    10.422687
# 371    37.350416
# dtype: float64

# %% [markdown]
# Some of the dimensions we have previously seen as having the highest values: `371`, `250`, `44`, `195`: [here](https://github.com/ClementineBleuze/WordEmbeddings/blob/main/Morphalou3/Investigating%20noun%20dimensions.ipynb).
#
# Dimension `326` was not previously investiagted, we can have a look at the top 20 nouns with highest values in the dimension `326` and botton 20 nouns with the lowest values in `326`:

# %%
unique_freq_n_we['326'].sort_values()[-20:]
# Out:
# patte       12.198476
# photos      12.265883
# objet       12.278166
# fleurs      12.279531
# poil        12.297997
# élément     12.353693
# poils       12.598932
# magasins    12.629414
# fers        12.740904
# chaînes     12.746919
# chemise     12.968505
# visage      13.011158
# position    13.245049
# toile       13.330914
# pantalon    13.465014
# chapeaux    13.678488
# paysage     13.763266
# cheveu      13.962662
# fil         15.256657
# vêtement    16.344282
# Name: 326, dtype: float64

# %%
unique_freq_n_we['326'].sort_values()[:20]
# Out:
# études        -1.676383
# intention     -1.597302
# morceau       -1.195826
# appel         -1.108422
# quart         -0.810918
# cri           -0.510924
# étude         -0.468958
# quarts        -0.342226
# notes         -0.248693
# anglaises     -0.035159
# espoirs        0.218262
# accord         0.303974
# fin            0.403139
# accords        0.427793
# professeure    0.493299
# or             0.518524
# efforts        0.557973
# moitié         0.578965
# airs           0.658743
# noirs          0.823840
# Name: 326, dtype: float64

# %% [markdown]
# ## Dimensions with the lowest average

# %%
unique_freq_n_we.loc[:, :'511'].mean().sort_values()[:5]
# Out:
# 52    -10.950035
# 274    -8.759658
# 181    -6.220996
# 138    -5.789016
# 355    -5.593191
# dtype: float64

# %% [markdown]
# Example of nouns for highest and lowest values of `52`, `274` and `138` can be found [here](https://github.com/ClementineBleuze/WordEmbeddings/blob/main/Morphalou3/Investigating%20noun%20dimensions.ipynb).
#
# Dimensions `181` and `355` were not looked at before and we can look at them righ now.

# %% [markdown]
# ### Dimension 181

# %%
unique_freq_n_we['181'].sort_values()[-20:]
# Out:
# forêt         -1.740409
# polices       -1.695406
# eaux          -1.682395
# hauteur       -1.644578
# détail        -1.639662
# droite        -1.561079
# eau           -1.356558
# numéro        -1.291714
# amitiés       -1.290581
# courage       -1.285148
# amitié        -1.267396
# françaises    -1.247621
# oncles        -1.206256
# coin          -0.834102
# kilomètre     -0.752624
# boulevard     -0.737056
# française     -0.638921
# couvertures   -0.582790
# feuilles      -0.506102
# numéros       -0.388196
# Name: 181, dtype: float64

# %%
unique_freq_n_we['181'].sort_values()[:20]
# Out:
# vêtement      -15.828648
# pantalons     -13.349597
# seins         -13.125753
# chemises      -12.764800
# pantalon      -12.581136
# visage        -12.477160
# premiers      -12.455402
# avion         -12.297463
# garçons       -12.292806
# robes         -12.170732
# instants      -12.073190
# vêtements     -12.022993
# nuages        -11.975925
# silhouettes   -11.937696
# sons          -11.860026
# paupières     -11.577159
# lunettes      -11.535264
# tête          -11.280148
# train         -11.264141
# veste         -11.236717
# Name: 181, dtype: float64

# %% [markdown]
# We can notice that all values of dimension `181` are negative and we can hypothesise that positive values of this dimension can correspond to non-nouns.

# %% [markdown]
# ### Dimenension 355

# %%
unique_freq_n_we['355'].sort_values()[-20:]
# Out:
# amitiés         0.466341
# vieilles        0.589841
# maître          0.897711
# mesdames        0.902082
# courage         1.024943
# côte            1.062192
# plage           1.419784
# mademoiselle    1.421283
# ors             1.747298
# professeure     1.791751
# enfance         2.015367
# lendemains      2.045393
# détail          2.122941
# sables          2.232556
# amitié          2.451087
# paysanne        2.613066
# monsieur        2.685090
# vieille         2.819256
# exemples        3.157083
# madame          3.630800
# Name: 355, dtype: float64

# %%
unique_freq_n_we['355'].sort_values()[:20]
# Out:
# poitrine     -17.556677
# vêtement     -16.150639
# seins        -16.125893
# intérieur    -15.367145
# suites       -15.325886
# espèce       -14.876024
# oreilles     -14.476932
# ventre       -14.020979
# pantalon     -13.736344
# cuisses      -13.608708
# ailes        -13.525702
# intérieurs   -13.002431
# blancs       -12.861234
# poils        -12.774035
# jambes       -12.376138
# salles       -12.287629
# fenêtre      -12.218022
# rang         -12.040234
# chemises     -12.032741
# mecs         -11.648692
# Name: 355, dtype: float64

# %% [markdown]
# ## Dimensions with the lowest std

# %% [markdown]
# We can create a hypithesis that these dimensions with the lowest deviation, represent the noun-ness.

# %%
unique_freq_n_we.loc[:, :'511'].std().sort_values()[:5]
# Out:
# 508    1.797948
# 408    1.843925
# 229    1.879214
# 497    1.898605
# 458    1.942430
# dtype: float64

# %% [markdown]
# None of these dimensions were previously analysed.

# %% [markdown]
# # Testing the correlation of noun-ness

# %% [markdown]
# We now have 6 potential dimentions that hold the information about noun-ness: `181`, `508`, `408`, `229`, `497` and `458`.
#
# We can test these dimensions for noun-ness by selecting top 1000 most frequent verbs (that can't be interpreted by nouns). For both nouns and verbs, we can create a column encoding the PoS: -1 for nouns and 1 for verbs. We can then check the correlation of each of the 6 dimensions with the PoS values.

# %% [markdown]
# First, we will create a DataFrame with words that are uniquely verbs:

# %%
top_unique_verbs = top_freq_v[~top_freq_v.index.isin(all_nouns_with_freq.index)][:2000]
top_unique_verbs
# Out:
#         lemme cgram  freqlemlivres
# Word
# es       être   VER       15085.47
# furent   être   VER       15085.47
# fus      être   VER       15085.47
# fusse    être   VER       15085.47
# fussent  être   VER       15085.47
# ...       ...   ...            ...
# lisez    lire   VER         324.80
# lisiez   lire   VER         324.80
# lisions  lire   VER         324.80
# lisons   lire   VER         324.80
# lu       lire   VER         324.80
#
# [2000 rows x 3 columns]

# %%
all_v_we = pd.read_csv('all_verb_we.csv', index_col=0)
unique_freq_v_we = all_v_we.merge(top_unique_verbs, left_index=True, right_index=True)
unique_freq_v_we['pos'] = 0

# %% [markdown]
# Now we can merge the DataFrame of words that are uniquely nouns and uniquely verbs and construct a new dimension of PoS encoding.

# %%
unique_n_and_v_we = pd.concat([unique_freq_n_we, unique_freq_v_we])

# %%
unique_n_and_v_we
# Out:
#                  0         1         2         3         4         5  \
# absence   3.322297 -0.768149  3.555035 -0.685460  1.201102 -3.151831
# absences  3.295355 -0.794079  2.472845  3.223941  5.035848 -4.848855
# accord   -0.732188 -2.024965  1.674970 -4.194049 -2.528312 -2.400746
# accords   1.037610 -0.246123  3.333316 -4.094496  0.056898 -2.978131
# acte      5.714411 -3.455246  1.156246  0.894613 -2.072708  1.619847
# ...            ...       ...       ...       ...       ...       ...
# était    -0.360612  3.057447 -1.896422  0.758237 -3.636281 -5.099815
# étant    -0.191904 -3.721749  1.320861  1.835078 -3.106010  0.611345
# étiez     2.699015  3.925134 -0.288921  3.405879  0.509377 -2.668795
# étions    1.500142  2.358283 -1.131927  3.812386  1.015860 -6.697923
# êtes      4.567974  2.507673 -1.470071 -1.268955 -0.785729 -0.363223
#
#                  6         7         8         9  ...       508       509  \
# absence  -3.592423  1.189369 -2.742928 -2.666739  ... -1.781391 -1.852207
# absences -4.557629 -2.719433 -1.932022 -6.440993  ... -5.453354 -1.545623
# accord   -4.672920  0.374903  6.015941 -0.066068  ... -3.012614 -2.688764
# accords  -4.198946 -2.159259  3.082677  2.101236  ... -2.874813 -3.825052
# acte     -2.930497 -1.164060  1.456195 -3.298590  ... -1.903922 -1.031769
# ...            ...       ...       ...       ...  ...       ...       ...
# était    -2.400843  1.776186 -3.402864  1.588920  ... -3.953760 -5.238096
# étant     5.408586  1.651916 -3.008237 -3.119596  ... -3.058255 -4.453317
# étiez    -3.456107 -0.748104 -1.055025 -1.999213  ... -2.040637 -1.456178
# étions    0.621375  0.781311 -7.201710  0.481353  ... -2.314893 -2.555169
# êtes     -1.276156 -0.668064 -0.077532 -4.630701  ... -2.513856 -1.356880
#
#                510       511        gn     gender    lemme  cgram  \
# absence   5.123568 -2.381779  singular   feminine  absence    NOM
# absences  5.919082  0.577700    plural   feminine  absence    NOM
# accord   -5.424189 -6.660925  singular  masculine   accord    NOM
# accords  -5.254343 -6.959417    plural  masculine   accord    NOM
# acte      1.625798 -3.859723  singular  masculine     acte    NOM
# ...            ...       ...       ...        ...      ...    ...
# était    -0.236460 -3.574182       NaN        NaN     être    VER
# étant     0.471147  3.705925       NaN        NaN     être    VER
# étiez    -0.829461 -2.423766       NaN        NaN     être    VER
# étions   -0.233668 -0.787560       NaN        NaN     être    VER
# êtes      1.715003 -4.430782       NaN        NaN     être    VER
#
#           freqlemlivres  pos
# absence           76.28    1
# absences          76.28    1
# accord           136.15    1
# accords          136.15    1
# acte              57.30    1
# ...                 ...  ...
# était          15085.47    0
# étant          15085.47    0
# étiez          15085.47    0
# étions         15085.47    0
# êtes           15085.47    0
#
# [1814 rows x 518 columns]

# %%
unique_n_and_v_we.loc[:, [ '181', '508', '408', '229', '497', '458', 'pos']].corr()
# Out:
#           181       508       408       229       497       458       pos
# 181  1.000000  0.002994 -0.004103  0.009032  0.106970 -0.221293 -0.180797
# 508  0.002994  1.000000  0.053127 -0.020234  0.053658  0.081258  0.204209
# 408 -0.004103  0.053127  1.000000  0.079723 -0.028967 -0.074247 -0.066497
# 229  0.009032 -0.020234  0.079723  1.000000  0.096122 -0.118621 -0.305888
# 497  0.106970  0.053658 -0.028967  0.096122  1.000000 -0.034902 -0.120919
# 458 -0.221293  0.081258 -0.074247 -0.118621 -0.034902  1.000000  0.482173
# pos -0.180797  0.204209 -0.066497 -0.305888 -0.120919  0.482173  1.000000

# %% [markdown]
# Dimension `458` seems to have a quite strong correlation with PoS values.

# %% [markdown]
# We can have a look at the dimensions with not only the most frequent nouns and verbs, but on the set of all words.

# %%
unique_verbs = top_freq_v[~top_freq_v.index.isin(all_nouns_with_freq.index)]
unique_verbs_we = all_v_we.merge(unique_verbs, left_index=True, right_index=True)
unique_nouns = all_nouns_with_freq[~all_nouns_with_freq.index.isin(top_freq_v.index)]
unique_nouns_we = all_n_we.merge(unique_nouns, left_index=True, right_index=True)
all_unique = pd.concat([unique_verbs_we, unique_nouns_we])
all_unique.loc[all_unique['cgram'] == 'NOM', 'pos'] = 1
all_unique.loc[all_unique['cgram'] == 'VER', 'pos'] = 0
all_unique
# Out:
#                     0         1         2         3         4         5  \
# abaisser    -0.747519 -0.113683  1.325009  0.911627 -1.904380 -9.002491
# abaissé     -0.900001 -2.879979  4.960132 -0.483775 -2.544398 -3.173751
# abandonnant -1.166685  2.856505 -2.728505  5.253222 -2.150984 -1.587207
# abandonne    1.095700  1.242779 -3.414932 -1.418493  1.171745 -7.126312
# abandonnent  2.760998  3.240831 -0.668230 -0.336963 -1.111903 -6.162507
# ...               ...       ...       ...       ...       ...       ...
# êtres        3.589590 -4.551544  6.088149  2.847501  3.829500 -3.342109
# île         -0.489183 -3.752668 -2.676017  4.677486  1.093927 -5.670148
# îles        -2.838814 -3.576476 -1.082639  5.224788  1.871563 -5.175120
# îlot         5.139837 -7.427926  4.884292  1.064615  1.387612 -4.198579
# îlots        0.316387 -5.135355  3.555227  3.901632  0.842719 -6.265700
#
#                     6         7         8         9  ...       508       509  \
# abaisser    -1.629585  0.944770  3.187650  2.009824  ... -7.782869 -5.602723
# abaissé      1.268426  1.158911  3.327402  4.604621  ... -7.752982 -2.755292
# abandonnant -0.212518  0.028500 -1.908678 -0.671578  ... -4.180759  0.671241
# abandonne   -2.851000 -3.415072  3.128422  1.300930  ... -7.359402 -4.790332
# abandonnent -1.919154 -1.619613  1.562258  3.144015  ... -5.456535 -4.212030
# ...               ...       ...       ...       ...  ...       ...       ...
# êtres        2.749030 -0.169812  1.994654  0.893699  ... -3.056951 -1.911428
# île         -0.456426  2.867334  2.531248 -2.738322  ... -3.766897 -7.543975
# îles         2.896314  1.005481  4.880717 -2.816181  ... -5.743091 -6.689997
# îlot        -1.997534  4.594993  2.311641  1.507236  ... -1.279163 -0.509667
# îlots       -2.832418  3.986920  2.747350  1.586111  ... -1.404029 -1.362893
#
#                   510       511       lemme  cgram  freqlemlivres        gn  \
# abaisser    -0.491549 -4.491615    abaisser    VER          18.04       NaN
# abaissé      2.423886 -0.766142    abaisser    VER          18.04       NaN
# abandonnant  1.610980 -0.135293  abandonner    VER         128.45       NaN
# abandonne    0.965371 -3.193502  abandonner    VER         128.45       NaN
# abandonnent  1.037980 -0.440188  abandonner    VER         128.45       NaN
# ...               ...       ...         ...    ...            ...       ...
# êtres        0.167977 -1.285041        être    NOM         122.57    plural
# île         -2.131077 -4.665631         île    NOM         108.24  singular
# îles         0.354014 -2.508205         île    NOM         108.24    plural
# îlot         1.712433 -3.325491        îlot    NOM          10.68  singular
# îlots       -0.495850  0.191013        îlot    NOM          10.68    plural
#
#                 gender  pos
# abaisser           NaN  0.0
# abaissé            NaN  0.0
# abandonnant        NaN  0.0
# abandonne          NaN  0.0
# abandonnent        NaN  0.0
# ...                ...  ...
# êtres        masculine  1.0
# île           feminine  1.0
# îles          feminine  1.0
# îlot         masculine  1.0
# îlots        masculine  1.0
#
# [16142 rows x 518 columns]

# %%
all_unique.loc[:, [ '181', '508', '408', '229', '497', '458', 'pos']].corr()
# Out:
#           181       508       408       229       497       458       pos
# 181  1.000000  0.049078 -0.025396  0.058481  0.024580 -0.163254 -0.124933
# 508  0.049078  1.000000 -0.004009 -0.012251  0.009153  0.086860  0.174297
# 408 -0.025396 -0.004009  1.000000  0.088653 -0.020888 -0.060099 -0.049640
# 229  0.058481 -0.012251  0.088653  1.000000  0.007196 -0.090234 -0.226726
# 497  0.024580  0.009153 -0.020888  0.007196  1.000000  0.127469  0.102225
# 458 -0.163254  0.086860 -0.060099 -0.090234  0.127469  1.000000  0.452948
# pos -0.124933  0.174297 -0.049640 -0.226726  0.102225  0.452948  1.000000

# %% [markdown]
# We can see that with selecting more verbs and nouns the correlation between PoS becomes weaker, however, correlation of dimensions `458` and `pos` still remains relatively strong which and can potentially contain the information about PoS.

# %% [markdown]
# # Finding dimensions with highest correlation to PoS values

# %% [markdown]
# Now for the top frequent nouns and verbs, we can go through all the dimensions and find the correlation of each  dimension with the PoS values: 1 for verbs and -1 for nouns.

# %%
pos_corr_freq_df = pd.DataFrame(columns=['corr_with_pos'])
pos_list = []

# Go through dimensions from 0 to 511
for i in range(512):
    # Find the correlation of the current column with "freqlemlivres" and add to the list
    pos_list.append(unique_n_and_v_we.loc[:, [str(i), 'pos']].corr().iloc[0][-1])

# Use the list values as 
pos_corr_freq_df['corr_with_pos'] = pos_list
pos_corr_freq_df['sign'] = np.sign(pos_corr_freq_df['corr_with_pos'])
pos_corr_freq_df['abs'] = abs(pos_corr_freq_df['corr_with_pos'])
pos_corr_freq_df.sort_values('abs')[-20:]
# Out:
#      corr_with_pos  sign       abs
# 31        0.461351   1.0  0.461351
# 87       -0.467586  -1.0  0.467586
# 434      -0.470088  -1.0  0.470088
# 282       0.470633   1.0  0.470633
# 192       0.474644   1.0  0.474644
# 504       0.476452   1.0  0.476452
# 310      -0.478556  -1.0  0.478556
# 346       0.479326   1.0  0.479326
# 341      -0.480961  -1.0  0.480961
# 458       0.482173   1.0  0.482173
# 29       -0.484897  -1.0  0.484897
# 168      -0.486088  -1.0  0.486088
# 89       -0.500218  -1.0  0.500218
# 401      -0.500686  -1.0  0.500686
# 462       0.501386   1.0  0.501386
# 137       0.505245   1.0  0.505245
# 51        0.518965   1.0  0.518965
# 198       0.546569   1.0  0.546569
# 480       0.563593   1.0  0.563593
# 159      -0.577832  -1.0  0.577832

# %% [markdown]
# We can see that previously seen dimension `458` is in top 20 of the most correlated dimensions with PoS but by far is not the dimension with the highest correlation. Dimensions `480` and `159` seem to have the strongest correlation with `PoS` with a lot of other dimensions (including `458` following closely by).

# %% [markdown]
# We can repeat the experiment on all unique nouns and verbs:

# %%
pos_corr_all_df = pd.DataFrame(columns=['corr_with_pos'])
pos_list = []

# Go through dimensions from 0 to 511
for i in range(512):
    # Find the correlation of the current column with "freqlemlivres" and add to the list
    pos_list.append(all_unique.loc[:, [str(i), 'pos']].corr().iloc[0][-1])

# Use the list values as 
pos_corr_all_df['corr_with_pos'] = pos_list
pos_corr_all_df['sign'] = np.sign(pos_corr_all_df['corr_with_pos'])
pos_corr_all_df['abs'] = abs(pos_corr_all_df['corr_with_pos'])
pos_corr_all_df.sort_values('abs')[-20:]
# Out:
#      corr_with_pos  sign       abs
# 282       0.340653   1.0  0.340653
# 479      -0.353590  -1.0  0.353590
# 212      -0.353986  -1.0  0.353986
# 198       0.362031   1.0  0.362031
# 362      -0.372121  -1.0  0.372121
# 65       -0.377942  -1.0  0.377942
# 31        0.378955   1.0  0.378955
# 192       0.381596   1.0  0.381596
# 341      -0.383088  -1.0  0.383088
# 305      -0.389222  -1.0  0.389222
# 409      -0.411112  -1.0  0.411112
# 128      -0.411578  -1.0  0.411578
# 310      -0.413206  -1.0  0.413206
# 29       -0.415774  -1.0  0.415774
# 346       0.427051   1.0  0.427051
# 401      -0.427715  -1.0  0.427715
# 504       0.439824   1.0  0.439824
# 458       0.452948   1.0  0.452948
# 480       0.475768   1.0  0.475768
# 159      -0.516704  -1.0  0.516704

# %% [markdown]
# Interestingly, if we look at the all noun and verb data, the order of most correlated dimensions changes: `458` rises much higher in the list and `51` and `137` (dimension #4 and #5 of frequent words strongly correlated to PoS) disappear completely.
#
# Dimensions `159` and `480` remain one of the strongest correlated dimensions to PoS both for frequent and all words, which can be a sign that these dimensions encode some fundamental information about verbs/nouns which can be recognized by NN even for less frequent words.
#
# We can have a look at correlation of values of dimensions `159` and `480` between each other, since if they both have PoS information, the expected correlation between them should be very strong. For the comparison, we can also include all the dimensions that appear in top 5 for frequent and all words. First, we can look at the correlation for the values of the most frequent words:

# %%
unique_n_and_v_we.loc[:, [ '159', '480', '198', '51', '137', '458', '504', '401']].corr()
# Out:
#           159       480       198        51       137       458       504  \
# 159  1.000000 -0.444656 -0.311024 -0.402294 -0.467884 -0.392620 -0.401734
# 480 -0.444656  1.000000  0.420567  0.257552  0.314238  0.337139  0.359058
# 198 -0.311024  0.420567  1.000000  0.438929  0.265428  0.239151  0.314604
# 51  -0.402294  0.257552  0.438929  1.000000  0.355326  0.190426  0.278007
# 137 -0.467884  0.314238  0.265428  0.355326  1.000000  0.385921  0.273349
# 458 -0.392620  0.337139  0.239151  0.190426  0.385921  1.000000  0.165645
# 504 -0.401734  0.359058  0.314604  0.278007  0.273349  0.165645  1.000000
# 401  0.345594 -0.292778 -0.432702 -0.400639 -0.047166 -0.217365 -0.308022
#
#           401
# 159  0.345594
# 480 -0.292778
# 198 -0.432702
# 51  -0.400639
# 137 -0.047166
# 458 -0.217365
# 504 -0.308022
# 401  1.000000

# %% [markdown]
# Dimensions `137` and `159` have the strongest correlation which is interesting since on the set of all words, dimension `137` is not represented at all. It can be a sign that this dimension relies more on co-occurences in the corpora then on a structural form to define the PoS. The second most correlated pair is indeed dimensions `159` and `480` which can be a strong sign that they indeed encode the PoS information. It's closely followed by `198` and `51`/`401`.
#
# We can now repeat the correlation test for WE of all unique words:

# %%
all_unique.loc[:, [ '159', '480', '198', '51', '137', '458', '504', '401']].corr()
# Out:
#           159       480       198        51       137       458       504  \
# 159  1.000000 -0.390031 -0.194657 -0.236285 -0.331719 -0.384801 -0.360135
# 480 -0.390031  1.000000  0.244190  0.171543  0.090790  0.244287  0.313805
# 198 -0.194657  0.244190  1.000000  0.199262  0.104509  0.172608  0.223125
# 51  -0.236285  0.171543  0.199262  1.000000  0.220459  0.169693  0.065999
# 137 -0.331719  0.090790  0.104509  0.220459  1.000000  0.264302  0.141692
# 458 -0.384801  0.244287  0.172608  0.169693  0.264302  1.000000  0.215746
# 504 -0.360135  0.313805  0.223125  0.065999  0.141692  0.215746  1.000000
# 401  0.266310 -0.239726 -0.367474 -0.180482  0.033731 -0.120900 -0.230859
#
#           401
# 159  0.266310
# 480 -0.239726
# 198 -0.367474
# 51  -0.180482
# 137  0.033731
# 458 -0.120900
# 504 -0.230859
# 401  1.000000

# %% [markdown]
# Here `480` and `159` have the strongest correlation which can be a sign that they may encode the PoS information based on some structural appearance of a word (or co-occurence with an article ???) that doesn't require a lot of corpus appearances to encode. Previously strong correlation of `51` and `198` is much weaker here which can be a sign that `51` is potentially containing some lexical information instead, which requires significant number of corpus appearances to encode.

# %% [markdown]
# # WE mean and WE std

# %% [markdown]
# We can hypothesise that not only a dimension value can be correspondent to a PoS information but a mean value of all dimensions of a WE can be holding a connection to its PoS: since potentially multiple dimensions are correspondant to PoS. And similarly, the row's std could be related to the PoS as well.
#
# To test this we will first create `mean` and `std` columns:

# %%
unique_n_and_v_we['mean'] = unique_n_and_v_we.loc[:, :'511'].mean(axis=1)
unique_n_and_v_we['std'] = unique_n_and_v_we.loc[:, :'511'].std(axis=1)
unique_n_and_v_we
# Out:
#                  0         1         2         3         4         5  \
# absence   3.322297 -0.768149  3.555035 -0.685460  1.201102 -3.151831
# absences  3.295355 -0.794079  2.472845  3.223941  5.035848 -4.848855
# accord   -0.732188 -2.024965  1.674970 -4.194049 -2.528312 -2.400746
# accords   1.037610 -0.246123  3.333316 -4.094496  0.056898 -2.978131
# acte      5.714411 -3.455246  1.156246  0.894613 -2.072708  1.619847
# ...            ...       ...       ...       ...       ...       ...
# était    -0.360612  3.057447 -1.896422  0.758237 -3.636281 -5.099815
# étant    -0.191904 -3.721749  1.320861  1.835078 -3.106010  0.611345
# étiez     2.699015  3.925134 -0.288921  3.405879  0.509377 -2.668795
# étions    1.500142  2.358283 -1.131927  3.812386  1.015860 -6.697923
# êtes      4.567974  2.507673 -1.470071 -1.268955 -0.785729 -0.363223
#
#                  6         7         8         9  ...       510       511  \
# absence  -3.592423  1.189369 -2.742928 -2.666739  ...  5.123568 -2.381779
# absences -4.557629 -2.719433 -1.932022 -6.440993  ...  5.919082  0.577700
# accord   -4.672920  0.374903  6.015941 -0.066068  ... -5.424189 -6.660925
# accords  -4.198946 -2.159259  3.082677  2.101236  ... -5.254343 -6.959417
# acte     -2.930497 -1.164060  1.456195 -3.298590  ...  1.625798 -3.859723
# ...            ...       ...       ...       ...  ...       ...       ...
# était    -2.400843  1.776186 -3.402864  1.588920  ... -0.236460 -3.574182
# étant     5.408586  1.651916 -3.008237 -3.119596  ...  0.471147  3.705925
# étiez    -3.456107 -0.748104 -1.055025 -1.999213  ... -0.829461 -2.423766
# étions    0.621375  0.781311 -7.201710  0.481353  ... -0.233668 -0.787560
# êtes     -1.276156 -0.668064 -0.077532 -4.630701  ...  1.715003 -4.430782
#
#                 gn     gender    lemme  cgram  freqlemlivres  pos      mean  \
# absence   singular   feminine  absence    NOM          76.28    1  0.107776
# absences    plural   feminine  absence    NOM          76.28    1  0.155890
# accord    singular  masculine   accord    NOM         136.15    1 -0.134159
# accords     plural  masculine   accord    NOM         136.15    1  0.163305
# acte      singular  masculine     acte    NOM          57.30    1  0.093330
# ...            ...        ...      ...    ...            ...  ...       ...
# était          NaN        NaN     être    VER       15085.47    0  0.070095
# étant          NaN        NaN     être    VER       15085.47    0 -0.131988
# étiez          NaN        NaN     être    VER       15085.47    0 -0.022156
# étions         NaN        NaN     être    VER       15085.47    0 -0.141204
# êtes           NaN        NaN     être    VER       15085.47    0 -0.134206
#
#                std
# absence   3.783511
# absences  4.046041
# accord    3.874766
# accords   3.767474
# acte      4.037395
# ...            ...
# était     3.995916
# étant     3.573195
# étiez     3.642806
# étions    3.711744
# êtes      3.489500
#
# [1814 rows x 520 columns]

# %%
unique_n_and_v_we.loc[:, ['pos', 'mean', 'std']].corr()
# Out:
#            pos      mean       std
# pos   1.000000  0.041829  0.373164
# mean  0.041829  1.000000  0.142289
# std   0.373164  0.142289  1.000000

# %% [markdown]
# Even though the correlation is not as strong as have been seen above, there is some correlation between PoS and standard deviation of values of a WE.

# %%
unique_n_and_v_we[unique_n_and_v_we['cgram'] == 'NOM']['std'].describe()
# Out:
# count    885.000000
# mean       3.901722
# std        0.246803
# min        3.158686
# 25%        3.730351
# 50%        3.883908
# 75%        4.048688
# max        4.715224
# Name: std, dtype: float64

# %%
unique_n_and_v_we[unique_n_and_v_we['cgram'] == 'VER']['std'].describe()
# Out:
# count    929.000000
# mean       3.691616
# std        0.274309
# min        3.048631
# 25%        3.494852
# 50%        3.672481
# 75%        3.860666
# max        4.863025
# Name: std, dtype: float64

# %% [markdown]
# We can see that nouns appear to have a relatively higher amplitude in the values of dimensions which can be interesting to keep an eye on.

# %% [markdown]
# # Constructing an average vector for nouns and verbs

# %% [markdown]
# We can construct an average WE for our set of unique frequent nouns and then one for unique frequent verbs.
#
# We can use this to find the closest and furthest dimensions between the 2 average vectors. For closest dimensions of an average noun and verb WE, we can assume that they don't encode PoS information and can be ignored. Contrary, the dimensions with furthest distance between dimensions can be considered for containing PoS information.
#
# Let's start by constructing the average WE vectors:

# %%
avg_n = unique_n_and_v_we[unique_n_and_v_we['cgram'] == 'NOM'].loc[:, :'511'].mean()
avg_n
# Out:
# 0      2.015118
# 1     -1.439105
# 2      0.434033
# 3     -0.740522
# 4      1.074243
#          ...
# 507   -3.489826
# 508   -3.139880
# 509   -3.304758
# 510    1.464510
# 511   -2.144934
# Length: 512, dtype: float64

# %%
avg_v = unique_n_and_v_we[unique_n_and_v_we['cgram'] == 'VER'].loc[:, :'511'].mean()
avg_v
# Out:
# 0      1.659160
# 1     -0.302842
# 2     -0.844155
# 3     -0.262993
# 4      0.460152
#          ...
# 507   -3.501847
# 508   -3.847898
# 509   -4.994116
# 510   -0.346755
# 511   -2.015994
# Length: 512, dtype: float64

# %% [markdown]
# Now we can find difference between the two:

# %%
diff = abs(avg_n - avg_v)
diff.sort_values()[:10]
# Out:
# 250    0.003349
# 46     0.005442
# 338    0.006380
# 68     0.009875
# 507    0.012020
# 258    0.014600
# 246    0.014610
# 206    0.014892
# 135    0.018301
# 169    0.018893
# dtype: float64

# %% [markdown]
# Dimension `250` appears to be the one with the lowest difference between nouns and verbs, meaning the information there is very unlikely to be PoS related and indeed we haven't see any of these dimensions in our previous analysis of dimensions for PoS information.

# %%
diff.sort_values()[-10:]
# Out:
# 401    2.961695
# 51     2.991950
# 159    3.016200
# 341    3.024006
# 310    3.098787
# 168    3.162027
# 212    3.254215
# 480    3.264893
# 137    3.347598
# 198    3.732486
# dtype: float64

# %% [markdown]
# We can see previously analysed dimensions `137`, `198` and `480` in the top of this experiment, which could potentially mean that this type of experiment is a good predictor of correlation results. Dimensions `168`, `212` and `310` were as well present in the PoS correlation analysis, however, were not in the very top.

# %% [markdown]
# # Constructing a median vector

# %% [markdown]
# Using the same logic, instead of using average we can have a look at a vector of median values for both frequent nouns and verbs:

# %%
med_n = unique_n_and_v_we[unique_n_and_v_we['pos'] == 1].loc[:, :'511'].median()
med_v = unique_n_and_v_we[unique_n_and_v_we['pos'] == 0].loc[:, :'511'].median()
diff_med = abs(med_n - med_v)
diff_med.sort_values()[-10:]
# Out:
# 159    3.002825
# 346    3.045815
# 51     3.110937
# 282    3.133529
# 480    3.296125
# 310    3.323717
# 212    3.333989
# 137    3.375651
# 168    3.470976
# 198    3.907393
# dtype: float64

# %% [markdown]
# Once again, all the dimensions have previously appeared during the correlation analysis and potentially this experiment can be used to predict correlation.

# %% [markdown]
# # Investigating the dimensions

# %% [markdown]
# We can now have a look at the dimensions that appear most frequently appearing dimensions:

# %%
set(diff_med.sort_values()[-10:].index).intersection(set(diff.sort_values()[-10:].index))
# Out:
# {'137', '159', '168', '198', '212', '310', '480', '51'}

# %% [markdown]
# We can have a look at the nouns and verbs that have the highest and lowest values in this dimensions to validate whether or not these dimensions can be correspondant to PoS.

# %% [markdown]
# ### Dimension 137

# %%
unique_freq_n_we.loc[:, '137'].describe()
# Out:
# count    885.000000
# mean       5.405422
# std        3.034216
# min       -5.022720
# 25%        3.353538
# 50%        5.421646
# 75%        7.585082
# max       13.818834
# Name: 137, dtype: float64

# %%
unique_freq_v_we.loc[:, '137'].describe()
# Out:
# count    929.000000
# mean       2.057824
# std        2.682810
# min       -5.134485
# 25%        0.185130
# 50%        2.045994
# 75%        3.720316
# max       11.635337
# Name: 137, dtype: float64

# %% [markdown]
# Verbs seem to have lowever values in this dimension on average and have values relatively close to one another.
# However, both verbs and nouns have similar values for max and min, we can plot all the values of dimension `137` first to see if it's outliers:

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(range(len(unique_freq_n_we)), unique_freq_n_we.loc[:, '137'], label='Nouns')
plt.plot(range(len(unique_freq_n_we)), unique_freq_v_we.loc[:, '137'][:len(unique_freq_n_we)], label='Verbs')
plt.xlabel('Word index')
plt.ylabel('Dimension 137 value')
plt.legend()

# %% [markdown]
# Indeed, generally nouns seem to have higher values in dimension `137` than verbs. Now we can have a look at the outliers. What are the verbs and nouns with highest and lowest values in this dimension. Potentially, verbs with higher values in it could be ambiguous with nouns or vice versa.

# %%
unique_freq_v_we.loc[:, '137'].sort_values()[-20:]
# Out:
# montent      7.576328
# arrive       7.615453
# veut         7.726127
# regardez     7.799977
# monte        7.959327
# voir         7.987017
# sont         8.013703
# parlent      8.334767
# meurt        8.656360
# parle        8.676083
# tombent      8.686765
# portés       8.724498
# vus          8.745435
# aimés        8.775960
# regarder     8.784038
# sortent      9.184559
# jouent       9.247888
# parlé        9.727236
# sortira      9.852461
# meurent     11.635337
# Name: 137, dtype: float64

# %%
unique_freq_n_we.loc[:, '137'].sort_values()[:10]
# Out:
# con         -5.022720
# or          -4.414763
# études      -4.105182
# seules      -3.594840
# seuls       -3.493194
# kilomètre   -3.305881
# quart       -3.203944
# ton         -2.508558
# midi        -2.458294
# long        -2.329259
# Name: 137, dtype: float64

# %% [markdown]
# Interestingly, the verbs with a higher count in this dimension except `vus`, `aimés`, `porté` (and partially `parlé`) are not ambiguous, the verb `meurent` with highest value can't be interpreted as a noun or any other PoS.
#
# For nouns, there are more ambiguous words at top `con` (can be an adjective), `or`, `seules`/`seuls`.

# %% [markdown]
# We can have a look at what verbs have the lowest values in the dimension and what nouns have the highest, assuming that these words should be non-ambiguously verbs and nouns:

# %%
unique_freq_v_we.loc[:, '137'].sort_values()[:10]
# Out:
# répondra     -5.134485
# restons      -5.129943
# attendant    -4.859307
# comprenant   -4.748883
# suivez       -4.656426
# eus          -4.476579
# posez        -4.403097
# sauraient    -4.261603
# poserait     -4.201146
# fussent      -4.188415
# Name: 137, dtype: float64

# %%
unique_freq_n_we.loc[:, '137'].sort_values()[-10:]
# Out:
# guerres       12.301328
# odeur         12.332694
# veste         12.359904
# couleurs      12.362883
# sueur         12.764534
# guerre        12.891715
# horreurs      13.026514
# princesses    13.235813
# lendemains    13.296439
# parfum        13.818834
# Name: 137, dtype: float64

# %% [markdown]
# Indeed, the verbs and nouns at the corresponding side of the spectrum are not ambiguous. However, it is interesting to notice that a the max side for both nouns and verbs there could be some lexical correlation `meurent` is the verb with highest value in the dimension and `guerre` appearing at the top of nouns, meaning that in addition to the PoS information the dimension could as well encode some lexical information.

# %% [markdown]
# ### Dimension 159

# %% [markdown]
# Dimension `159` has the highest correlation with PoS and we can have a look if it appears to be correct.

# %%
unique_freq_n_we.loc[:, '159'].describe()
# Out:
# count    885.000000
# mean      -3.336275
# std        2.358294
# min      -10.308782
# 25%       -4.965351
# 50%       -3.360263
# 75%       -1.778248
# max        3.860630
# Name: 159, dtype: float64

# %%
unique_freq_v_we.loc[:, '159'].describe()
# Out:
# count    929.000000
# mean      -0.320076
# std        1.888466
# min       -5.856759
# 25%       -1.612913
# 50%       -0.357438
# 75%        0.805712
# max        6.975687
# Name: 159, dtype: float64

# %%
plt.plot(range(len(unique_freq_n_we)), unique_freq_n_we.loc[:, '159'], label='Nouns')
plt.plot(range(len(unique_freq_n_we)), unique_freq_v_we.loc[:, '159'][:len(unique_freq_n_we)], label='Verbs')
plt.xlabel('Word index')
plt.ylabel('Dimension 159 value')
plt.legend()

# %% [markdown]
# Here, the values of the dimension for verbs seem to be around 0, and values for nouns seem to be lower on general. We can also see that only 7% of nouns have a positive value in this dimension:

# %%
np.sum(np.array(unique_freq_n_we.loc[:, '159']) >= 0)/len(unique_freq_n_we.loc[:, '159'])
# Out:
# 0.07344632768361582

# %% [markdown]
# In comparison, 40% of verbs have a positive value in this dimension:

# %%
np.sum(np.array(unique_freq_v_we.loc[:, '159']) >= 0)/len(unique_freq_v_we.loc[:, '159'])
# Out:
# 0.4133476856835307

# %% [markdown]
# We can have a look at the outliers:

# %%
unique_freq_v_we.loc[:, '159'].sort_values()[:20]
# Out:
# dues         -5.856759
# retrouvé     -5.783679
# dises        -5.557819
# retrouvés    -5.225046
# fais         -4.969552
# parlée       -4.828527
# seras        -4.758932
# meurs        -4.740520
# perdus       -4.735430
# mettes       -4.628924
# dus          -4.457342
# retrouvées   -4.455048
# perdues      -4.381512
# feras        -4.272197
# penses       -4.230485
# tiennes      -4.230162
# pourrons     -4.184775
# sentirez     -4.182521
# ferez        -4.173402
# arrêtée      -4.127716
# Name: 159, dtype: float64

# %% [markdown]
# We can potentially attribute these low values in verbs for several factors:
# - The verbs being transitive => `Tu le feras` and `le feras` being interpretted as a noun
# - `perdus`/`perdues` which can be used as a noun: `les perdus/perdues`
# - `les tiennes` being a possesive pronoun

# %%
unique_freq_n_we.loc[:, '159'].sort_values()[-20:]
# Out:
# carte           1.405075
# quart           1.453817
# soir            1.623893
# dimanche        1.775624
# ensemble        1.804850
# face            1.836086
# feuille         2.011260
# quarts          2.036620
# seule           2.492659
# heure           2.500959
# heures          2.567712
# madame          2.829990
# mademoiselle    2.902764
# côté            3.017199
# présences       3.464170
# semaine         3.526647
# instant         3.546476
# rang            3.764726
# numéros         3.842225
# numéro          3.860630
# Name: 159, dtype: float64

# %% [markdown]
# We can try to attribute the outlying high values of nouns to potential occurences of them without any article:
# - Par numero(s) / par carte / par semaine
# - à rang de / à côté de
# - Madame and mademoiselle being used to adress someone without any article
# - En face / en carte / en feuille
# - à dimanche / à soir
# - As well as ambiguous nouns `seule` (can be adjective) or `ensemble` (can be adverb)

# %%
unique_freq_v_we.loc[:, '159'].sort_values()[-20:]
# Out:
# écrivez        3.808041
# assis          3.869297
# appellent      3.872902
# parlaient      3.910728
# regardais      3.951928
# écrivent       3.968062
# appela         4.091023
# regardent      4.249136
# regarda        4.327001
# regardé        4.460762
# écrivait       4.534419
# écrivit        4.675721
# appelez        4.726689
# répondait      4.842369
# appeler        4.865578
# aimeriez       5.182109
# attendez       5.290317
# regardaient    5.372563
# regardait      5.537718
# lisait         6.975687
# Name: 159, dtype: float64

# %%
unique_freq_n_we.loc[:, '159'].sort_values()[:20]
# Out:
# parfum       -10.308782
# lait          -9.839472
# douceurs      -9.147656
# vin           -9.138720
# pains         -9.129437
# princesse     -9.089209
# bonheur       -9.004986
# fruits        -8.943031
# chevaux       -8.696256
# fruit         -8.673889
# bains         -8.579679
# chien         -8.524145
# pain          -8.521943
# salut         -8.464986
# princesses    -8.264921
# fers          -8.241133
# coeurs        -8.136814
# cuir          -8.132087
# chaleurs      -8.032098
# droit         -8.019373
# Name: 159, dtype: float64

# %% [markdown]
# We can see transitive verbs again in the list of verbs with highest values (potentially the verbs that shouldn't be confused with nouns). However, we can notice that some forms of the verbs are more rare: passé simple, which may mean that the transitive examples were not present in the corpus.
#
# We can still test the hypothesis of the correlation of this dimension values to transitivity of verbs later.

# %% [markdown]
# However, the theory of outlier nouns being there due to them frequently used without articles doesn't seem to hold: a lot of nouns with minimal values are frequently used without articles as well:
# - à droit
# - en cuir
# - au lait / au vin / au pain
#
# Hence, it is probablu unlikely that the values of this dimension correspond to the co-occurence of a word with articles.

# %% [markdown]
# ### Dimension 168

# %%
unique_freq_n_we.loc[:, '168'].describe()
# Out:
# count    885.000000
# mean      -4.523758
# std        2.950305
# min      -12.671767
# 25%       -6.560309
# 50%       -4.543676
# 75%       -2.521164
# max        4.759557
# Name: 168, dtype: float64

# %%
unique_freq_v_we.loc[:, '168'].describe()
# Out:
# count    929.000000
# mean      -1.361731
# std        2.737162
# min      -11.168934
# 25%       -3.035506
# 50%       -1.072700
# 75%        0.594586
# max        6.170630
# Name: 168, dtype: float64

# %%
plt.plot(range(len(unique_freq_n_we)), unique_freq_n_we.loc[:, '168'], label='Nouns')
plt.plot(range(len(unique_freq_n_we)), unique_freq_v_we.loc[:, '168'][:len(unique_freq_n_we)], label='Verbs')
plt.xlabel('Word index')
plt.ylabel('Dimension 168 value')
plt.legend()

# %% [markdown]
# Similarly to the dimension above, the nouns seem to have lower values in this dimension, however, the deviation for this dimension's value is higher. Let's have a look at the outliers:

# %%
unique_freq_v_we.loc[:, '168'].sort_values()[:20]
# Out:
# montés        -11.168934
# cherchez      -10.814021
# ailles         -9.924334
# cherchons      -9.687685
# écrivant       -9.320558
# meurs          -9.057507
# assis          -8.985550
# ferons         -8.778835
# monté          -8.751593
# comprenant     -8.632848
# sois           -8.556838
# mettes         -8.549283
# devenant       -8.308197
# pouvant        -8.250510
# passez         -8.061159
# marchant       -7.903432
# posant         -7.841803
# devenez        -7.806858
# comprennent    -7.770279
# restera        -7.620943
# Name: 168, dtype: float64

# %%
unique_freq_n_we.loc[:, '168'].sort_values()[-20:]
# Out:
# effets          1.482846
# anglaise        1.630561
# âges            1.880424
# conditions      1.880828
# allemands       1.995543
# attentes        2.010736
# douleurs        2.165696
# circonstance    2.202451
# habitude        2.232567
# anglaises       2.239074
# maladie         2.349483
# chances         2.494717
# maux            2.670144
# hiver           2.980102
# raison          3.061120
# exemple         3.471834
# allemand        3.602129
# preuve          4.202583
# allemande       4.729955
# preuves         4.759557
# Name: 168, dtype: float64

# %% [markdown]
# And if we look highest vlaues for verbs and lowest for nouns:

# %%
unique_freq_v_we.loc[:, '168'].sort_values()[-20:]
# Out:
# devrions        3.604436
# vient           3.626945
# voyaient        3.649285
# mettait         3.694002
# aimerions       3.751521
# commençaient    4.156486
# finissait       4.271875
# pourrions       4.352394
# croyaient       4.362838
# portait         4.459304
# aimerait        4.492030
# aimeraient      4.512638
# venait          4.517740
# arrêtera        4.651471
# croyait         4.754494
# perdait         4.956377
# pensaient       4.975551
# allaient        5.047371
# allait          6.066159
# faite           6.170630
# Name: 168, dtype: float64

# %%
unique_freq_n_we.loc[:, '168'].sort_values()[:20]
# Out:
# immeuble    -12.671767
# vacance     -12.612188
# fauteuil    -12.502253
# bureau      -12.409613
# bancs       -12.386861
# lits        -11.638282
# métier      -11.586425
# café        -11.579555
# parole      -11.419964
# homme       -11.279187
# photo       -11.239471
# cul         -11.120661
# immeubles   -11.075631
# jardin      -11.050344
# mecs        -10.835397
# peaux       -10.811297
# métiers     -10.767248
# bureaux     -10.754667
# salon       -10.748945
# coin        -10.661785
# Name: 168, dtype: float64

# %% [markdown]
# We can see for verbs a higher concentration of verbs in passe imparfait, which potentially can link the dimension to a verb tense.

# %% [markdown]
# ### Dimension 198

# %% [markdown]
# Description of dimension 198 for nouns:

# %%
unique_freq_n_we.loc[:, '198'].describe()
# Out:
# count    885.000000
# mean       3.956850
# std        2.805994
# min       -3.291219
# 25%        2.030376
# 50%        3.973633
# 75%        5.795240
# max       13.864323
# Name: 198, dtype: float64

# %% [markdown]
# Description of dimension 198 for verbs:

# %%
unique_freq_v_we.loc[:, '198'].describe()
# Out:
# count    929.000000
# mean       0.224365
# std        2.910625
# min       -6.979696
# 25%       -1.949626
# 50%        0.066240
# 75%        2.157778
# max       10.105935
# Name: 198, dtype: float64

# %% [markdown]
# This is the second dimension which could potentially be corresponding to PoS information where mean of verb dimension values is close to 0.

# %%
plt.plot(range(len(unique_freq_n_we)), unique_freq_n_we.loc[:, '198'], label='Nouns')
plt.plot(range(len(unique_freq_n_we)), unique_freq_v_we.loc[:, '198'][:len(unique_freq_n_we)], label='Verbs')
plt.xlabel('Word index')
plt.ylabel('Dimension 198 value')
plt.legend()

# %% [markdown]
# Outliers:

# %%
unique_freq_v_we.loc[:, '198'].sort_values()[-20:]
# Out:
# donnez        6.643557
# aimerions     6.691831
# parlée        6.750360
# demandera     6.771740
# demandées     6.771949
# sue           6.775420
# veuillez      6.869750
# demandés      6.961248
# écrivez       7.132521
# comprises     7.142180
# connue        7.482978
# pouvons       7.500731
# posée         7.628286
# portez        8.092013
# pourriez      8.303205
# demandez      8.759162
# pouvant       8.897729
# comprise      9.013088
# appelées      9.925882
# appelée      10.105935
# Name: 198, dtype: float64

# %%
unique_freq_n_we.loc[:, '198'].sort_values()[:20]
# Out:
# suite       -3.291219
# son         -2.844270
# chiennes    -2.787410
# prison      -2.786444
# retours     -2.670875
# flics       -2.500388
# trottoirs   -2.358661
# bains       -2.338661
# flic        -2.336440
# décisions   -2.266979
# coup        -2.251112
# ville       -2.150387
# raisons     -2.059132
# poil        -1.974905
# con         -1.944080
# cons        -1.906005
# vitesses    -1.865200
# destin      -1.857906
# quartiers   -1.856331
# peintures   -1.807843
# Name: 198, dtype: float64

# %% [markdown]
# ### Dimension 212

# %% [markdown]
# Description of dimension `212` for nouns:

# %%
unique_freq_n_we.loc[:, '212'].describe()
# Out:
# count    885.000000
# mean      -2.652333
# std        3.695436
# min      -14.721822
# 25%       -5.071174
# 50%       -2.584355
# 75%       -0.110150
# max        7.879390
# Name: 212, dtype: float64

# %% [markdown]
# Description of dimension `212` for verbs:

# %%
unique_freq_v_we.loc[:, '212'].describe()
# Out:
# count    929.000000
# mean       0.601883
# std        2.966327
# min      -10.970503
# 25%       -1.287454
# 50%        0.749634
# 75%        2.635196
# max        8.669662
# Name: 212, dtype: float64

# %% [markdown]
# Once again we can see that the values of the dimension for verbs are close to 0.

# %%
plt.plot(range(len(unique_freq_n_we)), unique_freq_n_we.loc[:, '212'], label='Nouns')
plt.plot(range(len(unique_freq_n_we)), unique_freq_v_we.loc[:, '212'][:len(unique_freq_n_we)], label='Verbs')
plt.xlabel('Word index')
plt.ylabel('Dimension 212 value')
plt.legend()

# %% [markdown]
# Outliers for verbs:

# %%
unique_freq_v_we.loc[:, '212'].sort_values()[:20]
# Out:
# ferons        -10.970503
# pensé         -10.215091
# posez          -9.451386
# trouveras      -8.364132
# laissons       -8.327107
# répondra       -8.155667
# devenez        -7.658653
# cherchons      -7.328263
# vivez          -7.216456
# trouvez        -7.024298
# jouez          -6.940198
# retrouverez    -6.631535
# trouverez      -6.532736
# ouvres         -6.252396
# passez         -6.245557
# retrouvez      -6.244762
# jouée          -6.055596
# devenant       -5.915195
# passerait      -5.890176
# vas            -5.531349
# Name: 212, dtype: float64

# %% [markdown]
# And what verbs have maximum values:

# %%
unique_freq_v_we.loc[:, '212'].sort_values()[-20:]
# Out:
# sus            6.088203
# voulus         6.104822
# connaissent    6.159629
# fallut         6.166365
# purent         6.390509
# connu          6.469507
# partaient      6.496856
# connue         6.605228
# suivies        6.738927
# portent        6.764989
# connus         6.851872
# reviennent     6.855385
# su             6.886478
# sachent        6.938191
# connues        7.471620
# voulues        7.594850
# demandés       7.662197
# appelées       7.765058
# appellent      7.889357
# appelée        8.669662
# Name: 212, dtype: float64

# %% [markdown]
# Outliers for nouns:

# %%
unique_freq_n_we.loc[:, '212'].sort_values()[-20:]
# Out:
# étranger      4.663223
# veste         4.795206
# âge           4.837571
# noires        4.963596
# grâces        5.043547
# ors           5.102256
# semaines      5.117509
# époque        5.167741
# besoin        5.290983
# noire         5.293870
# noirs         5.474766
# bien          5.785156
# terme         5.840644
# lendemains    6.016439
# années        6.165781
# jour          6.591836
# or            7.014434
# an            7.713143
# haut          7.745336
# hauts         7.879390
# Name: 212, dtype: float64

# %% [markdown]
# Nouns with minimum values for dimension 212:

# %%
unique_freq_n_we.loc[:, '212'].sort_values()[:20]
# Out:
# salon        -14.721822
# jardin       -13.704778
# miroirs      -12.397629
# salle        -12.340772
# mariage      -12.070496
# jeux         -12.052278
# bain         -11.923830
# boîte        -11.883881
# princesses   -11.761798
# chat         -11.742015
# chats        -11.466392
# pain         -10.840712
# verre        -10.700480
# chien        -10.694140
# chienne      -10.648285
# bains        -10.554235
# princesse    -10.549297
# pains        -10.385654
# fleurs       -10.283408
# plat         -10.189102
# Name: 212, dtype: float64

# %% [markdown]
# ### Dimension 480

# %% [markdown]
# Description of values of dimension 480 for nouns:

# %%
unique_freq_n_we.loc[:, '480'].describe()
# Out:
# count    885.000000
# mean       1.762518
# std        2.665479
# min       -8.640285
# 25%       -0.032480
# 50%        1.796206
# 75%        3.591281
# max        9.576292
# Name: 480, dtype: float64

# %% [markdown]
# For verbs:

# %%
unique_freq_v_we.loc[:, '480'].describe()
# Out:
# count    929.000000
# mean      -1.502375
# std        2.101437
# min       -7.979960
# 25%       -2.985793
# 50%       -1.499919
# 75%       -0.090489
# max        5.370016
# Name: 480, dtype: float64

# %%
plt.plot(range(len(unique_freq_n_we)), unique_freq_n_we.loc[:, '480'], label='Nouns')
plt.plot(range(len(unique_freq_n_we)), unique_freq_v_we.loc[:, '480'][:len(unique_freq_n_we)], label='Verbs')
plt.xlabel('Word index')
plt.ylabel('Dimension 480 value')
plt.legend()

# %% [markdown]
# Let's have a look at the outliers (nouns with lowest value of the dimension and verbs with the highest):

# %%
unique_freq_n_we.loc[:, '480'].sort_values()[:20]
# Out:
# présents        -8.640285
# présent         -6.480861
# nom             -6.347413
# dimanches       -6.303494
# nouveau         -6.232853
# seule           -5.462959
# seuls           -5.292027
# seul            -5.179367
# vent            -5.044795
# lieu            -5.034687
# dimanche        -4.872899
# suite           -4.664353
# voisines        -4.648246
# circonstances   -4.456377
# instant         -4.421569
# présences       -4.157806
# seules          -4.125321
# vents           -3.956634
# hasard          -3.939171
# famille         -3.904175
# Name: 480, dtype: float64

# %%
unique_freq_v_we.loc[:, '480'].sort_values()[-20:]
# Out:
# auraient      2.726310
# retrouvez     2.734980
# lira          2.756751
# saurons       2.852421
# finiront      2.853590
# retrouvées    2.859719
# écrivit       2.879265
# lu            2.888344
# tombera       2.909136
# meurent       2.974345
# finira        3.191820
# ailles        3.359642
# tirez         3.545007
# demandés      3.674566
# perdez        3.726598
# parus         3.993899
# écrira        4.099756
# jetez         4.102099
# arrêtez       4.166961
# levez         5.370016
# Name: 480, dtype: float64

# %% [markdown]
# None of the outliers could be really wrongly interpretted as another PoS on a glance.

# %% [markdown]
# ### Dimension 51

# %% [markdown]
# Values of dimension 51 for nouns:

# %%
unique_freq_n_we.loc[:, '51'].describe()
# Out:
# count    885.000000
# mean       3.820480
# std        2.495459
# min       -4.880090
# 25%        2.142937
# 50%        3.882829
# 75%        5.518551
# max       10.893773
# Name: 51, dtype: float64

# %% [markdown]
# For verbs:

# %%
unique_freq_v_we.loc[:, '51'].describe()
# Out:
# count    929.000000
# mean       0.828530
# std        2.434994
# min       -5.595367
# 25%       -0.935503
# 50%        0.771892
# 75%        2.322898
# max       10.593857
# Name: 51, dtype: float64

# %%
plt.plot(range(len(unique_freq_n_we)), unique_freq_n_we.loc[:, '51'], label='Nouns')
plt.plot(range(len(unique_freq_n_we)), unique_freq_v_we.loc[:, '51'][:len(unique_freq_n_we)], label='Verbs')
plt.xlabel('Word index')
plt.ylabel('Dimension 51 value')
plt.legend()

# %% [markdown]
# Outliers:

# %%
unique_freq_n_we.loc[:, '51'].sort_values()[:20]
# Out:
# contact     -4.880090
# ennemies    -4.473399
# ville       -2.803459
# papier      -2.798269
# paupières   -2.643359
# doigts      -2.628122
# ennemie     -2.504863
# cousins     -2.493898
# lèvres      -2.488328
# pains       -2.317813
# dernières   -2.110674
# ton         -1.978012
# voisines    -1.919840
# truc        -1.916490
# ports       -1.817926
# cousine     -1.785795
# paupière    -1.756715
# nouveau     -1.571904
# seins       -1.341382
# son         -1.325119
# Name: 51, dtype: float64

# %%
unique_freq_v_we.loc[:, '51'].sort_values()[-20:]
# Out:
# meurs         6.220694
# puisse        6.315912
# peuvent       6.411231
# ayons         6.546403
# sentons       6.596038
# voulons       6.736224
# aimer         6.748180
# entendons     6.753186
# parte         6.857549
# ayez          6.880438
# finis         6.922651
# puissions     6.977132
# peux          6.988788
# devrions      7.117481
# aimons        7.215671
# peut          7.351294
# puissiez      7.694643
# mettons       7.991395
# vivons        8.884030
# pouvons      10.593857
# Name: 51, dtype: float64

# %% [markdown]
# # Results

# %% [markdown]
# We can now perform a test by adding more PoS: adjectives, adverbs and seeing whether or not any of the dimensions remain strongly correlated to the PoS information.

# %% [markdown]
# # Adding adjectives and adverbs

# %%
top_freq_adj = pd.read_csv('Most Frequent Words/top1000_ADJ.csv', index_col=0)[:1000]

# %%
top_freq_adj['cgram'] = 'ADJ'
top_freq_adj
# Out:
#                      lemme cgram  freqlemlivres
# Word
# son                    son   ADJ        4696.15
# sa                      sa   ADJ        3732.43
# tous                  tout   ADJ        3171.35
# tout                  tout   ADJ        3171.35
# tout                  tout   ADJ        3171.35
# ...                    ...   ...            ...
# assise               assis   ADJ          30.27
# assises              assis   ADJ          30.27
# indifférent    indifférent   ADJ          30.14
# indifférente   indifférent   ADJ          30.14
# indifférentes  indifférent   ADJ          30.14
#
# [1000 rows x 3 columns]

# %%
from we import *

model, tokenizer, log = initiate_model()
# Out:
# /Users/egoliakova/opt/anaconda3/lib/python3.8/site-packages/requests/__init__.py:89: RequestsDependencyWarning: urllib3 (1.26.14) or chardet (3.0.4) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({}) doesn't match a supported "
# Some weights of the model checkpoint at flaubert/flaubert_small_cased were not used when initializing FlaubertModel: ['pred_layer.proj.bias', 'pred_layer.proj.weight']
# - This IS expected if you are initializing FlaubertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing FlaubertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
adj_we = create_words_df(model, tokenizer, top_freq_adj[~top_freq_adj.index.isin(top_freq_n.index)].index)
adj_we
# Out:
#                    0         1         2         3         4         5    \
# son          -1.371765  0.023384 -3.223059 -0.128716  1.743437 -5.050135
# sa            0.141941  1.930712 -3.402721  0.568273  0.315616 -4.563599
# tous          1.129453 -4.255967 -0.410349  0.146414  3.576469  4.121017
# toute         0.228007 -2.501421  0.797278 -6.389000  2.913804  1.568916
# toutes        1.389389 -3.404379 -1.706235 -1.811354  5.196568  3.528240
# ...                ...       ...       ...       ...       ...       ...
# assis         4.227304 -1.873211  1.711697  5.450985 -3.140384 -5.332380
# assise        6.605255 -3.188693  2.408048 -0.240419  1.644310 -6.952302
# assises       5.590267 -3.436942  2.810249 -4.377880  1.684232 -7.888458
# indifférent   2.131292 -0.417926 -0.228345  0.286183  3.341225 -3.808870
# indifférente  2.412852 -0.729873 -0.643178  0.491121  3.332215 -4.756021
#
#                    6         7         8         9    ...       502       503  \
# son          -2.566689  3.898434  2.324070  0.461080  ... -0.468684 -1.159611
# sa            1.713092  3.325673  2.165891  1.284356  ...  1.424293 -0.093632
# tous          0.134399 -2.209909 -1.514493 -0.690314  ... -0.823049 -3.983184
# toute        -4.957053 -2.731148  0.924702  1.271600  ...  0.988187  0.649038
# toutes       -3.168396 -3.312800 -0.271935 -1.351587  ... -0.057005 -1.179087
# ...                ...       ...       ...       ...  ...       ...       ...
# assis         2.003428  4.049249  4.066420 -1.730631  ... -5.446676 -3.099241
# assise       -4.144585  3.931452  5.756548 -0.215943  ... -3.587319  3.941912
# assises      -2.352491  0.879242  2.562158  3.040972  ... -5.217717  0.985175
# indifférent  -1.897214  3.034866  3.643936  1.819136  ... -4.606998 -1.038017
# indifférente -3.690552  0.843251  3.618783  0.801416  ... -5.082547  1.578490
#
#                    504       505       506       507       508       509  \
# son           0.185187  0.692381 -4.912082 -4.680734 -2.378969 -3.832992
# sa           -2.196225 -0.636604 -2.686444 -5.478354 -3.203217 -3.358541
# tous          0.169350 -4.874427  2.614017 -3.662928  1.788742 -6.000022
# toute        -1.996603 -3.299839  0.436457 -4.999957 -0.832127 -6.148788
# toutes        0.969326 -4.047242  2.138844 -4.193913  1.092826 -4.633731
# ...                ...       ...       ...       ...       ...       ...
# assis        -4.944200 -2.090297 -2.101048 -2.265973 -1.439263 -3.113337
# assise       -4.589899 -5.223729 -1.282132 -6.292689 -1.850765  0.482848
# assises      -3.590964 -2.811068 -2.729495 -6.910168 -3.678877  1.014451
# indifférent  -1.399645 -3.527106 -3.456003 -1.021520 -3.280523 -3.956781
# indifférente -1.879631 -3.062589 -2.277048 -1.746083 -3.812269 -3.434261
#
#                    510       511
# son          -0.688006 -4.490879
# sa            1.449512 -6.741152
# tous         -5.539269 -1.524175
# toute        -2.115986 -3.829260
# toutes       -3.549718  0.867384
# ...                ...       ...
# assis        -3.248899 -4.093177
# assise        0.276403 -8.054886
# assises      -1.778919 -4.747766
# indifférent   5.061137 -2.010664
# indifférente  3.941048 -1.088624
#
# [836 rows x 512 columns]

# %%
unique_freq_adj_we = adj_we.merge(top_freq_adj, left_index=True, right_index=True)
unique_freq_adj_we.columns = list(map(lambda x: str(x), unique_freq_adj_we.columns))
unique_freq_adj_we
# Out:
#                   0         1         2         3         4         5  \
# absolu     4.933391 -1.820655  1.532478 -1.979795  1.728292  0.517361
# absolue    4.234381 -0.431358 -0.230961 -0.056044  0.191299  0.593049
# absurde    3.756803  1.015494  0.616596 -1.308431  3.019945  4.145076
# absurdes   2.697266  0.319823  0.002797 -0.765813  1.198913  1.122232
# admirable  5.150778 -5.211925  5.518538  2.615006  6.667579  2.972428
# ...             ...       ...       ...       ...       ...       ...
# étroits    3.637715  1.597038  5.080803  0.715606 -1.297797 -4.529139
# évident    2.340510 -0.332801  2.248723  0.235987 -0.756931 -2.655907
# évidente   4.817487 -1.732906  4.693172 -1.503866  1.758747 -1.981044
# évidentes  4.127913 -0.139260  3.736150  1.509428 -0.238838 -3.402861
# évidents   3.761399 -0.572581  3.604520  1.861105 -0.316484 -2.269345
#
#                   6         7         8         9  ...       505       506  \
# absolu    -2.229984  4.105628 -2.711453  1.507046  ...  1.752741 -0.999988
# absolue   -3.839259  2.989963 -1.278115 -0.350125  ...  3.248165 -0.003822
# absurde   -0.925479 -0.032260  0.841586  5.597266  ... -3.673599 -0.109983
# absurdes  -0.262583  0.897586 -1.270633  3.957298  ... -2.672605 -2.171850
# admirable -6.595057  1.552289  0.413112  2.634962  ... -2.022568 -1.432461
# ...             ...       ...       ...       ...  ...       ...       ...
# étroits   -3.491086 -2.718746  3.092584  2.353549  ... -4.737136  3.492908
# évident   -4.716413  1.222106 -0.423593  0.004631  ... -4.120303  2.875386
# évidente  -4.529288  1.008203  0.146850 -0.596633  ... -0.314816  2.094974
# évidentes -4.729940  1.938044  0.244337 -5.802176  ... -0.755126  0.868269
# évidents  -2.034152  1.334489 -0.601565 -1.134129  ... -0.067700  2.230880
#
#                 507       508       509       510       511      lemme  cgram  \
# absolu    -3.802394 -0.709234 -3.994629  1.213610 -1.900828     absolu    ADJ
# absolue   -2.327732 -1.106974 -3.103743 -0.077974 -2.705171     absolu    ADJ
# absurde   -0.612023 -4.347472 -1.936714  5.816693  4.032070    absurde    ADJ
# absurdes  -1.001583 -4.618104 -2.425415  5.932143  4.784193    absurde    ADJ
# admirable -3.422603  1.299158 -0.653873  0.795807 -4.245778  admirable    ADJ
# ...             ...       ...       ...       ...       ...        ...    ...
# étroits   -0.856422 -2.255601 -0.500841  1.360816 -1.337827     étroit    ADJ
# évident   -1.700507 -2.543783 -8.283433  2.971671 -6.232332    évident    ADJ
# évidente  -2.281071 -1.359965 -6.485075  1.532511 -4.370127    évident    ADJ
# évidentes -1.814699 -1.389882 -7.313276  3.100853 -5.175048    évident    ADJ
# évidents  -0.558358 -0.240554 -7.466009  1.812035 -1.985085    évident    ADJ
#
#            freqlemlivres
# absolu             34.39
# absolue            34.39
# absurde            30.95
# absurdes           30.95
# admirable          31.55
# ...                  ...
# étroits            75.81
# évident            33.58
# évidente           33.58
# évidentes          33.58
# évidents           33.58
#
# [845 rows x 515 columns]

# %% [markdown]
# We can add encoding of 'ADJ' as PoS as `pos = 2`:

# %%
unique_freq_adj_we['pos'] = 2

# %% [markdown]
# Now adding adverbs:

# %%
top_freq_adv = pd.read_csv('Most Frequent Words/top1000_ADV.csv', index_col=0)[:1000]

# %%
adv_we = create_words_df(model, tokenizer, top_freq_adv[~top_freq_adv.index.isin(top_freq_n.index)].index)
adv_we
# Out:
#                       0         1         2         3         4         5    \
# n               -0.676710  3.449507 -1.735173  3.156701 -0.590798 -3.329250
# n'              -3.097368 -1.079689  0.067284 -3.135941  0.706760  1.007909
# ne              -2.281668 -1.370962 -0.403685 -0.073815  0.837571 -0.220982
# plus            -3.509048 -2.220096  1.762023 -0.791895 -2.215525 -1.303401
# bien            -1.731442  0.859784 -2.307073 -5.163003  1.377131 -5.495888
# ...                   ...       ...       ...       ...       ...       ...
# électriquement   8.631221 -3.871418  4.073094 -2.359468 -2.187433  1.437934
# épais            6.125545 -5.822879  5.330243 -2.898252  0.998407 -4.882508
# jà               5.297632 -3.015820 -0.500489  2.371873  1.007881 -0.054421
# post             1.562362 -1.066778 -2.478954 -3.414423 -0.828831 -0.633434
# unilatéralement  5.825255 -1.759136  1.764897  1.596690  0.324962  5.921582
#
#                       6         7         8         9    ...       502  \
# n               -7.041614  0.364143  0.853162  5.121193  ...  1.315812
# n'              -5.346002  1.035985 -2.897622  1.616330  ...  0.778125
# ne              -5.014138  0.451976  1.381517  2.327595  ... -2.500302
# plus            -1.088937 -0.509107 -2.603570  3.042406  ...  1.016149
# bien            -4.201455  4.921665 -1.770308 -1.760445  ... -5.705878
# ...                   ...       ...       ...       ...  ...       ...
# électriquement  -4.311751  4.438055  4.719334 -1.852672  ... -3.972917
# épais           -7.058368 -2.909385  3.399447  1.074606  ... -5.521036
# jà              -1.345942 -0.733034 -7.984251 -1.530580  ... -2.660295
# post            -2.639267 -1.668935  1.725153  0.329819  ...  2.379458
# unilatéralement -0.970027 -1.624280 -0.686181  0.575309  ...  2.572673
#
#                       503       504       505       506       507       508  \
# n               -2.259668 -2.202268 -0.837009 -1.478259  3.317715 -0.347990
# n'              -2.123144 -1.224010 -3.846741 -2.123554 -4.506597 -2.959948
# ne              -2.513185  0.119819 -1.138245 -1.521283 -3.855268 -3.555737
# plus             0.066032 -1.052608 -1.366760 -1.228347 -1.889529 -3.330955
# bien             2.306156  0.607199 -4.857283 -0.061548 -1.715081 -1.097555
# ...                   ...       ...       ...       ...       ...       ...
# électriquement  -2.165127 -1.363348  4.554272  1.618819 -4.006776 -1.494066
# épais            0.449374  0.928466 -3.658157  0.430408 -1.635432 -3.150975
# jà               2.614063 -0.094727  1.409462 -0.024955 -0.951452  1.071933
# post             1.137498  3.869631 -7.473512  0.944034 -3.988267 -4.131471
# unilatéralement  2.098354 -0.266045 -2.130454  0.676499 -3.439695 -4.434956
#
#                       509       510       511
# n               -1.692286 -0.049426 -1.379506
# n'              -2.108817 -0.951543  1.712145
# ne              -3.946141  2.373042 -0.525675
# plus            -3.745218 -2.395585  2.763508
# bien            -9.387454  0.864542 -3.865713
# ...                   ...       ...       ...
# électriquement  -5.174683  4.568310 -0.342058
# épais           -5.027833  0.371530 -1.185125
# jà              -5.745087  1.674073 -3.008836
# post            -1.907951  4.592034  1.847652
# unilatéralement -9.873369 -4.061777 -1.518856
#
# [507 rows x 512 columns]

# %%
unique_freq_adv_we = adv_we.merge(top_freq_adv, left_index=True, right_index=True)
unique_freq_adv_we.columns = list(map(lambda x: str(x), unique_freq_adv_we.columns))

# %% [markdown]
# Now we can encode adverbs' PoS as `3`:

# %%
unique_freq_adv_we['pos'] = 3

# %% [markdown]
# Now we can combine all 4 PoS together in one DataFrame:

# %%
unique_nvaa_we = pd.concat([unique_freq_adj_we, unique_freq_adv_we, unique_freq_n_we, unique_freq_v_we])

# %%
pos_corr_freq_df = pd.DataFrame(columns=['corr_with_pos'])
pos_list = []

# Go through dimensions from 0 to 511
for i in range(512):
    # Find the correlation of the current column with "freqlemlivres" and add to the list
    pos_list.append(unique_nvaa_we.loc[:, [str(i), 'pos']].corr().iloc[0][-1])

# Use the list values as 
pos_corr_freq_df['corr_with_pos'] = pos_list
pos_corr_freq_df['sign'] = np.sign(pos_corr_freq_df['corr_with_pos'])
pos_corr_freq_df['abs'] = abs(pos_corr_freq_df['corr_with_pos'])
pos_corr_freq_df.sort_values('abs')[-20:]
# Out:
#      corr_with_pos  sign       abs
# 140       0.275467   1.0  0.275467
# 280      -0.280062  -1.0  0.280062
# 318       0.281259   1.0  0.281259
# 286       0.293555   1.0  0.293555
# 157      -0.297521  -1.0  0.297521
# 469      -0.297811  -1.0  0.297811
# 224       0.299682   1.0  0.299682
# 395       0.301526   1.0  0.301526
# 52        0.304679   1.0  0.304679
# 416      -0.305388  -1.0  0.305388
# 50        0.311162   1.0  0.311162
# 132      -0.312609  -1.0  0.312609
# 393      -0.312846  -1.0  0.312846
# 220      -0.313117  -1.0  0.313117
# 291      -0.332471  -1.0  0.332471
# 341      -0.332666  -1.0  0.332666
# 182      -0.347233  -1.0  0.347233
# 250      -0.359529  -1.0  0.359529
# 158       0.369659   1.0  0.369659
# 89       -0.383813  -1.0  0.383813

# %% [markdown]
# The correlation between PoS encoding and the dimensions is much less stronger if we compare all 4 PoS together. However, if we compare the results in triples we can see much closer correlated dimensions. First, comparing nouns, adjectives and verbs:

# %%
unique_nvadj_we = pd.concat([unique_freq_adj_we, unique_freq_n_we, unique_freq_v_we])

# %%
pos_corr_freq_df = pd.DataFrame(columns=['corr_with_pos'])
pos_list = []

# Go through dimensions from 0 to 511
for i in range(512):
    # Find the correlation of the current column with "freqlemlivres" and add to the list
    pos_list.append(unique_nvadj_we.loc[:, [str(i), 'pos']].corr().iloc[0][-1])

# Use the list values as 
pos_corr_freq_df['corr_with_pos'] = pos_list
pos_corr_freq_df['sign'] = np.sign(pos_corr_freq_df['corr_with_pos'])
pos_corr_freq_df['abs'] = abs(pos_corr_freq_df['corr_with_pos'])
pos_corr_freq_df.sort_values('abs')[-20:]
# Out:
#      corr_with_pos  sign       abs
# 419       0.322337   1.0  0.322337
# 199       0.323839   1.0  0.323839
# 461       0.328696   1.0  0.328696
# 366       0.331265   1.0  0.331265
# 393      -0.333575  -1.0  0.333575
# 45       -0.339507  -1.0  0.339507
# 434      -0.346811  -1.0  0.346811
# 310      -0.352009  -1.0  0.352009
# 318       0.352824   1.0  0.352824
# 282       0.356257   1.0  0.356257
# 341      -0.358409  -1.0  0.358409
# 127      -0.371979  -1.0  0.371979
# 158       0.376757   1.0  0.376757
# 185      -0.379982  -1.0  0.379982
# 198       0.381260   1.0  0.381260
# 182      -0.391228  -1.0  0.391228
# 192       0.397564   1.0  0.397564
# 504       0.412132   1.0  0.412132
# 480       0.448680   1.0  0.448680
# 89       -0.530627  -1.0  0.530627

# %% [markdown]
# Firs of all, previously seen dimension `480` appears again and a new dimension `89` emerges which can be hypothesized to encode more information about adjectives than other dimensions.

# %% [markdown]
# Now we can compare nouns, adverbs and verbs:

# %%
unique_nvadv_we = pd.concat([unique_freq_adv_we, unique_freq_n_we, unique_freq_v_we])

# %%
pos_corr_freq_df = pd.DataFrame(columns=['corr_with_pos'])
pos_list = []

# Go through dimensions from 0 to 511
for i in range(512):
    # Find the correlation of the current column with "freqlemlivres" and add to the list
    pos_list.append(unique_nvadv_we.loc[:, [str(i), 'pos']].corr().iloc[0][-1])

# Use the list values as 
pos_corr_freq_df['corr_with_pos'] = pos_list
pos_corr_freq_df['sign'] = np.sign(pos_corr_freq_df['corr_with_pos'])
pos_corr_freq_df['abs'] = abs(pos_corr_freq_df['corr_with_pos'])
pos_corr_freq_df.sort_values('abs')[-20:]
# Out:
#      corr_with_pos  sign       abs
# 76        0.311962   1.0  0.311962
# 291      -0.313301  -1.0  0.313301
# 111       0.314102   1.0  0.314102
# 224       0.316016   1.0  0.316016
# 352       0.320583   1.0  0.320583
# 393      -0.320711  -1.0  0.320711
# 399      -0.322455  -1.0  0.322455
# 89       -0.322468  -1.0  0.322468
# 156      -0.326047  -1.0  0.326047
# 208      -0.329711  -1.0  0.329711
# 469      -0.331505  -1.0  0.331505
# 52        0.336897   1.0  0.336897
# 416      -0.337458  -1.0  0.337458
# 158       0.350336   1.0  0.350336
# 182      -0.350710  -1.0  0.350710
# 50        0.351323   1.0  0.351323
# 341      -0.353320  -1.0  0.353320
# 395       0.359925   1.0  0.359925
# 132      -0.387385  -1.0  0.387385
# 250      -0.402098  -1.0  0.402098

# %% [markdown]
# The correlation here is stronger but still much lower (and none of the previously studied dimensions appear again), this can be explained that adverbness and noun-ness are encoded in different dimensions.

# %% [markdown]
# Now if we compare adverbs, adjectives and verbs:

# %%
unique_vaa_we = pd.concat([unique_freq_adv_we, unique_freq_adj_we, unique_freq_v_we])

# %%
pos_corr_freq_df = pd.DataFrame(columns=['corr_with_pos'])
pos_list = []

# Go through dimensions from 0 to 511
for i in range(512):
    # Find the correlation of the current column with "freqlemlivres" and add to the list
    pos_list.append(unique_vaa_we.loc[:, [str(i), 'pos']].corr().iloc[0][-1])

# Use the list values as 
pos_corr_freq_df['corr_with_pos'] = pos_list
pos_corr_freq_df['sign'] = np.sign(pos_corr_freq_df['corr_with_pos'])
pos_corr_freq_df['abs'] = abs(pos_corr_freq_df['corr_with_pos'])
pos_corr_freq_df.sort_values('abs')[-20:]
# Out:
#      corr_with_pos  sign       abs
# 220      -0.333786  -1.0  0.333786
# 50        0.339374   1.0  0.339374
# 286       0.342259   1.0  0.342259
# 222      -0.342292  -1.0  0.342292
# 401      -0.343803  -1.0  0.343803
# 192       0.344208   1.0  0.344208
# 416      -0.345658  -1.0  0.345658
# 395       0.349355   1.0  0.349355
# 132      -0.349913  -1.0  0.349913
# 127      -0.352591  -1.0  0.352591
# 157      -0.354454  -1.0  0.354454
# 52        0.358407   1.0  0.358407
# 51        0.360275   1.0  0.360275
# 291      -0.373763  -1.0  0.373763
# 250      -0.382159  -1.0  0.382159
# 393      -0.395891  -1.0  0.395891
# 158       0.411930   1.0  0.411930
# 341      -0.431425  -1.0  0.431425
# 182      -0.441540  -1.0  0.441540
# 89       -0.470419  -1.0  0.470419

# %% [markdown]
# The correlations become stronger in comparison to nouns, however, are still weaker than Nouns vs Verbs. We can compare in general correlation of adverbs with other PoS in pairs, starting with verbs and adverbs:

# %%
unique_va_we = pd.concat([unique_freq_adv_we, unique_freq_v_we])

# %%
pos_corr_freq_df = pd.DataFrame(columns=['corr_with_pos'])
pos_list = []

# Go through dimensions from 0 to 511
for i in range(512):
    # Find the correlation of the current column with "freqlemlivres" and add to the list
    pos_list.append(unique_vadv_we.loc[:, [str(i), 'pos']].corr().iloc[0][-1])

# Use the list values as 
pos_corr_freq_df['corr_with_pos'] = pos_list
pos_corr_freq_df['sign'] = np.sign(pos_corr_freq_df['corr_with_pos'])
pos_corr_freq_df['abs'] = abs(pos_corr_freq_df['corr_with_pos'])
pos_corr_freq_df.sort_values('abs')[-20:]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-108-e52a59f3d6ec> in <module>
#       5 for i in range(512):
#       6     # Find the correlation of the current column with "freqlemlivres" and add to the list
# ----> 7     pos_list.append(unique_vadv_we.loc[:, [str(i), 'pos']].corr().iloc[0][-1])
#       8
#       9 # Use the list values as
#
# NameError: name 'unique_vadv_we' is not defined

# %% [markdown]
# Now for adjectives and adverbs:

# %%
unique_aa_we = pd.concat([unique_freq_adj_we, unique_freq_adv_we])

# %%
pos_corr_freq_df = pd.DataFrame(columns=['corr_with_pos'])
pos_list = []

# Go through dimensions from 0 to 511
for i in range(512):
    # Find the correlation of the current column with "freqlemlivres" and add to the list
    pos_list.append(unique_aa_we.loc[:, [str(i), 'pos']].corr().iloc[0][-1])

# Use the list values as 
pos_corr_freq_df['corr_with_pos'] = pos_list
pos_corr_freq_df['sign'] = np.sign(pos_corr_freq_df['corr_with_pos'])
pos_corr_freq_df['abs'] = abs(pos_corr_freq_df['corr_with_pos'])
pos_corr_freq_df.sort_values('abs')[-20:]

# %% [markdown]
# Correlation with adjectives seems to be much weaker.

# %% [markdown]
# # Conclusion

# %% [markdown]
# We have found a list of dimensions correlated to Verb-Noun PoS information:
#
# We have found a group of dimension correlated with PoS information **for verbs and nouns**: '137', '159', '168', '198', '212', '310', '480', '51'. Dimension **159** seems to be the closest to represent Noun<->Verb PoS. However, none of the dimension seem to represent PoS information only: the outliers don't appear to be ambiguous words that can be attributed to multiple parts of speech but in general quite regular looking nouns/verbs.
#
# Several points for further inverstigation:
# - Since the PoS information doesn't seem to be directly corresponding to any of the dimension, we can assume that PoS is retrieved from co-occurence information: e.g. nouns co-occuring with articles, verbs co-occuring with pronouns like je/il/...
# - We have observed that for several of the dimensions with the highest correlation to PoS information, mean for values of the dimension for verbs is relatively close to 0: 159, 212, 51, 198 which can be potentially interesting to investigate: the closeness of dimension values to 0 on average.
# - Dimension `480` remained strongly correlated with PoS with adding **adjectives** into experiment, making it the prime candidat for encoding verb-ness, noun-ness and adjective-ness.
# - PoS information for nouns/adj and adverbs seems less correlated, meaning that there is less likely to be an axis embedding all PoS. In [this work](https://arxiv.org/pdf/1906.00114.pdf) it's shown that there is a PCA component representing the Verb/Noun axis and Noun/Adjective axis and this is confirmed by what we're seeing: the adverbs seem to be encoded in a way that is not direcly oppositional to nouns.
