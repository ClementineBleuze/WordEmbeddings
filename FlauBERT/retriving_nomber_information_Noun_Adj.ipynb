# %% [markdown]
# This notebook attempts to analyze which dimensions may encode **singular** and **plural noun** information, and similarly, which dimensiosn may encode **singular** and **plural adjective** information. And then analyze whether the same dimension may encode the information of singular and plural of nouns and singular and plural of adjectives at the same time from the obtained results

# %% [markdown]
# # result

# %% [markdown]
# Dimension which have largest correlation with number: **singular** and **plural**

# %% [markdown]
# NOUN :  54 > 310 > 288 > 243 > 278 > 511 > 3 > 119 > 77 > 371
#
# ADJ : 310 > 5 > 54 > 384 > 84 > 278 > 192 > 250 > 385 > 371
#
# Commun dimension  :  310, 54, 278

# %% [markdown]
# Comprared with Adj, Noun have bigger  correlation with nb
#
# | dimension | Noun correlation with nb | Adj correlation with nb|
# | --- | --- | --- |
# | 310 | 0.458548 | 0.383794 |
# | 54  | 0.473204 | 0.338899 |
# | 278 | 0.340324 | 0.290632 |

# %% [markdown]
# Correlation between dimensions:
#
# | Noun | 310 | 54 | 278 |
# | --- | --- | --- | --- |
# | 301 | 1.000000 | 0.332007 | 0.178385 |
#
#
# Correlation between dimensions:
# | ADJ | 310 | 54 | 278 |
# | --- | --- | ---| --- |
# | 310 | 1.000000 | 0.207386 | 0.292527 |

# %% [markdown]
# In order to balance the corpus of nouns and adjectives, the following experiments will select respectively 309 singular nouns, 309 plural nouns, 309 singular adjectives, 309  plural adjectives.

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt

# %%
top_freq_n = pd.read_csv('Most Frequent Words/top_frequent_pure_NOUN_FlauBERT.csv', index_col='Word')
top_freq_n
# Out:
#                  Rang           lemme cgram genre nombre  freqlemlivres
# Word
# homme               0           homme   NOM     m      s        1398.85
# hommes              1           homme   NOM     m      p        1398.85
# jour                2            jour   NOM     m      s        1341.76
# jours               3            jour   NOM     m      p        1341.76
# oeil                5            oeil   NOM     m      s        1234.59
# ...               ...             ...   ...   ...    ...            ...
# éthylène        48267        éthylène   NOM     m      s           0.00
# étiquetage      48269      étiquetage   NOM     m      s           0.00
# évangélisation  48274  évangélisation   NOM     f      s           0.00
# évènement       48283       évènement   NOM     m      s           0.00
# évènements      48284       évènement   NOM     m      p           0.00
#
# [6356 rows x 6 columns]

# %% [markdown]
# 1000 Singular Nouns

# %%
top_sg_n = top_freq_n[top_freq_n["nombre"] == "s"][:309]
top_sg_n
# Out:
#               Rang         lemme cgram genre nombre  freqlemlivres
# Word
# homme            0         homme   NOM     m      s        1398.85
# jour             2          jour   NOM     m      s        1341.76
# oeil             5          oeil   NOM     m      s        1234.59
# main             8          main   NOM   NaN      s        1229.39
# femme           14         femme   NOM     f      s         995.74
# ...            ...           ...   ...   ...    ...            ...
# circonstance  1226  circonstance   NOM     f      s          58.24
# rang          1230          rang   NOM     m      s          58.24
# territoire    1232    territoire   NOM     m      s          58.24
# pitié         1234         pitié   NOM     f      s          58.11
# promenade     1236     promenade   NOM     f      s          58.11
#
# [309 rows x 6 columns]

# %% [markdown]
# 1000 Plural Nouns

# %%
top_pl_n = top_freq_n[top_freq_n["nombre"] == "p"][:309]
top_pl_n
# Out:
#            Rang     lemme cgram genre nombre  freqlemlivres
# Word
# hommes        1     homme   NOM     m      p        1398.85
# jours         3      jour   NOM     m      p        1341.76
# mains         9      main   NOM     f      p        1229.39
# fois         10      fois   NOM     f      p        1140.00
# femmes       15     femme   NOM     f      p         995.74
# ...         ...       ...   ...   ...    ...            ...
# violences  1283  violence   NOM     f      p          56.49
# dessins    1287    dessin   NOM     m      p          56.28
# récits     1291     récit   NOM     m      p          56.15
# fusils     1306     fusil   NOM     m      p          55.68
# collines   1308   colline   NOM     f      p          55.61
#
# [309 rows x 6 columns]

# %%
all_n_we = pd.read_csv('all_nouns_we.csv', index_col=0)
sg_n_we = all_n_we.merge(top_sg_n, left_index=True, right_index=True)
pl_n_we = all_n_we.merge(top_pl_n, left_index=True, right_index=True)

# %%
sg_n_we
# Out:
#                   0         1         2         3         4         5  \
# absence    3.322297 -0.768149  3.555035 -0.685460  1.201102 -3.151831
# accord    -0.732188 -2.024965  1.674970 -4.194049 -2.528312 -2.400746
# action     1.376720 -3.602622  0.270682 -7.004842  1.199668 -0.341319
# air       -0.491568 -1.776510 -0.420017 -5.103687 -2.064307 -1.580656
# allure     3.051527 -2.565099  1.431839 -2.976701 -2.084035 -2.772705
# ...             ...       ...       ...       ...       ...       ...
# époque    -1.408609 -2.313014  1.467428  3.642618 -2.794825 -6.724243
# état       6.066799 -3.826219  2.250722  0.372166  0.489586 -3.801058
# étude      5.819144  1.250730  3.289566  0.495318 -3.904241 -7.817052
# événement -0.693584 -0.753810  0.124109  2.200120  1.585398 -2.354075
# île       -0.489183 -3.752668 -2.676017  4.677486  1.093927 -5.670148
#
#                   6         7         8         9  ...       510       511  \
# absence   -3.592423  1.189369 -2.742928 -2.666739  ...  5.123568 -2.381779
# accord    -4.672920  0.374903  6.015941 -0.066068  ... -5.424189 -6.660925
# action     3.974475 -0.292309  2.597899  1.607074  ...  3.015040  0.167511
# air       -1.270584  3.064606  4.021414 -0.273294  ...  8.696856 -0.114973
# allure    -2.094211  1.903866  4.068268  1.678578  ...  0.107989 -1.414938
# ...             ...       ...       ...       ...  ...       ...       ...
# époque    -3.123537  2.466337 -4.937144 -2.049165  ... -2.431347 -6.811773
# état      -3.119510  2.989726 -6.064237 -4.039576  ...  2.295238 -2.403172
# étude     -2.101344  2.162380  1.859624  0.642219  ...  8.288882 -3.077851
# événement -2.994415  1.552121  4.762497 -1.361055  ...  0.740749 -3.701469
# île       -0.456426  2.867334  2.531248 -2.738322  ... -2.131077 -4.665631
#
#                  gn     gender  Rang      lemme  cgram  genre  nombre  \
# absence    singular   feminine   931    absence    NOM      f       s
# accord     singular  masculine   442     accord    NOM      m       s
# action     singular   feminine   771     action    NOM      f       s
# air        singular  masculine    34        air    NOM      m       s
# allure     singular   feminine  1087     allure    NOM      f       s
# ...             ...        ...   ...        ...    ...    ...     ...
# époque     singular   feminine   432     époque    NOM      f       s
# état       singular  masculine   232       état    NOM      m       s
# étude      singular   feminine  1141      étude    NOM      f       s
# événement  singular  masculine   800  événement    NOM      m       s
# île        singular   feminine   593        île    NOM      f       s
#
#            freqlemlivres
# absence            76.28
# accord            136.15
# action             87.43
# air               690.81
# allure             65.88
# ...                  ...
# époque            138.51
# état              218.18
# étude              63.04
# événement          84.59
# île               108.24
#
# [309 rows x 520 columns]

# %%
pl_n_we
# Out:
#                    0         1         2         3         4         5  \
# abris       3.634584 -4.644015  0.377342 -6.514875  1.314781 -7.105865
# absences    3.295355 -0.794079  2.472845  3.223941  5.035848 -4.848855
# accords     1.037610 -0.246123  3.333316 -4.094496  0.056898 -2.978131
# airs       -3.073402 -1.962807 -4.361338 -0.526964 -1.405528  1.335624
# allures    -0.368381 -8.159948  3.327872 -0.456663 -0.820404 -2.296919
# ...              ...       ...       ...       ...       ...       ...
# études      3.155492 -0.104454  6.523874 -1.430581 -6.250263 -8.157872
# étés        2.757932  0.903210  0.184015  1.369026 -0.241391 -3.674196
# événements -1.245101 -0.820061  1.330310  5.786696  3.966537 -3.242018
# êtres       3.589590 -4.551544  6.088149  2.847501  3.829500 -3.342109
# îles       -2.838814 -3.576476 -1.082639  5.224788  1.871563 -5.175120
#
#                    6         7         8         9  ...       510       511  \
# abris       1.637559  1.284117  2.511964  1.558493  ...  5.123267  0.749750
# absences   -4.557629 -2.719433 -1.932022 -6.440993  ...  5.919082  0.577700
# accords    -4.198946 -2.159259  3.082677  2.101236  ... -5.254343 -6.959417
# airs       -6.095512  2.331814  3.216961 -3.628428  ...  2.839080 -0.816238
# allures    -5.021822  4.406036  1.532774 -0.562674  ...  1.081968  1.521198
# ...              ...       ...       ...       ...  ...       ...       ...
# études     -2.711711 -0.706295 -1.090734 -4.388298  ...  5.456683 -5.749627
# étés        0.942077 -0.553418 -1.468072 -2.633826  ...  1.823255 -2.487086
# événements -0.265572  2.159446  0.661078 -0.936386  ...  1.265242  1.124227
# êtres       2.749030 -0.169812  1.994654  0.893699  ...  0.167977 -1.285041
# îles        2.896314  1.005481  4.880717 -2.816181  ...  0.354014 -2.508205
#
#                 gn     gender  Rang      lemme  cgram  genre  nombre  \
# abris       plural  masculine  1273       abri    NOM      m       p
# absences    plural   feminine   932    absence    NOM      f       p
# accords     plural  masculine   443     accord    NOM      m       p
# airs        plural  masculine    35        air    NOM      m       p
# allures     plural   feminine  1088     allure    NOM      f       p
# ...            ...        ...   ...        ...    ...    ...     ...
# études      plural   feminine  1142      étude    NOM      f       p
# étés        plural  masculine   498        été    NOM      m       p
# événements  plural  masculine   801  événement    NOM      m       p
# êtres       plural  masculine   514       être    NOM      m       p
# îles        plural   feminine   594        île    NOM      f       p
#
#             freqlemlivres
# abris               56.76
# absences            76.28
# accords            136.15
# airs               690.81
# allures             65.88
# ...                   ...
# études              63.04
# étés               125.47
# événements          84.59
# êtres              122.57
# îles               108.24
#
# [309 rows x 520 columns]

# %%
dim_indices = range(512)
avg_values_sg = [sg_n_we[str(i)].mean() for i in dim_indices]
avg_values_pl = [pl_n_we[str(i)].mean() for i in dim_indices]
d = [abs(s-p) for s,p in zip(avg_values_sg, avg_values_pl)]
diff={d[i]:i for i in dim_indices}

sg_avg = pd.DataFrame([avg_values_sg], index=["sg_avg"], columns=dim_indices)
pl_avg = pd.DataFrame([avg_values_pl], index=["pl_avg"], columns=dim_indices)

# %%
sg_avg
# Out:
#             0         1         2         3         4         5         6    \
# sg_avg  2.16517 -1.579502  0.502229 -1.610485  0.771038 -2.919544 -2.694495
#
#              7         8        9    ...       502       503       504  \
# sg_avg  0.409358  1.264012  0.01364  ... -1.067345  0.764338  0.140874
#
#              505       506       507       508       509       510       511
# sg_avg -2.614315  0.041101 -4.307483 -3.233728 -3.491806  1.383379 -3.150616
#
# [1 rows x 512 columns]

# %%
pl_avg
# Out:
#              0         1         2         3         4        5         6    \
# pl_avg  1.712646 -1.060523  0.180341  0.306577  1.614202 -3.58591 -2.406433
#
#              7         8         9    ...       502       503       504  \
# pl_avg -0.301847  0.114655 -0.234047  ... -1.555791  0.671422  0.764074
#
#              505       506       507      508       509       510       511
# pl_avg -1.948264 -0.792463 -2.805256 -3.19229 -3.016691  1.664061 -1.295747
#
# [1 rows x 512 columns]

# %%
diff
# Out:
# {0.4525243953656959: 0,
#  0.5189787780032376: 1,
#  0.3218883472155344: 2,
#  1.9170611891553406: 3,
#  0.8431638986177992: 4,
#  0.666365963453075: 5,
#  0.28806225187055334: 6,
#  0.7112052885838188: 7,
#  1.1493568875857605: 8,
#  0.24768701496116516: 9,
#  0.12734094922362504: 10,
#  0.2665778480194163: 11,
#  0.6275974081300972: 12,
#  0.7256109182232984: 13,
#  0.1317470398576044: 14,
#  0.5616323985126219: 15,
#  0.12768960780582503: 16,
#  0.6449541146711975: 17,
#  0.9281437665178052: 18,
#  1.1973440628543721: 19,
#  0.13862093104530926: 20,
#  1.4710792725951456: 21,
#  0.9927367209116504: 22,
#  0.35558383357475853: 23,
#  0.5808318561974115: 24,
#  0.8693496221315224: 25,
#  0.5232964679987049: 26,
#  0.752613356082784: 27,
#  0.5014565323210357: 28,
#  0.046174909629773886: 29,
#  0.386384408769256: 30,
#  0.1874191096343043: 31,
#  0.6767078311944972: 32,
#  0.692968158281527: 33,
#  0.07723594120388344: 34,
#  0.12811561751294676: 35,
#  0.3169850203786435: 36,
#  1.2751566940967638: 37,
#  0.21985414350485444: 38,
#  0.08121845279281525: 39,
#  0.870665840965372: 40,
#  1.02943505541424: 41,
#  0.5021518590019409: 42,
#  0.6577516072459549: 43,
#  0.06340444330097039: 44,
#  0.628171789229774: 45,
#  0.4015526709935249: 46,
#  0.15066292624271815: 47,
#  0.3647808099514562: 48,
#  0.43623260662588864: 49,
#  1.1179857203644015: 50,
#  0.2735501677983847: 51,
#  0.1823492152103583: 52,
#  0.170405012132687: 53,
#  2.4322284639223306: 54,
#  0.6663881922815513: 55,
#  0.24726957941100325: 56,
#  1.036992154331489: 57,
#  0.21893162327281546: 58,
#  0.38033333074919073: 59,
#  0.6646277090103565: 60,
#  0.041281911907119495: 61,
#  0.4071487963883498: 62,
#  0.8443883448155336: 63,
#  1.049619567210357: 64,
#  0.9625681805210387: 65,
#  0.006864121558718739: 66,
#  1.3845235062592212: 67,
#  0.06531655557928728: 68,
#  1.1216397956618123: 69,
#  0.247400859278319: 70,
#  0.09266282477346288: 71,
#  0.041281911907119495,
#  0.03994273899676387,
#  0.03981249240776763,
#  0.03844955706148778,
#  0.035789131740550095,
#  0.0357864021300931,
#  0.03510990954767079,
#  0.034547272104207716,
#  0.03293855252375555,
#  0.03215091655986768,
#  0.02952806447573053,
#  0.02950716257281427,
#  0.028488751673141355,
#  0.028435378329772387,
#  0.027467236128153605,
#  0.026566217355987132,
#  0.024685179400645296,
#  0.016984523980587696,
#  0.016612593993527103,
#  0.013439455035597181,
#  0.012200923226341587,
#  0.011157701708640944,
#  0.010002759928801286,
#  0.006864121558718739,
#  0.0033431233394840554]

# %% [markdown]
# Select 10 dimensions which have the largest average value

# %%
n = 10
topn = []
for v in d[:n]:
    print(diff[v], v)
    topn.append(diff[v])

print(topn)
# Out:
# 371 5.012935340453097
# 310 2.7147141465815556
# 54 2.4322284639223306
# 3 1.9170611891553406
# 278 1.8715031224588996
# 511 1.8548686021083152
# 119 1.8447403144724923
# 77 1.7471826979877
# 288 1.7291631697721692
# 243 1.6714288571346296
# [371, 310, 54, 3, 278, 511, 119, 77, 288, 243]

# %% [markdown]
# Select 10 dimensions which have the smallest average value

# %%
n = 10
botn = []
for v in d[-n:]:
    print(diff[v], v)
    botn.append(diff[v])

print(botn)
# Out:
# 427 0.026566217355987132
# 87 0.024685179400645296
# 284 0.016984523980587696
# 327 0.016612593993527103
# 157 0.013439455035597181
# 472 0.012200923226341587
# 364 0.011157701708640944
# 241 0.010002759928801286
# 66 0.006864121558718739
# 247 0.0033431233394840554
# [427, 87, 284, 327, 157, 472, 364, 241, 66, 247]

# %% [markdown]
# From the obtained results, we hypothesize that the dimensions 371, 310, 54，278, 3, 511, 119, 77, 288, 143 may encode information about Singular and Plural Nouns.
# And the dimensions such 418, 215, 453, 14, 51  don't encode this information.

# %% [markdown]
# For test our hypothesis, next we can see the correlation between these dimensions with  Singular Noun and Plural Noun, for do this we can create a new column "nb" in which encoding Singular Noun as 0 and Plural Nouns as 1:

# %%
sg_pl_n_we=pd.concat([sg_n_we, pl_n_we])
sg_pl_n_we.loc[sg_pl_n_we['gn'] == 'singular', 'nb'] = 0
sg_pl_n_we.loc[sg_pl_n_we['gn'] == 'plural', 'nb'] = 1
sg_pl_n_we
# Out:
#                    0         1         2         3         4         5  \
# absence     3.322297 -0.768149  3.555035 -0.685460  1.201102 -3.151831
# accord     -0.732188 -2.024965  1.674970 -4.194049 -2.528312 -2.400746
# action      1.376720 -3.602622  0.270682 -7.004842  1.199668 -0.341319
# air        -0.491568 -1.776510 -0.420017 -5.103687 -2.064307 -1.580656
# allure      3.051527 -2.565099  1.431839 -2.976701 -2.084035 -2.772705
# ...              ...       ...       ...       ...       ...       ...
# études      3.155492 -0.104454  6.523874 -1.430581 -6.250263 -8.157872
# étés        2.757932  0.903210  0.184015  1.369026 -0.241391 -3.674196
# événements -1.245101 -0.820061  1.330310  5.786696  3.966537 -3.242018
# êtres       3.589590 -4.551544  6.088149  2.847501  3.829500 -3.342109
# îles       -2.838814 -3.576476 -1.082639  5.224788  1.871563 -5.175120
#
#                    6         7         8         9  ...       511        gn  \
# absence    -3.592423  1.189369 -2.742928 -2.666739  ... -2.381779  singular
# accord     -4.672920  0.374903  6.015941 -0.066068  ... -6.660925  singular
# action      3.974475 -0.292309  2.597899  1.607074  ...  0.167511  singular
# air        -1.270584  3.064606  4.021414 -0.273294  ... -0.114973  singular
# allure     -2.094211  1.903866  4.068268  1.678578  ... -1.414938  singular
# ...              ...       ...       ...       ...  ...       ...       ...
# études     -2.711711 -0.706295 -1.090734 -4.388298  ... -5.749627    plural
# étés        0.942077 -0.553418 -1.468072 -2.633826  ... -2.487086    plural
# événements -0.265572  2.159446  0.661078 -0.936386  ...  1.124227    plural
# êtres       2.749030 -0.169812  1.994654  0.893699  ... -1.285041    plural
# îles        2.896314  1.005481  4.880717 -2.816181  ... -2.508205    plural
#
#                gender  Rang      lemme  cgram  genre  nombre  freqlemlivres  \
# absence      feminine   931    absence    NOM      f       s          76.28
# accord      masculine   442     accord    NOM      m       s         136.15
# action       feminine   771     action    NOM      f       s          87.43
# air         masculine    34        air    NOM      m       s         690.81
# allure       feminine  1087     allure    NOM      f       s          65.88
# ...               ...   ...        ...    ...    ...     ...            ...
# études       feminine  1142      étude    NOM      f       p          63.04
# étés        masculine   498        été    NOM      m       p         125.47
# événements  masculine   801  événement    NOM      m       p          84.59
# êtres       masculine   514       être    NOM      m       p         122.57
# îles         feminine   594        île    NOM      f       p         108.24
#
#              nb
# absence     0.0
# accord      0.0
# action      0.0
# air         0.0
# allure      0.0
# ...         ...
# études      1.0
# étés        1.0
# événements  1.0
# êtres       1.0
# îles        1.0
#
# [618 rows x 521 columns]

# %%
sg_pl_n_we
# Out:
#                    0         1         2         3         4         5  \
# absence     3.322297 -0.768149  3.555035 -0.685460  1.201102 -3.151831
# accord     -0.732188 -2.024965  1.674970 -4.194049 -2.528312 -2.400746
# action      1.376720 -3.602622  0.270682 -7.004842  1.199668 -0.341319
# air        -0.491568 -1.776510 -0.420017 -5.103687 -2.064307 -1.580656
# allure      3.051527 -2.565099  1.431839 -2.976701 -2.084035 -2.772705
# ...              ...       ...       ...       ...       ...       ...
# études      3.155492 -0.104454  6.523874 -1.430581 -6.250263 -8.157872
# étés        2.757932  0.903210  0.184015  1.369026 -0.241391 -3.674196
# événements -1.245101 -0.820061  1.330310  5.786696  3.966537 -3.242018
# êtres       3.589590 -4.551544  6.088149  2.847501  3.829500 -3.342109
# îles       -2.838814 -3.576476 -1.082639  5.224788  1.871563 -5.175120
#
#                    6         7         8         9  ...       511        gn  \
# absence    -3.592423  1.189369 -2.742928 -2.666739  ... -2.381779  singular
# accord     -4.672920  0.374903  6.015941 -0.066068  ... -6.660925  singular
# action      3.974475 -0.292309  2.597899  1.607074  ...  0.167511  singular
# air        -1.270584  3.064606  4.021414 -0.273294  ... -0.114973  singular
# allure     -2.094211  1.903866  4.068268  1.678578  ... -1.414938  singular
# ...              ...       ...       ...       ...  ...       ...       ...
# études     -2.711711 -0.706295 -1.090734 -4.388298  ... -5.749627    plural
# étés        0.942077 -0.553418 -1.468072 -2.633826  ... -2.487086    plural
# événements -0.265572  2.159446  0.661078 -0.936386  ...  1.124227    plural
# êtres       2.749030 -0.169812  1.994654  0.893699  ... -1.285041    plural
# îles        2.896314  1.005481  4.880717 -2.816181  ... -2.508205    plural
#
#                gender  Rang      lemme  cgram  genre  nombre  freqlemlivres  \
# absence      feminine   931    absence    NOM      f       s          76.28
# accord      masculine   442     accord    NOM      m       s         136.15
# action       feminine   771     action    NOM      f       s          87.43
# air         masculine    34        air    NOM      m       s         690.81
# allure       feminine  1087     allure    NOM      f       s          65.88
# ...               ...   ...        ...    ...    ...     ...            ...
# études       feminine  1142      étude    NOM      f       p          63.04
# étés        masculine   498        été    NOM      m       p         125.47
# événements  masculine   801  événement    NOM      m       p          84.59
# êtres       masculine   514       être    NOM      m       p         122.57
# îles         feminine   594        île    NOM      f       p         108.24
#
#              nb
# absence     0.0
# accord      0.0
# action      0.0
# air         0.0
# allure      0.0
# ...         ...
# études      1.0
# étés        1.0
# événements  1.0
# êtres       1.0
# îles        1.0
#
# [618 rows x 521 columns]

# %% [markdown]
# Test the correlation of "nb" with 10 dimensions of average which have the smallest difference.

# %%
sg_pl_n_we.loc[:, [ '427', '87', '284', '327', '157','472','364','241','66','247','nb']].corr()
# Out:
#           427        87       284       327       157       472       364  \
# 427  1.000000 -0.149721  0.225742  0.004077  0.031908 -0.080132 -0.005256
# 87  -0.149721  1.000000 -0.001075 -0.129986 -0.239279 -0.034263 -0.088631
# 284  0.225742 -0.001075  1.000000 -0.100402 -0.125646 -0.166434 -0.092373
# 327  0.004077 -0.129986 -0.100402  1.000000 -0.011732 -0.066084  0.270994
# 157  0.031908 -0.239279 -0.125646 -0.011732  1.000000  0.079122 -0.005477
# 472 -0.080132 -0.034263 -0.166434 -0.066084  0.079122  1.000000  0.077120
# 364 -0.005256 -0.088631 -0.092373  0.270994 -0.005477  0.077120  1.000000
# 241  0.160114 -0.029384 -0.075368 -0.035529  0.051727 -0.160022 -0.014505
# 66   0.152527  0.048896 -0.144190  0.059574  0.230839  0.041116 -0.001147
# 247  0.079280  0.000043 -0.129510 -0.088497 -0.234315  0.122984 -0.113445
# nb   0.004655  0.004831  0.003260 -0.003714 -0.002874  0.001843 -0.002463
#
#           241        66       247        nb
# 427  0.160114  0.152527  0.079280  0.004655
# 87  -0.029384  0.048896  0.000043  0.004831
# 284 -0.075368 -0.144190 -0.129510  0.003260
# 327 -0.035529  0.059574 -0.088497 -0.003714
# 157  0.051727  0.230839 -0.234315 -0.002874
# 472 -0.160022  0.041116  0.122984  0.001843
# 364 -0.014505 -0.001147 -0.113445 -0.002463
# 241  1.000000  0.218538 -0.101768  0.001842
# 66   0.218538  1.000000 -0.105789  0.001355
# 247 -0.101768 -0.105789  1.000000 -0.000639
# nb   0.001842  0.001355 -0.000639  1.000000

# %% [markdown]
# Smallest correlation with nb : 247, 66, 241,472, 364, 157,327,284,427,87

# %% [markdown]
# All these dimenensions have a small correlation with "nb".

# %% [markdown]
# Test the correlation of "nb" with 10 dimensions of average which have the largest difference.

# %%
sg_pl_n_we.loc[:, [ '371', '310', '54', '3', '278','511','119','77','288','243','nb']].corr()
# Out:
#           371       310        54         3       278       511       119  \
# 371  1.000000  0.520632  0.322395 -0.237611 -0.135671 -0.231915 -0.669641
# 310  0.520632  1.000000  0.332007 -0.099252 -0.178385 -0.310605 -0.387434
# 54   0.322395  0.332007  1.000000 -0.234484 -0.326504 -0.251330 -0.247949
# 3   -0.237611 -0.099252 -0.234484  1.000000  0.131617  0.017607  0.257083
# 278 -0.135671 -0.178385 -0.326504  0.131617  1.000000  0.149943 -0.028221
# 511 -0.231915 -0.310605 -0.251330  0.017607  0.149943  1.000000  0.206030
# 119 -0.669641 -0.387434 -0.247949  0.257083 -0.028221  0.206030  1.000000
# 77  -0.139162 -0.342295 -0.171694  0.223468  0.223993  0.268146  0.139456
# 288 -0.241403 -0.361935 -0.246609  0.081146  0.094612  0.228523  0.273024
# 243  0.476563  0.313485  0.362297 -0.259191 -0.348356 -0.049914 -0.267053
# nb  -0.194826 -0.458548 -0.473204  0.292501  0.340324  0.303587  0.288786
#
#            77       288       243        nb
# 371 -0.139162 -0.241403  0.476563 -0.194826
# 310 -0.342295 -0.361935  0.313485 -0.458548
# 54  -0.171694 -0.246609  0.362297 -0.473204
# 3    0.223468  0.081146 -0.259191  0.292501
# 278  0.223993  0.094612 -0.348356  0.340324
# 511  0.268146  0.228523 -0.049914  0.303587
# 119  0.139456  0.273024 -0.267053  0.288786
# 77   1.000000  0.285673 -0.290873  0.274066
# 288  0.285673  1.000000 -0.161797  0.387939
# 243 -0.290873 -0.161797  1.000000 -0.340573
# nb   0.274066  0.387939 -0.340573  1.000000

# %% [markdown]
# Largest correlation with nb : 54 > 310 > 288 > 243 > 278 > 511 > 3 > 119 > 77 > 371

# %% [markdown]
# Compared to the above dimensions, these dimensions have significantly better correlation  with "nb". 310, 54, 288, 278, 243 have the highest correlation with "nb".

# %%
sg_pl_n_we.loc[:, [ '310', '54', '288', '278', '243', '278', '511', '3','119', '77','371', '247', '66','241','364','472']].corr()
# Out:
#           310        54       288       278       243       278       511  \
# 310  1.000000  0.332007 -0.361935 -0.178385  0.313485 -0.178385 -0.310605
# 54   0.332007  1.000000 -0.246609 -0.326504  0.362297 -0.326504 -0.251330
# 288 -0.361935 -0.246609  1.000000  0.094612 -0.161797  0.094612  0.228523
# 278 -0.178385 -0.326504  0.094612  1.000000 -0.348356  1.000000  0.149943
# 243  0.313485  0.362297 -0.161797 -0.348356  1.000000 -0.348356 -0.049914
# 278 -0.178385 -0.326504  0.094612  1.000000 -0.348356  1.000000  0.149943
# 511 -0.310605 -0.251330  0.228523  0.149943 -0.049914  0.149943  1.000000
# 3   -0.099252 -0.234484  0.081146  0.131617 -0.259191  0.131617  0.017607
# 119 -0.387434 -0.247949  0.273024 -0.028221 -0.267053 -0.028221  0.206030
# 77  -0.342295 -0.171694  0.285673  0.223993 -0.290873  0.223993  0.268146
# 371  0.520632  0.322395 -0.241403 -0.135671  0.476563 -0.135671 -0.231915
# 247  0.027008 -0.031779  0.107659 -0.053090  0.039384 -0.053090  0.053296
# 66  -0.135179  0.104382  0.107960 -0.087703  0.019609 -0.087703 -0.079182
# 241  0.045552  0.115128  0.068059 -0.041920  0.064926 -0.041920 -0.063530
# 364 -0.185595 -0.111969  0.005908 -0.125279 -0.143502 -0.125279 -0.047282
# 472  0.065661 -0.145704 -0.040466 -0.040061  0.136664 -0.040061 -0.177401
#
#             3       119        77       371       247        66       241  \
# 310 -0.099252 -0.387434 -0.342295  0.520632  0.027008 -0.135179  0.045552
# 54  -0.234484 -0.247949 -0.171694  0.322395 -0.031779  0.104382  0.115128
# 288  0.081146  0.273024  0.285673 -0.241403  0.107659  0.107960  0.068059
# 278  0.131617 -0.028221  0.223993 -0.135671 -0.053090 -0.087703 -0.041920
# 243 -0.259191 -0.267053 -0.290873  0.476563  0.039384  0.019609  0.064926
# 278  0.131617 -0.028221  0.223993 -0.135671 -0.053090 -0.087703 -0.041920
# 511  0.017607  0.206030  0.268146 -0.231915  0.053296 -0.079182 -0.063530
# 3    1.000000  0.257083  0.223468 -0.237611  0.173715  0.011888  0.019734
# 119  0.257083  1.000000  0.139456 -0.669641  0.028689  0.009234  0.017751
# 77   0.223468  0.139456  1.000000 -0.139162  0.076890  0.134075 -0.000002
# 371 -0.237611 -0.669641 -0.139162  1.000000  0.002631  0.047450  0.005028
# 247  0.173715  0.028689  0.076890  0.002631  1.000000 -0.105789 -0.101768
# 66   0.011888  0.009234  0.134075  0.047450 -0.105789  1.000000  0.218538
# 241  0.019734  0.017751 -0.000002  0.005028 -0.101768  0.218538  1.000000
# 364  0.180521  0.238161 -0.075677 -0.215329 -0.113445 -0.001147 -0.014505
# 472  0.143016 -0.132463 -0.015219  0.234457  0.122984  0.041116 -0.160022
#
#           364       472
# 310 -0.185595  0.065661
# 54  -0.111969 -0.145704
# 288  0.005908 -0.040466
# 278 -0.125279 -0.040061
# 243 -0.143502  0.136664
# 278 -0.125279 -0.040061
# 511 -0.047282 -0.177401
# 3    0.180521  0.143016
# 119  0.238161 -0.132463
# 77  -0.075677 -0.015219
# 371 -0.215329  0.234457
# 247 -0.113445  0.122984
# 66  -0.001147  0.041116
# 241 -0.014505 -0.160022
# 364  1.000000  0.077120
# 472  0.077120  1.000000

# %% [markdown]
# Dimensions with largest correlation: 371 and 310, 310 and 288, 243 and 54, 310 and 77, 243 and 278

# %%
sg_pl_n_we.columns = sg_pl_n_we.columns.str.replace('nombre', 'number')

# %%
sg_pl_n_we.to_csv('sg_pls_n_we.csv')
df=pd.read_csv('sg_pls_n_we.csv')

# %% [markdown]
# # See in dimensions

# %% [markdown]
# Test dimensions for lowest correlation with "nb"

# %% [markdown]
# Dimension 247,66,241,364,472

# %%
import seaborn as sns
from matplotlib import pyplot as plt

# %%
fig, axs = plt.subplots(5,1,figsize=(8,10))
sns.histplot(data=df, x="247", hue="nombre", kde=True, ax=axs[0])
sns.histplot(data=df, x="66", hue="nombre", kde=True, ax=axs[1])
sns.histplot(data=df, x="241", hue="nombre", kde=True, ax=axs[2])
sns.histplot(data=df, x="364", hue="nombre", kde=True, ax=axs[3])
sns.histplot(data=df, x="472", hue="nombre", kde=True, ax=axs[4])
# Out:
# <AxesSubplot:xlabel='472', ylabel='Count'>

# %% [markdown]
# It seems that these dimensions don't encode the information of singular and plural

# %% [markdown]
# Test dimensions for largest correlation with "nb"

# %% [markdown]
# Dimension: 54, 310, 288, 243,278,511, 3,119,77,371

# %%
fig, axs = plt.subplots(10,1,figsize=(10,15))
sns.histplot(data=df, x="54", hue="number", kde=True, ax=axs[0])
sns.histplot(data=df, x="310", hue="number", kde=True, ax=axs[1])
sns.histplot(data=df, x="288", hue="number", kde=True, ax=axs[2])
sns.histplot(data=df, x="243", hue="number", kde=True, ax=axs[3])
sns.histplot(data=df, x="278", hue="number", kde=True, ax=axs[4])
sns.histplot(data=df, x="511", hue="number", kde=True, ax=axs[5])
sns.histplot(data=df, x="3", hue="number", kde=True, ax=axs[6])
sns.histplot(data=df, x="119", hue="number", kde=True, ax=axs[7])
sns.histplot(data=df, x="77", hue="number", kde=True, ax=axs[8])
sns.histplot(data=df, x="371", hue="number", kde=True, ax=axs[9])
# Out:
# <AxesSubplot:xlabel='371', ylabel='Count'>

# %% [markdown]
# Dimension 54, 310, 288, 243, 278 seems possible  encode information about singular and plural Noun.

# %% [markdown]
# # ADJ

# %% [markdown]
# Next we will do the same experiment with adjectives

# %%
top_freq_adj = pd.read_csv('Most Frequent Words/top_frequent_pure_ADJ_FlauBERT.csv', index_col='Word')
top_freq_adj
# Out:
#                Unnamed: 0        lemme    cgram genre  freqlemlivres    number
# Word
# sûr                    26          sûr      ADJ     m         412.97  singular
# sûrs                   27          sûr      ADJ     m         412.97    plural
# aucun                  47        aucun  ADJ:ind     m         180.95  singular
# léger                  61        léger      ADJ     m         151.01  singular
# cher                   78         cher      ADJ     m         133.65  singular
# ...                   ...          ...      ...   ...            ...       ...
# relationnelle       22068  relationnel      ADJ     f           0.00  singular
# salariale           22087     salarial      ADJ     f           0.00  singular
# sociétale           22108     sociétal      ADJ     f           0.00  singular
# structurelle        22124   structurel      ADJ     f           0.00  singular
# trine               22168         trin      ADJ     f           0.00  singular
#
# [800 rows x 6 columns]

# %%
top_sg_adj = top_freq_adj[top_freq_adj["number"] == "singular"][:309]
top_sg_adj
# Out:
#                Unnamed: 0         lemme    cgram genre  freqlemlivres  \
# Word
# sûr                    26           sûr      ADJ     m         412.97
# aucun                  47         aucun  ADJ:ind     m         180.95
# léger                  61         léger      ADJ     m         151.01
# cher                   78          cher      ADJ     m         133.65
# tel                    85           tel  ADJ:ind     m         115.74
# ...                   ...           ...      ...   ...            ...
# imminente           13209      imminent      ADJ     f           7.64
# inaperçue           13231      inaperçu      ADJ     f           7.57
# bienveillante       13235  bienveillant      ADJ     f           7.50
# distante            13237       distant      ADJ     f           7.50
# croissante          13251     croissant      ADJ     f           7.43
#
#                  number
# Word
# sûr            singular
# aucun          singular
# léger          singular
# cher           singular
# tel            singular
# ...                 ...
# imminente      singular
# inaperçue      singular
# bienveillante  singular
# distante       singular
# croissante     singular
#
# [309 rows x 6 columns]

# %%
top_pl_adj = top_freq_adj[top_freq_adj["number"] == "plural"][:309]
top_pl_adj
# Out:
#                  Unnamed: 0         lemme cgram genre  freqlemlivres  number
# Word
# sûrs                     27           sûr   ADJ     m         412.97  plural
# chers                    79          cher   ADJ     m         133.65  plural
# normaux                 164        normal   ADJ     m          62.77  plural
# vains                   185          vain   ADJ     m          57.03  plural
# gais                    246           gai   ADJ     m          41.76  plural
# ...                     ...           ...   ...   ...            ...     ...
# restrictives          20223    restrictif   ADJ     f           0.20  plural
# promotionnelles       20701  promotionnel   ADJ     f           0.14  plural
# quantitatives         20710   quantitatif   ADJ     f           0.14  plural
# sectorielles          20735     sectoriel   ADJ     f           0.14  plural
# cognitives            20981      cognitif   ADJ     f           0.07  plural
#
# [309 rows x 6 columns]

# %%
all_adj_we = pd.read_csv('all_adjectives_we.csv', index_col=0)
sg_adj_we = all_adj_we.merge(top_sg_adj, left_index=True, right_index=True)
pl_adj_we = all_adj_we.merge(top_pl_adj, left_index=True, right_index=True)

# %%
sg_adj_we
# Out:
#                     0         1         2         3         4         5  \
# abusif       4.867257  0.789795  1.264146 -5.154982  2.566070  1.738820
# additionnel -0.616941 -6.087230  1.547413 -4.345960 -5.995902 -4.461722
# adjacent     5.479729 -2.366716  4.206669 -5.540428  0.928443  0.836656
# adéquat      2.973334 -2.308775 -0.624867  0.556190  4.157913 -2.216389
# aisé         8.850835 -0.002206  4.278875 -2.989154  3.220093 -1.767394
# ...               ...       ...       ...       ...       ...       ...
# éternelle   -0.678022 -3.079195  2.727036 -4.399039  2.790866  1.177965
# étonnante   -0.186054 -5.661340  2.166106  2.146834  2.167503 -3.062837
# éventuelle  -2.610230 -3.862970 -0.216105  1.952953 -3.365779  0.195184
# évidente     4.817487 -1.732906  4.693172 -1.503866  1.758747 -1.981044
# évolutif     4.163014 -9.127982  0.745465  3.814919  4.521577  0.618396
#
#                     6         7         8         9  ...       508       509  \
# abusif       4.101534 -0.010137  0.905952  0.975548  ... -3.621304  3.065237
# additionnel  0.117647  1.059721  7.412957  2.215156  ... -4.569757  0.161442
# adjacent    -0.615396  3.815086  5.509338  1.130770  ... -1.085630 -0.102630
# adéquat     -2.466419  1.002295  0.208676 -1.249406  ... -3.604785 -3.884492
# aisé        -1.251915  3.012408 -2.121538  1.423463  ...  1.109587 -0.850020
# ...               ...       ...       ...       ...  ...       ...       ...
# éternelle   -4.356398 -1.728209  1.062834  1.278158  ...  0.987698 -1.886698
# étonnante   -3.232288  6.259716 -0.753196  4.111769  ... -1.769989 -5.936738
# éventuelle  -0.672919 -0.463622  6.378855 -3.762104  ... -4.791579 -0.807169
# évidente    -4.529288  1.008203  0.146850 -0.596633  ... -1.359965 -6.485075
# évolutif    -0.025326  1.220651  0.866402  2.154563  ... -4.306684 -2.328375
#
#                   510       511  Unnamed: 0        lemme  cgram  genre  \
# abusif       0.466652  4.294173        4074       abusif    ADJ      m
# additionnel -0.308504 -1.276925        7600  additionnel    ADJ      m
# adjacent    -0.292161 -1.544128        5600     adjacent    ADJ      m
# adéquat      1.151281 -4.876080        2043      adéquat    ADJ      m
# aisé        -3.543136  0.384168        1331         aisé    ADJ      m
# ...               ...       ...         ...          ...    ...    ...
# éternelle    1.152633 -1.243356       12026      éternel    ADJ      f
# étonnante    0.300664 -0.013148       12176     étonnant    ADJ      f
# éventuelle   3.241624  2.172905       12626     éventuel    ADJ      f
# évidente     1.532511 -4.370127       12129      évident    ADJ      f
# évolutif     0.128012  2.529598        8951     évolutif    ADJ      m
#
#              freqlemlivres    number
# abusif                1.82  singular
# additionnel           0.34  singular
# adjacent              0.95  singular
# adéquat               4.80  singular
# aisé                  7.77  singular
# ...                    ...       ...
# éternelle            45.88  singular
# étonnante            30.00  singular
# éventuelle           13.18  singular
# évidente             33.58  singular
# évolutif              0.20  singular
#
# [309 rows x 518 columns]

# %%
pl_adj_we
# Out:
#                        0         1         2         3         4         5  \
# abondantes      2.469189 -3.042181 -0.594103  1.006183  8.231537 -4.990061
# accueillants    0.576559 -1.515551  4.017187 -0.952490  3.881024 -3.182856
# additionnelles -1.906001 -1.936373 -1.148156 -3.933651  1.829767 -7.428360
# additionnels   -1.639899 -2.043320 -2.027816 -2.177728 -4.045338 -4.147024
# adjacentes      2.826725 -1.366994  2.822716 -4.164242  0.131783 -2.770362
# ...                  ...       ...       ...       ...       ...       ...
# éternelles      1.867638 -1.348335  0.897797 -0.578476  4.255240 -0.675513
# étonnantes      2.100773 -2.296238  2.066491  3.788027  2.790904 -5.988153
# éventuelles    -4.537793 -2.413064 -1.959062  0.323099 -0.666984 -3.476775
# évidentes       4.127914 -0.139260  3.736150  1.509428 -0.238839 -3.402861
# évidents        3.761399 -0.572581  3.604520  1.861105 -0.316484 -2.269345
#
#                        6         7         8         9  ...       508  \
# abondantes     -1.689534 -3.603422  2.321808  2.781798  ... -0.016274
# accueillants   -0.789583  4.141278  0.657677 -0.656314  ... -1.023133
# additionnelles  0.893348  3.207361  6.501829 -0.337551  ... -2.192537
# additionnels    2.337263  2.441301  7.244435  0.401192  ... -4.491076
# adjacentes     -2.895708  1.490072  7.278826  0.694695  ... -2.540189
# ...                  ...       ...       ...       ...  ...       ...
# éternelles     -6.125883 -2.439762  3.454988  0.431836  ...  0.174759
# étonnantes     -2.217326  5.938934  0.327719  1.193367  ... -1.541108
# éventuelles    -0.984208 -4.031217  5.632687 -1.332556  ... -6.807765
# évidentes      -4.729940  1.938044  0.244337 -5.802175  ... -1.389882
# évidents       -2.034152  1.334489 -0.601564 -1.134129  ... -0.240554
#
#                      509       510       511  Unnamed: 0        lemme  cgram  \
# abondantes     -4.509098 -2.544398 -1.298414       13344     abondant    ADJ
# accueillants   -1.989711  0.480750  3.795453        1941  accueillant    ADJ
# additionnelles -2.576034  4.537546  1.684395       19266  additionnel    ADJ
# additionnels   -0.360925  0.766329 -0.458547        7601  additionnel    ADJ
# adjacentes     -1.402581 -3.017852  5.041753       17481     adjacent    ADJ
# ...                  ...       ...       ...         ...          ...    ...
# éternelles     -3.533939  1.028604 -1.422772       12027      éternel    ADJ
# étonnantes     -3.612943  5.448961  1.811032       12177     étonnant    ADJ
# éventuelles    -2.607736  4.961835 -0.272189       12627     éventuel    ADJ
# évidentes      -7.313276  3.100853 -5.175048       12130      évident    ADJ
# évidents       -7.466009  1.812035 -1.985085         320      évident    ADJ
#
#                 genre  freqlemlivres  number
# abondantes          f           7.03  plural
# accueillants        m           5.07  plural
# additionnelles      f           0.34  plural
# additionnels        m           0.34  plural
# adjacentes          f           0.95  plural
# ...               ...            ...     ...
# éternelles          f          45.88  plural
# étonnantes          f          30.00  plural
# éventuelles         f          13.18  plural
# évidentes           f          33.58  plural
# évidents            m          33.58  plural
#
# [309 rows x 518 columns]

# %%
dim_indices = range(512)
avg_values_sg = [sg_adj_we[str(i)].mean() for i in dim_indices]
avg_values_pl = [pl_adj_we[str(i)].mean() for i in dim_indices]
d = [abs(singular-plural) for singular,plural in zip(avg_values_sg, avg_values_pl)]
diff={d[i]:i for i in dim_indices}

sg_avg = pd.DataFrame([avg_values_sg], index=["sg_avg"], columns=dim_indices)
pl_avg = pd.DataFrame([avg_values_pl], index=["pl_avg"], columns=dim_indices)

# %%
sg_avg
# Out:
#              0         1         2         3         4         5         6    \
# sg_avg  2.814697 -2.929863  1.580876 -0.726001  2.329622 -0.965397 -2.045558
#
#             7         8         9    ...       502       503       504  \
# sg_avg  0.45846  1.684086  0.706123  ... -1.122445  1.334625  0.219188
#
#              505       506       507      508       509       510       511
# sg_avg -1.169695 -0.834826 -2.511605 -3.15262 -3.003996  0.160265 -1.561479
#
# [1 rows x 512 columns]

# %%
pl_avg
# Out:
#              0         1         2         3         4         5         6    \
# pl_avg  1.925913 -1.784404  1.525104  0.345413  2.118037 -3.350104 -1.578686
#
#              7         8         9    ...       502       503       504  \
# pl_avg -0.231169  0.444235 -0.505486  ... -1.586422  1.992835  0.627458
#
#              505      506       507       508       509       510       511
# pl_avg -1.162478 -1.07065 -2.170203 -3.313694 -3.558386 -0.135456 -0.229058
#
# [1 rows x 512 columns]

# %%
diff
# Out:
# {0.8887841299417474: 0,
#  1.1454598021537203: 1,
#  0.055771559629448575: 2,
#  1.0714136400080903: 3,
#  0.21158528886408012: 4,
#  2.384707482249189: 5,
#  0.4668724815184464: 6,
#  0.6896292473721684: 7,
#  1.2398504085048536: 8,
#  1.2116084493317154: 9,
#  0.32270413199029346: 10,
#  0.20907097399417607: 11,
#  0.33629395645113236: 12,
#  1.0646887116731425: 13,
#  0.3195370205857609: 14,
#  0.8775375721660166: 15,
#  0.5940657908569581: 16,
#  0.23531478491909408: 17,
#  0.164483029797569: 18,
#  0.31580013677087226: 19,
#  0.08191880235016358: 20,
#  1.261216551113269: 21,
#  0.10712049214886754: 22,
#  0.5244450495145645: 23,
#  1.049176790132686: 24,
#  1.163297868998704: 25,
#  0.220004456060515: 26,
#  0.36179204309682816: 27,
#  0.9163670189177995: 28,
#  0.7040428060258906: 29,
#  0.3472431135511324: 30,
#  0.8439227586860849: 31,
#  0.7915559296495145: 32,
#  0.2064871704313913: 33,
#  1.2894134190970872: 34,
#  0.2039059290000016: 35,
#  0.9060820534045262: 36,
#  0.5834314036922336: 37,
#  0.9694663652275082: 38,
#  0.18217727703883346: 39,
#  0.9048067173042071: 40,
#  0.15670357019676318,
#  0.15527526130097064,
#  0.15195885237378892,
#  0.14796812689644012,
#  0.14453738419741113,
#  0.1444349794482198,
#  0.14291509466019406,
#  0.13636580526537267,
#  0.1355636049708746,
#  0.12888057723948232,
#  0.1285763996012934,
#  0.12215532861489109,
#  0.12017448483546916,
#  0.11839847506472412,
#  0.11494655528640774,
#  0.10712049214886754,
#  0.1069656953495145,
#  0.10694401897443462,
#  0.10278760344336535,
#  0.09908959809385105,
#  0.09841611868932065,
#  0.09808032264854272,
#  0.09800030391261849,
#  0.09494180971974117,
#  0.09193085614562935,
#  0.08892998762135829,
#  0.08695902181941895,
#  0.08650084041262138,
#  0.08573699815016211,
#  0.08452296408737947,
#  0.08280611166019569,
#  0.08191880235016358,
#  0.07827661757928484,
#  0.06749678407443405,
#  0.06174807840453034,
#  0.05888318867313913,
#  0.058658012220061284,
#  0.05604348024595218,
#  0.055771559629448575,
#  0.05167640419741204,
#  0.048939544142718505,
#  0.04618648021585714,
#  0.04460548510841411,
#  0.04428166526925481,
#  0.04427789830744411,
#  0.03920821400420582,
#  0.039124390394822794,
#  0.038012579686084624,
#  0.03656551049158452,
#  0.03478155087757301,
#  0.03046071299925268,
#  0.029841910755339485,
#  0.02874974893203841,
#  0.02865596453721908,
#  0.026806661207123383,
#  0.025121769956957918,
#  0.024297666695791253,
#  0.020805535951453624,
#  0.02060460431067901,
#  0.0134100721326873,
#  0.01175226537443369,
#  0.009228535127508042,
#  0.00721673563430425,
#  0.004893135696118822,
#  0.0016123552394823604]

# %% [markdown]
# Select 10 dimensions which have the smallest average value

# %%
n = 10
bota = []
for i in d[-n:]:
    print(diff[i], i)
    bota.append(diff[i])

print(bota)
# Out:
# 305 0.025121769956957918
# 348 0.024297666695791253
# 269 0.020805535951453624
# 135 0.02060460431067901
# 279 0.0134100721326873
# 59 0.01175226537443369
# 89 0.009228535127508042
# 505 0.00721673563430425
# 436 0.004893135696118822
# 106 0.0016123552394823604
# [305, 348, 269, 135, 279, 59, 89, 505, 436, 106]

# %% [markdown]
# Select 10 dimensions which have the largest average value

# %%
n = 10
topa = []
for i in d[:n]:
    print(diff[i], i)
    topa.append(diff[i])

print(topa)
# Out:
# 371 2.5581292152750876
# 5 2.384707482249189
# 310 2.3236644984724917
# 84 1.988863068182201
# 54 1.8944675590194175
# 385 1.8651916436699052
# 384 1.8171725303370527
# 192 1.790080318152106
# 250 1.7701297735275032
# 278 1.7557686605838185
# [371, 5, 310, 84, 54, 385, 384, 192, 250, 278]

# %%
sg_pl_adj_we=pd.concat([sg_adj_we, pl_adj_we])
sg_pl_adj_we.loc[sg_pl_adj_we['number'] == 'singular', 'nb'] = 0
sg_pl_adj_we.loc[sg_pl_adj_we['number'] == 'plural', 'nb'] = 1
sg_pl_adj_we
# Out:
#                     0         1         2         3         4         5  \
# abusif       4.867257  0.789795  1.264146 -5.154982  2.566070  1.738820
# additionnel -0.616941 -6.087230  1.547413 -4.345960 -5.995902 -4.461722
# adjacent     5.479729 -2.366716  4.206669 -5.540428  0.928443  0.836656
# adéquat      2.973334 -2.308775 -0.624867  0.556190  4.157913 -2.216389
# aisé         8.850835 -0.002206  4.278875 -2.989154  3.220093 -1.767394
# ...               ...       ...       ...       ...       ...       ...
# éternelles   1.867638 -1.348335  0.897797 -0.578476  4.255240 -0.675513
# étonnantes   2.100773 -2.296238  2.066491  3.788027  2.790904 -5.988153
# éventuelles -4.537793 -2.413064 -1.959062  0.323099 -0.666984 -3.476775
# évidentes    4.127914 -0.139260  3.736150  1.509428 -0.238839 -3.402861
# évidents     3.761399 -0.572581  3.604520  1.861105 -0.316484 -2.269345
#
#                     6         7         8         9  ...       509       510  \
# abusif       4.101534 -0.010137  0.905952  0.975548  ...  3.065237  0.466652
# additionnel  0.117647  1.059721  7.412957  2.215156  ...  0.161442 -0.308504
# adjacent    -0.615396  3.815086  5.509338  1.130770  ... -0.102630 -0.292161
# adéquat     -2.466419  1.002295  0.208676 -1.249406  ... -3.884492  1.151281
# aisé        -1.251915  3.012408 -2.121538  1.423463  ... -0.850020 -3.543136
# ...               ...       ...       ...       ...  ...       ...       ...
# éternelles  -6.125883 -2.439762  3.454988  0.431836  ... -3.533939  1.028604
# étonnantes  -2.217326  5.938934  0.327719  1.193367  ... -3.612943  5.448961
# éventuelles -0.984208 -4.031217  5.632687 -1.332556  ... -2.607736  4.961835
# évidentes   -4.729940  1.938044  0.244337 -5.802175  ... -7.313276  3.100853
# évidents    -2.034152  1.334489 -0.601564 -1.134129  ... -7.466009  1.812035
#
#                   511  Unnamed: 0        lemme  cgram  genre  freqlemlivres  \
# abusif       4.294173        4074       abusif    ADJ      m           1.82
# additionnel -1.276925        7600  additionnel    ADJ      m           0.34
# adjacent    -1.544128        5600     adjacent    ADJ      m           0.95
# adéquat     -4.876080        2043      adéquat    ADJ      m           4.80
# aisé         0.384168        1331         aisé    ADJ      m           7.77
# ...               ...         ...          ...    ...    ...            ...
# éternelles  -1.422772       12027      éternel    ADJ      f          45.88
# étonnantes   1.811032       12177     étonnant    ADJ      f          30.00
# éventuelles -0.272189       12627     éventuel    ADJ      f          13.18
# évidentes   -5.175048       12130      évident    ADJ      f          33.58
# évidents    -1.985085         320      évident    ADJ      m          33.58
#
#                number   nb
# abusif       singular  0.0
# additionnel  singular  0.0
# adjacent     singular  0.0
# adéquat      singular  0.0
# aisé         singular  0.0
# ...               ...  ...
# éternelles     plural  1.0
# étonnantes     plural  1.0
# éventuelles    plural  1.0
# évidentes      plural  1.0
# évidents       plural  1.0
#
# [618 rows x 519 columns]

# %%
sg_pl_adj_we.loc[:, [ '371', '5', '310', '84', '54','385','384','192','250','278','nb']].corr()
# Out:
#           371         5       310        84        54       385       384  \
# 371  1.000000 -0.168453  0.480712  0.018934  0.178011 -0.002716  0.481750
# 5   -0.168453  1.000000  0.047901 -0.098304 -0.047198  0.070337 -0.112842
# 310  0.480712  0.047901  1.000000 -0.232729  0.207386  0.056905  0.244617
# 84   0.018934 -0.098304 -0.232729  1.000000 -0.206391  0.006578  0.090300
# 54   0.178011 -0.047198  0.207386 -0.206391  1.000000 -0.036264 -0.176475
# 385 -0.002716  0.070337  0.056905  0.006578 -0.036264  1.000000 -0.059424
# 384  0.481750 -0.112842  0.244617  0.090300 -0.176475 -0.059424  1.000000
# 192 -0.084943 -0.377981 -0.213517  0.087627 -0.054619 -0.020550  0.010634
# 250  0.342104 -0.129943 -0.002241  0.098999 -0.153555  0.056447  0.339518
# 278 -0.169052 -0.007474 -0.292527  0.233898 -0.172667 -0.186230 -0.137490
# nb  -0.093436 -0.383531 -0.383794  0.292875 -0.338899 -0.263689  0.301979
#
#           192       250       278        nb
# 371 -0.084943  0.342104 -0.169052 -0.093436
# 5   -0.377981 -0.129943 -0.007474 -0.383531
# 310 -0.213517 -0.002241 -0.292527 -0.383794
# 84   0.087627  0.098999  0.233898  0.292875
# 54  -0.054619 -0.153555 -0.172667 -0.338899
# 385 -0.020550  0.056447 -0.186230 -0.263689
# 384  0.010634  0.339518 -0.137490  0.301979
# 192  1.000000 -0.021612  0.210370  0.289995
# 250 -0.021612  1.000000  0.075938  0.288955
# 278  0.210370  0.075938  1.000000  0.290632
# nb   0.289995  0.288955  0.290632  1.000000

# %% [markdown]
# Dimension with largest correlation with nb: 310 > 5 > 54 > 384 > 84 > 278 > 192 > 250 > 385 > 371

# %%
sg_pl_adj_we.loc[:, [ '305', '348', '269', '135', '279','59','89','505','436','106','nb']].corr()
# Out:
#           305       348       269       135       279        59        89  \
# 305  1.000000  0.226167  0.102446 -0.035907  0.154129  0.033158 -0.113696
# 348  0.226167  1.000000  0.290238 -0.008189  0.185840 -0.048606  0.092698
# 269  0.102446  0.290238  1.000000  0.040088  0.167630  0.035064  0.051398
# 135 -0.035907 -0.008189  0.040088  1.000000 -0.111063  0.142912  0.071411
# 279  0.154129  0.185840  0.167630 -0.111063  1.000000  0.067925  0.002054
# 59   0.033158 -0.048606  0.035064  0.142912  0.067925  1.000000 -0.123758
# 89  -0.113696  0.092698  0.051398  0.071411  0.002054 -0.123758  1.000000
# 505  0.031050  0.034721  0.018211 -0.136623 -0.124244 -0.123340 -0.069491
# 436 -0.076228  0.002348  0.051612  0.026827 -0.130178 -0.297720 -0.020694
# 106  0.120224  0.185727  0.060570  0.053679  0.062681 -0.109347 -0.011099
# nb  -0.005494 -0.004160 -0.003063  0.003895 -0.002492 -0.002163  0.001860
#
#           505       436       106        nb
# 305  0.031050 -0.076228  0.120224 -0.005494
# 348  0.034721  0.002348  0.185727 -0.004160
# 269  0.018211  0.051612  0.060570 -0.003063
# 135 -0.136623  0.026827  0.053679  0.003895
# 279 -0.124244 -0.130178  0.062681 -0.002492
# 59  -0.123340 -0.297720 -0.109347 -0.002163
# 89  -0.069491 -0.020694 -0.011099  0.001860
# 505  1.000000 -0.051564  0.119603  0.001373
# 436 -0.051564  1.000000 -0.055190  0.000787
# 106  0.119603 -0.055190  1.000000  0.000280
# nb   0.001373  0.000787  0.000280  1.000000

# %% [markdown]
# Dimention with smallest correlation with nb: 106 < 436 < 505 < 89 < 59 < 279 < 269 < 135 < 348 < 305

# %%
sg_pl_adj_we.loc[:, [ '310', '54', '5', '384', '84','278', '192','250','385','371', '106', '436','505','89','59']].corr()
# Out:
#           310        54         5       384        84       278       192  \
# 310  1.000000  0.207386  0.047901  0.244617 -0.232729 -0.292527 -0.213517
# 54   0.207386  1.000000 -0.047198 -0.176475 -0.206391 -0.172667 -0.054619
# 5    0.047901 -0.047198  1.000000 -0.112842 -0.098304 -0.007474 -0.377981
# 384  0.244617 -0.176475 -0.112842  1.000000  0.090300 -0.137490  0.010634
# 84  -0.232729 -0.206391 -0.098304  0.090300  1.000000  0.233898  0.087627
# 278 -0.292527 -0.172667 -0.007474 -0.137490  0.233898  1.000000  0.210370
# 192 -0.213517 -0.054619 -0.377981  0.010634  0.087627  0.210370  1.000000
# 250 -0.002241 -0.153555 -0.129943  0.339518  0.098999  0.075938 -0.021612
# 385  0.056905 -0.036264  0.070337 -0.059424  0.006578 -0.186230 -0.020550
# 371  0.480712  0.178011 -0.168453  0.481750  0.018934 -0.169052 -0.084943
# 106 -0.120798 -0.010717 -0.066151  0.063162  0.102807  0.017843 -0.064492
# 436 -0.236587 -0.038322  0.102769 -0.090109  0.104718  0.217735  0.173471
# 505 -0.090714 -0.035731  0.008117 -0.148060  0.133077  0.251125 -0.060082
# 89   0.061710  0.102960  0.112898 -0.061997 -0.206582  0.015211 -0.132349
# 59   0.052472  0.006232 -0.009569  0.018317 -0.008173 -0.232397 -0.057869
#
#           250       385       371       106       436       505        89  \
# 310 -0.002241  0.056905  0.480712 -0.120798 -0.236587 -0.090714  0.061710
# 54  -0.153555 -0.036264  0.178011 -0.010717 -0.038322 -0.035731  0.102960
# 5   -0.129943  0.070337 -0.168453 -0.066151  0.102769  0.008117  0.112898
# 384  0.339518 -0.059424  0.481750  0.063162 -0.090109 -0.148060 -0.061997
# 84   0.098999  0.006578  0.018934  0.102807  0.104718  0.133077 -0.206582
# 278  0.075938 -0.186230 -0.169052  0.017843  0.217735  0.251125  0.015211
# 192 -0.021612 -0.020550 -0.084943 -0.064492  0.173471 -0.060082 -0.132349
# 250  1.000000  0.056447  0.342104 -0.124434 -0.036812 -0.228692  0.082084
# 385  0.056447  1.000000 -0.002716  0.085443  0.119468 -0.071821 -0.028152
# 371  0.342104 -0.002716  1.000000 -0.003394 -0.138693 -0.217420 -0.128498
# 106 -0.124434  0.085443 -0.003394  1.000000 -0.055190  0.119603 -0.011099
# 436 -0.036812  0.119468 -0.138693 -0.055190  1.000000 -0.051564 -0.020694
# 505 -0.228692 -0.071821 -0.217420  0.119603 -0.051564  1.000000 -0.069491
# 89   0.082084 -0.028152 -0.128498 -0.011099 -0.020694 -0.069491  1.000000
# 59  -0.064754  0.003207  0.010289 -0.109347 -0.297720 -0.123340 -0.123758
#
#            59
# 310  0.052472
# 54   0.006232
# 5   -0.009569
# 384  0.018317
# 84  -0.008173
# 278 -0.232397
# 192 -0.057869
# 250 -0.064754
# 385  0.003207
# 371  0.010289
# 106 -0.109347
# 436 -0.297720
# 505 -0.123340
# 89  -0.123758
# 59   1.000000

# %% [markdown]
# Dimensions with largest correlation: 310 and 371, 192 and 5, 384 and 250,  310 and 278, 310 and 384, 310 and 84

# %%
sg_pl_adj_we= sg_pl_adj_we.replace(['singular','plural'],['s','p'])
sg_pl_adj_we= sg_pl_adj_we.replace('ADJ:ind','ADJ')

# %%
sg_pl_adj_we.to_csv('sg_pls_adjs_we.csv')
df_a=pd.read_csv('sg_pls_adjs_we.csv')

# %%
import seaborn as sns
from matplotlib import pyplot as plt

# %% [markdown]
# dimention with smallest correlation with nb: 106,436,505,89,59

# %%
fig, axs = plt.subplots(5,1,figsize=(8,10))
sns.histplot(data=df_a, x="106", hue="number", kde=True, ax=axs[0])
sns.histplot(data=df_a, x="436", hue="number", kde=True, ax=axs[1])
sns.histplot(data=df_a, x="505", hue="number", kde=True, ax=axs[2])
sns.histplot(data=df_a, x="89", hue="number", kde=True, ax=axs[3])
sns.histplot(data=df_a, x="59", hue="number", kde=True, ax=axs[4])
# Out:
# <AxesSubplot:xlabel='59', ylabel='Count'>

# %% [markdown]
# It seems that these dimensions don't encode the information for sigular adj and plural adj

# %% [markdown]
# dimention with largest correlation with nb: 310,5,54,384,84

# %% [markdown]
# 310 > 5 > 54 > 384 > 84 > 278 > 192 > 250 > 385 > 371

# %%
fig, axs = plt.subplots(10,1,figsize=(10,15))
sns.histplot(data=df_a, x="310", hue="number", kde=True, ax=axs[0])
sns.histplot(data=df_a, x="5", hue="number", kde=True, ax=axs[1])
sns.histplot(data=df_a, x="54", hue="number", kde=True, ax=axs[2])
sns.histplot(data=df_a, x="384", hue="number", kde=True, ax=axs[3])
sns.histplot(data=df_a, x="84", hue="number", kde=True, ax=axs[4])
sns.histplot(data=df_a, x="278", hue="number", kde=True, ax=axs[5])
sns.histplot(data=df_a, x="192", hue="number", kde=True, ax=axs[6])
sns.histplot(data=df_a, x="250", hue="number", kde=True, ax=axs[7])
sns.histplot(data=df_a, x="385", hue="number", kde=True, ax=axs[8])
sns.histplot(data=df_a, x="371", hue="number", kde=True, ax=axs[9])
# Out:
# <AxesSubplot:xlabel='371', ylabel='Count'>

# %% [markdown]
# Dimension 310, 5, 54, 384, 192 possible encode the information about singualr and plural adj

# %% [markdown]
# # ADJ AND NOUN

# %%
sg_pl_n_adj_we=pd.concat([sg_pl_n_we, sg_pl_adj_we])

# %%
sg_pl_n_adj_we.to_csv('sg_pl_n_adj_we.csv')

# %%
df_a_adj=pd.read_csv('sg_pl_n_adj_we.csv')
# Out:
# /Users/chunyang/opt/anaconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3444: DtypeWarning: Columns (513,514) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df_a_adj
# Out:
#        Unnamed: 0         0         1         2         3         4         5  \
# 0         absence  3.322297 -0.768149  3.555035 -0.685460  1.201102 -3.151831
# 1          accord -0.732188 -2.024965  1.674970 -4.194049 -2.528312 -2.400746
# 2          action  1.376720 -3.602622  0.270682 -7.004842  1.199668 -0.341319
# 3             air -0.491568 -1.776510 -0.420017 -5.103687 -2.064307 -1.580656
# 4          allure  3.051527 -2.565099  1.431839 -2.976701 -2.084035 -2.772705
# ...           ...       ...       ...       ...       ...       ...       ...
# 1231   éternelles  1.867638 -1.348335  0.897797 -0.578476  4.255240 -0.675513
# 1232   étonnantes  2.100773 -2.296238  2.066491  3.788027  2.790904 -5.988153
# 1233  éventuelles -4.537793 -2.413064 -1.959062  0.323099 -0.666984 -3.476775
# 1234    évidentes  4.127914 -0.139260  3.736150  1.509428 -0.238839 -3.402861
# 1235     évidents  3.761399 -0.572581  3.604520  1.861105 -0.316484 -2.269345
#
#              6         7         8  ...        gn     gender    Rang  \
# 0    -3.592423  1.189369 -2.742928  ...  singular   feminine   931.0
# 1    -4.672920  0.374903  6.015941  ...  singular  masculine   442.0
# 2     3.974475 -0.292309  2.597899  ...  singular   feminine   771.0
# 3    -1.270584  3.064606  4.021414  ...  singular  masculine    34.0
# 4    -2.094211  1.903866  4.068268  ...  singular   feminine  1087.0
# ...        ...       ...       ...  ...       ...        ...     ...
# 1231 -6.125883 -2.439762  3.454988  ...       NaN        NaN     NaN
# 1232 -2.217326  5.938934  0.327719  ...       NaN        NaN     NaN
# 1233 -0.984208 -4.031217  5.632687  ...       NaN        NaN     NaN
# 1234 -4.729940  1.938044  0.244337  ...       NaN        NaN     NaN
# 1235 -2.034152  1.334489 -0.601564  ...       NaN        NaN     NaN
#
#          lemme  cgram  genre  number  freqlemlivres   nb  Unnamed: 0.1
# 0      absence    NOM      f       s          76.28  0.0           NaN
# 1       accord    NOM      m       s         136.15  0.0           NaN
# 2       action    NOM      f       s          87.43  0.0           NaN
# 3          air    NOM      m       s         690.81  0.0           NaN
# 4       allure    NOM      f       s          65.88  0.0           NaN
# ...        ...    ...    ...     ...            ...  ...           ...
# 1231   éternel    ADJ      f       p          45.88  1.0       12027.0
# 1232  étonnant    ADJ      f       p          30.00  1.0       12177.0
# 1233  éventuel    ADJ      f       p          13.18  1.0       12627.0
# 1234   évident    ADJ      f       p          33.58  1.0       12130.0
# 1235   évident    ADJ      m       p          33.58  1.0         320.0
#
# [1236 rows x 523 columns]

# %% [markdown]
# Test de correlation of commun dimension : 310, 54, 278 with cgram : NOM, ADJ , number : singular , plural.

# %%
sns.catplot(x="cgram", y="310", hue='number', data=df_a_adj, kind='point')
sns.catplot(x="cgram", y="54", hue='number', data=df_a_adj, kind='point')
sns.catplot(x="cgram", y="278", hue='number', data=df_a_adj, kind='point')

# %% [markdown]
# Test de correlation of other  dimensions : 5, 106, 384,  288  with cgram : NOM, ADJ , number : singular , plural.

# %%
sns.catplot(x="cgram", y="5", hue='number', data=df_a_adj, kind='point')
sns.catplot(x="cgram", y="106", hue='number', data=df_a_adj, kind='point')
sns.catplot(x="cgram", y="384", hue='number', data=df_a_adj, kind='point')
sns.catplot(x="cgram", y="288", hue='number', data=df_a_adj, kind='point')

# %% [markdown]
# From the above results, it seems that common dimension : 310, 54, 278 have a parallel relationship between singular, plural nouns and singular, plural adjectives, but other dimensions do not.

# %%
sns.catplot(data=df_a_adj, x="cgram", y="310", col="number",kind="bar", height=4, aspect=.6,)
sns.catplot(data=df_a_adj, x="cgram", y="54", col="number",kind="bar", height=4, aspect=.6,)
sns.catplot(data=df_a_adj, x="cgram", y="278", col="number",kind="bar", height=4, aspect=.6,)
sns.catplot(data=df_a_adj, x="cgram", y="5", col="number",kind="bar", height=4, aspect=.6,)
