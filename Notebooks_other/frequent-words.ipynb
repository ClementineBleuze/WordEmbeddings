# %% [markdown]
# # 1000 Frequent French words by POS

# %% [markdown]
# ## How were the words selected ?

# %% [markdown]
# * The words were selected using __[OpenLexicon](http://www.lexique.org/shiny/openlexicon/)__ : a tool allowing to navigate databases and query them with regards to POS, lemma, etc.
# * For grammatical categories NOUN, VERB, ADJ and ADV, I selected all forms **ordered by frequency** in one of the source corpora of the lexicon (column **freqlemlivres**).
#
# For more information, see :
# Pallier, Christophe & New, Boris & Jessica Bourgin (2019) Openlexicon, GitHub repository, https://github.com/chrplr/openlexicon

# %% [markdown]
# ### Post-treatment [TO FINISH]
# In order to facilitate our studies, we decided not to keep in our list:
# - Words that do not have an Embedding in FLAUBERT [done for Nouns]
# - Words whose grammatical category is ambiguous just from their form (e.g "lit": can be a NOUN or a VERB)

# %%
import pandas as pd

forms = pd.read_csv("top_frequent_NOUN.csv")
print(forms)
FlauBERT = set(pd.read_csv("../all_nouns_we.csv")["Unnamed: 0"])

to_remove = [i for i in range(len(forms)) if forms.loc[i,"Word"] not in FlauBERT]
forms = forms.drop(forms.index[to_remove])
print(forms)

forms.to_csv("top_frequent_NOUN_FlauBERT.csv")
# Out:
#              Word      lemme cgram genre nombre  freqlemlivres
# 0           homme      homme   NOM     m      s        1398.85
# 1          hommes      homme   NOM     m      p        1398.85
# 2            jour       jour   NOM     m      s        1341.76
# 3           jours       jour   NOM     m      p        1341.76
# 4           temps      temps   NOM     m      s        1289.39
# ...           ...        ...   ...   ...    ...            ...
# 48282   évitement  évitement   NOM     m      s           0.00
# 48283   évènement  évènement   NOM     m      s           0.00
# 48284  évènements  évènement   NOM     m      p           0.00
# 48285     être-là    être-là   NOM     m    NaN           0.00
# 48286     îlotier    îlotier   NOM     m      s           0.00
#
# [48287 rows x 6 columns]
#                  Word           lemme cgram genre nombre  freqlemlivres
# 0               homme           homme   NOM     m      s        1398.85
# 1              hommes           homme   NOM     m      p        1398.85
# 2                jour            jour   NOM     m      s        1341.76
# 3               jours            jour   NOM     m      p        1341.76
# 5                oeil            oeil   NOM     m      s        1234.59
# ...               ...             ...   ...   ...    ...            ...
# 48267        éthylène        éthylène   NOM     m      s           0.00
# 48269      étiquetage      étiquetage   NOM     m      s           0.00
# 48274  évangélisation  évangélisation   NOM     f      s           0.00
# 48283       évènement       évènement   NOM     m      s           0.00
# 48284      évènements       évènement   NOM     m      p           0.00
#
# [11353 rows x 6 columns]

# %%
# also for VERBS
forms = pd.read_csv("top_frequent_VERB.csv")
FlauBERT = set(pd.read_csv("../all_verb_we.csv")["Unnamed: 0"])
to_remove = [i for i in range(len(forms)) if forms.loc[i,"Word"] not in FlauBERT]
forms = forms.drop(forms.index[to_remove])
forms.to_csv("top_frequent_VERB_FlauBERT.csv")

# %%
# and adjectives
import pandas as pd

forms = pd.read_csv("top_frequent_ADJ.csv")
FlauBERT = set(pd.read_csv("../all_adjectives_we.csv")["Unnamed: 0"])
to_remove = [i for i in range(len(forms)) if forms.loc[i,"Word"] not in FlauBERT]
forms = forms.drop(forms.index[to_remove])
forms.to_csv("top_frequent_ADJ_FlauBERT.csv")

# %%
# removing nouns and verbs that are not "pure" nouns / verbs (POS ambiguity)
nouns_df = pd.read_csv("../../Morphalou3/data/csv/all_nouns.csv", dtype= str)
nouns = []
for c in nouns_df.columns:
    if c not in ["Unnamed: 0", "gender", "category"]:
        nouns.extend(list(nouns_df[c]))
morphalou_nouns = set(nouns)

verbs_df = pd.read_csv("../../Morphalou3/data/csv/all_verbs.csv", dtype= str)
verbs = []
for c in verbs_df.columns:
    if c != "Unnamed: 0":
        verbs.extend(list(verbs_df[c]))
morphalou_verbs = set(verbs)

adj_df = pd.read_csv("../../Morphalou3/data/csv/all_adjectives.csv", dtype= str)
adj = []
for c in adj_df.columns:
    if c!= "Unnamed: 0":
        adj.extend(list(adj_df[c]))
morphalou_adj = set(adj)

noun_verbs = morphalou_nouns.intersection(morphalou_verbs)
noun_adj = morphalou_nouns.intersection(morphalou_adj)
verb_ajd = morphalou_verbs.intersection(morphalou_adj)
morphalou_ambig = noun_verbs.union(noun_adj, verb_ajd)
morphalou_ambig
# Out:
# {'caspien',
#  'modeste',
#  'irrésolu',
#  'métissés',
#  'prépositionnés',
#  'foreuse',
#  'ansériformes',
#  'lorrain',
#  'élégantes',
#  'antiimpérialistes',
#  'convoqués',
#  'camoufles',
#  'contrecollés',
#  'édificateurs',
#  'opposé',
#  'cocaïnomanes',
#  'effrayés',
#  'tiqueté',
#  'tantièmes',
#  'honorés',
#  'lobées',
#  'antiprogestatifs',
#  'limitant',
#  'humanoïde',
#  'entendues',
#  'morse',
#  'baragouinant',
#  'arroseuses',
#  'wahhabites',
#  'gaufres',
#  'nanosomes',
#  'entier',
#  'institutionnalisé',
#  'avilie',
#  'cuivrées',
#  'larguées',
#  'ocellée',
#  'indonésiens',
#  'carbonylée',
#  'slaves',
#  'mépris',
#  'dédoré',
#  'remort',
#  'maniérées',
#  'dynamité',
#  'cubito-carpien',
#  'herbées',
#  'attendues',
#  'secondipare',
#  'physiocrate',
#  'débouté',
#  'explicites',
#  'sédentarisées',
#  'lipothymiques',
#  'déconstruite',
#  'nuancées',
#  'étalons',
#  'fine',
#  'combustibles',
#  'rephosphorés',
#  'encapsulée',
#  'norroises',
#  'recommencé',
#  'recréé',
#  'superfinies',
#  'locomobiles',
#  'communisant',
#  'traficoteurs',
#  'apathique',
#  'ongulé',
#  'régi',
#  'péloponnésienne',
#  'eskuarien',
#  'crayonneuses',
#  'croate',
#  'rouleautés',
#  'gravettienne',
#  'réadaptés',
#  'goudronnée',
#  'traite',
#  'gémeau',
#  'jacobien',
#  'punaises',
#  'pigeonne',
#  'survenues',
#  'défécateur',
#  'infirmières',
#  'régissant',
#  'réquisitionné',
#  'prêteuses',
#  'communiquée',
#  'gomorrhéennes',
#  'churchillienne',
#  'lézardée',
#  'accusé',
#  'chronométrés',
#  'bhoutanais',
#  'traversiers',
#  'éludés',
#  'drogués',
#  'creuse',
#  'ravages',
#  'monorimes',
#  'galonnés',
#  'transparents',
#  'charriés',
#  'fuvélien',
#  'conquise',
#  'dégantée',
#  'aphélies',
#  'contrefaits',
#  'numérotées',
#  'traversières',
#  'tare',
#  'maline',
#  'percluses',
#  'pervertie',
#  'essoucheurs',
#  'iodé',
#  'jaspé',
#  'encordés',
#  'rock',
#  'inhibitionniste',
#  'assommants',
#  'abdicataire',
#  'vertébré',
#  'factorisées',
#  'lilliputienne',
#  'phrasés',
#  'asiates',
#  'menottée',
#  'miniaturisées',
#  'escarmouches',
#  'entretissé',
#  'mémorisée',
#  'bouterolles',
#  'perverse',
#  'fanfare',
#  'confiné',
#  'vanisé',
#  'consolée',
#  'frustres',
#  'lettons',
#  'lithiasiques',
#  'diligentées',
#  'conjoint',
#  'concédante',
#  'coquilliers',
#  'déferré',
#  'chevillons',
#  'intestins',
#  'hypertrophiés',
#  'rastafaris',
#  'irradiant',
#  'expatriées',
#  'verticales',
#  'égalisatrice',
#  'râpé',
#  'différentiées',
#  'revenant',
#  'délitée',
#  'dus',
#  'catéchisé',
#  'techno',
#  'guide',
#  'intellectuel',
#  'saint-simonienne',
#  'anèmes',
#  'étroit',
#  'regretté',
#  'phénolés',
#  'accumulées',
#  'gazouillé',
#  'toilés',
#  'funiculaire',
#  'antifébrile',
#  'cryoprécipités',
#  'daghestanaises',
#  'réprobatrices',
#  'réexaminées',
#  'exemptes',
#  'mononucléaires',
#  'dégondés',
#  'déboisés',
#  'antimonarchiste',
#  'cerf-voliste',
#  'rétroactive',
#  'bruts',
#  'rancuneuses',
#  'microbicides',
#  'imbu',
#  'plaignant',
#  'ambassadrice',
#  'temporisées',
#  'vihueliste',
#  'minimisés',
#  'dolent',
#  'subjectif',
#  'suiviste',
#  'manipulateurs',
#  'embouées',
#  'sanctifiés',
#  'pinasses',
#  'gesticulé',
#  'parodié',
#  'longé',
#  'étronçonnée',
#  'congruent',
#  'encaisse',
#  'émerisés',
#  'désorbitée',
#  'amarre',
#  'intérocepteur',
#  'administrant',
#  'havi',
#  'contrasté',
#  'dépouillées',
#  'prototype',
#  'liquéfiées',
#  'empalés',
#  'balourdes',
#  'déballés',
#  'déictiques',
#  'chérie',
#  'dragonne',
#  'douche',
#  'flash',
#  'dionysiaques',
#  'traducteur',
#  'autoanalyse',
#  'antiabolitionniste',
#  'plongeant',
#  'contre-plaqué',
#  'bitumées',
#  'fédéraux',
#  'bordée',
#  'chiqués',
#  'échardonné',
#  'engrossés',
#  'préimpressionniste',
#  'farandoles',
#  'sulfite',
#  'intriqués',
#  'profès',
#  'superlourd',
#  'dégarnis',
#  'incréé',
#  'comblées',
#  'mussolinienne',
#  'contraltos',
#  'toungouses',
#  'raidisseuse',
#  'centres',
#  'satiriques',
#  'authentifiées',
#  'rudentées',
#  'vermoulus',
#  'antisudoraux',
#  'poulards',
#  'busées',
#  'disculpées',
#  'infantilisant',
#  'supprimés',
#  'adonnés',
#  'sauvetés',
#  'bovins',
#  'quincaillières',
#  'accueillis',
#  'monotriche',
#  'flapi',
#  'conspirateur',
#  'déploré',
#  'néantisant',
#  'pourries',
#  'narquois',
#  'purgées',
#  'dérouillées',
#  'responsabilisées',
#  'paragrêle',
#  'lactosé',
#  'zigouillés',
#  'prêches',
#  'tigré',
#  'fröbéliennes',
#  'parse',
#  'portionnaire',
#  'fétial',
#  'échoppée',
#  'pollueuse',
#  'habsbourgeois',
#  'macrobiotiques',
#  'cycadées',
#  'coécrit',
#  'cravachant',
#  'réécrit',
#  'ramiste',
#  'cavaleuses',
#  'ismaélite',
#  'massacres',
#  'arrecteurs',
#  'assonancés',
#  'disculpés',
#  'exterminatrice',
#  'allégis',
#  'panaches',
#  'truffes',
#  'cantonaises',
#  'cinéraires',
#  'dompteuse',
#  'manqué',
#  'hallucinée',
#  'technicocommerciales',
#  'orthopédiste',
#  'infecté',
#  'bichromaté',
#  'contrastes',
#  'effluent',
#  'cabrioles',
#  'épiés',
#  'exécutés',
#  'ganse',
#  'gynandre',
#  'possessoires',
#  'stockeuse',
#  'publicitaires',
#  'figées',
#  'fondateurs',
#  'social',
#  'forceur',
#  'atterrie',
#  'intermittent',
#  'localisée',
#  'oubliées',
#  'triballes',
#  'insonorisées',
#  'dure-à-cuire',
#  'rafistolées',
#  'andréide',
#  'existante',
#  'disloqué',
#  'incidents',
#  'poecilotherme',
#  'mouflé',
#  'accaparées',
#  'regarnies',
#  'transfiguré',
#  'hydrostatique',
#  'perlières',
#  'régulationniste',
#  'malienne',
#  'jambiers',
#  'causatifs',
#  'piaulant',
#  'modernisées',
#  'déloqué',
#  'désadaptés',
#  'volante',
#  'violent',
#  'inflationnistes',
#  'sauvettes',
#  'judéo-chrétiens',
#  'rappé',
#  'improvisé',
#  'ourlé',
#  'expatriée',
#  'buché',
#  'îlienne',
#  'phéniquées',
#  'fuchsia',
#  'amasse',
#  'attaques',
#  'dionysienne',
#  'khâgneux',
#  'sikhe',
#  'entêtant',
#  'céphalogyres',
#  'lupercales',
#  'repeint',
#  'grillage',
#  'flette',
#  'calotins',
#  'péloponnésiens',
#  'hypertextes',
#  'grondées',
#  'empêchée',
#  'carouble',
#  'bailles',
#  'sensuel',
#  'désillusionnés',
#  'minoens',
#  'dépeuplée',
#  'induits',
#  'partageuses',
#  'désinfectants',
#  'recelés',
#  'débourreurs',
#  'zélée',
#  'coquin',
#  'chancreuse',
#  'australanthropiens',
#  'ibséniens',
#  'spiritain',
#  'abimée',
#  'lessivière',
#  'mineures',
#  'flous',
#  'béats',
#  'arboricole',
#  'dogmatique',
#  'rancunière',
#  'boulangère',
#  'économistes',
#  'polaires',
#  'pneumogastrique',
#  'parthes',
#  'abbevillienne',
#  'fertilisateur',
#  'renonce',
#  'paludière',
#  'cravates',
#  'grondé',
#  'dessiné',
#  'renvoyés',
#  'troque',
#  'sabéenne',
#  'régissants',
#  'buccine',
#  'charbonné',
#  'armoricaine',
#  'fleurette',
#  'chambristes',
#  'inféodés',
#  'gradués',
#  'vergée',
#  'pleinairistes',
#  'préadamite',
#  'retapissée',
#  'diamantine',
#  'tontine',
#  'mendiant',
#  'piaillardes',
#  'réunifiés',
#  'thymoleptique',
#  'aryténoïdes',
#  'quittes',
#  'agaillardis',
#  'adaptées',
#  'alismée',
#  'bouquetée',
#  'énoncées',
#  'huche',
#  'borates',
#  'élidés',
#  'vacanciers',
#  'emblavés',
#  'inséminées',
#  'désoccupé',
#  'souffrotant',
#  'affilié',
#  'terrinée',
#  'modalisateur',
#  'annonces',
#  'macédonien',
#  'thérapeutique',
#  'assené',
#  'sud-vietnamiennes',
#  'mensurateurs',
#  'remorquées',
#  'pluriel',
#  'envolés',
#  'tronqué',
#  'professées',
#  'frelatée',
#  'pédicure',
#  'crêtés',
#  'médecines',
#  'coucheuse',
#  'revitalisant',
#  'grivois',
#  'gantelé',
#  'reployée',
#  'canne',
#  'anuriques',
#  'agaricines',
#  'curé',
#  'écœurant',
#  'congréganiste',
#  'tracassés',
#  'mignons',
#  'agrariens',
#  'muri',
#  'racontée',
#  'métropolitain',
#  'saumure',
#  'beurrières',
#  'priées',
#  'invocatrice',
#  'dopes',
#  'lacée',
#  'briard',
#  'foires',
#  'sacrant',
#  'antiinflationniste',
#  'biarrotes',
#  'métropolitains',
#  'évalué',
#  'gifle',
#  'quadrupède',
#  'immunisés',
#  'potelées',
#  'cicatrisant',
#  'myorelaxants',
#  'ruskof',
#  'banderolée',
#  'anesthésiées',
#  'lycéen',
#  'bouclé',
#  'pyrrhoniennes',
#  'incomprise',
#  'pressurisée',
#  'antivomitif',
#  'ossifiés',
#  'prônes',
#  'ôtées',
#  'hurlant',
#  'cabote',
#  'insolée',
#  'taguées',
#  'domicilié',
#  'éludées',
#  'herses',
#  'kikuyus',
#  'porte-fleurs',
#  'oléacée',
#  'jouées',
#  'dateurs',
#  'espagnoles',
#  'actualisateur',
#  'liégeoise',
#  'reconsidéré',
#  'duplique',
#  'givrée',
#  'typographié',
#  'éthique',
#  'zinzolin',
#  'échiné',
#  'fulminant',
#  'bahulées',
#  'pavés',
#  'photorécepteur',
#  'hazaras',
#  'gondole',
#  'policés',
#  'ravisseur',
#  'baconien',
#  'pulmonés',
#  'gothes',
#  'projetées',
#  'confitures',
#  'laineuse',
#  'farnésiens',
#  'écloses',
#  'fumistes',
#  'massée',
#  'putoisée',
#  'menées',
#  'biarrote',
#  'actualisée',
#  'scolastique',
#  'aliénant',
#  'géophysiques',
#  'libérales',
#  'franchouillards',
#  'geindre',
#  'caractérisés',
#  'tourbière',
#  'exonérés',
#  'exténuée',
#  'surcreusée',
#  'sertie',
#  'efféminés',
#  'lauréates',
#  'féculières',
#  'cigarettières',
#  'retenues',
#  'glycogène',
#  'enchâssées',
#  'duplicateurs',
#  'élégis',
#  'barbets',
#  'tubéreuses',
#  'morigénés',
#  'saurisseuse',
#  'indisposés',
#  'appauvrissant',
#  'honoré',
#  'maccarthystes',
#  'compilés',
#  'gelée',
#  'externes',
#  'industrielles',
#  'disubstituée',
#  'plan-concave',
#  'contredisante',
#  'habitées',
#  'éviscérés',
#  'volantées',
#  'patois',
#  'assolés',
#  'décodés',
#  'vasoconstrictif',
#  'explosophore',
#  'pronominal',
#  'folichonnes',
#  'synchro',
#  'buttés',
#  'cocues',
#  'contondant',
#  'dégraissé',
#  'farine',
#  'désinhibiteurs',
#  'lutinées',
#  'gourmande',
#  'usés',
#  'fluoriques',
#  'chaude',
#  'applaudi',
#  'sunnites',
#  'larvée',
#  'économique',
#  'imprégnés',
#  'analysées',
#  'stipendiaire',
#  'déprédé',
#  'vélaire',
#  'marmotteuse',
#  'affines',
#  'hétérotrophe',
#  'ressuscitées',
#  'opto-électronique',
#  'lancequine',
#  'dénoncé',
#  'phrygienne',
#  'déchaînée',
#  'hydrofugées',
#  'adventistes',
#  'torture',
#  'meurtriers',
#  'drainés',
#  'essayées',
#  'fruste',
#  'capsien',
#  'chicaneurs',
#  'enchemisé',
#  'délibérées',
#  'discrète',
#  'faiblards',
#  'vidanges',
#  'hétéropage',
#  'scalpée',
#  'confisquée',
#  'opale',
#  'coupés',
#  'charabia',
#  'trogloxène',
#  'répétitrice',
#  'échangée',
#  'fraternisant',
#  'sinoques',
#  'contributrice',
#  'essuyé',
#  'désescalades',
#  'ciselier',
#  'mattes',
#  'délinquante',
#  'propérispomènes',
#  'biturbopropulseur',
#  'brandillant',
#  'expertisées',
#  'tonicardiaques',
#  'roques',
#  'anti-révolutionnaire',
#  'musicalistes',
#  'amochés',
#  'piratées',
#  'partielles',
#  'nobiliaires',
#  'rectiligne',
#  'acétifiée',
#  'débattu',
#  'abonnataires',
#  'treillissée',
#  'physiognomonique',
#  'agricultrice',
#  'insonorisés',
#  'stationnés',
#  'époutis',
#  'agglutinatif',
#  'butée',
#  'vérolés',
#  'demi-juive',
#  'socialisés',
#  'style',
#  'berkeleyen',
#  'formule',
#  'thérapeutiques',
#  'caqueteuse',
#  'décaféinée',
#  'issu',
#  'oiseleur',
#  'sénescents',
#  'antinatalistes',
#  'cooptée',
#  'bousculeuse',
#  'nickel',
#  'néocapitaliste',
#  'repassés',
#  'exulcéré',
#  'suintant',
#  'prêtées',
#  'recrus',
#  'pontificaux',
#  'révolutionnaires',
#  'quadricœurs',
#  'ambitionnées',
#  'omissions',
#  'contredits',
#  'chélateurs',
#  'communs',
#  'raies',
#  'darnes',
#  'émigré',
#  'enrichie',
#  'néofasciste',
#  'abondant',
#  'gravigrade',
#  'amnistié',
#  'désenchanté',
#  'voies',
#  'égrainés',
#  'râpées',
#  'totémiste',
#  'griffeurs',
#  'traducteurs',
#  'manifestées',
#  'rousseauistes',
#  'avantageuses',
#  'déconnectée',
#  'dilapidatrices',
#  'discounter',
#  'conculcatrice',
#  'microfilaricides',
#  'croisillons',
#  'abotés',
#  'inspirés',
#  'imités',
#  'malbâtis',
#  'arènes',
#  'délirante',
#  'mets',
#  'pâtissière',
#  'entes',
#  'incapables',
#  'homousiens',
#  'annamites',
#  'xylophages',
#  'encordé',
#  'ausonnien',
#  'mésothermes',
#  'conchoïde',
#  'émondés',
#  'apiquée',
#  'tenaillé',
#  'réfléchisseuses',
#  'sphacèles',
#  'grisonne',
#  'tutoyeuse',
#  'frottée',
#  'écossé',
#  'piaillarde',
#  'gainé',
#  'paysages',
#  'exposées',
#  'jaspineuse',
#  'polyparasitée',
#  'galiléenne',
#  'quiétistes',
#  'alambiquée',
#  'cautionnés',
#  'réinterprétée',
#  'ferruginisées',
#  'antépénultième',
#  'dirigeante',
#  'rupine',
#  'comptée',
#  'patentées',
#  'attitré',
#  'vermillonnée',
#  'tamiseuse',
#  'rénovées',
#  'apprivoiseuses',
#  'caribéenne',
#  'courtisées',
#  'manuaire',
#  'criailleuse',
#  'atteinte',
#  'généralistes',
#  'durions',
#  'courant',
#  'grevée',
#  'becqueté',
#  'débectant',
#  'propagatrice',
#  'bateleuse',
#  'indifférente',
#  'étalés',
#  'nimbée',
#  'surveilles',
#  'écossée',
#  'influencés',
#  'sulfites',
#  'bottines',
#  'leptoprosope',
#  'lorrains',
#  'bloqueur',
#  'nuagées',
#  'atlantistes',
#  'viabilisé',
#  'patiné',
#  'attentionné',
#  'visionnée',
#  'sonnée',
#  'abandonnée',
#  'païen',
#  'idolâtrés',
#  'néocrétacique',
#  'canope',
#  'mormone',
#  'assyro-babyloniennes',
#  'ombre',
#  'oeillères',
#  'éradicatrices',
#  'abolitionniste',
#  'précaire',
#  'cooptées',
#  'acense',
#  'cloutée',
#  'rhétiens',
#  'perçu',
#  'artésien',
#  'maléficiées',
#  'hypergéométrique',
#  'kimbanguistes',
#  'rouvieux',
#  'génomique',
#  'catadioptriques',
#  'stabile',
#  'diarrhéiques',
#  'échignées',
#  'redresseuse',
#  'rescisoire',
#  'fixateurs',
#  'comitiale',
#  'exceptionnel',
#  'snob',
#  'pasteurisateurs',
#  'bricole',
#  'tranchées',
#  'discounté',
#  'salutistes',
#  'épargneuse',
#  'continentes',
#  'tonne',
#  'sondeuses',
#  'utilisatrices',
#  'sidérant',
#  'franchouillardes',
#  'prisons',
#  'wallingant',
#  'bordière',
#  'destinatrices',
#  'droit-fil',
#  'tringles',
#  'phonémiques',
#  'athéroscléreuse',
#  'exhumée',
#  'flatteur',
#  'ovulés',
#  'sulfate',
#  'guyanaises',
#  'compactions',
#  'transfigurés',
#  'opalisée',
#  'réhydratée',
#  'ritualisés',
#  'fourragère',
#  'gantoise',
#  'naufragée',
#  'chamaerhinien',
#  'quantièmes',
#  'cardiaque',
#  'diffractions',
#  'aquariens',
#  'laminés',
#  'lunettières',
#  'hautain',
#  'champions',
#  'chamailles',
#  'macrocéphale',
#  'félibres',
#  'traversées',
#  'interrogative',
#  'antiparkinsonien',
#  'transformateurs',
#  'fariboles',
#  'chiffonnes',
#  'inclinée',
#  'fanatisé',
#  'cavaliers',
#  'givre',
#  'tannant',
#  'amnistie',
#  'gauchisant',
#  'constitutionnels',
#  'bosniens',
#  'masculins',
#  'réconfortante',
#  'rondelets',
#  'rétrécie',
#  'rétreinte',
#  'soutenue',
#  'récitées',
#  'démodés',
#  'déliés',
#  'défloculant',
#  'monorchide',
#  'mesmériens',
#  'gallo-grec',
#  'utérin',
#  'retraduite',
#  'populaire',
#  'décrite',
#  'rattachiste',
#  'cerclées',
#  'enrayée',
#  'chevronnée',
#  'rompis',
#  'chamelier',
#  'identificateur',
#  'jaffes',
#  'africain',
#  'autolâtres',
#  'solidarisées',
#  'talibane',
#  'bouillons',
#  'autoconcurrence',
#  'tutoyeuses',
#  'verrée',
#  'sautillant',
#  'rémunératrice',
#  'vidangés',
#  'humble',
#  'important',
#  'finlandais',
#  'nazillonnes',
#  'vicariant',
#  'sous-exploité',
#  'dévaluées',
#  'médianes',
#  'masquées',
#  'légiféré',
#  'rétrofléchi',
#  'rubanière',
#  'horodateur',
#  'désabusée',
#  'embaluchonnées',
#  'épuisés',
#  'marginale',
#  'mesure',
#  'indemnitaires',
#  'anabaptistes',
#  'béguines',
#  'guerrier',
#  'désaccordée',
#  'assouvis',
#  'élastique',
#  'achètes',
#  'finalisée',
#  'réactogènes',
#  'perles',
#  'étrangère',
#  'sixième',
#  'agoniste',
#  'néo-impressionnistes',
#  'mordoré',
#  'recordée',
#  'querelleurs',
#  'excommuniée',
#  'résiné',
#  'adjectives',
#  ...}

# %%
forms = pd.read_csv("top_frequent_NOUN_FlauBERT.csv")
to_remove = [i for i in range(len(forms)) if forms.loc[i,"Word"] in morphalou_ambig]
forms = forms.drop(forms.index[to_remove])
print(forms)

forms.to_csv("top_frequent_pure_NOUN_FlauBERT.csv", index=False)
# Out:
#        Unnamed: 0            Word           lemme cgram genre nombre  \
# 0               0           homme           homme   NOM     m      s
# 1               1          hommes           homme   NOM     m      p
# 2               2            jour            jour   NOM     m      s
# 3               3           jours            jour   NOM     m      p
# 4               5            oeil            oeil   NOM     m      s
# ...           ...             ...             ...   ...   ...    ...
# 11348       48267        éthylène        éthylène   NOM     m      s
# 11349       48269      étiquetage      étiquetage   NOM     m      s
# 11350       48274  évangélisation  évangélisation   NOM     f      s
# 11351       48283       évènement       évènement   NOM     m      s
# 11352       48284      évènements       évènement   NOM     m      p
#
#        freqlemlivres
# 0            1398.85
# 1            1398.85
# 2            1341.76
# 3            1341.76
# 4            1234.59
# ...              ...
# 11348           0.00
# 11349           0.00
# 11350           0.00
# 11351           0.00
# 11352           0.00
#
# [6356 rows x 7 columns]

# %%
forms = pd.read_csv("top_frequent_VERB_FlauBERT.csv")
to_remove = [i for i in range(len(forms)) if forms.loc[i,"Word"] in morphalou_ambig]
forms = forms.drop(forms.index[to_remove])
print(forms)

forms.to_csv("top_frequent_pure_VERB_FlauBERT.csv", index=False)
# Out:
#       Unnamed: 0         Word        lemme cgram  freqlemlivres
# 0              0           es         être   VER       15085.47
# 2              2       furent         être   VER       15085.47
# 3              3          fus         être   VER       15085.47
# 4              5      fussent         être   VER       15085.47
# 7             13         sera         être   VER       15085.47
# ...          ...          ...          ...   ...            ...
# 8976       64773         sais         sais   VER           0.00
# 8980       64876       tiller       tiller   VER           0.00
# 8981       64896  télécharger  télécharger   VER           0.00
# 8982       64900  téléchargez  télécharger   VER           0.00
# 8984       64913       voulez       vouler   VER           0.00
#
# [4216 rows x 5 columns]

# %%
forms = pd.read_csv("top_frequent_ADJ_FlauBERT.csv")
to_remove = [i for i in range(len(forms)) if forms.loc[i,"Word"] in morphalou_ambig]
forms = forms.drop(forms.index[to_remove])
print(forms)

forms.to_csv("top_frequent_pure_ADJ_FlauBERT.csv", index=False)
# Out:
#       Unnamed: 0           Word        lemme    cgram genre  freqlemlivres
# 18            26            sûr          sûr      ADJ     m         412.97
# 19            27           sûrs          sûr      ADJ     m         412.97
# 31            47          aucun        aucun  ADJ:ind     m         180.95
# 44            61          léger        léger      ADJ     m         151.01
# 60            78           cher         cher      ADJ     m         133.65
# ...          ...            ...          ...      ...   ...            ...
# 4801       22068  relationnelle  relationnel      ADJ     f           0.00
# 4803       22087      salariale     salarial      ADJ     f           0.00
# 4804       22108      sociétale     sociétal      ADJ     f           0.00
# 4805       22124   structurelle   structurel      ADJ     f           0.00
# 4807       22168          trine         trin      ADJ     f           0.00
#
# [800 rows x 6 columns]

# %%
# adding number information
import pandas as pd
adj_df = pd.read_csv("top_frequent_pure_ADJ_FlauBERT.csv")
morph = pd.read_csv("../../Morphalou3/data/csv/all_adjectives.csv")
number = []

for form in list(adj_df["Word"]):
    j = 0
    if form == "publique":
            number.append("singular")
    elif form == "publiques":
        number.append("plural")
    else:
        for col in morph.columns:
            
                if col != "lemma" and form in list(morph[col]):
                    if "singular" in col:
                        number.append("singular")
                        j += 1
                    elif "plural" in col:
                        number.append("plural")
                        j += 1
                    else:
                        number.append("invariable")
                        j += 1
    if j > 1:
        print(form)

print(len(number), len(list(adj_df["Word"])))
# Out:
# 800 800

# %%
adj_df["number"] = number

# %%
adj_df.to_csv("top_frequent_pure_ADJ_FlauBERT.csv", index = False)

# %%
adj_df
# Out:
#      Unnamed: 0           Word        lemme    cgram genre  freqlemlivres  \
# 0            26            sûr          sûr      ADJ     m         412.97
# 1            27           sûrs          sûr      ADJ     m         412.97
# 2            47          aucun        aucun  ADJ:ind     m         180.95
# 3            61          léger        léger      ADJ     m         151.01
# 4            78           cher         cher      ADJ     m         133.65
# ..          ...            ...          ...      ...   ...            ...
# 795       22068  relationnelle  relationnel      ADJ     f           0.00
# 796       22087      salariale     salarial      ADJ     f           0.00
# 797       22108      sociétale     sociétal      ADJ     f           0.00
# 798       22124   structurelle   structurel      ADJ     f           0.00
# 799       22168          trine         trin      ADJ     f           0.00
#
#        number
# 0    singular
# 1      plural
# 2    singular
# 3    singular
# 4    singular
# ..        ...
# 795  singular
# 796  singular
# 797  singular
# 798  singular
# 799  singular
#
# [800 rows x 7 columns]

# %% [markdown]
# ## How to access the words ?

# %% [markdown]
# ### Example: most frequent nouns

# %%
import pandas as pd
NOUNS = []

df = pd.read_csv("top_frequent_NOUN.csv", encoding="utf-8")
NOUNS = list(df["Word"])
print(NOUNS[:1000])
# Out:
# ['homme', 'hommes', 'jour', 'jours', 'temps', 'oeil', 'oeils', 'yeux', 'main', 'mains', 'fois', 'chose', 'choses', 'peu', 'femme', 'femmes', 'heure', 'heures', 'tête', 'têtes', 'vie', 'vies', 'coup', 'coups', 'mère', 'mères', 'monde', 'mondes', 'nuit', 'nuits', 'enfant', 'enfants', 'père', 'pères', 'air', 'airs', 'moment', 'moments', 'an', 'ans', 'porte', 'portes', 'voix', 'fille', 'filles', 'maison', 'maisons', 'côté', 'côtés', 'visage', 'visages', 'rue', 'rues', 'soir', 'soirs', 'mot', 'mots', 'bras', 'pied', 'pieds', 'corps', 'place', 'places', 'eau', 'eaux', 'terre', 'terres', 'mort', 'morte', 'mortes', 'morts', 'regard', 'regards', 'chambre', 'chambres', 'gens', 'amour', 'amours', 'coeur', 'coeurs', 'peine', 'peines', 'bout', 'bouts', 'matin', 'matins', 'dieu', 'dieux', 'nom', 'noms', 'table', 'tables', 'fond', 'année', 'années', 'histoire', 'histoires', 'fait', 'faits', 'guerre', 'guerres', 'ami', 'amie', 'amies', 'amis', 'ville', 'villes', 'doute', 'doutes', 'force', 'forces', 'instant', 'instants', 'lit', 'lits', 'soleil', 'soleils', 'pas', 'idée', 'idées', 'question', 'questions', 'silence', 'silences', 'messieurs', 'monsieur', 'point', 'points', 'part', 'parts', 'mur', 'murs', 'fin', 'fins', 'peur', 'peurs', 'raison', 'raisons', 'tour', 'tours', 'sorte', 'sortes', 'ciel', 'ciels', 'mois', 'bois', 'nouveau', 'nouveaux', 'nouvelle', 'nouvelles', 'épaule', 'épaules', 'train', 'trains', 'route', 'routes', 'livre', 'livres', 'bouche', 'bouches', 'voiture', 'voitures', 'bruit', 'bruits', 'tout', 'touts', 'fenêtre', 'fenêtres', 'façon', 'façons', 'pièce', 'pièces', 'suite', 'suites', 'famille', 'familles', 'lumière', 'lumières', 'geste', 'gestes', 'face', 'faces', 'cheveu', 'cheveux', 'lieu', 'lieus', 'lieux', 'besoin', 'besoins', 'travail', 'travaux', 'garçon', 'garçons', 'envie', 'envies', 'mer', 'mers', 'doigt', 'doigts', 'milieu', 'milieux', 'lettre', 'lettres', 'affaire', 'affaires', 'fils', 'travers', 'pays', 'général', 'générale', 'générales', 'généraux', 'feu', 'feux', 'ordre', 'ordres', 'plaisir', 'plaisirs', 'ombre', 'ombres', 'chemin', 'chemins', 'verre', 'verres', 'bord', 'bords', 'lèvre', 'lèvres', 'jambe', 'jambes', 'vent', 'vents', 'état', 'états', 'sens', 'âge', 'âges', 'cas', 'frère', 'frères', 'esprit', 'esprits', 'salle', 'salles', 'sourire', 'sourires', 'dos', 'partie', 'parties', 'personne', 'personnes', 'arbre', 'arbres', 'compte', 'comptes', 'sang', 'sangs', 'chef', 'chefs', 'madame', 'mesdames', 'papier', 'papiers', 'minute', 'minutes', 'coin', 'coins', 'couleur', 'couleurs', 'journal', 'journaux', 'semaine', 'semaines', 'cause', 'causes', 'souvenir', 'souvenirs', 'odeur', 'odeurs', 'argent', 'argents', 'oreille', 'oreilles', 'mal', 'maux', 'effet', 'effets', 'pierre', 'pierres', 'image', 'images', 'peau', 'peaux', 'jardin', 'jardins', 'vieille', 'vieilles', 'vieux', 'chien', 'chienne', 'chiennes', 'chiens', 'type', 'types', 'mouvement', 'mouvements', 'journée', 'journées', 'cheval', 'chevaux', 'parole', 'paroles', 'nez', 'café', 'cafés', 'cours', 'forme', 'formes', 'sac', 'sacs', 'premier', 'premiers', 'première', 'premières', 'jeu', 'jeux', 'long', 'longs', 'petit', 'petite', 'petites', 'petits', 'reste', 'restes', 'français', 'française', 'françaises', 'fleur', 'fleurs', 'droit', 'droits', 'bonheur', 'bonheurs', 'ligne', 'lignes', 'signe', 'signes', 'soeur', 'soeurs', 'front', 'fronts', 'hôtel', 'hôtels', 'retour', 'retours', 'genre', 'genres', 'manière', 'manières', 'sentiment', 'sentiments', 'rire', 'rires', 'cri', 'cris', 'impression', 'impressions', 'habitude', 'habitudes', 'passage', 'passages', 'marche', 'marches', 'âme', 'âmes', 'pensée', 'pensées', 'maître', 'maîtres', 'dame', 'dames', 'sol', 'sols', 'joie', 'joies', 'cour', 'bureau', 'bureaux', 'lendemain', 'lendemains', 'escalier', 'escaliers', 'robe', 'robes', 'armée', 'armées', 'parent', 'parente', 'parentes', 'parents', 'ton', 'tons', 'poche', 'poches', 'église', 'églises', 'maman', 'mamans', 'vue', 'vues', 'village', 'villages', 'éco ...
