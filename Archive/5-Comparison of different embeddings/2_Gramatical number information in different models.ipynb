# %%
import sys
sys.path.append('../Util')

# %%
from evaluation import aabcc, sig_props, correlation, lr, perceptron, kmeans_1dim, \
                     score_comparison, run_tests, report, dimensions_report, repeated_dimensions, \
                    kmeans_multi_dim
from preparation import prepare_dataset, read_datasets

# %%
import pandas as pd
import numpy as np
from scipy.stats import shapiro
import seaborn as sns

# %%
models = [
    {
        'name': 'flaubert/flaubert_small_cased',
        'label': 'flau_small_c'
    },
    {
    
        'name': 'flaubert/flaubert_base_uncased', 
        'label': 'flau_base_u'

    },
    {
        'name': 'flaubert/flaubert_base_cased',
        'label': 'flau_base_c'
    },
    {
        'name': 'flaubert/flaubert_large_cased',
        'label': 'flau_large_c'
    },
    {
        'name': 'camembert/camembert-base',
        'label': 'cam_base'
    }
    
]

# %%
labels = [m['label'] for m in models]

# %% [markdown]
# # Nouns

# %%
we_with_features = read_datasets(
                            path = '../Data',
                            model_labels = labels,
                            file_name = 'all_unique_pos_we.csv'
                    )

# %%
feature_col_count = 6
feature = 'Number'

# %%
we_with_features[0][we_with_features[0].POS == 'NOUN']['Number'].unique()
# Out:
# array(['invariable', 'singular', 'plural'], dtype=object)

# %% [markdown]
# We can also see that `Number` can contain `invariable` values, since our tests are tailored to be binary, we will exclude these words from datasets prior to normalization.

# %%
normalized_dims = []
feature_vectors = []

# %%
for we in we_with_features:
    we = we[we.POS == 'NOUN']
    we_binary = we[we.Number != 'invariable']
    dims, f_vec = prepare_dataset(we_binary, feature_col_count=feature_col_count, feature_name=feature)
    normalized_dims.append(dims)
    feature_vectors.append(f_vec)

# %% [markdown]
# Now we will run our 6 tests (aabcc, sig-props, correlation, logistic regression weights, perceptron weights, Kmeans clustering on one dimension) for each of the models.

# %%
tests = [
    aabcc,
    sig_props,
    correlation,
    lr,
    perceptron,
    kmeans_1dim
]

# %%
all_res = run_tests(tests, normalized_dims, feature_vectors, labels, report_progress=True)
# Out:
# Currently running: AABCC
# 		Model: flau_small_c
# 		Model: flau_base_u
# 		Model: flau_base_c
# 		Model: flau_large_c
# 		Model: cam_base
# Done
# =======================================
# Currently running: SIG_PROPS
# 		Model: flau_small_c
# 		Model: flau_base_u
# 		Model: flau_base_c
# 		Model: flau_large_c
# 		Model: cam_base
# Done
# =======================================
# Currently running: CORRELATION
# 		Model: flau_small_c
# 		Model: flau_base_u
# 		Model: flau_base_c
# 		Model: flau_large_c
# 		Model: cam_base
# Done
# =======================================
# Currently running: LR
# 		Model: flau_small_c
# 		Model: flau_base_u
# 		Model: flau_base_c
# 		Model: flau_large_c
# 		Model: cam_base
# Done
# =======================================
# Currently running: PERCEPTRON
# 		Model: flau_small_c
# 		Model: flau_base_u
# 		Model: flau_base_c
# 		Model: flau_large_c
# 		Model: cam_base
# Done
# =======================================
# Currently running: KMEANS_1DIM
# 		Model: flau_small_c
# 		Model: flau_base_u
# 		Model: flau_base_c
# 		Model: flau_large_c
# 		Model: cam_base
# Done
# =======================================

# %% [markdown]
# Now we can compare the distribution of test results for each test and each model:

# %%
report_df = report(all_res, tests, labels)
report_df
# Out:
#                                Min       Max          Mean           25%  \
# AABCC_flau_small_c           22244     48568  24216.335938  23369.250000
# AABCC_flau_base_u            28853     32313  30457.335938  30078.000000
# AABCC_flau_base_c            22386     34012  23757.272135  23247.500000
# AABCC_flau_large_c           22133     99703  25131.213867  23454.250000
# AABCC_cam_base               21741     26388  23776.319010  23285.750000
# SIG_PROPS_flau_small_c    0.000078  0.106517      0.023430      0.009008
# SIG_PROPS_flau_base_u     0.000007  0.031809      0.008123      0.003207
# SIG_PROPS_flau_base_c     0.000035   0.10563      0.015027      0.005839
# SIG_PROPS_flau_large_c    0.000049  0.148887      0.029722      0.012866
# SIG_PROPS_cam_base        0.000004   0.02249      0.005000      0.001949
# CORRELATION_flau_small_c  0.000258  0.404366      0.083665      0.032684
# CORRELATION_flau_base_u   0.000026  0.112739      0.029733      0.011880
# CORRELATION_flau_base_c   0.000134   0.32531      0.056246      0.023736
# CORRELATION_flau_large_c  0.000174   0.51732      0.108987      0.047400
# CORRELATION_cam_base      0.000011  0.067194      0.014166      0.006165
# LR_flau_small_c            0.00054  2.980269      0.646663      0.271104
# LR_flau_base_u            0.000138  3.712168      0.486681      0.189910
# LR_flau_base_c            0.001491  2.399946      0.566670      0.191291
# LR_flau_large_c           0.002008  2.287712      0.385802      0.145203
# LR_cam_base               0.000496  1.673062      0.381983      0.163306
# PERCEPTRON_flau_small_c   0.012712  0.924224      0.191232      0.071346
# PERCEPTRON_flau_base_u    0.011663  0.234276      0.055035      0.028833
# PERCEPTRON_flau_base_c    0.011715  0.505523      0.086078      0.033647
# PERCEPTRON_flau_large_c   0.008402  0.579863      0.107711      0.042673
# PERCEPTRON_cam_base        0.00953  0.034466      0.020797      0.017172
# KMEANS_1DIM_flau_small_c -0.002063  0.096621      0.006345      0.000273
# KMEANS_1DIM_flau_base_u  -0.015797  0.018775     -0.000130     -0.002616
# KMEANS_1DIM_flau_base_c  -0.021441  0.060955     -0.001289     -0.005770
# KMEANS_1DIM_flau_large_c  -0.00282  0.201408      0.010860      0.000663
# KMEANS_1DIM_cam_base     -0.016562  0.011555     -0.001773     -0.004401
#
#                                    50%           75%           95%  \
# AABCC_flau_small_c        23797.500000  24547.250000  26736.550000
# AABCC_flau_base_u         30423.000000  30860.750000  31388.850000
# AABCC_flau_base_c         23592.000000  24049.000000  25181.350000
# AABCC_flau_large_c        23987.000000  25218.500000  30207.200000
# AABCC_cam_base            23741.500000  24167.250000  24937.600000
# SIG_PROPS_flau_small_c        0.020049      0.033445      0.055108
# SIG_PROPS_flau_base_u         0.006719      0.012186      0.019770
# SIG_PROPS_flau_base_c         0.012248      0.021794      0.037590
# SIG_PROPS_flau_large_c        0.024545      0.040563      0.073748
# SIG_PROPS_cam_base            0.004032      0.007126      0.012639
# CORRELATION_flau_small_c      0.073090      0.119950      0.199987
# CORRELATION_flau_base_u       0.024789      0.044673      0.071472
# CORRELATION_flau_base_c       0.046643      0.080046      0.138225
# CORRELATION_flau_large_c      0.091486      0.150281      0.266850
# CORRELATION_cam_base          0.012244      0.021027      0.033134
# LR_flau_small_c               0.527600      0.910014      1.661750
# LR_flau_base_u                0.397629      0.665331      1.207424
# LR_flau_base_c                0.484337      0.832076      1.426822
# LR_flau_large_c               0.333018      0.552331      0.971634
# LR_cam_base                   0.329758      0.542574      0.904608
# PERCEPTRON_flau_small_c       0.156333      0.274857      0.479956
# PERCEPTRON_flau_base_u        0.046424      0.071397      0.123332
# PERCEPTRON_flau_base_c        0.070993      0.119255      0.200584
# PERCEPTRON_flau_large_c       0.088740      0.148193      0.263174
# PERCEPTRON_cam_base           0.020671      0.024065      0.028948
# KMEANS_1DIM_flau_small_c      0.002776      0.008826      0.024598
# KMEANS_1DIM_flau_base_u      -0.000436      0.001734      0.007511
# KMEANS_1DIM_flau_base_c      -0.001727      0.001243      0.011888
# KMEANS_1DIM_flau_large_c      0.004335      0.012934      0.042689
# KMEANS_1DIM_cam_base         -0.001423      0.000526      0.005359
#
#                                  97.7%         99.9%
# AABCC_flau_small_c        28568.515000  42061.948000
# AABCC_flau_base_u         31665.513000  32247.038000
# AABCC_flau_base_c         25618.055000  30441.615000
# AABCC_flau_large_c        34123.363000  83129.946000
# AABCC_cam_base            25330.103000  26206.988000
# SIG_PROPS_flau_small_c        0.063523      0.101663
# SIG_PROPS_flau_base_u         0.022096      0.030548
# SIG_PROPS_flau_base_c         0.044900      0.084040
# SIG_PROPS_flau_large_c        0.086076      0.141795
# SIG_PROPS_cam_base            0.014400      0.021805
# CORRELATION_flau_small_c      0.232976      0.360566
# CORRELATION_flau_base_u       0.080850      0.110592
# CORRELATION_flau_base_c       0.163537      0.271938
# CORRELATION_flau_large_c      0.318896      0.515780
# CORRELATION_cam_base          0.037364      0.058011
# LR_flau_small_c               1.892819      2.801880
# LR_flau_base_u                1.380499      3.439948
# LR_flau_base_c                1.612699      2.208393
# LR_flau_large_c               1.107169      1.709750
# LR_cam_base                   1.035643      1.493368
# PERCEPTRON_flau_small_c       0.567439      0.892645
# PERCEPTRON_flau_base_u        0.138593      0.221830
# PERCEPTRON_flau_base_c        0.249351      0.458782
# PERCEPTRON_flau_large_c       0.318423      0.494674
# PERCEPTRON_cam_base           0.030527      0.034367
# KMEANS_1DIM_flau_small_c      0.033131      0.076457
# KMEANS_1DIM_flau_base_u       0.009389      0.017142
# KMEANS_1DIM_flau_base_c       0.017161      0.041238
# KMEANS_1DIM_flau_large_c      0.060166      0.163868
# KMEANS_1DIM_cam_base          0.007787      0.011411

# %%
percentile = 99

# %%
dimensions_df = dimensions_report(all_res, tests, labels, percentile)
dimensions_df
# Out:
#                               flau_small_c  \
# AABCC         [310, 54, 288, 243, 285, 81]
# SIG_PROPS     [310, 54, 288, 278, 285, 81]
# CORRELATION   [310, 54, 285, 278, 288, 81]
# LR           [310, 158, 54, 359, 208, 182]
# PERCEPTRON   [158, 54, 310, 285, 172, 420]
# KMEANS_1DIM  [310, 54, 243, 285, 288, 278]
#
#                                           flau_base_u  \
# AABCC          [234, 419, 316, 538, 687, 191, 27, 56]
# SIG_PROPS       [687, 384, 27, 11, 133, 626, 538, 77]
# CORRELATION     [687, 384, 11, 27, 133, 538, 431, 81]
# LR           [626, 402, 191, 473, 316, 252, 293, 356]
# PERCEPTRON      [626, 687, 11, 402, 56, 706, 431, 27]
# KMEANS_1DIM      [384, 27, 81, 687, 431, 23, 96, 127]
#
#                                           flau_base_c  \
# AABCC        [238, 594, 176, 343, 180, 466, 509, 125]
# SIG_PROPS     [238, 594, 672, 176, 82, 117, 180, 466]
# CORRELATION  [238, 594, 176, 466, 325, 125, 467, 180]
# LR            [205, 594, 77, 580, 292, 274, 717, 191]
# PERCEPTRON   [238, 176, 672, 594, 127, 466, 268, 148]
# KMEANS_1DIM   [238, 682, 176, 127, 509, 34, 610, 620]
#
#                                                   flau_large_c  \
# AABCC        [296, 691, 1022, 556, 576, 641, 591, 238, 243,...
# SIG_PROPS    [691, 576, 296, 556, 238, 641, 591, 1022, 703,...
# CORRELATION  [576, 691, 641, 296, 556, 238, 591, 703, 1022,...
# LR           [576, 352, 851, 691, 387, 486, 103, 137, 185, ...
# PERCEPTRON   [576, 691, 556, 634, 370, 508, 921, 373, 1015,...
# KMEANS_1DIM  [691, 576, 641, 296, 703, 238, 556, 591, 1022,...
#
#                                              cam_base
# AABCC          [233, 384, 547, 41, 42, 572, 339, 147]
# SIG_PROPS      [24, 100, 374, 309, 119, 714, 485, 57]
# CORRELATION    [24, 374, 485, 294, 595, 758, 57, 404]
# LR            [58, 327, 345, 580, 374, 118, 661, 275]
# PERCEPTRON   [340, 409, 227, 628, 517, 705, 359, 762]
# KMEANS_1DIM  [309, 100, 714, 467, 272, 348, 717, 577]

# %%
repeated_dimensions_df = repeated_dimensions(dimensions_df, labels)

# %%
repeated_dimensions_df
# Out:
#                                                          1 test  \
# flau_small_c  [54, 81, 158, 172, 182, 208, 243, 278, 285, 28...
# flau_base_u   [11, 23, 27, 56, 77, 81, 96, 127, 133, 191, 23...
# flau_base_c   [34, 77, 82, 117, 125, 127, 148, 176, 180, 191...
# flau_large_c  [103, 137, 185, 238, 243, 296, 352, 370, 373, ...
# cam_base      [24, 41, 42, 57, 58, 100, 118, 119, 147, 227, ...
#
#                                                         2 tests  \
# flau_small_c             [54, 81, 158, 243, 278, 285, 288, 310]
# flau_base_u   [11, 27, 56, 81, 133, 191, 316, 384, 402, 431,...
# flau_base_c       [125, 127, 176, 180, 238, 466, 509, 594, 672]
# flau_large_c  [238, 296, 370, 373, 505, 556, 576, 591, 641, ...
# cam_base                      [24, 57, 100, 309, 374, 485, 714]
#
#                                                         3 tests  \
# flau_small_c                       [54, 81, 278, 285, 288, 310]
# flau_base_u                   [11, 27, 384, 431, 538, 626, 687]
# flau_base_c                           [176, 180, 238, 466, 594]
# flau_large_c  [238, 296, 505, 556, 576, 591, 641, 691, 703, ...
# cam_base                                                  [374]
#
#                                                      4 tests          5 tests  \
# flau_small_c                             [54, 285, 288, 310]   [54, 285, 310]
# flau_base_u                                        [27, 687]        [27, 687]
# flau_base_c                             [176, 238, 466, 594]  [176, 238, 594]
# flau_large_c  [238, 296, 556, 576, 591, 641, 691, 703, 1022]  [556, 576, 691]
# cam_base                                                  []               []
#
#                  6 tests
# flau_small_c   [54, 310]
# flau_base_u           []
# flau_base_c           []
# flau_large_c  [576, 691]
# cam_base              []

# %%
ari_scores_df = pd.DataFrame(columns = ['All_dims', '1_dim_best', 
                                        '1_test_dims', '2_test_dims',
                                        '3_test_dims', '4_test_dims',
                                        '5_test_dims', '6_test_dims'
                                       ])

# %%
for i in range(len(labels)):
    model = labels[i]
    n_dims = len(all_res[0][i])
    ari_scores_df.loc[model] = {
        'All_dims' : kmeans_multi_dim(normalized_dims[i], list(range(n_dims)), feature_vectors[i]), 
        '1_dim_best': all_res[-1][i][0][1], 
        '1_test_dims': kmeans_multi_dim(normalized_dims[i], repeated_dimensions_df.loc[model]['1 test'], feature_vectors[i]), 
        '2_test_dims': kmeans_multi_dim(normalized_dims[i], repeated_dimensions_df.loc[model]['2 tests'], feature_vectors[i]),
        '3_test_dims': kmeans_multi_dim(normalized_dims[i], repeated_dimensions_df.loc[model]['3 tests'], feature_vectors[i]),
        '4_test_dims': kmeans_multi_dim(normalized_dims[i], repeated_dimensions_df.loc[model]['4 tests'], feature_vectors[i]),
        '5_test_dims': kmeans_multi_dim(normalized_dims[i], repeated_dimensions_df.loc[model]['5 tests'], feature_vectors[i]),
        '6_test_dims': kmeans_multi_dim(normalized_dims[i], repeated_dimensions_df.loc[model]['6 tests'], feature_vectors[i]),
    }

# %%
ari_scores_df
# Out:
#               All_dims  1_dim_best  1_test_dims  2_test_dims  3_test_dims  \
# flau_small_c  0.004134    0.096621     0.151337     0.179701     0.258801
# flau_base_u   0.003068    0.018775     0.000150     0.002399     0.011314
# flau_base_c   0.000692    0.060955     0.014000     0.114666     0.108591
# flau_large_c  0.018905    0.201408     0.646613     0.609155     0.534539
# cam_base      0.011367    0.011555     0.011367     0.011367    -0.009612
#
#               4_test_dims  5_test_dims  6_test_dims
# flau_small_c     0.197642     0.157240     0.120284
# flau_base_u      0.023658     0.023658          NaN
# flau_base_c      0.125442     0.102629          NaN
# flau_large_c     0.514189     0.316251     0.350003
# cam_base              NaN          NaN          NaN

# %% [markdown]
# # Adjectives

# %% [markdown]
# We can now repeat the experiment for Adjectives.

# %%
normalized_dims = []
feature_vectors = []

# %%
for we in we_with_features:
    we = we[we.POS == 'ADJ']
    we_binary = we[we.Number != 'invariable']
    dims, f_vec = prepare_dataset(we_binary, feature_col_count=feature_col_count, feature_name=feature)
    normalized_dims.append(dims)
    feature_vectors.append(f_vec)

# %%
all_res_adj = run_tests(tests, normalized_dims, feature_vectors, labels, report_progress=True)
# Out:
# Currently running: AABCC
# 		Model: flau_small_c
# 		Model: flau_base_u
# 		Model: flau_base_c
# 		Model: flau_large_c
# 		Model: cam_base
# Done
# =======================================
# Currently running: SIG_PROPS
# 		Model: flau_small_c
# 		Model: flau_base_u
# 		Model: flau_base_c
# 		Model: flau_large_c
# 		Model: cam_base
# Done
# =======================================
# Currently running: CORRELATION
# 		Model: flau_small_c
# 		Model: flau_base_u
# 		Model: flau_base_c
# 		Model: flau_large_c
# 		Model: cam_base
# Done
# =======================================
# Currently running: LR
# 		Model: flau_small_c
# 		Model: flau_base_u
# 		Model: flau_base_c
# 		Model: flau_large_c
# 		Model: cam_base
# Done
# =======================================
# Currently running: PERCEPTRON
# 		Model: flau_small_c
# 		Model: flau_base_u
# 		Model: flau_base_c
# 		Model: flau_large_c
# 		Model: cam_base
# Done
# =======================================
# Currently running: KMEANS_1DIM
# 		Model: flau_small_c
# 		Model: flau_base_u
# 		Model: flau_base_c
# 		Model: flau_large_c
# 		Model: cam_base
# Done
# =======================================

# %%
report_adj_df = report(all_res_adj, tests, labels)
report_adj_df
# Out:
#                                Min       Max         Mean          25%  \
# AABCC_flau_small_c            5205      8481  5867.908203  5658.500000
# AABCC_flau_base_u             6242      7375  6773.348958  6652.750000
# AABCC_flau_base_c             5307      7936  5801.888021  5653.750000
# AABCC_flau_large_c            5276     20939  6030.698242  5688.750000
# AABCC_cam_base                5902      9829  6942.095052  6624.000000
# SIG_PROPS_flau_small_c    0.000271  0.112395     0.027404     0.011423
# SIG_PROPS_flau_base_u     0.000013  0.042709     0.008828     0.003423
# SIG_PROPS_flau_base_c     0.000039  0.100737     0.017824     0.006774
# SIG_PROPS_flau_large_c    0.000059   0.16405     0.031920     0.012833
# SIG_PROPS_cam_base        0.000054  0.092014     0.020008     0.007883
# CORRELATION_flau_small_c  0.000922  0.407669     0.094481     0.039050
# CORRELATION_flau_base_u   0.000054  0.156603     0.033227     0.012657
# CORRELATION_flau_base_c   0.000155  0.358808     0.066143     0.026364
# CORRELATION_flau_large_c  0.000211  0.539636     0.115670     0.045973
# CORRELATION_cam_base      0.000167  0.138874     0.049872     0.023796
# LR_flau_small_c           0.001205  2.295846     0.447242     0.171542
# LR_flau_base_u            0.000203  1.763705     0.406207     0.170191
# LR_flau_base_c              0.0016  1.980098     0.429624     0.154831
# LR_flau_large_c           0.000133   1.56719     0.284666     0.106852
# LR_cam_base               0.000052  1.332394     0.312949     0.114271
# PERCEPTRON_flau_small_c   0.010479  0.428661     0.097471     0.040268
# PERCEPTRON_flau_base_u     0.00942  0.256338     0.044045     0.021072
# PERCEPTRON_flau_base_c    0.008608  0.267683     0.056123     0.023521
# PERCEPTRON_flau_large_c   0.004843  0.283612     0.065473     0.027132
# PERCEPTRON_cam_base       0.007746  0.034432     0.020069     0.017077
# KMEANS_1DIM_flau_small_c -0.001304  0.115765     0.008395     0.000345
# KMEANS_1DIM_flau_base_u  -0.008724   0.02733     0.001655    -0.001853
# KMEANS_1DIM_flau_base_c  -0.011257  0.098172     0.001345    -0.002381
# KMEANS_1DIM_flau_large_c -0.001302   0.25373     0.014058     0.000952
# KMEANS_1DIM_cam_base     -0.026407  0.055561     0.014702     0.006392
#
#                                   50%          75%          95%        97.7%  \
# AABCC_flau_small_c        5806.500000  5975.750000  6466.600000  6667.820000
# AABCC_flau_base_u         6763.000000  6880.500000  7082.000000  7155.154000
# AABCC_flau_base_c         5771.500000  5906.500000  6205.900000  6343.872000
# AABCC_flau_large_c        5859.500000  6085.750000  7015.050000  7684.448000
# AABCC_cam_base            6887.000000  7195.250000  7776.000000  8108.129000
# SIG_PROPS_flau_small_c       0.023514     0.039546     0.065579     0.075119
# SIG_PROPS_flau_base_u        0.007321     0.012847     0.021420     0.025335
# SIG_PROPS_flau_base_c        0.014787     0.025342     0.044941     0.049363
# SIG_PROPS_flau_large_c       0.027471     0.045430     0.076536     0.090656
# SIG_PROPS_cam_base           0.016227     0.027982     0.049259     0.061104
# CORRELATION_flau_small_c     0.080578     0.137247     0.225524     0.250058
# CORRELATION_flau_base_u      0.027508     0.048448     0.080142     0.094650
# CORRELATION_flau_base_c      0.056111     0.093447     0.161833     0.186561
# CORRELATION_flau_large_c     0.100587     0.164817     0.273187     0.328441
# CORRELATION_cam_base         0.047589     0.072086     0.102314     0.112922
# LR_flau_small_c              0.365617     0.652796     1.107821     1.443881
# LR_flau_base_u               0.340401     0.577221     0.996484     1.131574
# LR_flau_base_c               0.362436     0.637426     1.045087     1.198908
# LR_flau_large_c              0.222844     0.408465     0.741545     0.899813
# LR_cam_base                  0.265935     0.441697     0.805911     0.954083
# PERCEPTRON_flau_small_c      0.079999     0.141195     0.228023     0.265386
# PERCEPTRON_flau_base_u       0.034131     0.059925     0.105386     0.119937
# PERCEPTRON_flau_base_c       0.044217     0.077676     0.130301     0.153652
# PERCEPTRON_flau_large_c      0.052604     0.090737     0.158287     0.188484
# PERCEPTRON_cam_base          0.019871     0.022588     0.027810     0.029637
# KMEANS_1DIM_flau_small_c     0.003876     0.011739     0.032291     0.042086
# KMEANS_1DIM_flau_base_u      0.000553     0.004262     0.010864     0.013707
# KMEANS_1DIM_flau_base_c     -0.000340     0.002591     0.013817     0.021276
# KMEANS_1DIM_flau_large_c     0.006166     0.016893     0.050920     0.077034
# KMEANS_1DIM_cam_base         0.014167     0.022577     0.037803     0.042734
#
#                                  99.9%
# AABCC_flau_small_c         7891.306000
# AABCC_flau_base_u          7316.708000
# AABCC_flau_base_c          7613.860000
# AABCC_flau_large_c        15593.919000
# AABCC_cam_base             9056.631000
# SIG_PROPS_flau_small_c        0.101266
# SIG_PROPS_flau_base_u         0.036916
# SIG_PROPS_flau_base_c         0.094704
# SIG_PROPS_flau_large_c        0.156243
# SIG_PROPS_cam_base            0.091020
# CORRELATION_flau_small_c      0.367523
# CORRELATION_flau_base_u       0.138704
# CORRELATION_flau_base_c       0.319588
# CORRELATION_flau_large_c      0.524112
# CORRELATION_cam_base          0.135298
# LR_flau_small_c               2.144385
# LR_flau_base_u                1.596261
# LR_flau_base_c                1.614768
# LR_flau_large_c               1.349987
# LR_cam_base                   1.299391
# PERCEPTRON_flau_small_c       0.386740
# PERCEPTRON_flau_base_u        0.192263
# PERCEPTRON_flau_base_c        0.245320
# PERCEPTRON_flau_large_c       0.281767
# PERCEPTRON_cam_base           0.034085
# KMEANS_1DIM_flau_small_c      0.100371
# KMEANS_1DIM_flau_base_u       0.027217
# KMEANS_1DIM_flau_base_c       0.055993
# KMEANS_1DIM_flau_large_c      0.225688
# KMEANS_1DIM_cam_base          0.054584

# %%
dimensions_adj_df = dimensions_report(all_res_adj, tests, labels, percentile)
dimensions_adj_df
# Out:
#                               flau_small_c  \
# AABCC         [310, 360, 54, 81, 250, 477]
# SIG_PROPS     [310, 54, 250, 81, 477, 360]
# CORRELATION  [310, 54, 250, 360, 477, 384]
# LR           [310, 54, 359, 384, 250, 285]
# PERCEPTRON   [310, 54, 285, 445, 477, 172]
# KMEANS_1DIM   [310, 54, 250, 360, 477, 81]
#
#                                           flau_base_u  \
# AABCC        [629, 282, 608, 477, 268, 516, 186, 329]
# SIG_PROPS     [687, 127, 635, 81, 218, 145, 580, 221]
# CORRELATION   [687, 127, 635, 499, 81, 524, 221, 218]
# LR             [687, 706, 252, 763, 598, 635, 27, 97]
# PERCEPTRON      [687, 706, 580, 198, 11, 81, 221, 29]
# KMEANS_1DIM    [687, 127, 85, 499, 72, 700, 635, 615]
#
#                                           flau_base_c  \
# AABCC         [594, 238, 163, 180, 467, 199, 127, 23]
# SIG_PROPS     [238, 594, 180, 82, 117, 467, 199, 672]
# CORRELATION   [238, 594, 180, 467, 34, 163, 176, 253]
# LR             [36, 597, 507, 82, 292, 253, 594, 290]
# PERCEPTRON   [238, 176, 290, 127, 169, 594, 467, 509]
# KMEANS_1DIM  [238, 176, 127, 467, 675, 264, 495, 175]
#
#                                                   flau_large_c  \
# AABCC        [576, 556, 296, 641, 1022, 691, 634, 161, 928,...
# SIG_PROPS    [576, 691, 641, 556, 296, 1022, 161, 921, 783,...
# CORRELATION  [576, 556, 641, 296, 691, 1022, 161, 634, 921,...
# LR           [556, 1022, 638, 641, 576, 787, 250, 452, 237,...
# PERCEPTRON   [556, 641, 576, 691, 1022, 161, 928, 787, 591,...
# KMEANS_1DIM  [556, 576, 691, 1022, 641, 296, 161, 921, 591,...
#
#                                              cam_base
# AABCC         [567, 118, 419, 188, 39, 442, 267, 362]
# SIG_PROPS      [100, 272, 309, 459, 714, 3, 467, 153]
# CORRELATION    [233, 153, 459, 643, 3, 536, 602, 512]
# LR           [268, 459, 235, 369, 655, 587, 323, 482]
# PERCEPTRON    [173, 139, 436, 542, 38, 637, 435, 478]
# KMEANS_1DIM  [741, 211, 472, 709, 675, 169, 208, 615]

# %%
repeated_dimensions_adj_df = repeated_dimensions(dimensions_adj_df, labels)
repeated_dimensions_adj_df
# Out:
#                                                          1 test  \
# flau_small_c  [54, 81, 172, 250, 285, 310, 359, 360, 384, 44...
# flau_base_u   [11, 27, 29, 72, 81, 85, 97, 127, 145, 186, 19...
# flau_base_c   [23, 34, 36, 82, 117, 127, 163, 169, 175, 176,...
# flau_large_c  [147, 161, 237, 243, 250, 296, 330, 352, 452, ...
# cam_base      [3, 38, 39, 100, 118, 139, 153, 169, 173, 188,...
#
#                                                         2 tests  \
# flau_small_c             [54, 81, 250, 285, 310, 360, 384, 477]
# flau_base_u        [81, 127, 218, 221, 499, 580, 635, 687, 706]
# flau_base_c   [82, 127, 163, 176, 180, 199, 238, 253, 290, 4...
# flau_large_c  [161, 243, 296, 556, 576, 591, 634, 641, 691, ...
# cam_base                                          [3, 153, 459]
#
#                                                         3 tests  \
# flau_small_c                       [54, 81, 250, 310, 360, 477]
# flau_base_u                            [81, 127, 221, 635, 687]
# flau_base_c                      [127, 176, 180, 238, 467, 594]
# flau_large_c  [161, 296, 556, 576, 591, 634, 641, 691, 783, ...
# cam_base                                                  [459]
#
#                                            4 tests  \
# flau_small_c              [54, 250, 310, 360, 477]
# flau_base_u                             [635, 687]
# flau_base_c                        [238, 467, 594]
# flau_large_c  [161, 296, 556, 576, 641, 691, 1022]
# cam_base                                        []
#
#                                       5 tests                6 tests
# flau_small_c              [54, 250, 310, 477]              [54, 310]
# flau_base_u                             [687]                     []
# flau_base_c                   [238, 467, 594]                     []
# flau_large_c  [161, 556, 576, 641, 691, 1022]  [556, 576, 641, 1022]
# cam_base                                   []                     []

# %%
ari_scores_adj_df = pd.DataFrame(columns = ['All_dims', '1_dim_best', 
                                        '1_test_dims', '2_test_dims',
                                        '3_test_dims', '4_test_dims',
                                        '5_test_dims', '6_test_dims'
                                       ])

# %%
for i in range(len(labels)):
    model = labels[i]
    n_dims = len(all_res[0][i])
    ari_scores_adj_df.loc[model] = {
        'All_dims' : kmeans_multi_dim(normalized_dims[i], list(range(n_dims)), feature_vectors[i]), 
        '1_dim_best': all_res_adj[-1][i][0][1], 
        '1_test_dims': kmeans_multi_dim(normalized_dims[i], repeated_dimensions_adj_df.loc[model]['1 test'], feature_vectors[i]), 
        '2_test_dims': kmeans_multi_dim(normalized_dims[i], repeated_dimensions_adj_df.loc[model]['2 tests'], feature_vectors[i]),
        '3_test_dims': kmeans_multi_dim(normalized_dims[i], repeated_dimensions_adj_df.loc[model]['3 tests'], feature_vectors[i]),
        '4_test_dims': kmeans_multi_dim(normalized_dims[i], repeated_dimensions_adj_df.loc[model]['4 tests'], feature_vectors[i]),
        '5_test_dims': kmeans_multi_dim(normalized_dims[i], repeated_dimensions_adj_df.loc[model]['5 tests'], feature_vectors[i]),
        '6_test_dims': kmeans_multi_dim(normalized_dims[i], repeated_dimensions_adj_df.loc[model]['6 tests'], feature_vectors[i]),
    }

# %%
ari_scores_adj_df
# Out:
#               All_dims  1_dim_best  1_test_dims  2_test_dims  3_test_dims  \
# flau_small_c  0.002865    0.115765     0.408764     0.223059     0.379892
# flau_base_u  -0.003180    0.027330     0.024735    -0.003837     0.039666
# flau_base_c   0.002051    0.098172     0.016122     0.026081     0.127452
# flau_large_c -0.002011    0.253730     0.693412     0.627352     0.627302
# cam_base     -0.026407    0.055561    -0.026407    -0.025258    -0.005929
#
#               4_test_dims  5_test_dims  6_test_dims
# flau_small_c     0.163161     0.218003     0.142799
# flau_base_u      0.030349     0.027330          NaN
# flau_base_c      0.132977     0.132977          NaN
# flau_large_c     0.585543     0.589016     0.511710
# cam_base              NaN          NaN          NaN

# %% [markdown]
# For all FlauBERT models we see clustering quality improvement when using dimensions appearing in 99th percentile of test results. On FlauBERTlarge  ARI metric reaches 0.6+ which can be a sign of a good clustering.
#
# However, for CamemBERT the highest ARI scores are seen on one dimension only and they stay pretty low.
