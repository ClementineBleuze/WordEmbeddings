# %%
# !pip install transformers
# !pip install sacremoses
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting transformers
#   Downloading transformers-4.26.1-py3-none-any.whl (6.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 66.9 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.8/dist-packages (from transformers) (3.9.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.8/dist-packages (from transformers) (6.0)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1
#   Downloading tokenizers-0.13.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 82.5 MB/s eta 0:00:00
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from transformers) (23.0)
# Collecting huggingface-hub<1.0,>=0.11.0
#   Downloading huggingface_hub-0.12.1-py3-none-any.whl (190 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.3/190.3 KB 19.9 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.8/dist-packages (from transformers) (1.22.4)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.8/dist-packages (from transformers) (2022.6.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from transformers) (2.25.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.8/dist-packages (from transformers) (4.64.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.8/dist-packages (from huggingface-hub<1.0,>=0.11.0->transformers) (4.5.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests->transformers) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests->transformers) (4.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests->transformers) (2022.12.7)
# Installing collected packages: tokenizers, huggingface-hub, transformers
# Successfully installed huggingface-hub-0.12.1 tokenizers-0.13.2 transformers-4.26.1
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting sacremoses
#   Downloading sacremoses-0.0.53.tar.gz (880 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 880.6/880.6 KB 18.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: regex in /usr/local/lib/python3.8/dist-packages (from sacremoses) (2022.6.2)
# Requirement already satisfied: six in /usr/local/lib/python3.8/dist-packages (from sacremoses) (1.15.0)
# Requirement already satisfied: click in /usr/local/lib/python3.8/dist-packages (from sacremoses) (7.1.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.8/dist-packages (from sacremoses) (1.2.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.8/dist-packages (from sacremoses) (4.64.1)
# Building wheels for collected packages: sacremoses
#   Building wheel for sacremoses (setup.py) ... done
#   Created wheel for sacremoses: filename=sacremoses-0.0.53-py3-none-any.whl size=895260 sha256=ceafc31124556bddae6a5149788684778190de710f6dfa613bec7b794499f456
#   Stored in directory: /root/.cache/pip/wheels/82/ab/9b/c15899bf659ba74f623ac776e861cf2eb8608c1825ddec66a4
# Successfully built sacremoses
# Installing collected packages: sacremoses
# Successfully installed sacremoses-0.0.53

# %%
import xml.etree.ElementTree as et
import pandas as pd
# %matplotlib inline

# %%
xtree = et.parse("data/Morphalou3_formatLMF/verb_Morphalou3_LMF.xml")
xroot = xtree.getroot()

# %%
dict_list = []
counter = 0

for le in xroot.iter('lexicalEntry'):
    le_dict = {}
    for lemma in le.iter('lemmatizedForm'):
        le_dict['lemma'] = lemma.find('orthography').text
       
        
    for form in le.iter('inflectedForm'):
        try:
            gn = form.find('grammaticalNumber').text  
        
        except:
            pass
        
        try:
            gm = form.find('grammaticalMood').text
       
        except:
            pass

        try:
            gt = form.find('grammaticalTense').text
            
        except:
            pass
        
        try:
            gp = form.find('grammaticalPerson').text
            
        except:
            pass
        try:
            gg=form.find('grammaticalGender').text
           
        except:
            pass

        try:
            le_dict[gn,gm,gt,gp,gg] = form.find('orthography').text
        except:
            pass
        
       
    
    dict_list.append(le_dict)
    counter += 1
    if counter % 1000 == 0:
        print('.', end='')

# %%
verbs_df = pd.DataFrame(dict_list)
verbs_df

# %%
verbs_df.to_csv('all_verbs.csv')

# %%
import sys
sys.path.append('../FlauBERT')

# %%
from we import *

# %%
model, tokenizer, log = initiate_model()
# Out:
# Downloading (…)lve/main/config.json:   0%|          | 0.00/1.49k [00:00<?, ?B/s]
# Downloading (…)"pytorch_model.bin";:   0%|          | 0.00/218M [00:00<?, ?B/s]
# Some weights of the model checkpoint at flaubert/flaubert_small_cased were not used when initializing FlaubertModel: ['pred_layer.proj.weight', 'pred_layer.proj.bias']
# - This IS expected if you are initializing FlaubertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing FlaubertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Downloading (…)olve/main/vocab.json:   0%|          | 0.00/1.56M [00:00<?, ?B/s]
# Downloading (…)olve/main/merges.txt:   0%|          | 0.00/896k [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/28.0 [00:00<?, ?B/s]

# %%
df = pd.read_csv('all_verbs.csv')
df
# Out:
# /usr/local/lib/python3.8/dist-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (125,127,129,130,134,136,137,143,144,145,147,148,149,150,151,152,153,154,155,156,157,158,159,160,161,162,163,164,165,166,167,168,169,170,171,172,173,174,175,176,177,178,179,180,181,182,183,184,185,186,187,188,189,190,191,192,193,194,195,196,197,198,199,200,201,202,203,204,205,206,207,208,209,210,211,212,213,214,215,216) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#        Unnamed: 0        lemma  \
# 0               0     abaisser
# 1               1     abalober
# 2               2   abalourdir
# 3               3   abandonner
# 4               4   abasourdir
# ...           ...          ...
# 14757       14757       îloter
# 14758       14758         ôter
# 14759       14759       œiller
# 14760       14760  œilletonner
# 14761       14761       œuvrer
#
#       ('plural', 'participle', 'past', 'thirdPerson', 'masculine')  \
# 0                                               abaissés
# 1                                               abalobés
# 2                                                    NaN
# 3                                             abandonnés
# 4                                                    NaN
# ...                                                  ...
# 14757                                             îlotés
# 14758                                                NaN
# 14759                                                NaN
# 14760                                        œilletonnés
# 14761                                                NaN
#
#       ('singular', 'participle', 'past', 'thirdPerson', 'masculine')  \
# 0                                                abaissé
# 1                                                abalobé
# 2                                                    NaN
# 3                                              abandonné
# 4                                                    NaN
# ...                                                  ...
# 14757                                              îloté
# 14758                                                NaN
# 14759                                                NaN
# 14760                                         œilletonné
# 14761                                                NaN
#
#       ('singular', 'participle', 'past', 'thirdPerson', 'feminine')  \
# 0                                               abaissée
# 1                                               abalobée
# 2                                                    NaN
# 3                                             abandonnée
# 4                                                    NaN
# ...                                                  ...
# 14757                                             îlotée
# 14758                                                NaN
# 14759                                                NaN
# 14760                                        œilletonnée
# 14761                                                NaN
#
#       ('plural', 'participle', 'past', 'thirdPerson', 'feminine')  \
# 0                                              abaissées
# 1                                              abalobées
# 2                                                    NaN
# 3                                            abandonnées
# 4                                                    NaN
# ...                                                  ...
# 14757                                            îlotées
# 14758                                                NaN
# 14759                                                NaN
# 14760                                       œilletonnées
# 14761                                                NaN
#
#       ('singular', 'indicative', 'simplePast', 'thirdPerson', 'feminine')  \
# 0                                                    NaN
# 1                                                abaloba
# 2                                             abalourdit
# 3                                                    NaN
# 4                                             abasourdit
# ...                                                  ...
# 14757                                                NaN
# 14758                                                NaN
# 14759                                              œilla
# 14760                                         œilletonna
# 14761                                                NaN
#
#       ('singular', 'indicative', 'simplePast', 'firstPerson', 'feminine')  \
# 0                                                    NaN
# 1                                               abalobai
# 2                                             abalourdis
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 14757                                                NaN
# 14758                                                NaN
# 14759                                             œillai
# 14760                                        œilletonnai
# 14761                                                NaN
#
#       ('plural', 'indicative', 'imperfect', 'thirdPerson', 'feminine')  \
# 0                                                    NaN
# 1                                            abalobaient
# 2                                       abalourdissaient
# 3                                                    NaN
# 4                                       abasourdissaient
# ...                                                  ...
# 14757                                                NaN
# 14758                                                NaN
# 14759                                          œillaient
# 14760                                     œilletonnaient
# 14761                                                NaN
#
#       ('singular', 'indicative', 'imperfect', 'firstPerson', 'feminine')  ...  \
# 0                                                    NaN                  ...
# 1                                              abalobais                  ...
# 2                                         abalourdissais                  ...
# 3                                                    NaN                  ...
# 4                                                    NaN                  ...
# ...                                                  ...                  ...
# 14757                                                NaN                  ...
# 14758                                                NaN                  ...
# 14759                                            œillais                  ...
# 14760                                       œilletonnais                  ...
# 14761                                                NaN                  ...
#
#       ('invariable', 'participle', 'present', 'thirdPerson', 'invariable')  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 14757                                                NaN
# 14758                                                NaN
# 14759                                                NaN
# 14760                                                NaN
# 14761                                                NaN
#
#       ('plural', 'infinitive', 'imperfect', 'firstPerson', 'invariable')  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 14757                                                NaN
# 14758                                                NaN
# 14759                                                NaN
# 14760                                                NaN
# 14761                                                NaN
#
#       ('invariable', 'indicative', 'present', 'thirdPerson', 'masculine')  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 14757                                                NaN
# 14758                                                NaN
# 14759                                                NaN
# 14760                                                NaN
# 14761                                                NaN
#
#       ('invariable', 'infinitive', 'present', 'thirdPerson', 'masculine')  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 14757                                                NaN
# 14758                                                NaN
# 14759                                                NaN
# 14760                                                NaN
# 14761                                                NaN
#
#       ('plural', 'participle', 'present', 'secondPerson', 'feminine')  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 14757                                                NaN
# 14758                                                NaN
# 14759                                                NaN
# 14760                                                NaN
# 14761                                                NaN
#
#       ('singular', 'infinitive', 'imperfect', 'thirdPerson', 'feminine')  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 14757                                                NaN
# 14758                                                NaN
# 14759                                                NaN
# 14760                                                NaN
# 14761                                                NaN
#
#       ('plural', 'infinitive', 'past', 'firstPerson', 'masculine')  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 14757                                                NaN
# 14758                                                NaN
# 14759                                                NaN
# 14760                                                NaN
# 14761                                                NaN
#
#       ('invariable', 'infinitive', 'past', 'secondPerson', 'invariable')  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 14757                                                NaN
# 14758                                                NaN
# 14759                                                NaN
# 14760                                                NaN
# 14761                                                NaN
#
#       ('invariable', 'indicative', 'present', 'thirdPerson', 'feminine')  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 14757                                                NaN
# 14758                                                NaN
# 14759                                                NaN
# 14760                                                NaN
# 14761                                                NaN
#
#       ('plural', 'infinitive', 'present', 'secondPerson', 'invariable')
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 14757                                                NaN
# 14758                                                NaN
# 14759                                                NaN
# 14760                                                NaN
# 14761                                                NaN
#
# [14762 rows x 217 columns]

# %%
df.__delitem__('Unnamed: 0')

# %%
df.fillna('', inplace=True)
df
# Out:
#              lemma  \
# 0         abaisser
# 1         abalober
# 2       abalourdir
# 3       abandonner
# 4       abasourdir
# ...            ...
# 14757       îloter
# 14758         ôter
# 14759       œiller
# 14760  œilletonner
# 14761       œuvrer
#
#       ('plural', 'participle', 'past', 'thirdPerson', 'masculine')  \
# 0                                               abaissés
# 1                                               abalobés
# 2
# 3                                             abandonnés
# 4
# ...                                                  ...
# 14757                                             îlotés
# 14758
# 14759
# 14760                                        œilletonnés
# 14761
#
#       ('singular', 'participle', 'past', 'thirdPerson', 'masculine')  \
# 0                                                abaissé
# 1                                                abalobé
# 2
# 3                                              abandonné
# 4
# ...                                                  ...
# 14757                                              îloté
# 14758
# 14759
# 14760                                         œilletonné
# 14761
#
#       ('singular', 'participle', 'past', 'thirdPerson', 'feminine')  \
# 0                                               abaissée
# 1                                               abalobée
# 2
# 3                                             abandonnée
# 4
# ...                                                  ...
# 14757                                             îlotée
# 14758
# 14759
# 14760                                        œilletonnée
# 14761
#
#       ('plural', 'participle', 'past', 'thirdPerson', 'feminine')  \
# 0                                              abaissées
# 1                                              abalobées
# 2
# 3                                            abandonnées
# 4
# ...                                                  ...
# 14757                                            îlotées
# 14758
# 14759
# 14760                                       œilletonnées
# 14761
#
#       ('singular', 'indicative', 'simplePast', 'thirdPerson', 'feminine')  \
# 0
# 1                                                abaloba
# 2                                             abalourdit
# 3
# 4                                             abasourdit
# ...                                                  ...
# 14757
# 14758
# 14759                                              œilla
# 14760                                         œilletonna
# 14761
#
#       ('singular', 'indicative', 'simplePast', 'firstPerson', 'feminine')  \
# 0
# 1                                               abalobai
# 2                                             abalourdis
# 3
# 4
# ...                                                  ...
# 14757
# 14758
# 14759                                             œillai
# 14760                                        œilletonnai
# 14761
#
#       ('plural', 'indicative', 'imperfect', 'thirdPerson', 'feminine')  \
# 0
# 1                                            abalobaient
# 2                                       abalourdissaient
# 3
# 4                                       abasourdissaient
# ...                                                  ...
# 14757
# 14758
# 14759                                          œillaient
# 14760                                     œilletonnaient
# 14761
#
#       ('singular', 'indicative', 'imperfect', 'firstPerson', 'feminine')  \
# 0
# 1                                              abalobais
# 2                                         abalourdissais
# 3
# 4
# ...                                                  ...
# 14757
# 14758
# 14759                                            œillais
# 14760                                       œilletonnais
# 14761
#
#       ('singular', 'indicative', 'imperfect', 'secondPerson', 'feminine')  \
# 0
# 1                                              abalobais
# 2                                         abalourdissais
# 3
# 4                                         abasourdissais
# ...                                                  ...
# 14757
# 14758
# 14759                                            œillais
# 14760                                       œilletonnais
# 14761
#
#        ...  \
# 0      ...
# 1      ...
# 2      ...
# 3      ...
# 4      ...
# ...    ...
# 14757  ...
# 14758  ...
# 14759  ...
# 14760  ...
# 14761  ...
#
#       ('invariable', 'participle', 'present', 'thirdPerson', 'invariable')  \
# 0
# 1
# 2
# 3
# 4
# ...                                                  ...
# 14757
# 14758
# 14759
# 14760
# 14761
#
#       ('plural', 'infinitive', 'imperfect', 'firstPerson', 'invariable')  \
# 0
# 1
# 2
# 3
# 4
# ...                                                  ...
# 14757
# 14758
# 14759
# 14760
# 14761
#
#       ('invariable', 'indicative', 'present', 'thirdPerson', 'masculine')  \
# 0
# 1
# 2
# 3
# 4
# ...                                                  ...
# 14757
# 14758
# 14759
# 14760
# 14761
#
#       ('invariable', 'infinitive', 'present', 'thirdPerson', 'masculine')  \
# 0
# 1
# 2
# 3
# 4
# ...                                                  ...
# 14757
# 14758
# 14759
# 14760
# 14761
#
#       ('plural', 'participle', 'present', 'secondPerson', 'feminine')  \
# 0
# 1
# 2
# 3
# 4
# ...                                                  ...
# 14757
# 14758
# 14759
# 14760
# 14761
#
#       ('singular', 'infinitive', 'imperfect', 'thirdPerson', 'feminine')  \
# 0
# 1
# 2
# 3
# 4
# ...                                                  ...
# 14757
# 14758
# 14759
# 14760
# 14761
#
#       ('plural', 'infinitive', 'past', 'firstPerson', 'masculine')  \
# 0
# 1
# 2
# 3
# 4
# ...                                                  ...
# 14757
# 14758
# 14759
# 14760
# 14761
#
#       ('invariable', 'infinitive', 'past', 'secondPerson', 'invariable')  \
# 0
# 1
# 2
# 3
# 4
# ...                                                  ...
# 14757
# 14758
# 14759
# 14760
# 14761
#
#       ('invariable', 'indicative', 'present', 'thirdPerson', 'feminine')  \
# 0
# 1
# 2
# 3
# 4
# ...                                                  ...
# 14757
# 14758
# 14759
# 14760
# 14761
#
#       ('plural', 'infinitive', 'present', 'secondPerson', 'invariable')
# 0
# 1
# 2
# 3
# 4
# ...                                                  ...
# 14757
# 14758
# 14759
# 14760
# 14761
#
# [14762 rows x 216 columns]

# %%
col_2=df["('singular', 'indicative', 'simplePast', 'firstPerson', 'masculine')"]
col_2
# Out:
# 0
# 1
# 2
# 3        abandonnai
# 4
#             ...
# 14757
# 14758          ôtai
# 14759
# 14760
# 14761        œuvrai
# Name: ('singular', 'indicative', 'simplePast', 'firstPerson', 'masculine'), Length: 14762, dtype: object

# %%
col_1=df.iloc[:,1]
col_1
# Out:
# 0           abaissés
# 1           abalobés
# 2
# 3         abandonnés
# 4
#             ...
# 14757         îlotés
# 14758
# 14759
# 14760    œilletonnés
# 14761
# Name: ('plural', 'participle', 'past', 'thirdPerson', 'masculine'), Length: 14762, dtype: object

# %%
col_1_df = create_words_df(model, tokenizer, col_1, progress=True)

col_1_df
# Out:
# ...............
#                   0         1         2         3         4         5    \
# abandonnés   4.381264  2.659399 -0.302107  0.330216 -0.782302 -5.653428
# abonnés      3.654129 -2.818286  4.460589  2.206700 -0.561531 -2.632590
# abordés      1.917792 -2.273916  4.270368  4.163424  4.632642 -1.743235
# acceptés     5.366228  0.379400  1.669905 -0.518430  2.731387 -0.901801
# accompagnés  1.390014 -2.450902  1.609426  4.196467 -1.099670 -1.392771
# ...               ...       ...       ...       ...       ...       ...
# étonnés      1.663339  1.316887  0.772728  3.166754 -1.721289 -4.421558
# étudiés      8.540934  0.061990  1.735099  9.251062  0.962489 -2.594066
# évacués      3.478244 -3.813870  2.747409  0.856851  0.044579 -6.091686
# évalués      8.058141 -0.802736  3.230951  6.411384 -2.095179 -2.462882
# évoqués      3.076418 -1.937876  2.082110  3.961746  1.971364  0.158139
#
#                   6         7         8         9    ...       502       503  \
# abandonnés  -1.347951  2.838605 -5.429185 -0.678537  ... -0.014876 -2.035768
# abonnés     -0.512392 -2.032883  3.031250 -0.485668  ... -0.512917 -6.217239
# abordés     -5.513284  6.197087 -0.148433 -4.252090  ...  1.778179  2.936710
# acceptés     0.391395  1.858353 -3.252812 -0.839973  ...  2.218356  0.006154
# accompagnés  0.290229  1.824908  1.147109 -4.246204  ...  2.216980  4.360596
# ...               ...       ...       ...       ...  ...       ...       ...
# étonnés      1.624101  2.941848  1.119474  2.118531  ... -4.037564  0.464134
# étudiés     -1.002361  1.388945 -0.308337  0.418625  ... -1.430812  0.516062
# évacués      1.160987  4.125816 -0.813237  1.399030  ...  2.886464 -1.329341
# évalués      2.041423  4.888093 -1.348910  0.536262  ... -3.636461  1.458000
# évoqués     -3.527072  1.186305 -0.623158 -6.664658  ...  0.215009  0.296829
#
#                   504       505       506       507       508       509  \
# abandonnés   0.316176 -2.783943 -0.994184 -3.623416 -3.733533 -5.347572
# abonnés      1.857775  0.439603 -2.930176 -5.878294 -7.231788 -1.898046
# abordés     -3.660851 -1.828262  1.751439  0.766645 -2.441900 -3.864922
# acceptés    -0.361472 -4.365201  0.375057 -1.018353 -2.144008 -5.612575
# accompagnés -0.592385 -1.011451  1.563586 -2.935498 -2.773654 -5.905937
# ...               ...       ...       ...       ...       ...       ...
# étonnés     -1.605394 -2.404596 -1.246375  2.141960 -6.135213 -6.477948
# étudiés     -5.019915 -0.613142  2.724079 -1.008348 -3.820975 -7.942867
# évacués     -1.131383  1.366344 -4.298313 -5.720682 -7.141437 -3.194011
# évalués     -4.108881  0.859853 -0.741042 -1.280156 -2.391687 -7.094583
# évoqués     -1.651821 -2.939775  3.909779 -1.731102 -4.360871 -4.475760
#
#                   510       511
# abandonnés   4.459942 -1.087983
# abonnés      4.563114  5.113810
# abordés      0.461346 -6.275189
# acceptés     1.666004 -5.892756
# accompagnés  0.620300 -6.162280
# ...               ...       ...
# étonnés      4.082718 -3.592772
# étudiés      1.265288 -4.147405
# évacués      1.390623 -1.701988
# évalués      3.096194 -5.672167
# évoqués      3.723722 -3.390584
#
# [498 rows x 512 columns]

# %%
plot_we_heatmap(col_1_df.sample(n=20), size=(20, 20), label = 'Plot of 100 random verb with singular, indicative, simplePast, thirdPerson, masculine')

# %%
verbs_we= df.iloc[:,0]
n_columns = len(df.columns)
for i in range(1, n_columns):
  a=df.iloc[:,i]
  verbs_we = pd.concat([verbs_we, a])
print(verbs_we)
# Out:
# 0          abaisser
# 1          abalober
# 2        abalourdir
# 3        abandonner
# 4        abasourdir
#             ...
# 14757
# 14758
# 14759
# 14760
# 14761
# Length: 3188592, dtype: object

# %%
verbs_we_df = create_words_df(model, tokenizer, verbs_we, progress=True)
# Out:
# .....................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................

# %%
verbs_we_df
# Out:
#                  0         1         2         3         4         5    \
# abaisser   -0.747519 -0.113683  1.325009  0.911627 -1.904380 -9.002491
# abandonner  1.390643  2.159090 -2.062917 -1.866176 -2.612017 -6.143830
# abattre     1.831470  0.906042 -1.346421 -2.178033 -1.647874 -4.480566
# abolir      0.642638 -0.279848 -2.408875  0.720843 -2.659510 -1.736096
# abonner     4.842296  0.787345 -2.811515  0.931225  3.630959 -2.983525
# ...              ...       ...       ...       ...       ...       ...
# ri         -0.392870  1.035102  2.555569 -4.648828 -2.734535 -0.016542
# souri       1.518366 -1.673151  4.385755 -0.285692 -0.589451 -2.244247
# suffi       3.183763  0.405156  2.462578 -0.079444  3.258432 -3.559424
# été         3.416337 -0.773586  1.706467 -0.731092 -2.286620 -4.172236
# sachant     0.705618 -2.827220 -3.136203  0.786572  0.082493 -0.260785
#
#                  6         7         8         9    ...       502       503  \
# abaisser   -1.629585  0.944770  3.187650  2.009824  ...  2.685377  3.416851
# abandonner -4.830592 -0.031206  1.532932 -2.049455  ...  2.740225  0.275028
# abattre    -2.788281 -2.075789  2.570961 -0.989937  ... -0.506417 -3.029911
# abolir     -1.391011  0.856842 -0.086003  2.630179  ...  2.001883  1.335928
# abonner    -0.609328 -4.929424  2.715345 -3.431795  ...  4.551510  1.479332
# ...              ...       ...       ...       ...  ...       ...       ...
# ri          1.948242 -5.096567 -0.430416 -2.920654  ... -0.514121  1.772056
# souri      -1.982214 -0.230587  2.276996 -2.305416  ... -3.545237  2.244371
# suffi      -8.482520 -1.301205  3.466282 -3.398628  ... -2.408332  2.093470
# été         0.249760  2.382638 -0.532814 -1.754949  ... -1.167793  1.600534
# sachant     1.441894  1.866828 -3.724940 -1.368859  ... -0.597366  3.720646
#
#                  504       505       506       507       508       509  \
# abaisser   -3.167169  0.655781  0.679771 -2.816759 -7.782869 -5.602723
# abandonner  0.014792 -3.817796  1.162358 -6.707489 -5.114801 -3.397800
# abattre    -1.880436 -3.290468 -2.952549 -3.258610 -5.390528 -3.662323
# abolir      0.147248  0.789997 -1.141161 -2.566548 -4.268200 -5.605224
# abonner     0.832494 -3.701814  3.679448 -2.403465 -6.765020 -3.323872
# ...              ...       ...       ...       ...       ...       ...
# ri         -2.415262 -1.964800 -2.450147 -5.602681 -3.914068 -4.803717
# souri       0.904917 -3.390943  1.779433 -4.982320 -3.352296 -3.566676
# suffi      -3.225399  1.424573 -1.749826 -3.106265 -2.797306 -7.580166
# été        -3.600604 -3.045681  3.401185 -7.156822 -2.926211 -7.060627
# sachant    -3.159732  2.413465 -0.000124 -2.597996 -1.138444 -4.677323
#
#                  510       511
# abaisser   -0.491549 -4.491615
# abandonner  2.333867 -4.365515
# abattre    -1.486962 -4.619687
# abolir     -2.125008 -0.673525
# abonner     7.202050  0.545049
# ...              ...       ...
# ri          1.754554 -1.397613
# souri      -1.845987 -0.893933
# suffi       0.023397 -4.864722
# été         4.555849 -4.830540
# sachant     1.684083 -2.412234
#
# [10088 rows x 512 columns]

# %%
verbs_we_df.to_csv('all_verb_we.csv')
