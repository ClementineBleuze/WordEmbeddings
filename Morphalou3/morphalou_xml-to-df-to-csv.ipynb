# %% [markdown]
# ## Morphalou data: from XML to DataFrame, to .csv
# In this Notebook: Conversion from XML format (original Morphalou3 data) to .csv format. Some information from the initial data hasn't been kept in the .csv format, as it was of no use in this project.

# %%
import xml.etree.ElementTree as et
import pandas as pd
# %matplotlib inline

# %% [markdown]
# ### 1. Nouns

# %%
xtree = et.parse("data/commonNoun_Morphalou3_LMF.xml")
xroot = xtree.getroot()

dict_list = []
counter = 0

for le in xroot.iter('lexicalEntry'):
    le_dict = {}
    for lemma in le.iter('lemmatizedForm'):
        le_dict['lemma'] = lemma.find('orthography').text
        try:
            le_dict['gender'] = lemma.find('grammaticalGender').text
        except:
            pass
        le_dict['category'] = lemma.find('grammaticalCategory').text
        
    for form in le.iter('inflectedForm'):
        gn = form.find('grammaticalNumber').text
        le_dict[gn] = form.find('orthography').text
    
    dict_list.append(le_dict)
    counter += 1
    if counter % 1000 == 0:
        print('.', end='')

nouns_df = pd.DataFrame(dict_list)
nouns_df
# Out:
# ......................................................................................................
#              lemma     gender    category  invariable singular plural
# 0       100-mètres  masculine  commonNoun  100-mètres      NaN    NaN
# 1               2D   feminine  commonNoun          2D      NaN    NaN
# 2               3D   feminine  commonNoun          3D      NaN    NaN
# 3                A  masculine  commonNoun          µA      NaN    NaN
# 4                a  masculine  commonNoun           a      NaN    NaN
# ...            ...        ...         ...         ...      ...    ...
# 102220           φ  masculine  commonNoun           φ      NaN    NaN
# 102221           χ  masculine  commonNoun           χ      NaN    NaN
# 102222           ψ  masculine  commonNoun           ψ      NaN    NaN
# 102223           ω  masculine  commonNoun           ω      NaN    NaN
# 102224           Ω  masculine  commonNoun           Ω      NaN    NaN
#
# [102225 rows x 6 columns]

# %%
nouns_df.to_csv('data/csv/all_nouns.csv')

# %% [markdown]
# ## 2. Verbs

# %%
xtree = et.parse("data/verb_Morphalou3_LMF.xml")
xroot = xtree.getroot()

dict_list = []
counter = 0

for le in xroot.iter('lexicalEntry'):
    le_dict = {}
    for lemma in le.iter('lemmatizedForm'):
        le_dict['lemma'] = lemma.find('orthography').text
       
        
    for form in le.iter('inflectedForm'):
        try:
            gn = form.find('grammaticalNumber').text  
        
        except:
            pass
        
        try:
            gm = form.find('grammaticalMood').text
       
        except:
            pass

        try:
            gt = form.find('grammaticalTense').text
            
        except:
            pass
        
        try:
            gp = form.find('grammaticalPerson').text
            
        except:
            pass
        try:
            gg=form.find('grammaticalGender').text
           
        except:
            pass

        try:
            le_dict[gn,gm,gt,gp,gg] = form.find('orthography').text
        except:
            pass
        
       
    
    dict_list.append(le_dict)
    counter += 1
    if counter % 1000 == 0:
        print('.', end='')

verbs_df = pd.DataFrame(dict_list)
verbs_df
# Out:
# ..............
#              lemma (singular, indicative, simplePast, thirdPerson, masculine)  \
# 0         abaisser                                            abaissa
# 1         abalober                                                NaN
# 2       abalourdir                                                NaN
# 3       abandonner                                          abandonna
# 4       abasourdir                                                NaN
# ...            ...                                                ...
# 14757       îloter                                                NaN
# 14758         ôter                                                ôta
# 14759       œiller                                                NaN
# 14760  œilletonner                                                NaN
# 14761       œuvrer                                              œuvra
#
#       (singular, indicative, simplePast, firstPerson, masculine)  \
# 0                                               abaissai
# 1                                                    NaN
# 2                                                    NaN
# 3                                             abandonnai
# 4                                                    NaN
# ...                                                  ...
# 14757                                                NaN
# 14758                                               ôtai
# 14759                                                NaN
# 14760                                                NaN
# 14761                                             œuvrai
#
#       (plural, indicative, imperfect, thirdPerson, masculine)  \
# 0                                            abaissaient
# 1                                                    NaN
# 2                                                    NaN
# 3                                          abandonnaient
# 4                                                    NaN
# ...                                                  ...
# 14757                                                NaN
# 14758                                            ôtaient
# 14759                                                NaN
# 14760                                                NaN
# 14761                                          œuvraient
#
#       (singular, indicative, imperfect, secondPerson, masculine)  \
# 0                                              abaissais
# 1                                                    NaN
# 2                                                    NaN
# 3                                            abandonnais
# 4                                                    NaN
# ...                                                  ...
# 14757                                                NaN
# 14758                                              ôtais
# 14759                                                NaN
# 14760                                                NaN
# 14761                                            œuvrais
#
#       (singular, indicative, imperfect, thirdPerson, masculine)  \
# 0                                              abaissait
# 1                                                    NaN
# 2                                                    NaN
# 3                                            abandonnait
# 4                                                    NaN
# ...                                                  ...
# 14757                                                NaN
# 14758                                              ôtait
# 14759                                                NaN
# 14760                                                NaN
# 14761                                            œuvrait
#
#       (singular, participle, present, thirdPerson, masculine)  \
# 0                                              abaissant
# 1                                                    NaN
# 2                                                    NaN
# 3                                            abandonnant
# 4                                                    NaN
# ...                                                  ...
# 14757                                                NaN
# 14758                                              ôtant
# 14759                                                NaN
# 14760                                                NaN
# 14761                                                NaN
#
#       (singular, indicative, simplePast, secondPerson, masculine)  \
# 0                                               abaissas
# 1                                                    NaN
# 2                                                    NaN
# 3                                             abandonnas
# 4                                                    NaN
# ...                                                  ...
# 14757                                                NaN
# 14758                                               ôtas
# 14759                                                NaN
# 14760                                                NaN
# 14761                                             œuvras
#
#       (singular, subjunctive, imperfect, firstPerson, masculine)  \
# 0                                             abaissasse
# 1                                                    NaN
# 2                                                    NaN
# 3                                           abandonnasse
# 4                                                    NaN
# ...                                                  ...
# 14757                                                NaN
# 14758                                             ôtasse
# 14759                                                NaN
# 14760                                                NaN
# 14761                                           œuvrasse
#
#       (plural, subjunctive, imperfect, thirdPerson, masculine)  ...  \
# 0                                           abaissassent        ...
# 1                                                    NaN        ...
# 2                                                    NaN        ...
# 3                                         abandonnassent        ...
# 4                                                    NaN        ...
# ...                                                  ...        ...
# 14757                                                NaN        ...
# 14758                                           ôtassent        ...
# 14759                                                NaN        ...
# 14760                                                NaN        ...
# 14761                                         œuvrassent        ...
#
#       (invariable, participle, present, thirdPerson, invariable)  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 14757                                                NaN
# 14758                                                NaN
# 14759                                                NaN
# 14760                                                NaN
# 14761                                                NaN
#
#       (plural, infinitive, imperfect, firstPerson, invariable)  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 14757                                                NaN
# 14758                                                NaN
# 14759                                                NaN
# 14760                                                NaN
# 14761                                                NaN
#
#       (invariable, indicative, present, thirdPerson, masculine)  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 14757                                                NaN
# 14758                                                NaN
# 14759                                                NaN
# 14760                                                NaN
# 14761                                                NaN
#
#       (invariable, infinitive, present, thirdPerson, masculine)  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 14757                                                NaN
# 14758                                                NaN
# 14759                                                NaN
# 14760                                                NaN
# 14761                                                NaN
#
#       (plural, participle, present, secondPerson, feminine)  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 14757                                                NaN
# 14758                                                NaN
# 14759                                                NaN
# 14760                                                NaN
# 14761                                                NaN
#
#       (singular, infinitive, imperfect, thirdPerson, feminine)  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 14757                                                NaN
# 14758                                                NaN
# 14759                                                NaN
# 14760                                                NaN
# 14761                                                NaN
#
#       (plural, infinitive, past, firstPerson, masculine)  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 14757                                                NaN
# 14758                                                NaN
# 14759                                                NaN
# 14760                                                NaN
# 14761                                                NaN
#
#       (invariable, infinitive, past, secondPerson, invariable)  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 14757                                                NaN
# 14758                                                NaN
# 14759                                                NaN
# 14760                                                NaN
# 14761                                                NaN
#
#       (invariable, indicative, present, thirdPerson, feminine)  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 14757                                                NaN
# 14758                                                NaN
# 14759                                                NaN
# 14760                                                NaN
# 14761                                                NaN
#
#       (plural, infinitive, present, secondPerson, invariable)
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 14757                                                NaN
# 14758                                                NaN
# 14759                                                NaN
# 14760                                                NaN
# 14761                                                NaN
#
# [14762 rows x 216 columns]

# %%
verbs_df.to_csv('data/csv/all_verbs.csv')

# %% [markdown]
# ## 3. Adjectives

# %%
xtree = et.parse("data/adjective_Morphalou3_LMF.xml")
xroot = xtree.getroot()

dict_list = []
counter = 0

for le in xroot.iter('lexicalEntry'):
    le_dict = {}
    for lemma in le.iter('lemmatizedForm'):
        le_dict['lemma'] = lemma.find('orthography').text
       
        
    for form in le.iter('inflectedForm'):
        try:
            gn = form.find('grammaticalNumber').text  
        
        except:
            pass
        
        try:
            gg=form.find('grammaticalGender').text
           
        except:
            pass

        try:
            le_dict[gn,gg] = form.find('orthography').text
        except:
            pass
        
       
    
    dict_list.append(le_dict)
    counter += 1
    if counter % 1000 == 0:
        print('.', end='')

adjectives_df = pd.DataFrame(dict_list)
adjectives_df
# Out:
# ....................................
#                   lemma (singular, masculine) (plural, masculine)  \
# 0              a-humain              a-humain                 NaN
# 1             a-raciste             a-raciste                 NaN
# 2              aalénien              aalénien           aaléniens
# 3              aaronide              aaronide                 NaN
# 4            abactérien            abactérien         abactériens
# ...                 ...                   ...                 ...
# 36518         œstrogène                   NaN                 NaN
# 36519      œstrogénique                   NaN                 NaN
# 36520         œstromane                   NaN                 NaN
# 36521  œstroprogestatif      œstroprogestatif   œstroprogestatifs
# 36522              œuvé                  œuvé               œuvés
#
#       (singular, feminine)  (plural, feminine) (singular, invariable)  \
# 0                      NaN                 NaN                    NaN
# 1                      NaN                 NaN                    NaN
# 2               aalénienne         aaléniennes                    NaN
# 3                      NaN                 NaN                    NaN
# 4             abactérienne       abactériennes                    NaN
# ...                    ...                 ...                    ...
# 36518                  NaN                 NaN              œstrogène
# 36519                  NaN                 NaN           œstrogénique
# 36520                  NaN                 NaN              œstromane
# 36521    œstroprogestative  œstroprogestatives                    NaN
# 36522                œuvée              œuvées                    NaN
#
#       (plural, invariable) (invariable, masculine) (invariable, invariable)  \
# 0                      NaN                     NaN                      NaN
# 1                      NaN                     NaN                      NaN
# 2                      NaN                     NaN                      NaN
# 3                      NaN                     NaN                      NaN
# 4                      NaN                     NaN                      NaN
# ...                    ...                     ...                      ...
# 36518           œstrogènes                     NaN                      NaN
# 36519        œstrogéniques                     NaN                      NaN
# 36520           œstromanes                     NaN                      NaN
# 36521                  NaN                     NaN                      NaN
# 36522                  NaN                     NaN                      NaN
#
#       (invariable, feminine)
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN
# ...                      ...
# 36518                    NaN
# 36519                    NaN
# 36520                    NaN
# 36521                    NaN
# 36522                    NaN
#
# [36523 rows x 10 columns]

# %%
adjectives_df.to_csv("data/csv/all_adjectives.csv")

# %% [markdown]
# ## 4. Adverbs

# %%
xtree = et.parse("data/adverb_Morphalou3_LMF.xml")
xroot = xtree.getroot()

dict_list = []
counter = 0

for le in xroot.iter('lexicalEntry'):
    le_dict = {}
    for lemma in le.iter('lemmatizedForm'):
        le_dict['lemma'] = lemma.find('orthography').text
       
        try:
            loc = lemma.find('locution').text  
        except:
            loc = "non"

        try:
            le_dict["locution"] = loc
        except:
            pass
        
    dict_list.append(le_dict)
    counter += 1
    if counter % 1000 == 0:
        print('.', end='')

adverbs_df = pd.DataFrame(dict_list)
adverbs_df
# Out:
# ....
#                    lemma locution
# 0            a contrario      oui
# 1             a fortiori      oui
# 2               a latere      oui
# 3               a minima      oui
# 4           a posteriori      oui
# ...                  ...      ...
# 4150          évidemment      non
# 4151       évolutivement      non
# 4152  événementiellement      non
# 4153                   ô      non
# 4154      œnologiquement      non
#
# [4155 rows x 2 columns]

# %%
adverbs_df.to_csv("data/csv/all_adverbs.csv")

# %% [markdown]
# ## 5. Grammatical Words

# %%
xtree = et.parse("data/grammaticalWords_Morphalou3_LMF.xml")
xroot = xtree.getroot()

dict_list = []
counter = 0

for le in xroot.iter('lexicalEntry'):
    le_dict = {}
    attributes = []
    for lemma in le.iter('lemmatizedForm'):
        le_dict["lemma"] = lemma.find('orthography').text
        
        try:
            gc = lemma.find("grammaticalCategory").text
            le_dict["grammaticalCategory"] = gc
        except:
            pass

        try:
            gsc = lemma.find("grammaticalSubCategory").text
            le_dict["grammaticalSubCategory"] = gsc
        except:
            pass

        try:
            loc = lemma.find("locution").text
            le_dict["locution"] = loc
        except:
            pass
       
    i = 1    
    for form in le.iter('inflectedForm'):
        try:
            ort = form.find('orthography').text  
            le_dict["inflectedForm_"+str(i)] = ort
            i += 1
        except:
            pass
       
    
    dict_list.append(le_dict)
    counter += 1
    if counter % 1000 == 0:
        print('.', end='')
        
gwords_df = pd.DataFrame(dict_list)
gwords_df
# Out:
#                lemma grammaticalCategory  inflectedForm_1  \
# 0                  a         preposition                a
# 1            afin de         conjunction          afin de
# 2            afin de         preposition          afin de
# 3           afin que         conjunction         afin que
# 4               ains         conjunction             ains
# ..               ...                 ...              ...
# 806               ça             pronoun               ça
# 807               ça             pronoun               ça
# 808               ès         preposition               ès
# 809  étant donné que         conjunction  étant donné que
# 810              ôté         preposition              ôté
#
#     grammaticalSubCategory locution  inflectedForm_2 inflectedForm_3  \
# 0                      NaN      NaN              NaN             NaN
# 1            subordination      oui              NaN             NaN
# 2                      NaN      oui          afin d'             NaN
# 3            subordination      oui         afin qu'             NaN
# 4             coordination      NaN              NaN             NaN
# ..                     ...      ...              ...             ...
# 806          demonstrative      NaN               ç'             NaN
# 807               personal      NaN              NaN             NaN
# 808                    NaN      NaN              NaN             NaN
# 809          subordination      oui  étant donné qu'             NaN
# 810                    NaN      NaN              NaN             NaN
#
#     inflectedForm_4 inflectedForm_5 inflectedForm_6 inflectedForm_7  \
# 0               NaN             NaN             NaN             NaN
# 1               NaN             NaN             NaN             NaN
# 2               NaN             NaN             NaN             NaN
# 3               NaN             NaN             NaN             NaN
# 4               NaN             NaN             NaN             NaN
# ..              ...             ...             ...             ...
# 806             NaN             NaN             NaN             NaN
# 807             NaN             NaN             NaN             NaN
# 808             NaN             NaN             NaN             NaN
# 809             NaN             NaN             NaN             NaN
# 810             NaN             NaN             NaN             NaN
#
#     inflectedForm_8
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
# ..              ...
# 806             NaN
# 807             NaN
# 808             NaN
# 809             NaN
# 810             NaN
#
# [811 rows x 12 columns]

# %%
gwords_df.to_csv("data/csv/all_grammaticalWords.csv")

# %% [markdown]
# ## 6. Interjections

# %%
xtree = et.parse("data/interjection_Morphalou3_LMF.xml")
xroot = xtree.getroot()

dict_list = []
counter = 0

for le in xroot.iter('lexicalEntry'):
    le_dict = {}
    attributes = []
    for lemma in le.iter('lemmatizedForm'):
        le_dict["lemma"] = lemma.find('orthography').text
        

        try:
            loc = lemma.find("locution").text
            le_dict["locution"] = loc
        except:
            pass
       
    i = 1    
    for form in le.iter('inflectedForm'):
        try:
            ort = form.find('orthography').text  
            le_dict["inflectedForm_"+str(i)] = ort
            i += 1
        except:
            pass
       
    
    dict_list.append(le_dict)
    counter += 1
    if counter % 1000 == 0:
        print('.', end='')
        
interjections_df = pd.DataFrame(dict_list)
interjections_df
# Out:
#        lemma inflectedForm_1 locution
# 0       acré            acré      NaN
# 1      adieu           adieu      NaN
# 2    aglagla         aglagla      NaN
# 3         ah              ah      NaN
# 4        aha             aha      NaN
# ..       ...             ...      ...
# 417   à plus          à plus      oui
# 418       çà              çà      NaN
# 419    évohé           évohé      NaN
# 420     évoé            évoé      NaN
# 421        ô               ô      NaN
#
# [422 rows x 3 columns]

# %%
interjections_df.to_csv("data/csv/all_interjections.csv")

# %% [markdown]
# ## 7. Others

# %%
xtree = et.parse("data/noCategory_Morphalou3_LMF.xml")
xroot = xtree.getroot()

dict_list = []
counter = 0

for le in xroot.iter('lexicalEntry'):
    le_dict = {}
    attributes = []
    for lemma in le.iter('lemmatizedForm'):
        le_dict["lemma"] = lemma.find('orthography').text
           
    dict_list.append(le_dict)
    counter += 1
    if counter % 1000 == 0:
        print('.', end='')
        
noCategory_df = pd.DataFrame(dict_list)
noCategory_df
# Out:
#             lemma
# 0      a demi-mot
# 1       a divinis
# 2      a fortiori
# 3        a maxima
# 4        a minima
# ..            ...
# 347   à vau-l'eau
# 348  à vau-le-feu
# 349    à vau-vent
# 350      étouffée
# 351           ô _
#
# [352 rows x 1 columns]

# %%
noCategory_df.to_csv("data/csv/all_noCategory.csv")
