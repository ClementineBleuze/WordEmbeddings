# %% [markdown]
# This  Notebook will attempts to isolate Word Embeddings dimension coding for ** nomber information** (Singular/Plural) in a sample of Word Embeddings for **common Nouns**, and try to analysis which vectors might encode Singular and Plural Noun information.

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt

# %%
top_freq_n = pd.read_csv('Most Frequent Words/top_frequent_NOUN_FlauBERT.csv', index_col='Word')
top_freq_n
# Out:
#                 Unnamed: 0           lemme cgram genre nombre  freqlemlivres
# Word
# homme                    0           homme   NOM     m      s        1398.85
# hommes                   1           homme   NOM     m      p        1398.85
# jour                     2            jour   NOM     m      s        1341.76
# jours                    3            jour   NOM     m      p        1341.76
# oeil                     5            oeil   NOM     m      s        1234.59
# ...                    ...             ...   ...   ...    ...            ...
# éthylène             48267        éthylène   NOM     m      s           0.00
# étiquetage           48269      étiquetage   NOM     m      s           0.00
# évangélisation       48274  évangélisation   NOM     f      s           0.00
# évènement            48283       évènement   NOM     m      s           0.00
# évènements           48284       évènement   NOM     m      p           0.00
#
# [11353 rows x 6 columns]

# %% [markdown]
# 1000 Singular Nouns

# %%
top_sg_n = top_freq_n[top_freq_n["nombre"] == "s"][:1000]
top_sg_n
# Out:
#          Unnamed: 0    lemme cgram genre nombre  freqlemlivres
# Word
# homme             0    homme   NOM     m      s        1398.85
# jour              2     jour   NOM     m      s        1341.76
# oeil              5     oeil   NOM     m      s        1234.59
# main              8     main   NOM   NaN      s        1229.39
# chose            11    chose   NOM     f      s        1057.64
# ...             ...      ...   ...   ...    ...            ...
# muscle         2172   muscle   NOM     m      s          34.53
# écart          2174    écart   NOM     m      s          34.53
# acier          2176    acier   NOM     m      s          34.46
# formule        2178  formule   NOM     f      s          34.39
# placard        2180  placard   NOM     m      s          34.39
#
# [1000 rows x 6 columns]

# %% [markdown]
# 1000 Plural Nouns

# %%
top_pl_n = top_freq_n[top_freq_n["nombre"] == "p"][:1000]
top_pl_n
# Out:
#            Unnamed: 0     lemme cgram genre nombre  freqlemlivres
# Word
# hommes              1     homme   NOM     m      p        1398.85
# jours               3      jour   NOM     m      p        1341.76
# mains               9      main   NOM     f      p        1229.39
# fois               10      fois   NOM     f      p        1140.00
# choses             12     chose   NOM     f      p        1057.64
# ...               ...       ...   ...   ...    ...            ...
# bougies          2518    bougie   NOM     f      p          29.86
# paliers          2526    palier   NOM     m      p          29.80
# comédies         2528   comédie   NOM     f      p          29.73
# conneries        2530  connerie   NOM     f      p          29.73
# anciennes        2534    ancien   NOM     f      p          29.66
#
# [1000 rows x 6 columns]

# %%
all_n_we = pd.read_csv('all_nouns_we.csv', index_col=0)
sg_n_we = all_n_we.merge(top_sg_n, left_index=True, right_index=True)
pl_n_we = all_n_we.merge(top_pl_n, left_index=True, right_index=True)

# %%
sg_n_we
# Out:
#                   0         1         2         3         4         5  \
# abri       5.471711 -4.372995  1.739335 -4.412735  4.930413 -8.995445
# absence    3.322297 -0.768149  3.555035 -0.685460  1.201102 -3.151831
# accent    -1.783984 -0.983782  2.905572 -3.458411 -1.267276 -3.330925
# accident   4.179721  2.913542  1.124980  2.269820  0.573966 -3.254911
# accord    -0.732188 -2.024965  1.674970 -4.194049 -2.528312 -2.400746
# ...             ...       ...       ...       ...       ...       ...
# été        3.416338 -0.773585  1.706465 -0.731093 -2.286620 -4.172235
# évidence   3.323571  1.512269  5.297979 -0.080244 -1.670055 -3.890020
# événement -0.693584 -0.753810  0.124109  2.200120  1.585398 -2.354075
# être       0.166950 -1.121742  3.855680  0.846314 -3.065409  0.577782
# île       -0.489183 -3.752668 -2.676017  4.677486  1.093927 -5.670148
#
#                   6         7         8         9  ...       510       511  \
# abri       2.661912  0.189424  4.682540 -1.069355  ...  5.668764 -2.120574
# absence   -3.592423  1.189369 -2.742928 -2.666739  ...  5.123568 -2.381779
# accent    -2.833155  6.685886  2.322869  1.045544  ...  4.514214 -5.526344
# accident  -2.611606 -1.138910  5.944216 -1.380369  ...  5.891779 -3.223269
# accord    -4.672920  0.374903  6.015941 -0.066068  ... -5.424189 -6.660925
# ...             ...       ...       ...       ...  ...       ...       ...
# été        0.249760  2.382637 -0.532811 -1.754951  ...  4.555850 -4.830541
# évidence  -4.678585  1.379389 -0.347799 -1.198223  ...  3.639242 -3.688165
# événement -2.994415  1.552121  4.762497 -1.361055  ...  0.740749 -3.701469
# être       1.696410  0.962429  1.131322 -5.577701  ...  1.669239 -4.337866
# île       -0.456426  2.867334  2.531248 -2.738322  ... -2.131077 -4.665631
#
#                  gn     gender  Unnamed: 0      lemme  cgram  genre  nombre  \
# abri       singular  masculine        1272       abri    NOM      m       s
# absence    singular   feminine         931    absence    NOM      f       s
# accent     singular  masculine        1632     accent    NOM      m       s
# accident   singular  masculine        1676   accident    NOM      m       s
# accord     singular  masculine         442     accord    NOM      m       s
# ...             ...        ...         ...        ...    ...    ...     ...
# été        singular  masculine         497        été    NOM      m       s
# évidence   singular   feminine        1885   évidence    NOM      f       s
# événement  singular  masculine         800  événement    NOM      m       s
# être       singular  masculine         513       être    NOM      m       s
# île        singular   feminine         593        île    NOM      f       s
#
#            freqlemlivres
# abri               56.76
# absence            76.28
# accent             45.54
# accident           44.80
# accord            136.15
# ...                  ...
# été               125.47
# évidence           39.93
# événement          84.59
# être              122.57
# île               108.24
#
# [1000 rows x 520 columns]

# %%
pl_n_we
# Out:
#                    0         1         2         3         4         5  \
# abris       3.634584 -4.644015  0.377342 -6.514875  1.314781 -7.105865
# absences    3.295355 -0.794079  2.472845  3.223941  5.035848 -4.848855
# accents    -2.852492 -6.941010  2.654853  0.080606  2.219124  0.272673
# accidents   2.268600  4.139071  0.183023  3.481640  0.530478 -3.582917
# accords     1.037610 -0.246123  3.333316 -4.094496  0.056898 -2.978131
# ...              ...       ...       ...       ...       ...       ...
# étudiants   3.238430 -4.186950  3.466894  0.049728 -6.309442 -8.333128
# étés        2.757932  0.903210  0.184015  1.369026 -0.241391 -3.674196
# événements -1.245101 -0.820061  1.330310  5.786696  3.966537 -3.242018
# êtres       3.589590 -4.551544  6.088149  2.847501  3.829500 -3.342109
# îles       -2.838814 -3.576476 -1.082639  5.224788  1.871563 -5.175120
#
#                    6         7         8         9  ...       510       511  \
# abris       1.637559  1.284117  2.511964  1.558493  ...  5.123267  0.749750
# absences   -4.557629 -2.719433 -1.932022 -6.440993  ...  5.919082  0.577700
# accents    -6.729390  6.506963 -2.533498 -0.707858  ...  0.470607 -1.465352
# accidents   0.113348 -3.074070  3.846386 -0.874110  ...  4.060133 -2.090280
# accords    -4.198946 -2.159259  3.082677  2.101236  ... -5.254343 -6.959417
# ...              ...       ...       ...       ...  ...       ...       ...
# étudiants   1.362076  3.088547  1.290309 -0.169715  ...  1.396118 -3.539086
# étés        0.942077 -0.553418 -1.468072 -2.633826  ...  1.823255 -2.487086
# événements -0.265572  2.159446  0.661078 -0.936386  ...  1.265242  1.124227
# êtres       2.749030 -0.169812  1.994654  0.893699  ...  0.167977 -1.285041
# îles        2.896314  1.005481  4.880717 -2.816181  ...  0.354014 -2.508205
#
#                 gn     gender  Unnamed: 0      lemme  cgram  genre  nombre  \
# abris       plural  masculine        1273       abri    NOM      m       p
# absences    plural   feminine         932    absence    NOM      f       p
# accents     plural  masculine        1633     accent    NOM      m       p
# accidents   plural  masculine        1677   accident    NOM      m       p
# accords     plural  masculine         443     accord    NOM      m       p
# ...            ...        ...         ...        ...    ...    ...     ...
# étudiants   plural  masculine        1949   étudiant    NOM      m       p
# étés        plural  masculine         498        été    NOM      m       p
# événements  plural  masculine         801  événement    NOM      m       p
# êtres       plural  masculine         514       être    NOM      m       p
# îles        plural   feminine         594        île    NOM      f       p
#
#             freqlemlivres
# abris               56.76
# absences            76.28
# accents             45.54
# accidents           44.80
# accords            136.15
# ...                   ...
# étudiants           38.45
# étés               125.47
# événements          84.59
# êtres              122.57
# îles               108.24
#
# [1003 rows x 520 columns]

# %%
dim_indices = range(512)
avg_values_sg = [sg_n_we[str(i)].mean() for i in dim_indices]
avg_values_pl = [pl_n_we[str(i)].mean() for i in dim_indices]
d = [abs(s-p) for s,p in zip(avg_values_sg, avg_values_pl)]
diff={d[i]:i for i in dim_indices}

sg_avg = pd.DataFrame([avg_values_sg], index=["sg_avg"], columns=dim_indices)
pl_avg = pd.DataFrame([avg_values_pl], index=["pl_avg"], columns=dim_indices)

# %%
sg_avg
# Out:
#              0         1         2         3         4         5         6    \
# sg_avg  2.601957 -1.807742  0.619541 -1.778036  0.670534 -2.731147 -2.613026
#
#              7         8        9    ...       502       503       504  \
# sg_avg  0.167918  1.391258  0.49421  ... -1.117636  0.695403  0.358586
#
#              505       506       507       508       509      510       511
# sg_avg -2.513595 -0.355353 -4.083591 -3.155055 -3.554188  1.66638 -3.015085
#
# [1 rows x 512 columns]

# %%
pl_avg
# Out:
#              0         1         2         3         4         5         6    \
# pl_avg  2.055555 -1.257942  0.442833  0.116288  1.386727 -3.749978 -2.406069
#
#              7         8        9    ...       502       503       504  \
# pl_avg -0.646846  0.099718  0.20298  ... -1.603712  0.646049  1.028271
#
#              505       506      507       508       509       510       511
# pl_avg -1.802236 -1.143349 -2.59853 -3.238867 -3.207549  1.682263 -1.457299
#
# [1 rows x 512 columns]

# %%
diff
# Out:
# {0.546401389443484: 0,
#  0.5498003577268014: 1,
#  0.1767074417295465: 2,
#  1.8943241294386828: 3,
#  0.7161930632079411: 4,
#  1.0188308633363885: 5,
#  0.20695643561576604: 6,
#  0.8147644082449768: 7,
#  1.2915402254961372: 8,
#  0.2912301421122643: 9,
#  0.1303916505297913: 10,
#  0.3314422128734975: 11,
#  0.5904375725706308: 12,
#  0.8597344217943599: 13,
#  0.0035446135943584256: 14,
#  0.604948885833411: 15,
#  0.33776401989208116: 16,
#  0.4419632075201849: 17,
#  0.843169796619414: 18,
#  0.9719992379120428: 19,
#  0.016340001885609468: 20,
#  1.3412619839370186: 21,
#  0.9340386902742484: 22,
#  0.35378773873595026: 23,
#  0.7485027102251196: 24,
#  0.9343719237614279: 25,
#  0.5412670256914804: 26,
#  0.5068491447644853: 27,
#  0.4613673908720836: 28,
#  0.12441212610764918: 29,
#  0.26389573450096554: 30,
#  0.4229683782755781: 31,
#  0.46042576409499514: 32,
#  0.3927731890975563: 33,
#  0.1164006285860142: 34,
#  0.19682278870107428: 35,
#  0.11224585417229482: 36,
#  1.078400461177274: 37,
#  0.061161604707702696: 38,
#  0.0682978505899019: 39,
#  0.6055510342959299: 40,
#  0.9338347659316755: 41,
#  0.4101161695485619: 42,
#  0.5826421442439823: 43,
#  0.015552463867130939: 44,
#  0.44014433273563425: 45,
#  0.10103189143969704: 46,
#  0.17345604280980598: 47,
#  0.31736257152351915: 48,
#  0.46524495783429143: 49,
#  1.082758222137667: 50,
#  0.00367684498843035: 51,
#  0.10243948940585845: 52,
#  0.3024693261639826: 53,
#  2.292172058910911: 54,
#  0.6594084207695752: 55,
#  0.5979295945617611: 56,
#  1.2114687272040967: 57,
#  0.04702376473958003: 58,
#  0.19129782801269896: 59,
#  0.7080395341308197: 60,
#  0.04091456090597556: 61,
#  0.42605322831795606: 62,
#  0.8555935648643787: 63,
#  1.0254165581053503: 64,
#  0.8891965854145365: 65,
#  0.07281062088845813: 66,
#  1.2628122585983033: 67,
#  0.10717701298806077: 68,
#  0.9815591444838228: 69,
#  0.33432023481451445: 70,
#  0.035850852477479433: 71,
#  0.07230438531016808: 72,
#  0.591995956017358: 73,
#  0.5117503575291584: 74,
#  0.518295427879089: 75,
#  0.6191168581717016: 76,
#  1.4573339392853164: 77,
#  0.26513463284639205: 78,
#  0.466326827228254: 79,
#  0.5714076253639278: 80,
#  1.446470194318132: 81,
#  0.5704430115966215: 82,
#  0.9584375707766433: 83,
#  0.7564780487309991: 84,
#  0.22163691188469792: 85,
#  0.5775814561507642: 86,
#  0.11978413911023766: 87,
#  0.07443880099223693: 88,
#  0.20140816003302614: 89,
#  0.6449330184747364: 90,
#  0.26320762207411463: 91,
#  1.1837938203218925: 92,
#  0.07242802089842981: 93,
#  0.07416093129653878: 94,
#  0.18577134469592327: 95,
#  0.8485810065517054: 96,
#  0.11915944700471276: 97,
#  0.41171514609551985: 98,
#  0.41419025322127523: 99,
#  0.07651775041459558: 100,
#  0.9599479781674884: 101,
#  1.0917421233373807: 102,
#  0.9471186800105396: 103,
#  0.34940434861504954: 104,
#  1.1018002108106317: 105,
#  0.9213883498076009: 106,
#  0.26078221245679223: 107,
#  0.3982427169291487: 108,
#  0.8198561621648022: 109,
#  0.7742651837678101: 110,
#  0.21732217994076852: 111,
#  0.11871873418830359: 112,
#  0.14835809364984853: 113,
#  0.5218355766984586: 114,
#  0.7538943808416048: 115,
#  0.6179155335827606: 116,
#  1.0991264091776667: 117,
#  0.08478863083419697: 118,
#  1.579381912438917: 119,
#  0.01392462218818502: 120,
#  0.008289468456221805: 121,
#  0.4959930063632383: 122,
#  0.14696798319198312: 123,
#  0.4959286562695284: 124,
#  0.6801162079530393: 125,
#  0.14744764466553661: 126,
#  0.045216779674729146: 127,
#  0.8435612378919772: 128,
#  0.880453710560001: 129,
#  0.18826546781721165: 130,
#  0.8785161676307498: 131,
#  0.5066591295754252: 132,
#  0.20830706889089612: 133,
#  0.5898425538383487: 134,
#  0.3541029843825103: 135,
#  0.9959079185389865: 136,
#  0.6286527633774437: 137,
#  0.6983292038561855: 138,
#  0.3172300281028644: 139,
#  0.38599629279152714: 140,
#  0.21553806733739567: 141,
#  0.11366361913921685: 142,
#  0.30090842791178685: 143,
#  0.690012178837776: 144,
#  0.1266419634540057: 145,
#  0.8436091676616624: 146,
#  0.21835264786559228: 147,
#  0.5047751913491876: 148,
#  0.38696855981326905: 149,
#  0.4108302127703598: 150,
#  0.2785740072699314: 151,
#  0.14665825999509918: 152,
#  0.6910602651440229: 153,
#  0.7106272016048485: 154,
#  0.6593278870033217: 155,
#  0.476901224156354: 156,
#  0.017380646070933148: 157,
#  0.8803303933939172: 158,
#  0.4230760131225848: 159,
#  1.0039635096198731: 160,
#  0.10631440293431593: 161,
#  0.04461433910985102: 162,
#  0.029082693102009394: 163,
#  0.5836666955754475: 164,
#  0.2954304245380498: 165,
#  0.415838905583648: 166,
#  0.8692164451761042: 167,
#  0.3129128544587987: 168,
#  1.1900542855836047: 169,
#  0.4459327794633854: 170,
#  0.8203049734006572: 171,
#  1.6585721513390301: 172,
#  0.2744347262057125: 173,
#  0.5763100062957394: 174,
#  0.7257639736649018: 175,
#  0.06758021601837683: 176,
#  0.5314917444618226: 177,
#  0.290529336205373: 178,
#  0.5071878223034021: 179,
#  0.9365096843818341: 180,
#  0.19505004692204686: 181,
#  1.096602637687056: 182,
#  1.209659337074269: 183,
#  0.2344503230063839: 184,
#  1.1024218625610283: 185,
#  0.37804705161252583: 186,
#  0.7493132890983665: 187,
#  0.22707789436137382: 188,
#  0.18606790476808577: 189,
#  0.5046080929054377: 190,
#  0.35617040837842406: 191,
#  0.6939032491668407: 192,
#  0.2778396408255954: 193,
#  1.0776687340380198: 194,
#  0.0942900742809778: 195,
#  0.07918842966572504: 196,
#  1.116016310237599: 197,
#  0.9444398776353466: 198,
#  0.7035917957559883: 199,
#  1.3140708968787302: 200,
#  0.4820020244250145: 201,
#  0.37773280865076675: 202,
#  0.2825516503367025: 203,
#  1.2243228119620728: 204,
#  1.4170991466947398: 205,
#  0.230355934553085: 206,
#  0.5386110778212898: 207,
#  0.9735548962721783: 208,
#  0.17198135492015887: 209,
#  0.8058725053391207: 210,
#  1.0053933599519067: 211,
#  0.8258841106849752: 212,
#  1.172706421627479: 213,
#  0.31952861664870147: 214,
#  0.0003032592505619776: 215,
#  0.8790528667922621: 216,
#  0.2746267315330879: 217,
#  0.7970933750949194: 218,
#  0.5967777587544072: 219,
#  0.5996729735784035: 220,
#  0.3687321673218211: 221,
#  0.15680279008094988: 222,
#  0.4733526180008959: 223,
#  0.6261555639956764: 224,
#  0.2839899440223991: 225,
#  0.5642142632877123: 226,
#  0.7426658743374799: 227,
#  0.532815751396261: 228,
#  0.4496059347205652: 229,
#  0.3152393208342308: 230,
#  0.2942984361288996: 231,
#  0.34035652389302307: 232,
#  0.2678010566497655: 233,
#  0.47361687880810943: 234,
#  0.11940042658498706: 235,
#  0.14360188031838456: 236,
#  0.4464504116736703: 237,
#  0.44179967076115567: 238,
#  0.5730643387947569: 239,
#  0.031060931372439593: 240,
#  0.1109243159875608: 241,
#  0.4239595799140621: 242,
#  1.5157175300073709: 243,
#  0.3298344981873276: 244,
#  0.43282211734099946: 245,
#  0.9709560155827152: 246,
#  0.1382030460732162: 247,
#  0.3193070311096742: 248,
#  0.6359371537863753: 249,
#  1.3614448506637995: 250,
#  0.026688403168191266: 251,
#  0.6205403267550463: 252,
#  0.2198940255363237: 253,
#  0.5394204928413946: 254,
#  0.5693747456008884: 255,
#  0.32873155462296166: 256,
#  1.0866313862770407: 257,
#  0.6342594628783536: 258,
#  0.7992735948370769: 259,
#  0.29226074937597346: 260,
#  0.9688012065033584: 261,
#  0.2257648265567918: 262,
#  0.014690413070738373: 263,
#  0.6822186833438795: 264,
#  0.25680566815940753: 265,
#  0.3273031176844712: 266,
#  0.8614660469627378: 267,
#  0.9544261617626311: 268,
#  1.1822398639902187: 269,
#  0.36865493970104146: 270,
#  0.33896806059331785: 271,
#  0.4104116598871242: 272,
#  0.9458085513078931: 273,
#  0.8574135711762665: 274,
#  0.10778898575878704: 275,
#  0.19494262450664968: 276,
#  0.9715443526983439: 277,
#  1.9677215817332097: 278,
#  0.009783823458469065: 279,
#  0.686704150207896: 280,
#  0.7135105284691929: 281,
#  0.5087231298955774: 282,
#  0.4691483463471132: 283,
#  0.04922112112643795: 284,
#  1.5369562292951193: 285,
#  0.6752154295445781: 286,
#  0.42606155025523895: 287,
#  1.7284977498746914: 288,
#  1.280254650741155: 289,
#  0.16069294567745707: 290,
#  0.36921456455495205: 291,
#  0.005347836494855374: 292,
#  0.8160449447665844: 293,
#  0.24023486107184855: 294,
#  0.7075202375153647: 295,
#  0.8104951519296448: 296,
#  1.332292494927506: 297,
#  0.5034798434995019: 298,
#  0.15659550773494574: 299,
#  0.2185982578377632: 300,
#  0.6381906696234529: 301,
#  0.7153858811437441: 302,
#  0.813967033032367: 303,
#  0.017857728701018205: 304,
#  0.5018080329527441: 305,
#  0.6032315173676501: 306,
#  0.57887449839136: 307,
#  0.8694392784736029: 308,
#  1.160027646088977: 309,
#  2.725862278762511: 310,
#  1.0980143780649243: 311,
#  0.3386106790313362: 312,
#  0.2989648278022936: 313,
#  0.44735155041591845: 314,
#  0.4971802274328655: 315,
#  0.22869892629957134: 316,
#  0.623020724997748: 317,
#  0.9238157629742805: 318,
#  0.7265516260931473: 319,
#  0.15882053857936407: 320,
#  0.3933311327448741: 321,
#  0.26061787592417074: 322,
#  0.05196000481018803: 323,
#  0.4838067281017855: 324,
#  0.34767598182968706: 325,
#  0.04408597144207782: 326,
#  0.04806455324560144: 327,
#  1.6672878606879797: 328,
#  0.194920771377614: 329,
#  0.21879080925250494: 330,
#  0.32432353409612213: 331,
#  0.03934080803211337: 332,
#  0.15976156393740482: 333,
#  0.12282541727225049: 334,
#  0.08190588114354158: 335,
#  0.14455056538271216: 336,
#  1.0625060925883991: 337,
#  0.6283378718101922: 338,
#  0.9871881951775521: 339,
#  0.48279270083867604: 340,
#  0.24886457175579402: 341,
#  1.1818658655488479: 342,
#  0.2567373473446979: 343,
#  0.33093175414666864: 344,
#  0.7782946651619009: 345,
#  0.15634145209090677: 346,
#  0.0043700555209440495: 347,
#  0.27082401218955826: 348,
#  0.13409288992147794: 349,
#  0.6995169156924093: 350,
#  0.1972837898404709: 351,
#  1.1385176653343214: 352,
#  0.3370162436244497: 353,
#  0.3466997953823019: 354,
#  1.0425629625396535: 355,
#  0.8641259348945722: 356,
#  0.9347633840905882: 357,
#  0.5696881057506381: 358,
#  1.454186397169792: 359,
#  0.223734943224409: 360,
#  1.120723511034396: 361,
#  1.1047783395888313: 362,
#  0.4547942134928755: 363,
#  0.02604911065686115: 364,
#  0.6039253169232541: 365,
#  0.8471881024531842: 366,
#  0.8893822889091014: 367,
#  0.486755058497008: 368,
#  1.020365968427984: 369,
#  0.07816886876048945: 370,
#  3.891695213894941: 371,
#  0.6429563257835799: 372,
#  0.1125735163890984: 373,
#  0.8505748390830492: 374,
#  0.49972944116008433: 375,
#  0.637133820803518: 376,
#  0.6803298703071206: 377,
#  0.7868411539058601: 378,
#  0.6625777505023904: 379,
#  0.2053555888275339: 380,
#  1.1776830578908748: 381,
#  0.7168477511788525: 382,
#  0.07898602807864608: 383,
#  1.3540094641328422: 384,
#  0.3873042491892309: 385,
#  0.03738590889265514: 386,
#  0.7876773040510563: 387,
#  0.007586689743118491: 388,
#  0.15988778013015104: 389,
#  0.36222216625097003: 390,
#  0.18977713568296384: 391,
#  0.4164739596047652: 392,
#  0.804930495422688: 393,
#  0.3760423662676956: 394,
#  0.1992996640136382: 395,
#  0.7360630862265086: 396,
#  0.6776695266323698: 397,
#  0.649814654185234: 398,
#  1.0264309237398552: 399,
#  0.016730184620224575: 400,
#  0.8989716883893526: 401,
#  0.864404213044931: 402,
#  0.547410794152849: 403,
#  0.11940751270962341: 404,
#  0.1655677115402696: 405,
#  0.3720415715922042: 406,
#  0.12585492635090878: 407,
#  0.2306904437677113: 408,
#  0.19633671380744366: 409,
#  0.09286243079579187: 410,
#  0.09017225685370267: 411,
#  0.4412289629892334: 412,
#  0.05825634838157123: 413,
#  0.9395370241201038: 414,
#  0.16320798721788599: 415,
#  0.8672054472205344: 416,
#  0.2638388465895698: 417,
#  4.379189770178926e-05: 418,
#  0.8618573385038975: 419,
#  0.9450245271175435: 420,
#  0.0729180348764849: 421,
#  0.47146751756668615: 422,
#  0.046800754088333285: 423,
#  0.2465853202426399: 424,
#  0.6966632730776715: 425,
#  0.5254798849026945: 426,
#  0.10294674602265978: 427,
#  1.212226897398704: 428,
#  0.034852191925149434: 429,
#  1.1500285848518224: 430,
#  0.20240647418281443: 431,
#  0.4251294813668496: 432,
#  0.221667607625533: 433,
#  0.2597632695243801: 434,
#  0.6848735676920135: 435,
#  1.2498315619076825: 436,
#  0.13940737999256037: 437,
#  0.5641748493094247: 438,
#  0.3472004731690146: 439,
#  0.47044681724450665: 440,
#  0.6078682620719107: 441,
#  1.1148440034532827: 442,
#  0.2378970347923436: 443,
#  0.30371630814035466: 444,
#  0.570732892802745: 445,
#  0.9558656599575688: 446,
#  0.013035444327033074: 447,
#  0.6574168237588949: 448,
#  0.6265437341939399: 449,
#  0.6886733217392315: 450,
#  1.1662769363012746: 451,
#  0.6480929130568818: 452,
#  0.0033797097442367363: 453,
#  1.4133955102857725: 454,
#  0.766170735285923: 455,
#  0.3433136865212687: 456,
#  0.6876967574619275: 457,
#  0.3674372548802971: 458,
#  0.07588945761230703: 459,
#  0.5202086152381153: 460,
#  1.1814302063489879: 461,
#  0.15591230660106126: 462,
#  0.6156969993675839: 463,
#  0.6837768407841702: 464,
#  0.3430201146503602: 465,
#  0.4111005455455361: 466,
#  0.5089347648127854: 467,
#  0.6063671307617801: 468,
#  0.4759581511624984: 469,
#  0.6577980097265712: 470,
#  0.0689104665129382: 471,
#  0.07448327264452015: 472,
#  0.6237804210562824: 473,
#  1.0537474928162087: 474,
#  0.5094853967342736: 475,
#  0.1723024706044961: 476,
#  0.2667601901597403: 477,
#  0.16596379045512966: 478,
#  0.3795888649105805: 479,
#  0.40495064452114216: 480,
#  1.1288195995400572: 481,
#  0.3884831708887697: 482,
#  0.17162223333511406: 483,
#  0.7117537263003049: 484,
#  1.0312444416333137: 485,
#  1.4926627110589905: 486,
#  1.492835692280799: 487,
#  0.5066968834180836: 488,
#  1.3693073059330791: 489,
#  0.6782890541207727: 490,
#  0.7774855637051388: 491,
#  0.4561350626773669: 492,
#  0.3474556918641456: 493,
#  0.07157093972564876: 494,
#  1.3930718758126424: 495,
#  0.8239733605057029: 496,
#  0.409506876079325: 497,
#  0.8155556565993642: 498,
#  0.8052728461454097: 499,
#  0.9013443695908501: 500,
#  0.5885859849362269: 501,
#  0.48607655918053494: 502,
#  0.04935433856069815: 503,
#  0.6696850376181003: 504,
#  0.7113592257530208: 505,
#  0.7879965239166515: 506,
#  1.4850603652921421: 507,
#  0.08381191289503276: 508,
#  0.3466382188249577: 509,
#  0.015883496769173222: 510,
#  1.5577854161032965: 511}

# %%
from matplotlib import pyplot as plt 
plt.hist(d, bins=20)
plt.show()

# %%
d.sort(reverse=True)
d
# Out:
# [3.891695213894941,
#  2.725862278762511,
#  2.292172058910911,
#  1.9677215817332097,
#  1.8943241294386828,
#  1.7284977498746914,
#  1.6672878606879797,
#  1.6585721513390301,
#  1.579381912438917,
#  1.5577854161032965,
#  1.5369562292951193,
#  1.5157175300073709,
#  1.492835692280799,
#  1.4926627110589905,
#  1.4850603652921421,
#  1.4573339392853164,
#  1.454186397169792,
#  1.446470194318132,
#  1.4170991466947398,
#  1.4133955102857725,
#  1.3930718758126424,
#  1.3693073059330791,
#  1.3614448506637995,
#  1.3540094641328422,
#  1.3412619839370186,
#  1.332292494927506,
#  1.3140708968787302,
#  1.2915402254961372,
#  1.280254650741155,
#  1.2628122585983033,
#  1.2498315619076825,
#  1.2243228119620728,
#  1.212226897398704,
#  1.2114687272040967,
#  1.209659337074269,
#  1.1900542855836047,
#  1.1837938203218925,
#  1.1822398639902187,
#  1.1818658655488479,
#  1.1814302063489879,
#  1.1776830578908748,
#  1.172706421627479,
#  1.1662769363012746,
#  1.160027646088977,
#  1.1500285848518224,
#  1.1385176653343214,
#  1.1288195995400572,
#  1.120723511034396,
#  1.116016310237599,
#  1.1148440034532827,
#  1.1047783395888313,
#  1.1024218625610283,
#  1.1018002108106317,
#  1.0991264091776667,
#  1.0980143780649243,
#  1.096602637687056,
#  1.0917421233373807,
#  1.0866313862770407,
#  1.082758222137667,
#  1.078400461177274,
#  1.0776687340380198,
#  1.0625060925883991,
#  1.0537474928162087,
#  1.0425629625396535,
#  1.0312444416333137,
#  1.0264309237398552,
#  1.0254165581053503,
#  1.020365968427984,
#  1.0188308633363885,
#  1.0053933599519067,
#  1.0039635096198731,
#  0.9959079185389865,
#  0.9871881951775521,
#  0.9815591444838228,
#  0.9735548962721783,
#  0.9719992379120428,
#  0.9715443526983439,
#  0.9709560155827152,
#  0.9688012065033584,
#  0.9599479781674884,
#  0.9584375707766433,
#  0.9558656599575688,
#  0.9544261617626311,
#  0.9471186800105396,
#  0.9458085513078931,
#  0.9450245271175435,
#  0.9444398776353466,
#  0.9395370241201038,
#  0.9365096843818341,
#  0.9347633840905882,
#  0.9343719237614279,
#  0.9340386902742484,
#  0.9338347659316755,
#  0.9238157629742805,
#  0.9213883498076009,
#  0.9013443695908501,
#  0.8989716883893526,
#  0.8893822889091014,
#  0.8891965854145365,
#  0.880453710560001,
#  0.8803303933939172,
#  0.8790528667922621,
#  0.8785161676307498,
#  0.8694392784736029,
#  0.8692164451761042,
#  0.8672054472205344,
#  0.864404213044931,
#  0.8641259348945722,
#  0.8618573385038975,
#  0.8614660469627378,
#  0.8597344217943599,
#  0.8574135711762665,
#  0.8555935648643787,
#  0.8505748390830492,
#  0.8485810065517054,
#  0.8471881024531842,
#  0.8436091676616624,
#  0.8435612378919772,
#  0.843169796619414,
#  0.8258841106849752,
#  0.8239733605057029,
#  0.8203049734006572,
#  0.8198561621648022,
#  0.8160449447665844,
#  0.8155556565993642,
#  0.8147644082449768,
#  0.813967033032367,
#  0.8104951519296448,
#  0.8058725053391207,
#  0.8052728461454097,
#  0.804930495422688,
#  0.7992735948370769,
#  0.7970933750949194,
#  0.7879965239166515,
#  0.7876773040510563,
#  0.7868411539058601,
#  0.7782946651619009,
#  0.7774855637051388,
#  0.7742651837678101,
#  0.766170735285923,
#  0.7564780487309991,
#  0.7538943808416048,
#  0.7493132890983665,
#  0.7485027102251196,
#  0.7426658743374799,
#  0.7360630862265086,
#  0.7265516260931473,
#  0.7257639736649018,
#  0.7168477511788525,
#  0.7161930632079411,
#  0.7153858811437441,
#  0.7135105284691929,
#  0.7117537263003049,
#  0.7113592257530208,
#  0.7106272016048485,
#  0.7080395341308197,
#  0.7075202375153647,
#  0.7035917957559883,
#  0.6995169156924093,
#  0.6983292038561855,
#  0.6966632730776715,
#  0.6939032491668407,
#  0.6910602651440229,
#  0.690012178837776,
#  0.6886733217392315,
#  0.6876967574619275,
#  0.686704150207896,
#  0.6848735676920135,
#  0.6837768407841702,
#  0.6822186833438795,
#  0.6803298703071206,
#  0.6801162079530393,
#  0.6782890541207727,
#  0.6776695266323698,
#  0.6752154295445781,
#  0.6696850376181003,
#  0.6625777505023904,
#  0.6594084207695752,
#  0.6593278870033217,
#  0.6577980097265712,
#  0.6574168237588949,
#  0.649814654185234,
#  0.6480929130568818,
#  0.6449330184747364,
#  0.6429563257835799,
#  0.6381906696234529,
#  0.637133820803518,
#  0.6359371537863753,
#  0.6342594628783536,
#  0.6286527633774437,
#  0.6283378718101922,
#  0.6265437341939399,
#  0.6261555639956764,
#  0.6237804210562824,
#  0.623020724997748,
#  0.6205403267550463,
#  0.6191168581717016,
#  0.6179155335827606,
#  0.6156969993675839,
#  0.6078682620719107,
#  0.6063671307617801,
#  0.6055510342959299,
#  0.604948885833411,
#  0.6039253169232541,
#  0.6032315173676501,
#  0.5996729735784035,
#  0.5979295945617611,
#  0.5967777587544072,
#  0.591995956017358,
#  0.5904375725706308,
#  0.5898425538383487,
#  0.5885859849362269,
#  0.5836666955754475,
#  0.5826421442439823,
#  0.57887449839136,
#  0.5775814561507642,
#  0.5763100062957394,
#  0.5730643387947569,
#  0.5714076253639278,
#  0.570732892802745,
#  0.5704430115966215,
#  0.5696881057506381,
#  0.5693747456008884,
#  0.5642142632877123,
#  0.5641748493094247,
#  0.5498003577268014,
#  0.547410794152849,
#  0.546401389443484,
#  0.5412670256914804,
#  0.5394204928413946,
#  0.5386110778212898,
#  0.532815751396261,
#  0.5314917444618226,
#  0.5254798849026945,
#  0.5218355766984586,
#  0.5202086152381153,
#  0.518295427879089,
#  0.5117503575291584,
#  0.5094853967342736,
#  0.5089347648127854,
#  0.5087231298955774,
#  0.5071878223034021,
#  0.5068491447644853,
#  0.5066968834180836,
#  0.5066591295754252,
#  0.5047751913491876,
#  0.5046080929054377,
#  0.5034798434995019,
#  0.5018080329527441,
#  0.49972944116008433,
#  0.4971802274328655,
#  0.4959930063632383,
#  0.4959286562695284,
#  0.486755058497008,
#  0.48607655918053494,
#  0.4838067281017855,
#  0.48279270083867604,
#  0.4820020244250145,
#  0.476901224156354,
#  0.4759581511624984,
#  0.47361687880810943,
#  0.4733526180008959,
#  0.47146751756668615,
#  0.47044681724450665,
#  0.4691483463471132,
#  0.466326827228254,
#  0.46524495783429143,
#  0.4613673908720836,
#  0.46042576409499514,
#  0.4561350626773669,
#  0.4547942134928755,
#  0.4496059347205652,
#  0.44735155041591845,
#  0.4464504116736703,
#  0.4459327794633854,
#  0.4419632075201849,
#  0.44179967076115567,
#  0.4412289629892334,
#  0.44014433273563425,
#  0.43282211734099946,
#  0.42606155025523895,
#  0.42605322831795606,
#  0.4251294813668496,
#  0.4239595799140621,
#  0.4230760131225848,
#  0.4229683782755781,
#  0.4164739596047652,
#  0.415838905583648,
#  0.41419025322127523,
#  0.41171514609551985,
#  0.4111005455455361,
#  0.4108302127703598,
#  0.4104116598871242,
#  0.4101161695485619,
#  0.409506876079325,
#  0.40495064452114216,
#  0.3982427169291487,
#  0.3933311327448741,
#  0.3927731890975563,
#  0.3884831708887697,
#  0.3873042491892309,
#  0.38696855981326905,
#  0.38599629279152714,
#  0.3795888649105805,
#  0.37804705161252583,
#  0.37773280865076675,
#  0.3760423662676956,
#  0.3720415715922042,
#  0.36921456455495205,
#  0.3687321673218211,
#  0.36865493970104146,
#  0.3674372548802971,
#  0.36222216625097003,
#  0.35617040837842406,
#  0.3541029843825103,
#  0.35378773873595026,
#  0.34940434861504954,
#  0.34767598182968706,
#  0.3474556918641456,
#  0.3472004731690146,
#  0.3466997953823019,
#  0.3466382188249577,
#  0.3433136865212687,
#  0.3430201146503602,
#  0.34035652389302307,
#  0.33896806059331785,
#  0.3386106790313362,
#  0.33776401989208116,
#  0.3370162436244497,
#  0.33432023481451445,
#  0.3314422128734975,
#  0.33093175414666864,
#  0.3298344981873276,
#  0.32873155462296166,
#  0.3273031176844712,
#  0.32432353409612213,
#  0.31952861664870147,
#  0.3193070311096742,
#  0.31736257152351915,
#  0.3172300281028644,
#  0.3152393208342308,
#  0.3129128544587987,
#  0.30371630814035466,
#  0.3024693261639826,
#  0.30090842791178685,
#  0.2989648278022936,
#  0.2954304245380498,
#  0.2942984361288996,
#  0.29226074937597346,
#  0.2912301421122643,
#  0.290529336205373,
#  0.2839899440223991,
#  0.2825516503367025,
#  0.2785740072699314,
#  0.2778396408255954,
#  0.2746267315330879,
#  0.2744347262057125,
#  0.27082401218955826,
#  0.2678010566497655,
#  0.2667601901597403,
#  0.26513463284639205,
#  0.26389573450096554,
#  0.2638388465895698,
#  0.26320762207411463,
#  0.26078221245679223,
#  0.26061787592417074,
#  0.2597632695243801,
#  0.25680566815940753,
#  0.2567373473446979,
#  0.24886457175579402,
#  0.2465853202426399,
#  0.24023486107184855,
#  0.2378970347923436,
#  0.2344503230063839,
#  0.2306904437677113,
#  0.230355934553085,
#  0.22869892629957134,
#  0.22707789436137382,
#  0.2257648265567918,
#  0.223734943224409,
#  0.221667607625533,
#  0.22163691188469792,
#  0.2198940255363237,
#  0.21879080925250494,
#  0.2185982578377632,
#  0.21835264786559228,
#  0.21732217994076852,
#  0.21553806733739567,
#  0.20830706889089612,
#  0.20695643561576604,
#  0.2053555888275339,
#  0.20240647418281443,
#  0.20140816003302614,
#  0.1992996640136382,
#  0.1972837898404709,
#  0.19682278870107428,
#  0.19633671380744366,
#  0.19505004692204686,
#  0.19494262450664968,
#  0.194920771377614,
#  0.19129782801269896,
#  0.18977713568296384,
#  0.18826546781721165,
#  0.18606790476808577,
#  0.18577134469592327,
#  0.1767074417295465,
#  0.17345604280980598,
#  0.1723024706044961,
#  0.17198135492015887,
#  0.17162223333511406,
#  0.16596379045512966,
#  0.1655677115402696,
#  0.16320798721788599,
#  0.16069294567745707,
#  0.15988778013015104,
#  0.15976156393740482,
#  0.15882053857936407,
#  0.15680279008094988,
#  0.15659550773494574,
#  0.15634145209090677,
#  0.15591230660106126,
#  0.14835809364984853,
#  0.14744764466553661,
#  0.14696798319198312,
#  0.14665825999509918,
#  0.14455056538271216,
#  0.14360188031838456,
#  0.13940737999256037,
#  0.1382030460732162,
#  0.13409288992147794,
#  0.1303916505297913,
#  0.1266419634540057,
#  0.12585492635090878,
#  0.12441212610764918,
#  0.12282541727225049,
#  0.11978413911023766,
#  0.11940751270962341,
#  0.11940042658498706,
#  0.11915944700471276,
#  0.11871873418830359,
#  0.1164006285860142,
#  0.11366361913921685,
#  0.1125735163890984,
#  0.11224585417229482,
#  0.1109243159875608,
#  0.10778898575878704,
#  0.10717701298806077,
#  0.10631440293431593,
#  0.10294674602265978,
#  0.10243948940585845,
#  0.10103189143969704,
#  0.0942900742809778,
#  0.09286243079579187,
#  0.09017225685370267,
#  0.08478863083419697,
#  0.08381191289503276,
#  0.08190588114354158,
#  0.07918842966572504,
#  0.07898602807864608,
#  0.07816886876048945,
#  0.07651775041459558,
#  0.07588945761230703,
#  0.07448327264452015,
#  0.07443880099223693,
#  0.07416093129653878,
#  0.0729180348764849,
#  0.07281062088845813,
#  0.07242802089842981,
#  0.07230438531016808,
#  0.07157093972564876,
#  0.0689104665129382,
#  0.0682978505899019,
#  0.06758021601837683,
#  0.061161604707702696,
#  0.05825634838157123,
#  0.05196000481018803,
#  0.04935433856069815,
#  0.04922112112643795,
#  0.04806455324560144,
#  0.04702376473958003,
#  0.046800754088333285,
#  0.045216779674729146,
#  0.04461433910985102,
#  0.04408597144207782,
#  0.04091456090597556,
#  0.03934080803211337,
#  0.03738590889265514,
#  0.035850852477479433,
#  0.034852191925149434,
#  0.031060931372439593,
#  0.029082693102009394,
#  0.026688403168191266,
#  0.02604911065686115,
#  0.017857728701018205,
#  0.017380646070933148,
#  0.016730184620224575,
#  0.016340001885609468,
#  0.015883496769173222,
#  0.015552463867130939,
#  0.014690413070738373,
#  0.01392462218818502,
#  0.013035444327033074,
#  0.009783823458469065,
#  0.008289468456221805,
#  0.007586689743118491,
#  0.005347836494855374,
#  0.0043700555209440495,
#  0.00367684498843035,
#  0.0035446135943584256,
#  0.0033797097442367363,
#  0.0003032592505619776,
#  4.379189770178926e-05]

# %% [markdown]
# Select 10 dimensions which have the largest average value

# %%
n = 10
topn = []
for v in d[:n]:
    print(diff[v], v)
    topn.append(diff[v])

print(topn)
# Out:
# 371 3.891695213894941
# 310 2.725862278762511
# 54 2.292172058910911
# 278 1.9677215817332097
# 3 1.8943241294386828
# 288 1.7284977498746914
# 328 1.6672878606879797
# 172 1.6585721513390301
# 119 1.579381912438917
# 511 1.5577854161032965
# [371, 310, 54, 278, 3, 288, 328, 172, 119, 511]

# %% [markdown]
# Select 10 dimensions which have the smallest average value

# %%
n = 10
botn = []
for v in d[-n:]:
    print(diff[v], v)
    botn.append(diff[v])

print(botn)
# Out:
# 279 0.009783823458469065
# 121 0.008289468456221805
# 388 0.007586689743118491
# 292 0.005347836494855374
# 347 0.0043700555209440495
# 51 0.00367684498843035
# 14 0.0035446135943584256
# 453 0.0033797097442367363
# 215 0.0003032592505619776
# 418 4.379189770178926e-05
# [279, 121, 388, 292, 347, 51, 14, 453, 215, 418]

# %% [markdown]
# From the obtained results, we hypothesize that the dimensions 371, 310, 54，278, 3 may encode information about Singular and Plural Nouns.
# And the dimensions such 418, 215, 453, 14, 51  don't encode this information.

# %% [markdown]
# For test our hypothesis, next we can see the correlation between these dimensions with  Singular Noun and Plural Noun, for do this we can create a new column "nb" in which encoding Singular Noun as 0 and Plural Nouns as 1:

# %%
sg_pl_n_we=pd.concat([sg_n_we, pl_n_we])
sg_pl_n_we.loc[sg_pl_n_we['gn'] == 'singular', 'nb'] = 0
sg_pl_n_we.loc[sg_pl_n_we['gn'] == 'plural', 'nb'] = 1
sg_pl_n_we
# Out:
#                    0         1         2         3         4         5  \
# abri        5.471711 -4.372995  1.739335 -4.412735  4.930413 -8.995445
# absence     3.322297 -0.768149  3.555035 -0.685460  1.201102 -3.151831
# accent     -1.783984 -0.983782  2.905572 -3.458411 -1.267276 -3.330925
# accident    4.179721  2.913542  1.124980  2.269820  0.573966 -3.254911
# accord     -0.732188 -2.024965  1.674970 -4.194049 -2.528312 -2.400746
# ...              ...       ...       ...       ...       ...       ...
# étudiants   3.238430 -4.186950  3.466894  0.049728 -6.309442 -8.333128
# étés        2.757932  0.903210  0.184015  1.369026 -0.241391 -3.674196
# événements -1.245101 -0.820061  1.330310  5.786696  3.966537 -3.242018
# êtres       3.589590 -4.551544  6.088149  2.847501  3.829500 -3.342109
# îles       -2.838814 -3.576476 -1.082639  5.224788  1.871563 -5.175120
#
#                    6         7         8         9  ...       511        gn  \
# abri        2.661912  0.189424  4.682540 -1.069355  ... -2.120574  singular
# absence    -3.592423  1.189369 -2.742928 -2.666739  ... -2.381779  singular
# accent     -2.833155  6.685886  2.322869  1.045544  ... -5.526344  singular
# accident   -2.611606 -1.138910  5.944216 -1.380369  ... -3.223269  singular
# accord     -4.672920  0.374903  6.015941 -0.066068  ... -6.660925  singular
# ...              ...       ...       ...       ...  ...       ...       ...
# étudiants   1.362076  3.088547  1.290309 -0.169715  ... -3.539086    plural
# étés        0.942077 -0.553418 -1.468072 -2.633826  ... -2.487086    plural
# événements -0.265572  2.159446  0.661078 -0.936386  ...  1.124227    plural
# êtres       2.749030 -0.169812  1.994654  0.893699  ... -1.285041    plural
# îles        2.896314  1.005481  4.880717 -2.816181  ... -2.508205    plural
#
#                gender  Unnamed: 0      lemme  cgram  genre  nombre  \
# abri        masculine        1272       abri    NOM      m       s
# absence      feminine         931    absence    NOM      f       s
# accent      masculine        1632     accent    NOM      m       s
# accident    masculine        1676   accident    NOM      m       s
# accord      masculine         442     accord    NOM      m       s
# ...               ...         ...        ...    ...    ...     ...
# étudiants   masculine        1949   étudiant    NOM      m       p
# étés        masculine         498        été    NOM      m       p
# événements  masculine         801  événement    NOM      m       p
# êtres       masculine         514       être    NOM      m       p
# îles         feminine         594        île    NOM      f       p
#
#             freqlemlivres   nb
# abri                56.76  0.0
# absence             76.28  0.0
# accent              45.54  0.0
# accident            44.80  0.0
# accord             136.15  0.0
# ...                   ...  ...
# étudiants           38.45  1.0
# étés               125.47  1.0
# événements          84.59  1.0
# êtres              122.57  1.0
# îles               108.24  1.0
#
# [2003 rows x 521 columns]

# %% [markdown]
# Test the correlation of "nb" with 10 dimensions of average which have the smallest difference.

# %%
sg_pl_n_we.loc[:, [ '279', '121', '388', '292', '347','51','14','453','215','418','nb']].corr()
# Out:
#           279       121       388       292       347        51        14  \
# 279  1.000000  0.027593 -0.002351 -0.073639 -0.262766  0.070398  0.228692
# 121  0.027593  1.000000 -0.175328  0.021637 -0.085977  0.045028 -0.014902
# 388 -0.002351 -0.175328  1.000000 -0.055884 -0.195430  0.101429 -0.087396
# 292 -0.073639  0.021637 -0.055884  1.000000  0.044087  0.055084  0.062023
# 347 -0.262766 -0.085977 -0.195430  0.044087  1.000000 -0.102925  0.023018
# 51   0.070398  0.045028  0.101429  0.055084 -0.102925  1.000000  0.059133
# 14   0.228692 -0.014902 -0.087396  0.062023  0.023018  0.059133  1.000000
# 453  0.032550  0.023291 -0.063199 -0.055740  0.191158  0.022582 -0.016105
# 215 -0.188332  0.084678  0.013474 -0.007168  0.156062 -0.005059 -0.098475
# 418 -0.102646 -0.183004  0.030603  0.144580 -0.006715  0.238553  0.003935
# nb   0.001848  0.001511 -0.001285 -0.000978  0.000846 -0.000751  0.000642
#
#           453       215       418        nb
# 279  0.032550 -0.188332 -0.102646  0.001848
# 121  0.023291  0.084678 -0.183004  0.001511
# 388 -0.063199  0.013474  0.030603 -0.001285
# 292 -0.055740 -0.007168  0.144580 -0.000978
# 347  0.191158  0.156062 -0.006715  0.000846
# 51   0.022582 -0.005059  0.238553 -0.000751
# 14  -0.016105 -0.098475  0.003935  0.000642
# 453  1.000000  0.067114 -0.089462 -0.000711
# 215  0.067114  1.000000  0.009559 -0.000058
# 418 -0.089462  0.009559  1.000000  0.000009
# nb  -0.000711 -0.000058  0.000009  1.000000

# %% [markdown]
# All these dimenensions have a small correlation with "nb".

# %% [markdown]
# Test the correlation of "nb" with 10 dimensions of average which have the largest difference.

# %%
sg_pl_n_we.loc[:, [ '371', '310', '54', '278', '3','288','328','172','119','511','nb']].corr()
# Out:
#           371       310        54       278         3       288       328  \
# 371  1.000000  0.511196  0.278813 -0.131742 -0.159121 -0.258674 -0.111160
# 310  0.511196  1.000000  0.314957 -0.181509 -0.139288 -0.358493 -0.117761
# 54   0.278813  0.314957  1.000000 -0.308686 -0.214171 -0.203563 -0.079830
# 278 -0.131742 -0.181509 -0.308686  1.000000  0.130914  0.064219  0.027047
# 3   -0.159121 -0.139288 -0.214171  0.130914  1.000000  0.100026  0.086670
# 288 -0.258674 -0.358493 -0.203563  0.064219  0.100026  1.000000  0.289869
# 328 -0.111160 -0.117761 -0.079830  0.027047  0.086670  0.289869  1.000000
# 172 -0.006577  0.230552  0.153331 -0.237038 -0.140222 -0.237740 -0.015410
# 119 -0.662279 -0.395994 -0.199986 -0.018146  0.181574  0.292585  0.233641
# 511 -0.241202 -0.287538 -0.275803  0.141312 -0.031307  0.184464  0.098966
# nb  -0.146837 -0.446540 -0.445973  0.344856  0.286083  0.369830  0.292560
#
#           172       119       511        nb
# 371 -0.006577 -0.662279 -0.241202 -0.146837
# 310  0.230552 -0.395994 -0.287538 -0.446540
# 54   0.153331 -0.199986 -0.275803 -0.445973
# 278 -0.237038 -0.018146  0.141312  0.344856
# 3   -0.140222  0.181574 -0.031307  0.286083
# 288 -0.237740  0.292585  0.184464  0.369830
# 328 -0.015410  0.233641  0.098966  0.292560
# 172  1.000000 -0.105738 -0.114167 -0.305622
# 119 -0.105738  1.000000  0.196862  0.235523
# 511 -0.114167  0.196862  1.000000  0.262537
# nb  -0.305622  0.235523  0.262537  1.000000

# %% [markdown]
# Compared to the above dimensions, these dimensions have significantly better correlation  with "nb". 310, 54, 288, 278, 172 have the highest correlation with "nb".

# %% [markdown]
# # See in dimensions

# %% [markdown]
# Dimension for lowest correlation with "nb"

# %% [markdown]
# Dimension 418

# %%
plt.plot(range(len(sg_n_we)), sg_n_we.loc[:, '418'], label='Singular Noun')
plt.plot(range(len(sg_n_we)), pl_n_we.loc[:, '418'][:len(sg_n_we)], label='Plural Noun')
plt.xlabel('Word index')
plt.ylabel('Dimension 418 value')
plt.legend()

# %%
sg_pl_n_we.loc[:, '418'].sort_values()[-10:]
# Out:
# réflexions      6.190972
# dizaine         6.195989
# herbe           6.214879
# circonstance    6.359576
# consciences     6.782515
# accords         6.850119
# cons            6.913197
# centaine        7.486449
# paroles         7.780978
# adresses        8.400760
# Name: 418, dtype: float64

# %%
sg_pl_n_we.loc[:, '418'].sort_values()[:10]
# Out:
# blessures   -9.184031
# laine       -8.813732
# jupe        -7.980783
# chutes      -7.975482
# plis        -7.950732
# col         -7.772820
# talons      -7.386537
# seins       -7.129294
# poitrine    -7.072843
# vitesses    -6.948288
# Name: 418, dtype: float64

# %% [markdown]
# Dimension 215

# %%
plt.plot(range(len(sg_n_we)), sg_n_we.loc[:, '215'], label='Singular Noun')
plt.plot(range(len(sg_n_we)), pl_n_we.loc[:, '215'][:len(sg_n_we)], label='Plural Noun')
plt.xlabel('Word index')
plt.ylabel('Dimension 215 value')
plt.legend()

# %%
sg_pl_n_we.loc[:, '215'].sort_values()[-10:]
# Out:
# milliers       7.410039
# chauffeur      7.949478
# samedis        8.232465
# dimanche       8.378491
# samedi         8.553403
# wagons         8.656518
# camions        9.048304
# centaines      9.691566
# dizaines       9.737687
# chauffeurs    10.136073
# Name: 215, dtype: float64

# %%
sg_pl_n_we.loc[:, '215'].sort_values()[:10]
# Out:
# opinions   -10.646559
# menton      -8.456471
# poitrine    -8.390445
# opinion     -7.993327
# visage      -7.702073
# portrait    -7.521085
# idées       -7.185877
# figure      -7.104073
# poing       -7.042628
# hanches     -7.005396
# Name: 215, dtype: float64

# %% [markdown]
# Dimension 453

# %%
plt.plot(range(len(sg_n_we)), sg_n_we.loc[:, '453'], label='Singular Noun')
plt.plot(range(len(sg_n_we)), pl_n_we.loc[:, '453'][:len(sg_n_we)], label='Plural Noun')
plt.xlabel('Word index')
plt.ylabel('Dimension 453 value')
plt.legend()

# %%
sg_pl_n_we.loc[:, '453'].sort_values()[-10:]
# Out:
# gendarme    4.988193
# chocs       5.026454
# taxi        5.267073
# crises      5.712227
# chemise     5.745047
# phares      5.833425
# taxis       5.838516
# matins      5.927477
# crise       6.197182
# chienne     6.859229
# Name: 453, dtype: float64

# %%
sg_pl_n_we.loc[:, '453'].sort_values()[:10]
# Out:
# présent     -10.688568
# cartons     -10.525474
# bande       -10.130072
# seconde      -9.909966
# espèce       -9.342473
# paires       -9.001535
# fins         -8.593749
# fins         -8.593749
# doute        -8.370351
# intention    -8.196182
# Name: 453, dtype: float64

# %% [markdown]
# Dimension 14

# %%
plt.plot(range(len(sg_n_we)), sg_n_we.loc[:, '14'], label='Singular Noun')
plt.plot(range(len(sg_n_we)), pl_n_we.loc[:, '14'][:len(sg_n_we)], label='Plural Noun')
plt.xlabel('Word index')
plt.ylabel('Dimension 14 value')
plt.legend()

# %%
sg_pl_n_we.loc[:, '14'].sort_values()[-10:]
# Out:
# idées        8.819974
# retraite     9.044084
# talents      9.251905
# inconnue     9.310341
# talent       9.462494
# rêves        9.654068
# taille      10.288196
# sourires    10.351396
# humeur      10.572078
# qualités    10.996766
# Name: 14, dtype: float64

# %%
sg_pl_n_we.loc[:, '14'].sort_values()[:10]
# Out:
# tout           -7.516728
# égard          -7.284020
# passage        -6.974144
# bains          -6.476223
# parois         -6.424981
# dispositions   -5.924611
# passages       -5.919564
# côté           -5.607656
# instructions   -5.562796
# coupe          -5.334624
# Name: 14, dtype: float64

# %% [markdown]
# Dimension 51

# %%
plt.plot(range(len(sg_n_we)), sg_n_we.loc[:, '51'], label='Singular Noun')
plt.plot(range(len(sg_n_we)), pl_n_we.loc[:, '51'][:len(sg_n_we)], label='Plural Noun')
plt.xlabel('Word index')
plt.ylabel('Dimension 51 value')
plt.legend()

# %%
sg_pl_n_we.loc[:, '51'].sort_values()[-10:]
# Out:
# colonne        9.875505
# villas         9.892974
# manière        9.915463
# forêts         9.963669
# vies          10.045238
# enfer         10.090341
# souffrance    10.450445
# violence      10.555352
# expression    10.712020
# solitude      10.893773
# Name: 51, dtype: float64

# %%
sg_pl_n_we.loc[:, '51'].sort_values()[:10]
# Out:
# lycée      -5.364751
# contact    -4.880090
# mouchoir   -4.860706
# ennemies   -4.473399
# étudiant   -3.517954
# pli        -3.485327
# carton     -3.346425
# lycées     -3.225104
# crayons    -2.813531
# ville      -2.803459
# Name: 51, dtype: float64

# %% [markdown]
# Dimension for largest correlation with "nb"

# %% [markdown]
# Dimension 310

# %%
plt.plot(range(len(sg_n_we)), sg_n_we.loc[:, '310'], label='Singular Noun')
plt.plot(range(len(sg_n_we)), pl_n_we.loc[:, '310'][:len(sg_n_we)], label='Plural Noun')
plt.xlabel('Word index')
plt.ylabel('Dimension 310 value')
plt.legend()

# %%
sg_pl_n_we.loc[:, '310'].sort_values()[-10:]
# Out:
# calme          11.550736
# article        11.632575
# détail         11.645336
# direction      11.658642
# ministre       12.018818
# sou            12.525866
# juge           12.530373
# nom            13.014243
# principe       13.236145
# commissaire    14.191738
# Name: 310, dtype: float64

# %%
sg_pl_n_we.loc[:, '310'].sort_values()[:10]
# Out:
# opinions    -5.967048
# lunettes    -5.083002
# assiettes   -4.786969
# juifs       -4.517591
# étrangers   -4.254983
# péchés      -4.043531
# messages    -4.040105
# inconnus    -4.017838
# lapins      -3.988821
# marchands   -3.920392
# Name: 310, dtype: float64

# %% [markdown]
# Dimension 54

# %%
plt.plot(range(len(sg_n_we)), sg_n_we.loc[:, '54'], label='Singular Noun')
plt.plot(range(len(sg_n_we)), pl_n_we.loc[:, '54'][:len(sg_n_we)], label='Plural Noun')
plt.xlabel('Word index')
plt.ylabel('Dimension 54 value')
plt.legend()

# %%
sg_pl_n_we.loc[:, '54'].sort_values()[-10:]
# Out:
# sommeil     7.168465
# médecin     7.178248
# rêve        7.298036
# voie        7.348004
# douleur     7.395598
# maladie     7.876612
# droit       8.174099
# allemand    8.252660
# séjour      8.461544
# train       8.613577
# Name: 54, dtype: float64

# %%
sg_pl_n_we.loc[:, '54'].sort_values()[:10]
# Out:
# fois         -7.326514
# présences    -7.192498
# incidents    -6.807852
# divisions    -6.497854
# échelles     -6.329957
# occasions    -6.272720
# directions   -6.269876
# sexes        -6.266834
# boutons      -6.264966
# crises       -6.230406
# Name: 54, dtype: float64

# %% [markdown]
# Dimension 288

# %%
plt.plot(range(len(sg_n_we)), sg_n_we.loc[:, '288'], label='Singular Noun')
plt.plot(range(len(sg_n_we)), pl_n_we.loc[:, '288'][:len(sg_n_we)], label='Plural Noun')
plt.xlabel('Word index')
plt.ylabel('Dimension 288 value')
plt.legend()

# %%
sg_pl_n_we.loc[:, '288'].sort_values()[-10:]
# Out:
# fusils      3.566502
# courants    3.757580
# prénoms     3.882285
# disques     3.892021
# mèches      3.940004
# balcons     4.338220
# poignets    4.350522
# thés        4.351564
# armoires    4.818262
# blonds      6.384378
# Name: 288, dtype: float64

# %%
sg_pl_n_we.loc[:, '288'].sort_values()[:10]
# Out:
# peine      -10.051662
# carrière    -8.846559
# figure      -8.744933
# rang        -8.556915
# vertu       -8.435489
# prison      -8.432453
# statue      -8.321226
# régime      -8.295894
# fonction    -8.215627
# menace      -8.082767
# Name: 288, dtype: float64

# %% [markdown]
# Dimension 278

# %%
plt.plot(range(len(sg_n_we)), sg_n_we.loc[:, '278'], label='Singular Noun')
plt.plot(range(len(sg_n_we)), pl_n_we.loc[:, '278'][:len(sg_n_we)], label='Plural Noun')
plt.xlabel('Word index')
plt.ylabel('Dimension 278 value')
plt.legend()

# %%
sg_pl_n_we.loc[:, '278'].sort_values()[-10:]
# Out:
# attitudes      9.242421
# taches         9.738168
# patrons        9.808451
# grosses        9.844550
# choses        10.097820
# immeubles     10.112993
# pompes        10.329314
# directeurs    10.395084
# ordres        11.454746
# ronds         11.924365
# Name: 278, dtype: float64

# %%
sg_pl_n_we.loc[:, '278'].sort_values()[:10]
# Out:
# déjeuner     -6.925068
# étranger     -6.730564
# prisonnier   -5.741570
# voyageurs    -5.514399
# lecture      -5.459531
# calme        -5.295695
# famille      -5.177739
# dîner        -5.012671
# voyageur     -5.011798
# charme       -4.890461
# Name: 278, dtype: float64

# %% [markdown]
# Dimension 172

# %%
plt.plot(range(len(sg_n_we)), sg_n_we.loc[:, '172'], label='Singular Noun')
plt.plot(range(len(sg_n_we)), pl_n_we.loc[:, '172'][:len(sg_n_we)], label='Plural Noun')
plt.xlabel('Word index')
plt.ylabel('Dimension 172 value')
plt.legend()

# %%
sg_pl_n_we.loc[:, '172'].sort_values()[-10:]
# Out:
# retraite     7.084777
# sou          7.132194
# cellule      7.222964
# oeuf         7.544065
# sels         7.750596
# larme        8.078182
# bout         8.323427
# cuisse       8.611100
# coude        8.822691
# genou       10.627484
# Name: 172, dtype: float64

# %%
sg_pl_n_we.loc[:, '172'].sort_values()[:10]
# Out:
# voyageurs   -9.391284
# marques     -9.333849
# bons        -8.317432
# bonnes      -7.584717
# tailles     -7.387342
# peintres    -6.907899
# trains      -6.826825
# magasins    -6.684028
# poètes      -6.607919
# écoles      -6.514872
# Name: 172, dtype: float64

# %% [markdown]
# From the above results, it can be seen that for dimensions with a low correlation  with "nb", the values of Singular and Pluaral Noun are almost coincident. However, for dimensions with a high correlation  with "nb", the values of Singular and Plural Noun are significantly different .
# At the same time, we also observed that for dimensions with high correlation with "nb", when we extract the 10 highest and lowest values, there are 10 Singular Nouns and Plural Nouns respectively. However, the low correlation  with "nb" does not have this observation.

# %% [markdown]
# Correlation between dimensions

# %% [markdown]
# We choose 10 dimensions which 5 for lower correlation (418, 215, 453, 14, 51)  with "nb", 5 for largest correlation (310, 54, 288, 278, 172) with "nb" , to see the correlation between them. We assume that these have largest correlation with "nb" have larger correlation between themselves comparing with these have smallest correlation with "nb"

# %%
sg_pl_n_we.loc[:, [ '310', '54', '288', '278', '172','418', '215','453','14','51']].corr()
# Out:
#           310        54       288       278       172       418       215  \
# 310  1.000000  0.314957 -0.358493 -0.181509  0.230552  0.074038  0.173220
# 54   0.314957  1.000000 -0.203563 -0.308686  0.153331 -0.001085  0.065784
# 288 -0.358493 -0.203563  1.000000  0.064219 -0.237740  0.045837 -0.073136
# 278 -0.181509 -0.308686  0.064219  1.000000 -0.237038 -0.033434 -0.023537
# 172  0.230552  0.153331 -0.237740 -0.237038  1.000000 -0.090239 -0.026350
# 418  0.074038 -0.001085  0.045837 -0.033434 -0.090239  1.000000  0.009559
# 215  0.173220  0.065784 -0.073136 -0.023537 -0.026350  0.009559  1.000000
# 453 -0.091632 -0.016140  0.065536  0.016716 -0.078912 -0.089462  0.067114
# 14  -0.185281 -0.071510 -0.134145 -0.046261  0.040525  0.003935 -0.098475
# 51   0.069749 -0.107255 -0.032164  0.061414 -0.023462  0.238553 -0.005059
#
#           453        14        51
# 310 -0.091632 -0.185281  0.069749
# 54  -0.016140 -0.071510 -0.107255
# 288  0.065536 -0.134145 -0.032164
# 278  0.016716 -0.046261  0.061414
# 172 -0.078912  0.040525 -0.023462
# 418 -0.089462  0.003935  0.238553
# 215  0.067114 -0.098475 -0.005059
# 453  1.000000 -0.016105  0.022582
# 14  -0.016105  1.000000  0.059133
# 51   0.022582  0.059133  1.000000

# %% [markdown]
# We see that dimensions 310, 54, 288, 278, 172 have a stronger correlation beetween them, and for 418, 215, 453, 14, 51, they  are neither highly correlated with other dimensions nor highly correlated with each other.

# %% [markdown]
# From the above results we can conclude that maybe one or several of these vectors ： 310， 54， 288， 278， 172 encode the information of Singular and Plural Noun.
