# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Visualizing some WE

# %%
# import data
verbs_df = pd.read_csv('../Data/FlauBERT_WE/all_verb_we.csv')
nouns_df = pd.read_csv('../Data/FlauBERT_WE/all_nouns_we.csv').drop(columns = ["number", "gender"])
adj_df = pd.read_csv('../Data/FlauBERT_WE/all_adjectives_we.csv').drop(columns = ["number", "gender"])

# create a new dataframe with samples of size 5 for each category
df = pd.concat([verbs_df.sample(5, random_state=42), nouns_df.sample(5, random_state=42), adj_df.sample(5,  random_state=42)])
df
# Out:
#                Word         0         1         2         3         4  \
# 9939           êtes  4.567974  2.507673 -1.470071 -1.268955 -0.785729
# 568        extraire  0.373393  1.212998 -0.934320  0.561964 -1.105061
# 8264    mentionnant -2.490006 -0.322799  0.181391 -1.117128 -2.473171
# 2344           fixé  2.823172 -1.065986  3.038691 -2.700218 -0.057217
# 5708       comprend  1.897120 -4.171976  3.831796 -0.383903 -3.092114
# 12386       pigeons  1.546819  2.077061 -1.642449 -2.344042  0.481034
# 385       baignoire  6.007092 -0.972676 -1.873890  4.626863 -2.310743
# 4896         façons  0.314502 -1.188888 -3.757533 -2.245267  1.394504
# 3971        vitesse  2.911135 -2.145964 -2.845298  1.136065 -3.373844
# 10393       verdict  0.324139 -0.312374 -1.020361 -4.544650 -2.185995
# 1357       manipulé  5.508278 -2.407641  3.534946  2.264221  0.117646
# 2080         sexuel  4.421635 -0.577544  3.052637 -5.323138  2.154920
# ...

# %%
# plot heatmaps
import seaborn as sns
import matplotlib.pyplot as plt
import sys
sys.path.append('../Util')
from we import plot_we_heatmap

# %%
# use the Word as index
df = df.set_index('Word')
df
# Out:
#                      0         1         2         3         4         5  \
# Word
# êtes          4.567974  2.507673 -1.470071 -1.268955 -0.785729 -0.363223
# extraire      0.373393  1.212998 -0.934320  0.561964 -1.105061 -6.654667
# mentionnant  -2.490006 -0.322799  0.181391 -1.117128 -2.473171  0.376347
# fixé          2.823172 -1.065986  3.038691 -2.700218 -0.057217 -2.029624
# comprend      1.897120 -4.171976  3.831796 -0.383903 -3.092114  1.347655
# pigeons       1.546819  2.077061 -1.642449 -2.344042  0.481034 -2.991235
# baignoire     6.007092 -0.972676 -1.873890  4.626863 -2.310743 -2.003164
# façons        0.314502 -1.188888 -3.757533 -2.245267  1.394504  1.241161
# vitesse       2.911135 -2.145964 -2.845298  1.136065 -3.373844 -0.263458
# verdict       0.324139 -0.312374 -1.020361 -4.544650 -2.185995 -0.683649
# manipulé      5.508278 -2.407641  3.534946  2.264221  0.117646 -0.094394
# sexuel        4.421635 -0.577544  3.052637 -5.323138  2.154920 -5.444261
# ...

# %%
words = df.index.values

# %%
plot_we_heatmap(df.loc[words, :'511'], save = "test-visualisation")
