# %%
import sys
sys.path.append('../Util')
import pickle
import os

# %%
from IPython.display import Image

# %%
from evaluation import correlation, lr, perceptron, get_anova_dims, get_mi_dims
from preparation import prepare_dataset, read_datasets

# %%
from we import get_we, initiate_model

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from scipy.stats import f_oneway

# %%
from sklearn.metrics import mean_absolute_error, accuracy_score
from sklearn.manifold import TSNE
from sklearn.preprocessing import MinMaxScaler, QuantileTransformer

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
models = [
    {
        'name': 'flaubert/flaubert_small_cased',
        'label': 'flau_small_c'
    },
    {
    
        'name': 'flaubert/flaubert_base_uncased', 
        'label': 'flau_base_u'

    },
    {
        'name': 'flaubert/flaubert_base_cased',
        'label': 'flau_base_c'
    },
    {
        'name': 'flaubert/flaubert_large_cased',
        'label': 'flau_large_c'
    },
    {
        'name': 'camembert/camembert-base',
        'label': 'cam_base'
    },
    {
        'name': 'xlm-roberta-large',
        'label': 'xlm_large'
    },
    {
    
        'name': 'xlm-roberta-base', 
        'label': 'xlm_base'

    },
    {
        'name': 'bert-base-multilingual-uncased',
        'label': 'bert_base_u'
    },
    {
        'name': 'distilbert-base-multilingual-cased',
        'label': 'distilbert_base'
    },
    {
        'name': 'bert-base-multilingual-cased',
        'label': 'bert_base_c'
    }
    
]

# %%
labels = [m['label'] for m in models]

# %%
we_with_features = read_datasets(
                            path = '../Data',
                            model_labels = labels,
                            file_name = 'all_nouns_we.csv'
                    )

# %%
we_with_features[-1].head()
# Out:
#                 0         1         2         3         4         5         6  \
# Word
# 2D       0.836139  0.551025  0.347197  0.789782  0.393246  0.300031  0.609232
# 3D       0.828946  0.549880  0.339958  0.797102  0.395346  0.301288  0.603051
# a        0.826660  0.556389  0.332618  0.805891  0.399844  0.295803  0.597985
# aa       0.826916  0.555891  0.332298  0.805754  0.400046  0.296797  0.597758
# abandon  0.826281  0.556306  0.332007  0.805256  0.399368  0.296458  0.597567
#
#                 7         8         9  ...       762       763       764  \
# Word                                   ...
# 2D       0.913722  0.178287  0.838988  ...  0.586894  0.674134  0.276217
# 3D       0.916539  0.185836  0.844714  ...  0.584636  0.674752  0.278596
# a        0.914675  0.201301  0.846672  ...  0.577705  0.673679  0.278649
# aa       0.914183  0.201098  0.845985  ...  0.578594  0.673429  0.278861
# abandon  0.914983  0.200809  0.846577  ...  0.578808  0.673362  0.279152
#
#               765       766       767      Number     Gender    Lemma  \
# Word
# 2D       0.081619  0.154076  0.553278  invariable   feminine       2D
# 3D       0.078074  0.143366  0.548315  invariable   feminine       3D
# a        0.081689  0.139490  0.533415  invariable  masculine        a
# aa       0.081218  0.139010  0.533594  invariable  masculine       aa
# abandon  0.081560  0.139390  0.534123    singular  masculine  abandon
#
#           Semantic
# Word
# 2D           Other
# 3D           Other
# a        Attribute
# aa           Other
# abandon      Other
#
# [5 rows x 772 columns]

# %%
# There are 3 extra feautres in addition to embedding dimensions in the file: number, gender, lemma, semantic info
feature_col_count = 4

# Feature to investigate in this notebook
feature = 'Gender'

# %% [markdown]
# In this notebook we will calculate **InfEnc** metric for word embeddings of different models, in order to compare the quality of information encoding about `Gender of Nouns`.
#
# Feminine words will be assigned 1 in the feature vector, while masculine words will be assigned 0. Invariable words will be discared.

# %% [markdown]
# # Nouns

# %%
pos = ['NOUN']

# %% [markdown]
# Split each model into train and test using k_fold cross validation:

# %%
X_noun_train = []
y_noun_train = []

X_noun_test = []
y_noun_test = []

# %%
n_folds = 5

# %%
for we in we_with_features:
    X, y = prepare_dataset(dataset=we[(we.Gender != 'invariable') & (we.Number != 'invariable')],
                                           feature_col_count=feature_col_count,
                                           feature_name=feature,
                                           normalize=False,
                                           encode=True,
                                           encode_as1='feminine',
                                           split=False,
                                           balance=True)
    X_trains = []
    y_trains = []
    
    X_tests = []
    y_tests = []
    
    X_folds = np.array_split(X, n_folds)
    y_folds = np.array_split(y, n_folds)
    
    for i in range(n_folds):
        X_trains.append(pd.DataFrame(np.concatenate(X_folds[:i] + X_folds[i+1:])))
        y_trains.append(np.concatenate(y_folds[:i] + y_folds[i+1:]))

        X_folds[i].columns = X_folds[i].columns.map(int)
        X_tests.append(X_folds[i])
        y_tests.append(y_folds[i])
        
    
    X_noun_train.append(X_trains)
    X_noun_test.append(X_tests)
    
    y_noun_train.append(y_trains)
    y_noun_test.append(y_tests)

# %%
dataset_sizes = pd.DataFrame(index=labels)
dataset_sizes['1 fold size'] = [len(x[0]) for x in X_noun_test]
dataset_sizes
# Out:
#                  1 fold size
# flau_small_c            2365
# flau_base_u             2802
# flau_base_c             2365
# flau_large_c            2365
# cam_base                1575
# xlm_large                458
# xlm_base                 458
# bert_base_u              885
# distilbert_base          618
# bert_base_c              618

# %% [markdown]
# Notably, FlauBERT-family vocabulary is the largest out of all other model families.

# %% [markdown]
# ## Non-independent dims

# %% [markdown]
# Calculate non-independendent dimensions for each of _k_ splits.

# %% [markdown]
# ANOVA test with p-value < 0.01:

# %%
anova_dims = []

# %%
for i in range(len(models)):
    anova_dims.append([])
    for j in range(n_folds):
        anova_dims[i].append(get_anova_dims(X_noun_train[i][j], y_noun_train[i][j]))

# %% [markdown]
# Get dimensions where MI > 0:

# %%
mi_dims = []

# %%
for i in range(len(models)):
    mi_dims.append([])
    for j in range(n_folds):
        mi_dims[i].append(get_mi_dims(X_noun_train[i][j], y_noun_train[i][j]))

# %%
for i in range(len(models)):
    for j in range(n_folds):
        temp = list(map(lambda x: int(x), mi_dims[i][j]))
        mi_dims[i][j] = temp

# %% [markdown]
# Get dimensions that are both found by the ANOVA independency test and MI test:

# %%
non_ind_dims = []

# %%
for i in range(len(models)):
    non_ind_dims.append([])
    for j in range(n_folds):
        non_ind_dims[i].append(list(set(anova_dims[i][j]).intersection(mi_dims[i][j])))

# %% [markdown]
# Stats about the number of dimensions for each model for the 1st split:

# %%
non_ind_df = pd.DataFrame(index=labels, columns=['ANOVA', 'MI', 'Total non independent'])

# %%
non_ind_df['ANOVA'] = [len(x[0]) for x in anova_dims]
non_ind_df['MI'] = [len(x[0]) for x in mi_dims]
non_ind_df['Total non independent'] = [len(x[0]) for x in non_ind_dims]

# %%
non_ind_df
# Out:
#                  ANOVA   MI  Total non independent
# flau_small_c       360  332                    256
# flau_base_u        259  683                    234
# flau_base_c        344  422                    208
# flau_large_c       812  765                    646
# cam_base           196  447                    121
# xlm_large          304  565                    184
# xlm_base            55  431                     33
# bert_base_u         11  498                      8
# distilbert_base    255  443                    170
# bert_base_c          0  468                      0

# %%
dims = {}

# %%
for i in range(len(models)):
    dims[labels[i]] = {}
    dims[labels[i]]['All dims'] = [X_noun_train[i][0].columns]*n_folds
    dims[labels[i]]['ANOVA'] = anova_dims[i]
    dims[labels[i]]['MI'] = mi_dims[i]
    dims[labels[i]]['All non ind'] = non_ind_dims[i]

# %% [markdown]
# ## Important dims

# %% [markdown]
# We can test different $\alpha$ values: 1%, 5%, 10%, 25%, 50%, 75%.

# %%
alphas = [1, 5, 10, 25, 50, 75]

# %% [markdown]
# Train Logistic Regression on train set for each model:

# %%
lr_res = []

# %%
for i in range(len(models)):
    lr_res.append([])
    for j in range(n_folds):
        lr_res[i].append(lr(X_noun_train[i][j], y_noun_train[i][j]))

# %% [markdown]
# Train Perceptron:

# %%
perceptron_res = []

# %%
for i in range(len(models)):
    perceptron_res.append([])
    for j in range(n_folds):
        perceptron_res[i].append(perceptron(X_noun_train[i][j], y_noun_train[i][j]))

# %% [markdown]
# Compute correlation to the gender vector:

# %%
corr_res = []

# %%
for i in range(len(models)):
    corr_res.append([])
    for j in range(n_folds):
        corr_res[i].append(correlation(X_noun_train[i][j], y_noun_train[i][j]))

# %%
for i in range(len(models)):
    for alpha in alphas:
        dims[labels[i]][f'LR{alpha}'] = []
        dims[labels[i]][f'Perc{alpha}'] = []
        dims[labels[i]][f'Corr{alpha}'] = []
        dims[labels[i]][f'All imp dims{alpha}'] = []
        for j in range(n_folds):
            num_imp_dims = len(X_noun_test[i][0].columns)*alpha//100
            lr_dims = [x[0] for x in lr_res[i][j][:num_imp_dims]]
            perc_dims = [x[0] for x in perceptron_res[i][j][:num_imp_dims]]
            corr_dims = [x[0] for x in corr_res[i][j][:num_imp_dims]]
            dims[labels[i]][f'LR{alpha}'].append(lr_dims)
            dims[labels[i]][f'Perc{alpha}'].append(perc_dims)
            dims[labels[i]][f'Corr{alpha}'].append(corr_dims)
            dims[labels[i]][f'All imp dims{alpha}'].append(list(set(lr_dims).intersection(perc_dims).intersection(corr_dims)))

# %% [markdown]
# ## Compute medians

# %% [markdown]
# For each of the dimension groups above, compute a median vector: the one that should describe the expected values of the dimensions the best.
# We compute median vector associated with feature vector values = 0 and another one for feature vector values = 1.

# %%
medians = {}

# %%
for i in range(len(models)):
    medians[labels[i]] = {}
    for dim_group in dims[labels[i]].keys():
        medians[labels[i]][dim_group] = []
        n = len(dims[labels[i]][dim_group])
        for j in range(n_folds):
            dim_list = dims[labels[i]][dim_group][j] if n == n_folds else list(dims[labels[i]][dim_group])
            # Median of dimensions where feature vector is equal to 0
            median_0 = X_noun_train[i][j][y_noun_train[i][j] == 0][dim_list].median()
            # Median of dimensions where feature vector is equal to 1
            median_1 = X_noun_train[i][j][y_noun_train[i][j] == 1][dim_list].median()

            medians[labels[i]][dim_group].append({
                    '0': median_0,
                    '1': median_1
                })

# %% [markdown]
# We can compare the number of dimensions found by each test for each model in the first fold:

# %%
dim_lens = {}

for model in dims.keys():
    dim_lens[model] = {}
    for dim_group in dims[model].keys():
        dim_lens[model][dim_group] = len(dims[model][dim_group][0]) if dim_group != 'All dims' else \
                len(dims[model][dim_group])

# %% [markdown]
# Below you can see the number of dimensions found by each type of testing for dimension candidates:

# %%
pd.DataFrame(dim_lens)
# Out:
#                 flau_small_c  flau_base_u  flau_base_c  flau_large_c  \
# All dims                   5            5            5             5
# ANOVA                    360          259          344           812
# MI                       332          683          422           765
# All non ind              256          234          208           646
# LR1                        5            7            7            10
# Perc1                      5            7            7            10
# Corr1                      5            7            7            10
# All imp dims1              1            0            0             0
# LR5                       25           38           38            51
# Perc5                     25           38           38            51
# Corr5                     25           38           38            51
# All imp dims5              7            5            9             5
# LR10                      51           76           76           102
# Perc10                    51           76           76           102
# Corr10                    51           76           76           102
# All imp dims10            20           14           18            19
# LR25                     128          192          192           256
# Perc25                   128          192          192           256
# Corr25                   128          192          192           256
# All imp dims25            52           47           65            85
# LR50                     256          384          384           512
# Perc50                   256          384          384           512
# Corr50                   256          384          384           512
# All imp dims50           129          174          175           239
# LR75                     384          576          576           768
# Perc75                   384          576          576           768
# Corr75                   384          576          576           768
# All imp dims75           251          376          358           514
#
#                 cam_base  xlm_large  xlm_base  bert_base_u  distilbert_base  \
# All dims               5          5         5            5                5
# ANOVA                196        304        55           11              255
# MI                   447        565       431          498              443
# All non ind          121        184        33            8              170
# LR1                    7         10         7            7                7
# Perc1                  7         10         7            7                7
# Corr1                  7         10         7            7                7
# All imp dims1          0          0         1            0                1
# LR5                   38         51        38           38               38
# Perc5                 38         51        38           38               38
# Corr5                 38         51        38           38               38
# All imp dims5          5          3         2            3                5
# LR10                  76        102        76           76               76
# Perc10                76        102        76           76               76
# Corr10                76        102        76           76               76
# All imp dims10         6          8         6            6                8
# LR25                 192        256       192          192              192
# Perc25               192        256       192          192              192
# Corr25               192        256       192          192              192
# All imp dims25        32         28        24           41               43
# LR50                 384        512       384          384              384
# Perc50               384        512       384          384              384
# Corr50               384        512       384          384              384
# All imp dims50       119        138        95          129              144
# LR75                 576        768       576          576              576
# Perc75               576        768       576          576              576
# Corr75               576        768       576          576              576
# All imp dims75       333        428       315          336              340
#
#                 bert_base_c
# All dims                  5
# ANOVA                     0
# MI                      468
# All non ind               0
# LR1                       7
# Perc1                     7
# Corr1                     7
# All imp dims1             0
# LR5                      38
# Perc5                    38
# Corr5                    38
# All imp dims5             1
# LR10                     76
# Perc10                   76
# Corr10                   76
# All imp dims10            4
# LR25                    192
# Perc25                  192
# Corr25                  192
# All imp dims25           23
# LR50                    384
# Perc50                  384
# Corr50                  384
# All imp dims50          120
# LR75                    576
# Perc75                  576
# Corr75                  576
# All imp dims75          339

# %% [markdown]
# ## Compute predictions

# %% [markdown]
# Using the median vectors computed for each group above, try to predict the value of the feature vector on test.
# For this, for any word embedding in test compute distances to median for feature vector values = 0 and for feature vector values = 1.
# If the given word embedding is closer to median of feature vector values = 0, assign 0 as predicted label, 1 otherwise.

# %%
y_preds = {}

# %%
for i in range(len(models)):
    y_preds[labels[i]] = {}
    for dim_group in dims[labels[i]].keys():
        y_preds[labels[i]][dim_group] = []
        n = len(dims[labels[i]][dim_group])
        for j in range(n_folds):
            dim_list = dims[labels[i]][dim_group][j] if n == n_folds else dims[labels[i]][dim_group]
            
            # If MSE for sample 0 is lower than for sample 1, the label should be 0. So we need to convert False to 0.
            mae0 = X_noun_test[i][j][dim_list].apply(lambda x: mean_absolute_error(medians[labels[i]][dim_group][j]['0'], x), axis=1)
            mae1 = X_noun_test[i][j][dim_list].apply(lambda x: mean_absolute_error(medians[labels[i]][dim_group][j]['1'], x), axis=1)
            
            y_preds[labels[i]][dim_group].append((mae0 > mae1).apply(int))

# %% [markdown]
# ## Compute accuracies

# %% [markdown]
# Using the predictions above, compute the accuracies for each dimension group.

# %%
accs = {}

# %%
for i in range(len(models)):
    accs[labels[i]] = {}
    for dim_group in dims[labels[i]].keys():
        accs[labels[i]][dim_group] = []
        for j in range(n_folds):
            y_true = y_noun_test[i][j]
            y_pred = y_preds[labels[i]][dim_group][j]
            if any(y_pred):
                acc = accuracy_score(y_true, y_pred)
            else:
                acc = 0
            accs[labels[i]][dim_group].append(acc)

# %%
# Compute average accuracy between 5 folds
avg_accs = {}

# %%
for i in range(len(models)):
    avg_accs[labels[i]] = {}
    for dim_group in dims[labels[i]].keys():
        avg_accs[labels[i]][dim_group] = np.average(accs[labels[i]][dim_group])

# %%
accs_df = pd.DataFrame(avg_accs)
accs_df
# Out:
#                 flau_small_c  flau_base_u  flau_base_c  flau_large_c  \
# All dims            0.735877     0.567034     0.632526      0.879398
# ANOVA               0.737822     0.578884     0.646058      0.878975
# MI                  0.736807     0.567890     0.627029      0.879567
# All non ind         0.736469     0.576314     0.634810      0.879483
# LR1                 0.615528     0.522273     0.544654      0.649105
# Perc1               0.628891     0.547473     0.573917      0.764970
# Corr1               0.639379     0.548758     0.590322      0.760826
# All imp dims1       0.235823     0.104605     0.000000      0.492061
# LR5                 0.695789     0.545402     0.589815      0.758543
# Perc5               0.727505     0.571388     0.623985      0.846415
# Corr5               0.700863     0.573030     0.626100      0.839988
# All imp dims5       0.649527     0.532053     0.570111      0.703570
# LR10                0.741882     0.551755     0.624323      0.821720
# Perc10              0.771313     0.586880     0.650372      0.874154
# Corr10              0.721839     0.577456     0.634641      0.856056
# All imp dims10      0.713465     0.544831     0.603350      0.781632
# LR25                0.769792     0.558824     0.645043      0.867304
# Perc25              0.804634     0.584809     0.666948      0.893014
# Corr25              0.728942     0.581097     0.647411      0.865866
# All imp dims25      0.748225     0.562679     0.630329      0.849713
# LR50                0.766493     0.566676     0.648257      0.873393
# Perc50              0.781546     0.583239     0.662381      0.892253
# Corr50              0.735708     0.573602     0.642929      0.876438
# All imp dims50      0.772159     0.580954     0.654601      0.875170
# LR75                0.751607     0.567818     0.639039      0.878045
# Perc75              0.757612     0.574672     0.644029      0.888447
# Corr75              0.736976     0.572102     0.638024      0.878890
# All imp dims75      0.769199     0.575457     0.648765      0.883627
#
#                 cam_base  xlm_large  xlm_base  bert_base_u  distilbert_base  \
# All dims        0.518292   0.542388  0.523601     0.479434         0.560194
# ANOVA           0.519181   0.548951  0.528857     0.490733         0.566019
# MI              0.518292   0.543269  0.523165     0.479660         0.563430
# All non ind     0.520452   0.546766  0.529296     0.491185         0.566019
# LR1             0.515371   0.543708  0.547644     0.482147         0.565696
# Perc1           0.527060   0.561179  0.539770     0.488247         0.563107
# Corr1           0.524009   0.557683  0.551143     0.503617         0.576375
# All imp dims1   0.000000   0.000000  0.113537     0.105989         0.112621
# LR5             0.519563   0.544589  0.534107     0.479660         0.583819
# Perc5           0.525280   0.555507  0.532790     0.482146         0.596764
# Corr5           0.522358   0.550693  0.531041     0.485987         0.578964
# All imp dims5   0.522996   0.417265  0.543714     0.493678         0.559223
# LR10            0.518673   0.547640  0.526669     0.479660         0.588997
# Perc10          0.522104   0.559438  0.528856     0.479660         0.591586
# Corr10          0.520960   0.545889  0.526670     0.481921         0.581553
# All imp dims10  0.521725   0.550700  0.539783     0.484407         0.564725
# LR25            0.518292   0.549826  0.525353     0.480112         0.582524
# Perc25          0.518673   0.551135  0.524478     0.479886         0.590939
# Corr25          0.518419   0.547638  0.524485     0.480564         0.567638
# All imp dims25  0.521215   0.557689  0.529731     0.480791         0.599029
# LR50            0.518419   0.545885  0.523604     0.479434         0.571521
# Perc50          0.518292   0.550257  0.523602     0.479434         0.578317
# Corr50          0.518292   0.543703  0.527103     0.480564         0.564401
# All imp dims50  0.519309   0.546325  0.529290     0.479886         0.586084
# LR75            0.518292   0.545015  0.523164     0.479208         0.569256
# Perc75          0.518292   0.543264  0.524038     0.479660         0.569256
# Corr75          0.518292   0.541954  0.523604     0.479208         0.560518
# All imp dims75  0.518419   0.545886  0.523603     0.479434         0.575405
#
#                 bert_base_c
# All dims           0.538835
# ANOVA              0.210032
# MI                 0.538835
# All non ind        0.208091
# LR1                0.537864
# Perc1              0.534951
# Corr1              0.544013
# All imp dims1      0.000000
# LR5                0.540777
# Perc5              0.539482
# Corr5              0.539482
# All imp dims5      0.440777
# LR10               0.540129
# Perc10             0.536246
# Corr10             0.541100
# All imp dims10     0.542071
# LR25               0.540129
# Perc25             0.537864
# Corr25             0.540129
# All imp dims25     0.538188
# LR50               0.538511
# Perc50             0.538188
# Corr50             0.537540
# All imp dims50     0.538835
# LR75               0.538188
# Perc75             0.539159
# Corr75             0.539482
# All imp dims75     0.537864

# %% [markdown]
# We can show what is the accuracy gain for each dimension test comparison to using all dimensions:

# %%
gains_df = (accs_df - accs_df.loc['All dims'])
gains_df
# Out:
#                 flau_small_c  flau_base_u  flau_base_c  flau_large_c  \
# All dims            0.000000     0.000000     0.000000      0.000000
# ANOVA               0.001945     0.011851     0.013532     -0.000423
# MI                  0.000931     0.000856    -0.005497      0.000169
# All non ind         0.000592     0.009280     0.002284      0.000085
# LR1                -0.120348    -0.044761    -0.087872     -0.230293
# Perc1              -0.106985    -0.019561    -0.058610     -0.114428
# Corr1              -0.096498    -0.018276    -0.042204     -0.118572
# All imp dims1      -0.500054    -0.462428    -0.632526     -0.387337
# LR5                -0.040087    -0.021632    -0.042711     -0.120855
# Perc5              -0.008372     0.004354    -0.008542     -0.032983
# Corr5              -0.035014     0.005996    -0.006427     -0.039410
# All imp dims5      -0.086350    -0.034981    -0.062415     -0.175828
# LR10                0.006005    -0.015278    -0.008203     -0.057678
# Perc10              0.035436     0.019846     0.017846     -0.005244
# Corr10             -0.014038     0.010423     0.002115     -0.023342
# All imp dims10     -0.022412    -0.022203    -0.029177     -0.097766
# LR25                0.033915    -0.008210     0.012517     -0.012094
# Perc25              0.068758     0.017775     0.034422      0.013616
# Corr25             -0.006935     0.014064     0.014885     -0.013532
# All imp dims25      0.012348    -0.004355    -0.002198     -0.029685
# LR50                0.030616    -0.000357     0.015731     -0.006004
# Perc50              0.045670     0.016205     0.029854      0.012855
# Corr50             -0.000169     0.006568     0.010403     -0.002960
# All imp dims50      0.036283     0.013920     0.022074     -0.004228
# LR75                0.015731     0.000785     0.006512     -0.001353
# Perc75              0.021736     0.007638     0.011502      0.009049
# Corr75              0.001100     0.005069     0.005497     -0.000507
# All imp dims75      0.033322     0.008424     0.016238      0.004229
#
#                     cam_base  xlm_large      xlm_base   bert_base_u  \
# All dims        0.000000e+00   0.000000  0.000000e+00  0.000000e+00
# ANOVA           8.892116e-04   0.006564  5.256419e-03  1.129892e-02
# MI              0.000000e+00   0.000881 -4.357257e-04  2.262443e-04
# All non ind     2.159698e-03   0.004378  5.695011e-03  1.175090e-02
# LR1            -2.920877e-03   0.001321  2.404327e-02  2.713143e-03
# Perc1           8.767552e-03   0.018792  1.616867e-02  8.813048e-03
# Corr1           5.716545e-03   0.015295  2.754245e-02  2.418335e-02
# All imp dims1  -5.182922e-01  -0.542388 -4.100637e-01 -3.734453e-01
# LR5             1.270648e-03   0.002202  1.050615e-02  2.259887e-04
# Perc5           6.987919e-03   0.013120  9.189416e-03  2.712376e-03
# Corr5           4.065348e-03   0.008306  7.439825e-03  6.552650e-03
# All imp dims5   4.704221e-03  -0.125123  2.011314e-02  1.424393e-02
# LR10            3.808717e-04   0.005253  3.068235e-03  2.259887e-04
# Perc10          3.811621e-03   0.017051  5.255463e-03  2.259887e-04
# Corr10          2.668038e-03   0.003501  3.069191e-03  2.486898e-03
# All imp dims10  3.432444e-03   0.008312  1.618205e-02  4.972774e-03
# LR25            8.067607e-08   0.007438  1.752458e-03  6.779661e-04
# Perc25          3.811137e-04   0.008747  8.771846e-04  4.522330e-04
# Corr25          1.270648e-04   0.005251  8.838734e-04  1.130455e-03
# All imp dims25  2.922410e-03   0.015301  6.129781e-03  1.357210e-03
# LR50            1.270648e-04   0.003497  2.866616e-06  0.000000e+00
# Perc50          0.000000e+00   0.007869  9.555388e-07  2.556433e-07
# Corr50          0.000000e+00   0.001315  3.502050e-03  1.130455e-03
# All imp dims50  1.016276e-03   0.003938  5.689278e-03  4.519774e-04
# LR75            0.000000e+00   0.002628 -4.366812e-04 -2.259887e-04
# Perc75          0.000000e+00   0.000876  4.376368e-04  2.259887e-04
# Corr75          0.000000e+00  -0.000434  2.866616e-06 -2.259887e-04
# All imp dims75  1.270648e-04   0.003498  1.911078e-06  0.000000e+00
#
#                 distilbert_base   bert_base_c
# All dims               0.000000  0.000000e+00
# ANOVA                  0.005825 -3.288026e-01
# MI                     0.003236  0.000000e+00
# All non ind            0.005825 -3.307443e-01
# LR1                    0.005502 -9.708738e-04
# Perc1                  0.002913 -3.883495e-03
# Corr1                  0.016181  5.177994e-03
# All imp dims1         -0.447573 -5.388350e-01
# LR5                    0.023625  1.941748e-03
# Perc5                  0.036570  6.472492e-04
# Corr5                  0.018770  6.472492e-04
# All imp dims5         -0.000971 -9.805825e-02
# LR10                   0.028803  1.294498e-03
# Perc10                 0.031392 -2.588997e-03
# Corr10                 0.021359  2.265372e-03
# All imp dims10         0.004531  3.236246e-03
# LR25                   0.022330  1.294498e-03
# Perc25                 0.030744 -9.708738e-04
# Corr25                 0.007443  1.294498e-03
# All imp dims25         0.038835 -6.472492e-04
# LR50                   0.011327 -3.236246e-04
# Perc50                 0.018123 -6.472492e-04
# Corr50                 0.004207 -1.294498e-03
# All imp dims50         0.025890  1.110223e-16
# LR75                   0.009061 -6.472492e-04
# Perc75                 0.009061  3.236246e-04
# Corr75                 0.000324  6.472492e-04
# All imp dims75         0.015210 -9.708738e-04

# %% [markdown]
# Here are the dimension groups and the accuracy gain this dimension group provides over all dimensions:

# %%
for i in range(len(models)):
    print(labels[i], gains_df.idxmax()[i], gains_df.loc[gains_df.idxmax()[i], labels[i]])
# Out:
# flau_small_c Perc25 0.06875754356217101
# flau_base_u Perc10 0.01984597628918594
# flau_base_c Perc25 0.03442200305498622
# flau_large_c Perc25 0.013616259394797936
# cam_base Perc1 0.00876755208648472
# xlm_large Perc1 0.01879162565812731
# xlm_base Corr1 0.027542449810325498
# bert_base_u Corr1 0.024183347393716303
# distilbert_base All imp dims25 0.03883495145631077
# bert_base_c Corr1 0.00517799352750814

# %% [markdown]
# Below, you can find the best achieved accuracy and the dimension group that produced it. This value is `InfEnc`.

# %%
for i in range(len(models)):
    print(labels[i], accs_df.idxmax()[i], accs_df.loc[accs_df.idxmax()[i], labels[i]])
# Out:
# flau_small_c Perc25 0.8046342780895962
# flau_base_u Perc10 0.5868796221192543
# flau_base_c Perc25 0.6669484480026329
# flau_large_c Perc25 0.8930140622372944
# cam_base Perc1 0.5270598011334987
# xlm_large Perc1 0.5611793259629442
# xlm_base Corr1 0.5511433021509178
# bert_base_u Corr1 0.5036173530689981
# distilbert_base All imp dims25 0.5990291262135923
# bert_base_c Corr1 0.5440129449838188

# %%
with open('../Data/best_results/gender_noun_dims.pickle', 'wb') as f:
    pickle.dump(dims, f)

# %%
with open('../Data/best_results/gender_noun_accs.pickle', 'wb') as f:
    pickle.dump(accs, f)

# %%
with open('../Data/best_results/gender_noun_medians.pickle', 'wb') as f:
    pickle.dump(medians, f)

# %% [markdown]
# # Conclusion

# %% [markdown]
# - Despite same vocabulary sizes, FlauBERT family models show different results. Bigger models (FlauBERT base) show worse results than the smaller model (FlauBERT small). Therefore, we can assume that a higher number of parameters doesn't guarantee better performance.
# - Similarly, DistilBERT performs better than FlauBERT base uncased, which has significantly bigger vocabulary. Therefore, we can assume that vocabulary size doesn't have a big affect on the results.
# - We can note that cased models (FlauBERT base and mBERT) perform better on the task than their uncased analogs.
# - For all models a subset of dimensions and not all dimensions gave the best InfEnc results.
