# %%
import sys
sys.path.append('../Util')
import pickle
import os

# %%
from IPython.display import Image

# %%
from evaluation import correlation, lr, perceptron, get_anova_dims, get_mi_dims
from preparation import prepare_dataset, read_datasets

# %%
from we import get_we, initiate_model

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from scipy.stats import f_oneway

# %%
from sklearn.metrics import mean_absolute_error, accuracy_score
from sklearn.manifold import TSNE
from sklearn.preprocessing import MinMaxScaler, QuantileTransformer

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
models = [
    {
        'name': 'flaubert/flaubert_small_cased',
        'label': 'flau_small_c'
    },
    {
    
        'name': 'flaubert/flaubert_base_uncased', 
        'label': 'flau_base_u'

    },
    {
        'name': 'flaubert/flaubert_base_cased',
        'label': 'flau_base_c'
    },
    {
        'name': 'flaubert/flaubert_large_cased',
        'label': 'flau_large_c'
    },
    {
        'name': 'camembert/camembert-base',
        'label': 'cam_base'
    },
    {
        'name': 'xlm-roberta-large',
        'label': 'xlm_large'
    },
    {
    
        'name': 'xlm-roberta-base', 
        'label': 'xlm_base'

    },
    {
        'name': 'bert-base-multilingual-uncased',
        'label': 'bert_base_u'
    },
    {
        'name': 'distilbert-base-multilingual-cased',
        'label': 'distilbert_base'
    },
    {
        'name': 'bert-base-multilingual-cased',
        'label': 'bert_base_c'
    }
    
]

# %%
labels = [m['label'] for m in models]

# %%
we_with_features = read_datasets(
                            path = '../Data',
                            model_labels = labels,
                            file_name = 'all_unique_pos_we.csv'
                    )

# %%
we_with_features[-1].head()
# Out:
#                 0         1         2         3         4         5         6  \
# Word
# 2D       0.909603  0.551025  0.436937  0.789782  0.311517  0.417476  0.629341
# 3D       0.901779  0.549880  0.427826  0.797102  0.313900  0.419226  0.623478
# aa       0.899570  0.555891  0.418186  0.805754  0.319232  0.412976  0.618457
# abandon  0.898879  0.556306  0.417821  0.805256  0.318463  0.412505  0.618276
# abbaye   0.895888  0.554461  0.420659  0.799339  0.322441  0.418141  0.618820
#
#                 7         8         9  ...       764       765       766  \
# Word                                   ...
# 2D       0.913722  0.349834  0.838988  ...  0.285154  0.057887  0.030874
# 3D       0.916539  0.355807  0.844714  ...  0.287610  0.054251  0.018604
# aa       0.914183  0.367882  0.845985  ...  0.287883  0.057476  0.013614
# abandon  0.914983  0.367654  0.846577  ...  0.288183  0.057827  0.014050
# abbaye   0.921033  0.367005  0.845904  ...  0.293985  0.057312  0.012175
#
#               767      Number     Gender    Lemma   POS  Tense  Person
# Word
# 2D       0.310204  invariable   feminine       2D  NOUN    NaN     NaN
# 3D       0.305226  invariable   feminine       3D  NOUN    NaN     NaN
# aa       0.290463  invariable  masculine       aa  NOUN    NaN     NaN
# abandon  0.290994    singular  masculine  abandon  NOUN    NaN     NaN
# abbaye   0.298473    singular   feminine   abbaye  NOUN    NaN     NaN
#
# [5 rows x 774 columns]

# %%
# There are 6 extra feautres in addition to embedding dimensions in the file
feature_col_count = 6

# Feature to investigate in this notebook
feature = 'Gender'

# %% [markdown]
# In this notebook we will calculate **InfEnc** metric for word embeddings of different models, in order to compare the quality of information encoding about `Gender of Nouns and Adjectives`.
#
#
# For this we will pick concatenate dimensions of word embedding of nouns and adjectives. Note that words that are both adjectives and nouns were discarded previously.
# Feminine words will be assigned 1 in the feature vector, while masculine words will be assigned 0. Invariable words will be discared.

# %% [markdown]
# # Nouns & Adjectives

# %%
pos = ['NOUN', 'ADJ']

# %% [markdown]
# Split each model into train and test using k_fold cross validation:

# %%
X_na_train = []
y_na_train = []

X_na_test = []
y_na_test = []

# %%
n_folds = 5

# %%
for we in we_with_features:
    X, y = prepare_dataset(dataset=we[(we.Gender != 'invariable') & (we.Number != 'invariable') & \
                                      (we.POS.isin(pos))],
                                           feature_col_count=feature_col_count,
                                           feature_name=feature,
                                           normalize=False,
                                           encode=True,
                                           encode_as1='feminine',
                                           split=False,
                                           balance=True)
    X_trains = []
    y_trains = []
    
    X_tests = []
    y_tests = []
    
    X_folds = np.array_split(X, n_folds)
    y_folds = np.array_split(y, n_folds)
    
    for i in range(n_folds):
        X_trains.append(pd.DataFrame(np.concatenate(X_folds[:i] + X_folds[i+1:])))
        y_trains.append(np.concatenate(y_folds[:i] + y_folds[i+1:]))

        X_folds[i].columns = X_folds[i].columns.map(int)
        X_tests.append(X_folds[i])
        y_tests.append(y_folds[i])
        
    
    X_na_train.append(X_trains)
    X_na_test.append(X_tests)
    
    y_na_train.append(y_trains)
    y_na_test.append(y_tests)

# %%
dataset_sizes = pd.DataFrame(index=labels)
dataset_sizes['1 fold size'] = [len(x[0]) for x in X_na_test]
dataset_sizes
# Out:
#                  1 fold size
# flau_small_c            1792
# flau_base_u             2296
# flau_base_c             1792
# flau_large_c            1792
# cam_base                1207
# xlm_large                396
# xlm_base                 396
# bert_base_u              770
# distilbert_base          528
# bert_base_c              528

# %% [markdown]
# ## Non-independent dims

# %% [markdown]
# Calculate non-independendent dimensions for each of _k_ splits.

# %% [markdown]
# ANOVA test with p-value < 0.01:

# %%
anova_dims = []

# %%
for i in range(len(models)):
    anova_dims.append([])
    for j in range(n_folds):
        anova_dims[i].append(get_anova_dims(X_na_train[i][j], y_na_train[i][j]))

# %% [markdown]
# Get dimensions where MI > 0:

# %%
mi_dims = []

# %%
for i in range(len(models)):
    mi_dims.append([])
    for j in range(n_folds):
        mi_dims[i].append(get_mi_dims(X_na_train[i][j], y_na_train[i][j]))

# %%
for i in range(len(models)):
    for j in range(n_folds):
        temp = list(map(lambda x: int(x), mi_dims[i][j]))
        mi_dims[i][j] = temp

# %% [markdown]
# Get dimensions that are both found by the ANOVA independency test and MI test:

# %%
non_ind_dims = []

# %%
for i in range(len(models)):
    non_ind_dims.append([])
    for j in range(n_folds):
        non_ind_dims[i].append(list(set(anova_dims[i][j]).intersection(mi_dims[i][j])))

# %% [markdown]
# Stats about the number of dimensions for each model for the 1st split:

# %%
non_ind_df = pd.DataFrame(index=labels, columns=['ANOVA', 'MI', 'Total non independent'])

# %%
non_ind_df['ANOVA'] = [len(x[0]) for x in anova_dims]
non_ind_df['MI'] = [len(x[0]) for x in mi_dims]
non_ind_df['Total non independent'] = [len(x[0]) for x in non_ind_dims]

# %%
non_ind_df
# Out:
#                  ANOVA   MI  Total non independent
# flau_small_c       347  344                    253
# flau_base_u        223  597                    187
# flau_base_c        326  411                    187
# flau_large_c       782  731                    609
# cam_base           323  540                    231
# xlm_large          411  633                    275
# xlm_base           272  406                    145
# bert_base_u         17  550                     13
# distilbert_base    239  489                    163
# bert_base_c          1  461                      0

# %%
dims = {}

# %%
for i in range(len(models)):
    dims[labels[i]] = {}
    dims[labels[i]]['All dims'] = [X_na_train[i][0].columns]*n_folds
    dims[labels[i]]['ANOVA'] = anova_dims[i]
    dims[labels[i]]['MI'] = mi_dims[i]
    dims[labels[i]]['All non ind'] = non_ind_dims[i]

# %% [markdown]
# ## Important dims

# %% [markdown]
# We can test different $\alpha$ values: 1%, 5%, 10%, 25%, 50%, 75%.

# %%
alphas = [1, 5, 10, 25, 50, 75]

# %% [markdown]
# Train Logistic Regression on train set for each model:

# %%
lr_res = []

# %%
for i in range(len(models)):
    lr_res.append([])
    for j in range(n_folds):
        lr_res[i].append(lr(X_na_train[i][j], y_na_train[i][j]))

# %% [markdown]
# Train Perceptron:

# %%
perceptron_res = []

# %%
for i in range(len(models)):
    perceptron_res.append([])
    for j in range(n_folds):
        perceptron_res[i].append(perceptron(X_na_train[i][j], y_na_train[i][j]))

# %% [markdown]
# Compute correlation to the gender vector:

# %%
corr_res = []

# %%
for i in range(len(models)):
    corr_res.append([])
    for j in range(n_folds):
        corr_res[i].append(correlation(X_na_train[i][j], y_na_train[i][j]))

# %%
for i in range(len(models)):
    for alpha in alphas:
        dims[labels[i]][f'LR{alpha}'] = []
        dims[labels[i]][f'Perc{alpha}'] = []
        dims[labels[i]][f'Corr{alpha}'] = []
        dims[labels[i]][f'All imp dims{alpha}'] = []
        for j in range(n_folds):
            num_imp_dims = len(X_na_test[i][0].columns)*alpha//100
            lr_dims = [x[0] for x in lr_res[i][j][:num_imp_dims]]
            perc_dims = [x[0] for x in perceptron_res[i][j][:num_imp_dims]]
            corr_dims = [x[0] for x in corr_res[i][j][:num_imp_dims]]
            dims[labels[i]][f'LR{alpha}'].append(lr_dims)
            dims[labels[i]][f'Perc{alpha}'].append(perc_dims)
            dims[labels[i]][f'Corr{alpha}'].append(corr_dims)
            dims[labels[i]][f'All imp dims{alpha}'].append(list(set(lr_dims).intersection(perc_dims).intersection(corr_dims)))

# %% [markdown]
# ## Compute medians

# %% [markdown]
# For each of the dimension groups above, compute a median vector: the one that should describe the expected values of the dimensions the best.
# We compute median vector associated with feature vector values = 0 and another one for feature vector values = 1.

# %%
medians = {}

# %%
for i in range(len(models)):
    medians[labels[i]] = {}
    for dim_group in dims[labels[i]].keys():
        medians[labels[i]][dim_group] = []
        n = len(dims[labels[i]][dim_group])
        for j in range(n_folds):
            dim_list = dims[labels[i]][dim_group][j] if n == n_folds else list(dims[labels[i]][dim_group])
            # Median of dimensions where feature vector is equal to 0
            median_0 = X_na_train[i][j][y_na_train[i][j] == 0][dim_list].median()
            # Median of dimensions where feature vector is equal to 1
            median_1 = X_na_train[i][j][y_na_train[i][j] == 1][dim_list].median()

            medians[labels[i]][dim_group].append({
                    '0': median_0,
                    '1': median_1
                })

# %% [markdown]
# We can compare the number of dimensions found by each test for each model in the first fold:

# %%
dim_lens = {}

for model in dims.keys():
    dim_lens[model] = {}
    for dim_group in dims[model].keys():
        dim_lens[model][dim_group] = len(dims[model][dim_group][0]) if dim_group != 'All dims' else \
                len(dims[model][dim_group])

# %%
pd.DataFrame(dim_lens)
# Out:
#                 flau_small_c  flau_base_u  flau_base_c  flau_large_c  \
# All dims                   5            5            5             5
# ANOVA                    347          223          326           782
# MI                       344          597          411           731
# All non ind              253          187          187           609
# LR1                        5            7            7            10
# Perc1                      5            7            7            10
# Corr1                      5            7            7            10
# All imp dims1              1            1            0             2
# LR5                       25           38           38            51
# Perc5                     25           38           38            51
# Corr5                     25           38           38            51
# All imp dims5              6            2            4            13
# LR10                      51           76           76           102
# Perc10                    51           76           76           102
# Corr10                    51           76           76           102
# All imp dims10            23            7           14            24
# LR25                     128          192          192           256
# Perc25                   128          192          192           256
# Corr25                   128          192          192           256
# All imp dims25            58           47           58            82
# LR50                     256          384          384           512
# Perc50                   256          384          384           512
# Corr50                   256          384          384           512
# All imp dims50           141          155          175           260
# LR75                     384          576          576           768
# Perc75                   384          576          576           768
# Corr75                   384          576          576           768
# All imp dims75           257          366          369           521
#
#                 cam_base  xlm_large  xlm_base  bert_base_u  distilbert_base  \
# All dims               5          5         5            5                5
# ANOVA                323        411       272           17              239
# MI                   540        633       406          550              489
# All non ind          231        275       145           13              163
# LR1                    7         10         7            7                7
# Perc1                  7         10         7            7                7
# Corr1                  7         10         7            7                7
# All imp dims1          0          0         1            0                0
# LR5                   38         51        38           38               38
# Perc5                 38         51        38           38               38
# Corr5                 38         51        38           38               38
# All imp dims5          1          4         2            2                3
# LR10                  76        102        76           76               76
# Perc10                76        102        76           76               76
# Corr10                76        102        76           76               76
# All imp dims10         5          6         6           13                7
# LR25                 192        256       192          192              192
# Perc25               192        256       192          192              192
# Corr25               192        256       192          192              192
# All imp dims25        21         24        22           45               43
# LR50                 384        512       384          384              384
# Perc50               384        512       384          384              384
# Corr50               384        512       384          384              384
# All imp dims50       104        146        97          132              156
# LR75                 576        768       576          576              576
# Perc75               576        768       576          576              576
# Corr75               576        768       576          576              576
# All imp dims75       325        441       308          331              354
#
#                 bert_base_c
# All dims                  5
# ANOVA                     1
# MI                      461
# All non ind               0
# LR1                       7
# Perc1                     7
# Corr1                     7
# All imp dims1             0
# LR5                      38
# Perc5                    38
# Corr5                    38
# All imp dims5             1
# LR10                     76
# Perc10                   76
# Corr10                   76
# All imp dims10            4
# LR25                    192
# Perc25                  192
# Corr25                  192
# All imp dims25           23
# LR50                    384
# Perc50                  384
# Corr50                  384
# All imp dims50          124
# LR75                    576
# Perc75                  576
# Corr75                  576
# All imp dims75          340

# %% [markdown]
# ## Compute predictions

# %% [markdown]
# Using the median vectors computed for each group above, try to predict the value of the feature vector on test.
# For this, for any word embedding in test compute distances to median for feature vector values = 0 and for feature vector values = 1.
# If the given word embedding is closer to median of feature vector values = 0, assign 0 as predicted label, 1 otherwise.

# %%
y_preds = {}

# %%
for i in range(len(models)):
    y_preds[labels[i]] = {}
    for dim_group in dims[labels[i]].keys():
        y_preds[labels[i]][dim_group] = []
        n = len(dims[labels[i]][dim_group])
        for j in range(n_folds):
            dim_list = dims[labels[i]][dim_group][j] if n == n_folds else dims[labels[i]][dim_group]
            
            # If MSE for sample 0 is lower than for sample 1, the label should be 0. So we need to convert False to 0.
            mae0 = X_na_test[i][j][dim_list].apply(lambda x: mean_absolute_error(medians[labels[i]][dim_group][j]['0'], x), axis=1)
            mae1 = X_na_test[i][j][dim_list].apply(lambda x: mean_absolute_error(medians[labels[i]][dim_group][j]['1'], x), axis=1)
            
            y_preds[labels[i]][dim_group].append((mae0 > mae1).apply(int))

# %% [markdown]
# ## Compute accuracies

# %% [markdown]
# Using the predictions above, compute the accuracies for each dimension group.

# %%
accs = {}

# %%
for i in range(len(models)):
    accs[labels[i]] = {}
    for dim_group in dims[labels[i]].keys():
        accs[labels[i]][dim_group] = []
        for j in range(n_folds):
            y_true = y_na_test[i][j]
            y_pred = y_preds[labels[i]][dim_group][j]
            if any(y_pred):
                acc = accuracy_score(y_true, y_pred)
            else:
                acc = 0
            accs[labels[i]][dim_group].append(acc)

# %%
# Compute average accuracy between 5 folds
avg_accs = {}

# %%
for i in range(len(models)):
    avg_accs[labels[i]] = {}
    for dim_group in dims[labels[i]].keys():
        avg_accs[labels[i]][dim_group] = np.average(accs[labels[i]][dim_group])

# %%
accs_df = pd.DataFrame(avg_accs)
accs_df
# Out:
#                 flau_small_c  flau_base_u  flau_base_c  flau_large_c  \
# All dims            0.725611     0.550366     0.583388      0.886694
# ANOVA               0.725834     0.561084     0.586178      0.886136
# MI                  0.719470     0.552806     0.587182      0.887476
# All non ind         0.721368     0.560822     0.591647      0.887699
# LR1                 0.615315     0.523090     0.536501      0.671691
# Perc1               0.632285     0.540258     0.581379      0.751955
# Corr1               0.641326     0.549234     0.590980      0.759880
# All imp dims1       0.580375     0.216685     0.000000      0.607946
# LR5                 0.710763     0.539125     0.593879      0.776289
# Perc5               0.721254     0.571976     0.631613      0.852423
# Corr5               0.696137     0.566661     0.599910      0.844274
# All imp dims5       0.646684     0.525271     0.560947      0.730630
# LR10                0.751844     0.548013     0.592651      0.834116
# Perc10              0.769257     0.575723     0.646571      0.876647
# Corr10              0.697479     0.568229     0.596893      0.865372
# All imp dims10      0.705626     0.548100     0.583274      0.781762
# LR25                0.781201     0.551063     0.603258      0.876647
# Perc25              0.793930     0.584350     0.653717      0.901987
# Corr25              0.720252     0.562827     0.599349      0.874748
# All imp dims25      0.752178     0.570670     0.610517      0.857000
# LR50                0.770375     0.556118     0.588744      0.893057
# Perc50              0.773055     0.568491     0.641099      0.903439
# Corr50              0.727285     0.559341     0.584168      0.885132
# All imp dims50      0.780868     0.574503     0.619555      0.897299
# LR75                0.742355     0.554548     0.578921      0.893168
# Perc75              0.747937     0.558818     0.611407      0.894955
# Corr75              0.725946     0.555071     0.578699      0.885801
# All imp dims75      0.763677     0.562478     0.603033      0.898080
#
#                 cam_base  xlm_large  xlm_base  bert_base_u  distilbert_base  \
# All dims        0.534981   0.564280  0.531377     0.500782         0.591797
# ANOVA           0.534816   0.563771  0.526816     0.518466         0.599763
# MI              0.534981   0.565287  0.531881     0.500782         0.584971
# All non ind     0.534816   0.571362  0.526819     0.516904         0.597869
# LR1             0.528679   0.561235  0.537444     0.500526         0.551608
# Perc1           0.533820   0.565790  0.538959     0.499479         0.585733
# Corr1           0.539125   0.579468  0.541488     0.518205         0.579651
# All imp dims1   0.000000   0.000000  0.332383     0.103251         0.113472
# LR5             0.535644   0.562754  0.527325     0.498182         0.591421
# Perc5           0.533654   0.585536  0.533902     0.501822         0.603176
# Corr5           0.536805   0.581488  0.525304     0.514825         0.600139
# All imp dims5   0.536799   0.330340  0.561238     0.504160         0.547407
# LR10            0.533987   0.568834  0.528840     0.500262         0.606968
# Perc10          0.535477   0.579468  0.529854     0.501562         0.611905
# Corr10          0.536308   0.571369  0.526318     0.503382         0.599764
# All imp dims10  0.527685   0.564269  0.531372     0.507023         0.578526
# LR25            0.534816   0.568322  0.530362     0.500782         0.604692
# Perc25          0.534981   0.575919  0.528339     0.500522         0.607349
# Corr25          0.534815   0.569845  0.531878     0.504683         0.598247
# All imp dims25  0.538628   0.591601  0.531377     0.503382         0.607351
# LR50            0.534981   0.562253  0.527834     0.502602         0.601658
# Perc50          0.534981   0.570355  0.530364     0.501042         0.608484
# Corr50          0.534981   0.566809  0.530364     0.500262         0.593309
# All imp dims50  0.535147   0.573388  0.533400     0.502342         0.615314
# LR75            0.534981   0.559725  0.529858     0.501302         0.592178
# Perc75          0.534981   0.567315  0.529857     0.500262         0.599384
# Corr75          0.534981   0.565291  0.529857     0.500782         0.586862
# All imp dims75  0.534981   0.568833  0.529857     0.500782         0.596728
#
#                 bert_base_c
# All dims           0.528460
# ANOVA              0.206258
# MI                 0.528458
# All non ind        0.100190
# LR1                0.528837
# Perc1              0.526940
# Corr1              0.529221
# All imp dims1      0.000000
# LR5                0.528460
# Perc5              0.523148
# Corr5              0.526947
# All imp dims5      0.100758
# LR10               0.528459
# Perc10             0.526942
# Corr10             0.527703
# All imp dims10     0.527701
# LR25               0.526943
# Perc25             0.527321
# Corr25             0.528840
# All imp dims25     0.528460
# LR50               0.527701
# Perc50             0.528460
# Corr50             0.526563
# All imp dims50     0.526944
# LR75               0.528839
# Perc75             0.526943
# Corr75             0.528459
# All imp dims75     0.526942

# %% [markdown]
# We can show what is the accuracy gain for each dimension test comparison to using all dimensions:

# %%
gains_df = (accs_df - accs_df.loc['All dims'])
gains_df
# Out:
#                 flau_small_c  flau_base_u  flau_base_c  flau_large_c  \
# All dims            0.000000     0.000000     0.000000      0.000000
# ANOVA               0.000223     0.010718     0.002790     -0.000558
# MI                 -0.006141     0.002440     0.003794      0.000782
# All non ind        -0.004243     0.010457     0.008259      0.001005
# LR1                -0.110296    -0.027276    -0.046887     -0.215003
# Perc1              -0.093326    -0.010108    -0.002009     -0.134740
# Corr1              -0.084285    -0.001131     0.007592     -0.126815
# All imp dims1      -0.145236    -0.333681    -0.583388     -0.278748
# LR5                -0.014848    -0.011240     0.010491     -0.110405
# Perc5              -0.004356     0.021610     0.048225     -0.034271
# Corr5              -0.029473     0.016295     0.016522     -0.042420
# All imp dims5      -0.078927    -0.025095    -0.022441     -0.156064
# LR10                0.026233    -0.002352     0.009263     -0.052578
# Perc10              0.043646     0.025357     0.063183     -0.010047
# Corr10             -0.028132     0.017864     0.013505     -0.021322
# All imp dims10     -0.019984    -0.002266    -0.000114     -0.104932
# LR25                0.055590     0.000697     0.019870     -0.010047
# Perc25              0.068319     0.033984     0.070329      0.015293
# Corr25             -0.005359     0.012461     0.015961     -0.011946
# All imp dims25      0.026567     0.020304     0.027129     -0.029694
# LR50                0.044764     0.005752     0.005356      0.006362
# Perc50              0.047444     0.018125     0.057711      0.016745
# Corr50              0.001674     0.008976     0.000780     -0.001563
# All imp dims50      0.055257     0.024137     0.036167      0.010605
# LR75                0.016744     0.004183    -0.004467      0.006474
# Perc75              0.022326     0.008452     0.028019      0.008261
# Corr75              0.000335     0.004705    -0.004689     -0.000893
# All imp dims75      0.038066     0.012113     0.019645      0.011386
#
#                     cam_base  xlm_large      xlm_base   bert_base_u  \
# All dims        0.000000e+00   0.000000  0.000000e+00  0.000000e+00
# ANOVA          -1.658375e-04  -0.000509 -4.560798e-03  1.768395e-02
# MI              0.000000e+00   0.001008  5.037719e-04  0.000000e+00
# All non ind    -1.658375e-04   0.007082 -4.558241e-03  1.612146e-02
# LR1            -6.302236e-03  -0.003044  6.066999e-03 -2.567004e-04
# Perc1          -1.161412e-03   0.001510  7.582151e-03 -1.303092e-03
# Corr1           4.143189e-03   0.015189  1.011124e-02  1.742253e-02
# All imp dims1  -5.349814e-01  -0.564280 -1.989937e-01 -3.975313e-01
# LR5             6.625255e-04  -0.001525 -4.051912e-03 -2.600442e-03
# Perc5          -1.327524e-03   0.021257  2.525253e-03  1.039299e-03
# Corr5           1.823388e-03   0.017209 -6.073392e-03  1.404320e-02
# All imp dims5   1.817892e-03  -0.233939  2.986063e-02  3.377974e-03
# LR10           -9.948875e-04   0.004554 -2.536760e-03 -5.204938e-04
# Perc10          4.958637e-04   0.015189 -1.522823e-03  7.802341e-04
# Corr10          1.326425e-03   0.007090 -5.059455e-03  2.599429e-03
# All imp dims10 -7.296437e-03  -0.000010 -5.114435e-06  6.240859e-03
# LR25           -1.658375e-04   0.004043 -1.015215e-03  0.000000e+00
# Perc25         -1.373964e-07   0.011639 -3.037975e-03 -2.600780e-04
# Corr25         -1.659749e-04   0.005566  5.012147e-04  3.900833e-03
# All imp dims25  3.646226e-03   0.027321  1.110223e-16  2.600105e-03
# LR50            0.000000e+00  -0.002027 -3.543025e-03  1.819533e-03
# Perc50          0.000000e+00   0.006076 -1.012658e-03  2.597403e-04
# Corr50          0.000000e+00   0.002529 -1.012658e-03 -5.198183e-04
# All imp dims50  1.655627e-04   0.009109  2.022759e-03  1.560130e-03
# LR75            0.000000e+00  -0.004554 -1.518987e-03  5.201560e-04
# Perc75          0.000000e+00   0.003035 -1.520266e-03 -5.201560e-04
# Corr75          0.000000e+00   0.001011 -1.520266e-03  0.000000e+00
# All imp dims75  0.000000e+00   0.004553 -1.520266e-03 -3.377637e-07
#
#                 distilbert_base   bert_base_c
# All dims               0.000000  0.000000e+00
# ANOVA                  0.007966 -3.222026e-01
# MI                    -0.006825 -2.156288e-06
# All non ind            0.006072 -4.282704e-01
# LR1                   -0.040189  3.773504e-04
# Perc1                 -0.006063 -1.520183e-03
# Corr1                 -0.012146  7.604508e-04
# All imp dims1         -0.478324 -5.284601e-01
# LR5                   -0.000376 -1.110223e-16
# Perc5                  0.011379 -5.312374e-03
# Corr5                  0.008342 -1.512995e-03
# All imp dims5         -0.044389 -4.277025e-01
# LR10                   0.015172 -7.187626e-07
# Perc10                 0.020108 -1.518027e-03
# Corr10                 0.007967 -7.575758e-04
# All imp dims10        -0.013271 -7.590133e-04
# LR25                   0.012895 -1.517308e-03
# Perc25                 0.015552 -1.139239e-03
# Corr25                 0.006450  3.802254e-04
# All imp dims25         0.015554 -2.220446e-16
# LR50                   0.009861 -7.590133e-04
# Perc50                 0.016688 -1.110223e-16
# Corr50                 0.001512 -1.896814e-03
# All imp dims50         0.023517 -1.515870e-03
# LR75                   0.000381  3.787879e-04
# Perc75                 0.007587 -1.517308e-03
# Corr75                -0.004934 -7.187626e-07
# All imp dims75         0.004931 -1.518027e-03

# %% [markdown]
# Here are the dimension groups and the accuracy gain this dimension group provides over all dimensions:

# %%
for i in range(len(models)):
    print(labels[i], gains_df.idxmax()[i], gains_df.loc[gains_df.idxmax()[i], labels[i]])
# Out:
# flau_small_c Perc25 0.06831908799952136
# flau_base_u Perc25 0.03398404348189121
# flau_base_c Perc25 0.07032888898859369
# flau_large_c Perc50 0.016744810361330575
# cam_base Corr1 0.004143189053352425
# xlm_large All imp dims25 0.027321314409921915
# xlm_base All imp dims5 0.02986063163278363
# bert_base_u ANOVA 0.017683954537010438
# distilbert_base All imp dims50 0.023517192800874054
# bert_base_c Corr1 0.0007604508078888905

# %% [markdown]
# Below, you can find the best achieved accuracy and the dimension group that produced it. This value is `InfEnc`.

# %%
for i in range(len(models)):
    print(labels[i], accs_df.idxmax()[i], accs_df.loc[accs_df.idxmax()[i], labels[i]])
# Out:
# flau_small_c Perc25 0.7939300296123475
# flau_base_u Perc25 0.584349783273743
# flau_base_c Perc25 0.6537168107402089
# flau_large_c Perc50 0.9034389457206669
# cam_base Corr1 0.5391245924478684
# xlm_large All imp dims25 0.591600818309679
# xlm_base All imp dims5 0.5612376933895922
# bert_base_u ANOVA 0.5184662151892321
# distilbert_base All imp dims50 0.6153139554942212
# bert_base_c Corr1 0.5292205738600424

# %%
with open('../Data/best_results/gender_na_dims.pickle', 'wb') as f:
    pickle.dump(dims, f)

# %%
with open('../Data/best_results/gender_na_accs.pickle', 'wb') as f:
    pickle.dump(accs, f)

# %%
with open('../Data/best_results/gender_na_medians.pickle', 'wb') as f:
    pickle.dump(medians, f)

# %% [markdown]
# # Conclusion

# %% [markdown]
# (Similar to Gender of Nouns and Gender of Adjectives):
#
# - Despite same vocabulary sizes, FlauBERT family models show different results. Bigger models (FlauBERT base) show worse results than the smaller model (FlauBERT small). Therefore, we can assume that a higher number of parameters doesn't guarantee better performance.
# - Similarly, DistilBERT performs better than CamemBERT, which has significantly bigger vocabulary. Therefore, we can assume that vocabulary size doesn't have a big affect on the results.
# - We can note that cased models (FlauBERT base and mBERT) perform better on the task than their uncased analogs.
# - For all models a subset of dimensions and not all dimensions gave the best InfEnc results.
