# %%
import sys
sys.path.append('../Util')
import pickle
import os

# %%
from IPython.display import Image

# %%
from evaluation import correlation, lr, perceptron, get_anova_dims, get_mi_dims
from preparation import prepare_dataset, read_datasets

# %%
from we import get_we, initiate_model

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from scipy.stats import f_oneway

# %%
from sklearn.metrics import mean_absolute_error, accuracy_score
from sklearn.manifold import TSNE
from sklearn.preprocessing import MinMaxScaler, QuantileTransformer

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
models = [
    {
        'name': 'flaubert/flaubert_small_cased',
        'label': 'flau_small_c'
    },
    {
    
        'name': 'flaubert/flaubert_base_uncased', 
        'label': 'flau_base_u'

    },
    {
        'name': 'flaubert/flaubert_base_cased',
        'label': 'flau_base_c'
    },
    {
        'name': 'flaubert/flaubert_large_cased',
        'label': 'flau_large_c'
    },
    {
        'name': 'camembert/camembert-base',
        'label': 'cam_base'
    },
    {
        'name': 'xlm-roberta-large',
        'label': 'xlm_large'
    },
    {
    
        'name': 'xlm-roberta-base', 
        'label': 'xlm_base'

    },
    {
        'name': 'bert-base-multilingual-uncased',
        'label': 'bert_base_u'
    },
    {
        'name': 'distilbert-base-multilingual-cased',
        'label': 'distilbert_base'
    },
    {
        'name': 'bert-base-multilingual-cased',
        'label': 'bert_base_c'
    }
    
]

# %%
labels = [m['label'] for m in models]

# %%
we_with_features = read_datasets(
                            path = '../Data',
                            model_labels = labels,
                            file_name = 'all_unique_pos_we.csv'
                    )

# %%
we_with_features[-1].head()
# Out:
#                 0         1         2         3         4         5         6  \
# Word
# 2D       0.909603  0.551025  0.436937  0.789782  0.311517  0.417476  0.629341
# 3D       0.901779  0.549880  0.427826  0.797102  0.313900  0.419226  0.623478
# aa       0.899570  0.555891  0.418186  0.805754  0.319232  0.412976  0.618457
# abandon  0.898879  0.556306  0.417821  0.805256  0.318463  0.412505  0.618276
# abbaye   0.895888  0.554461  0.420659  0.799339  0.322441  0.418141  0.618820
#
#                 7         8         9  ...       764       765       766  \
# Word                                   ...
# 2D       0.913722  0.349834  0.838988  ...  0.285154  0.057887  0.030874
# 3D       0.916539  0.355807  0.844714  ...  0.287610  0.054251  0.018604
# aa       0.914183  0.367882  0.845985  ...  0.287883  0.057476  0.013614
# abandon  0.914983  0.367654  0.846577  ...  0.288183  0.057827  0.014050
# abbaye   0.921033  0.367005  0.845904  ...  0.293985  0.057312  0.012175
#
#               767      Number     Gender    Lemma   POS  Tense  Person
# Word
# 2D       0.310204  invariable   feminine       2D  NOUN    NaN     NaN
# 3D       0.305226  invariable   feminine       3D  NOUN    NaN     NaN
# aa       0.290463  invariable  masculine       aa  NOUN    NaN     NaN
# abandon  0.290994    singular  masculine  abandon  NOUN    NaN     NaN
# abbaye   0.298473    singular   feminine   abbaye  NOUN    NaN     NaN
#
# [5 rows x 774 columns]

# %%
# There are 6 extra feautres in addition to embedding dimensions in the file
feature_col_count = 6

# Feature to investigate in this notebook
feature = 'Number'

# %% [markdown]
# In this notebook we will calculate **InfEnc** metric for word embeddings of different models, in order to compare the quality of information encoding about `Number of Nouns and Adjectives`.
#
# For this we will pick concatenate dimensions of word embedding of nouns and adjectives. Note that words that are both adjectives and nouns were discarded previously.

# %% [markdown]
# # Nouns

# %%
pos = ['NOUN', 'ADJ']

# %% [markdown]
# Split each model into train and test using k_fold cross validation:

# %%
X_na_train = []
y_na_train = []

X_na_test = []
y_na_test = []

# %%
n_folds = 5

# %%
for we in we_with_features:
    X, y = prepare_dataset(dataset=we[(we.Gender != 'invariable') & (we.Number != 'invariable') & \
                                      (we.POS.isin(pos))],
                                           feature_col_count=feature_col_count,
                                           feature_name=feature,
                                           normalize=False,
                                           encode=True,
                                           encode_as1='plural',
                                           split=False,
                                           balance=True)
    X_trains = []
    y_trains = []
    
    X_tests = []
    y_tests = []
    
    X_folds = np.array_split(X, n_folds)
    y_folds = np.array_split(y, n_folds)
    
    for i in range(n_folds):
        X_trains.append(pd.DataFrame(np.concatenate(X_folds[:i] + X_folds[i+1:])))
        y_trains.append(np.concatenate(y_folds[:i] + y_folds[i+1:]))

        X_folds[i].columns = X_folds[i].columns.map(int)
        X_tests.append(X_folds[i])
        y_tests.append(y_folds[i])
        
    
    X_na_train.append(X_trains)
    X_na_test.append(X_tests)
    
    y_na_train.append(y_trains)
    y_na_test.append(y_tests)

# %%
dataset_sizes = pd.DataFrame(index=labels)
dataset_sizes['1 fold size'] = [len(x[0]) for x in X_na_test]
dataset_sizes
# Out:
#                  1 fold size
# flau_small_c            1304
# flau_base_u             1553
# flau_base_c             1304
# flau_large_c            1304
# cam_base                 538
# xlm_large                106
# xlm_base                 106
# bert_base_u              389
# distilbert_base          257
# bert_base_c              257

# %% [markdown]
# ## Non-independent dims

# %% [markdown]
# Calculate non-independendent dimensions for each of _k_ splits.

# %% [markdown]
# ANOVA test with p-value < 0.01:

# %%
anova_dims = []

# %%
for i in range(len(models)):
    anova_dims.append([])
    for j in range(n_folds):
        anova_dims[i].append(get_anova_dims(X_na_train[i][j], y_na_train[i][j]))

# %% [markdown]
# Get dimensions where MI > 0:

# %%
mi_dims = []

# %%
for i in range(len(models)):
    mi_dims.append([])
    for j in range(n_folds):
        mi_dims[i].append(get_mi_dims(X_na_train[i][j], y_na_train[i][j]))

# %%
for i in range(len(models)):
    for j in range(n_folds):
        temp = list(map(lambda x: int(x), mi_dims[i][j]))
        mi_dims[i][j] = temp

# %% [markdown]
# Get dimensions that are both found by the ANOVA independency test and MI test:

# %%
non_ind_dims = []

# %%
for i in range(len(models)):
    non_ind_dims.append([])
    for j in range(n_folds):
        non_ind_dims[i].append(list(set(anova_dims[i][j]).intersection(mi_dims[i][j])))

# %% [markdown]
# Stats about the number of dimensions for each model for the 1st split:

# %%
non_ind_df = pd.DataFrame(index=labels, columns=['ANOVA', 'MI', 'Total non independent'])

# %%
non_ind_df['ANOVA'] = [len(x[0]) for x in anova_dims]
non_ind_df['MI'] = [len(x[0]) for x in mi_dims]
non_ind_df['Total non independent'] = [len(x[0]) for x in non_ind_dims]

# %%
non_ind_df
# Out:
#                  ANOVA   MI  Total non independent
# flau_small_c       388  366                    307
# flau_base_u        339  448                    208
# flau_base_c        499  542                    387
# flau_large_c       831  788                    689
# cam_base            12  362                      5
# xlm_large          175  593                    122
# xlm_base            46  417                     31
# bert_base_u        566  643                    480
# distilbert_base    277  595                    240
# bert_base_c          1  431                      0

# %%
dims = {}

# %%
for i in range(len(models)):
    dims[labels[i]] = {}
    dims[labels[i]]['All dims'] = [X_na_train[i][0].columns]*n_folds
    dims[labels[i]]['ANOVA'] = anova_dims[i]
    dims[labels[i]]['MI'] = mi_dims[i]
    dims[labels[i]]['All non ind'] = non_ind_dims[i]

# %% [markdown]
# ## Important dims

# %% [markdown]
# We can test different $\alpha$ values: 1%, 5%, 10%, 25%, 50%, 75%.

# %%
alphas = [1, 5, 10, 25, 50, 75]

# %% [markdown]
# Train Logistic Regression on train set for each model:

# %%
lr_res = []

# %%
for i in range(len(models)):
    lr_res.append([])
    for j in range(n_folds):
        lr_res[i].append(lr(X_na_train[i][j], y_na_train[i][j]))

# %% [markdown]
# Train Perceptron:

# %%
perceptron_res = []

# %%
for i in range(len(models)):
    perceptron_res.append([])
    for j in range(n_folds):
        perceptron_res[i].append(perceptron(X_na_train[i][j], y_na_train[i][j]))

# %% [markdown]
# Compute correlation to the gender vector:

# %%
corr_res = []

# %%
for i in range(len(models)):
    corr_res.append([])
    for j in range(n_folds):
        corr_res[i].append(correlation(X_na_train[i][j], y_na_train[i][j]))

# %%
for i in range(len(models)):
    for alpha in alphas:
        dims[labels[i]][f'LR{alpha}'] = []
        dims[labels[i]][f'Perc{alpha}'] = []
        dims[labels[i]][f'Corr{alpha}'] = []
        dims[labels[i]][f'All imp dims{alpha}'] = []
        for j in range(n_folds):
            num_imp_dims = len(X_na_test[i][0].columns)*alpha//100
            lr_dims = [x[0] for x in lr_res[i][j][:num_imp_dims]]
            perc_dims = [x[0] for x in perceptron_res[i][j][:num_imp_dims]]
            corr_dims = [x[0] for x in corr_res[i][j][:num_imp_dims]]
            dims[labels[i]][f'LR{alpha}'].append(lr_dims)
            dims[labels[i]][f'Perc{alpha}'].append(perc_dims)
            dims[labels[i]][f'Corr{alpha}'].append(corr_dims)
            dims[labels[i]][f'All imp dims{alpha}'].append(list(set(lr_dims).intersection(perc_dims).intersection(corr_dims)))

# %% [markdown]
# ## Compute medians

# %% [markdown]
# For each of the dimension groups above, compute a median vector: the one that should describe the expected values of the dimensions the best.
# We compute median vector associated with feature vector values = 0 and another one for feature vector values = 1.

# %%
medians = {}

# %%
for i in range(len(models)):
    medians[labels[i]] = {}
    for dim_group in dims[labels[i]].keys():
        medians[labels[i]][dim_group] = []
        n = len(dims[labels[i]][dim_group])
        for j in range(n_folds):
            dim_list = dims[labels[i]][dim_group][j] if n == n_folds else list(dims[labels[i]][dim_group])
            # Median of dimensions where feature vector is equal to 0
            median_0 = X_na_train[i][j][y_na_train[i][j] == 0][dim_list].median()
            # Median of dimensions where feature vector is equal to 1
            median_1 = X_na_train[i][j][y_na_train[i][j] == 1][dim_list].median()

            medians[labels[i]][dim_group].append({
                    '0': median_0,
                    '1': median_1
                })

# %% [markdown]
# We can compare the number of dimensions found by each test for each model in the first fold:

# %%
dim_lens = {}

for model in dims.keys():
    dim_lens[model] = {}
    for dim_group in dims[model].keys():
        dim_lens[model][dim_group] = len(dims[model][dim_group][0]) if dim_group != 'All dims' else \
                len(dims[model][dim_group])

# %%
pd.DataFrame(dim_lens)
# Out:
#                 flau_small_c  flau_base_u  flau_base_c  flau_large_c  \
# All dims                   5            5            5             5
# ANOVA                    388          339          499           831
# MI                       366          448          542           788
# All non ind              307          208          387           689
# LR1                        5            7            7            10
# Perc1                      5            7            7            10
# Corr1                      5            7            7            10
# All imp dims1              2            1            1             2
# LR5                       25           38           38            51
# Perc5                     25           38           38            51
# Corr5                     25           38           38            51
# All imp dims5             12            6            6            14
# LR10                      51           76           76           102
# Perc10                    51           76           76           102
# Corr10                    51           76           76           102
# All imp dims10            22           14           19            37
# LR25                     128          192          192           256
# Perc25                   128          192          192           256
# Corr25                   128          192          192           256
# All imp dims25            65           60           48           105
# LR50                     256          384          384           512
# Perc50                   256          384          384           512
# Corr50                   256          384          384           512
# All imp dims50           155          158          154           259
# LR75                     384          576          576           768
# Perc75                   384          576          576           768
# Corr75                   384          576          576           768
# All imp dims75           280          353          346           524
#
#                 cam_base  xlm_large  xlm_base  bert_base_u  distilbert_base  \
# All dims               5          5         5            5                5
# ANOVA                 12        175        46          566              277
# MI                   362        593       417          643              595
# All non ind            5        122        31          480              240
# LR1                    7         10         7            7                7
# Perc1                  7         10         7            7                7
# Corr1                  7         10         7            7                7
# All imp dims1          0          0         0            0                2
# LR5                   38         51        38           38               38
# Perc5                 38         51        38           38               38
# Corr5                 38         51        38           38               38
# All imp dims5          3          3         5            2                8
# LR10                  76        102        76           76               76
# Perc10                76        102        76           76               76
# Corr10                76        102        76           76               76
# All imp dims10         8         10         7            9               12
# LR25                 192        256       192          192              192
# Perc25               192        256       192          192              192
# Corr25               192        256       192          192              192
# All imp dims25        42         41        23           25               46
# LR50                 384        512       384          384              384
# Perc50               384        512       384          384              384
# Corr50               384        512       384          384              384
# All imp dims50       128        148        81          102              137
# LR75                 576        768       576          576              576
# Perc75               576        768       576          576              576
# Corr75               576        768       576          576              576
# All imp dims75       340        435       293          329              347
#
#                 bert_base_c
# All dims                  5
# ANOVA                     1
# MI                      431
# All non ind               0
# LR1                       7
# Perc1                     7
# Corr1                     7
# All imp dims1             0
# LR5                      38
# Perc5                    38
# Corr5                    38
# All imp dims5             1
# LR10                     76
# Perc10                   76
# Corr10                   76
# All imp dims10            5
# LR25                    192
# Perc25                  192
# Corr25                  192
# All imp dims25           20
# LR50                    384
# Perc50                  384
# Corr50                  384
# All imp dims50          127
# LR75                    576
# Perc75                  576
# Corr75                  576
# All imp dims75          331

# %% [markdown]
# ## Compute predictions

# %% [markdown]
# Using the median vectors computed for each group above, try to predict the value of the feature vector on test.
# For this, for any word embedding in test compute distances to median for feature vector values = 0 and for feature vector values = 1.
# If the given word embedding is closer to median of feature vector values = 0, assign 0 as predicted label, 1 otherwise.

# %%
y_preds = {}

# %%
for i in range(len(models)):
    y_preds[labels[i]] = {}
    for dim_group in dims[labels[i]].keys():
        y_preds[labels[i]][dim_group] = []
        n = len(dims[labels[i]][dim_group])
        for j in range(n_folds):
            dim_list = dims[labels[i]][dim_group][j] if n == n_folds else dims[labels[i]][dim_group]
            
            # If MSE for sample 0 is lower than for sample 1, the label should be 0. So we need to convert False to 0.
            mae0 = X_na_test[i][j][dim_list].apply(lambda x: mean_absolute_error(medians[labels[i]][dim_group][j]['0'], x), axis=1)
            mae1 = X_na_test[i][j][dim_list].apply(lambda x: mean_absolute_error(medians[labels[i]][dim_group][j]['1'], x), axis=1)
            
            y_preds[labels[i]][dim_group].append((mae0 > mae1).apply(int))

# %% [markdown]
# ## Compute accuracies

# %%
accs = {}

# %%
for i in range(len(models)):
    accs[labels[i]] = {}
    for dim_group in dims[labels[i]].keys():
        accs[labels[i]][dim_group] = []
        for j in range(n_folds):
            y_true = y_na_test[i][j]
            y_pred = y_preds[labels[i]][dim_group][j]
            if any(y_pred):
                acc = accuracy_score(y_true, y_pred)
            else:
                acc = 0
            accs[labels[i]][dim_group].append(acc)

# %%
# Compute average accuracy between 5 folds
avg_accs = {}

# %%
for i in range(len(models)):
    avg_accs[labels[i]] = {}
    for dim_group in dims[labels[i]].keys():
        avg_accs[labels[i]][dim_group] = np.average(accs[labels[i]][dim_group])

# %%
accs_df = pd.DataFrame(avg_accs)
accs_df
# Out:
#                 flau_small_c  flau_base_u  flau_base_c  flau_large_c  \
# All dims            0.899631     0.617980     0.592540      0.938765
# ANOVA               0.901780     0.622617     0.594842      0.939533
# MI                  0.899786     0.615534     0.601134      0.939072
# All non ind         0.899939     0.615017     0.602362      0.938765
# LR1                 0.756906     0.551262     0.624460      0.818447
# Perc1               0.748313     0.568906     0.688458      0.874923
# Corr1               0.751532     0.574830     0.686309      0.881216
# All imp dims1       0.705495     0.222151     0.637351      0.765497
# LR5                 0.855740     0.597504     0.627225      0.927410
# Perc5               0.859884     0.609222     0.697052      0.932321
# Corr5               0.849447     0.607934     0.657919      0.923726
# All imp dims5       0.817525     0.565689     0.645489      0.891957
# LR10                0.899786     0.609096     0.625228      0.938920
# Perc10              0.899634     0.626609     0.690298      0.944138
# Corr10              0.876766     0.609091     0.646868      0.932013
# All imp dims10      0.852209     0.588612     0.653312      0.921117
# LR25                0.936464     0.622359     0.616329      0.950276
# Perc25              0.932167     0.641292     0.666511      0.952271
# Corr25              0.892573     0.619782     0.622620      0.938305
# All imp dims25      0.910528     0.612053     0.665590      0.941835
# LR50                0.942142     0.618753     0.612644      0.946439
# Perc50              0.933241     0.633308     0.637199      0.949968
# Corr50              0.901167     0.622102     0.598218      0.939072
# All imp dims50      0.931554     0.628799     0.649476      0.947207
# LR75                0.919276     0.621202     0.599293      0.941527
# Perc75              0.919122     0.623004     0.614947      0.945518
# Corr75              0.901933     0.618882     0.593614      0.938612
# All imp dims75      0.928792     0.623518     0.622774      0.946592
#
#                 cam_base  xlm_large  xlm_base  bert_base_u  distilbert_base  \
# All dims        0.514153   0.585157  0.535975     0.561283         0.647206
# ANOVA           0.508188   0.581366  0.556819     0.561283         0.637080
# MI              0.502984   0.588931  0.535993     0.561283         0.650304
# All non ind     0.496653   0.581366  0.554933     0.561797         0.644866
# LR1             0.499994   0.598365  0.583378     0.556649         0.623814
# Perc1           0.507821   0.600341  0.564367     0.557683         0.646410
# Corr1           0.509299   0.602228  0.583396     0.556655         0.627739
# All imp dims1   0.099069   0.111321  0.109434     0.434262         0.360311
# LR5             0.517118   0.587026  0.553064     0.559741         0.666677
# Perc5           0.518246   0.590800  0.547314     0.559739         0.634776
# Corr5           0.513025   0.609829  0.554933     0.564891         0.653447
# All imp dims5   0.495530   0.609739  0.564349     0.556659         0.638628
# LR10            0.510431   0.604061  0.547367     0.559739         0.684594
# Perc10          0.517864   0.590818  0.539784     0.558707         0.649553
# Corr10          0.510047   0.588913  0.554933     0.565408         0.642531
# All imp dims10  0.500372   0.615490  0.547332     0.561800         0.665896
# LR25            0.516010   0.596550  0.541653     0.561797         0.671364
# Perc25          0.515264   0.594645  0.539766     0.559221         0.665899
# Corr25          0.512662   0.579479  0.549236     0.564893         0.644875
# All imp dims25  0.515269   0.596568  0.549254     0.561287         0.669024
# LR50            0.504469   0.583270  0.539766     0.561797         0.660457
# Perc50          0.517129   0.583252  0.539766     0.561282         0.652654
# Corr50          0.508199   0.581366  0.541653     0.563861         0.639421
# All imp dims50  0.511169   0.590872  0.547350     0.564376         0.664333
# LR75            0.512294   0.585157  0.537862     0.561283         0.653453
# Perc75          0.507819   0.579461  0.539766     0.561283         0.647982
# Corr75          0.510059   0.579497  0.539766     0.561283         0.640984
# All imp dims75  0.514898   0.583252  0.537862     0.561799         0.650325
#
#                 bert_base_c
# All dims           0.535804
# ANOVA              0.534259
# MI                 0.538138
# All non ind        0.431536
# LR1                0.549058
# Perc1              0.572383
# Corr1              0.558384
# All imp dims1      0.000000
# LR5                0.567735
# Perc5              0.543583
# Corr5              0.549839
# All imp dims5      0.231128
# LR10               0.566178
# Perc10             0.543580
# Corr10             0.545157
# All imp dims10     0.560752
# LR25               0.552161
# Perc25             0.535022
# Corr25             0.540479
# All imp dims25     0.560722
# LR50               0.540485
# Perc50             0.533469
# Corr50             0.538138
# All imp dims50     0.545148
# LR75               0.536582
# Perc75             0.537360
# Corr75             0.535804
# All imp dims75     0.538144

# %% [markdown]
# We can show what is the accuracy gain for each dimension test comparison to using all dimensions:

# %%
gains_df = (accs_df - accs_df.loc['All dims'])
gains_df
# Out:
#                 flau_small_c  flau_base_u  flau_base_c  flau_large_c  \
# All dims            0.000000     0.000000     0.000000      0.000000
# ANOVA               0.002149     0.004636     0.002302      0.000767
# MI                  0.000155    -0.002447     0.008595      0.000307
# All non ind         0.000309    -0.002964     0.009823      0.000000
# LR1                -0.142725    -0.066718     0.031920     -0.120318
# Perc1              -0.151318    -0.049074     0.095918     -0.063842
# Corr1              -0.148099    -0.043150     0.093769     -0.057549
# All imp dims1      -0.194136    -0.395830     0.044812     -0.173268
# LR5                -0.043891    -0.020477     0.034686     -0.011355
# Perc5              -0.039747    -0.008758     0.104513     -0.006444
# Corr5              -0.050184    -0.010046     0.065379     -0.015039
# All imp dims5      -0.082106    -0.052291     0.052950     -0.046808
# LR10                0.000155    -0.008885     0.032689      0.000155
# Perc10              0.000003     0.008629     0.097759      0.005373
# Corr10             -0.022865    -0.008889     0.054328     -0.006752
# All imp dims10     -0.047422    -0.029368     0.060772     -0.017648
# LR25                0.036833     0.004379     0.023790      0.011511
# Perc25              0.032536     0.023311     0.073971      0.013506
# Corr25             -0.007058     0.001802     0.030081     -0.000460
# All imp dims25      0.010897    -0.005927     0.073050      0.003070
# LR50                0.042511     0.000773     0.020105      0.007674
# Perc50              0.033610     0.015328     0.044659      0.011203
# Corr50              0.001536     0.004122     0.005678      0.000307
# All imp dims50      0.031923     0.010818     0.056936      0.008442
# LR75                0.019645     0.003221     0.006754      0.002762
# Perc75              0.019491     0.005024     0.022408      0.006753
# Corr75              0.002302     0.000902     0.001074     -0.000153
# All imp dims75      0.029161     0.005537     0.030235      0.007827
#
#                 cam_base  xlm_large  xlm_base  bert_base_u  distilbert_base  \
# All dims        0.000000   0.000000  0.000000     0.000000         0.000000
# ANOVA          -0.005965  -0.003792  0.020845     0.000000        -0.010126
# MI             -0.011169   0.003774  0.000018     0.000000         0.003098
# All non ind    -0.017500  -0.003792  0.018958     0.000514        -0.002341
# LR1            -0.014158   0.013208  0.047403    -0.004634        -0.023392
# Perc1          -0.006332   0.015184  0.028392    -0.003600        -0.000796
# Corr1          -0.004854   0.017071  0.047421    -0.004629        -0.019467
# All imp dims1  -0.415084  -0.473836 -0.426541    -0.127021        -0.286895
# LR5             0.002966   0.001869  0.017089    -0.001542         0.019470
# Perc5           0.004093   0.005642  0.011339    -0.001544        -0.012430
# Corr5          -0.001128   0.024672  0.018958     0.003608         0.006241
# All imp dims5  -0.018623   0.024582  0.028374    -0.004625        -0.008579
# LR10           -0.003722   0.018904  0.011393    -0.001544         0.037388
# Perc10          0.003711   0.005660  0.003810    -0.002576         0.002347
# Corr10         -0.004106   0.003756  0.018958     0.004125        -0.004675
# All imp dims10 -0.013780   0.030332  0.011357     0.000517         0.018689
# LR25            0.001857   0.011393  0.005678     0.000514         0.024158
# Perc25          0.001112   0.009488  0.003792    -0.002062         0.018692
# Corr25         -0.001490  -0.005678  0.013261     0.003610        -0.002332
# All imp dims25  0.001117   0.011411  0.013279     0.000004         0.021817
# LR50           -0.009683  -0.001887  0.003792     0.000514         0.013251
# Perc50          0.002976  -0.001905  0.003792    -0.000001         0.005447
# Corr50         -0.005953  -0.003792  0.005678     0.002577        -0.007785
# All imp dims50 -0.002984   0.005714  0.011375     0.003093         0.017127
# LR75           -0.001859   0.000000  0.001887     0.000000         0.006247
# Perc75         -0.006334  -0.005696  0.003792     0.000000         0.000775
# Corr75         -0.004094  -0.005660  0.003792     0.000000        -0.006223
# All imp dims75  0.000745  -0.001905  0.001887     0.000515         0.003119
#
#                 bert_base_c
# All dims           0.000000
# ANOVA             -0.001544
# MI                 0.002335
# All non ind       -0.104268
# LR1                0.013254
# Perc1              0.036579
# Corr1              0.022580
# All imp dims1     -0.535804
# LR5                0.031931
# Perc5              0.007779
# Corr5              0.014035
# All imp dims5     -0.304675
# LR10               0.030375
# Perc10             0.007776
# Corr10             0.009354
# All imp dims10     0.024948
# LR25               0.016358
# Perc25            -0.000781
# Corr25             0.004675
# All imp dims25     0.024918
# LR50               0.004681
# Perc50            -0.002335
# Corr50             0.002335
# All imp dims50     0.009345
# LR75               0.000778
# Perc75             0.001556
# Corr75             0.000000
# All imp dims75     0.002341

# %% [markdown]
# Here are the dimension groups and the accuracy gain this dimension group provides over all dimensions:

# %%
for i in range(len(models)):
    print(labels[i], gains_df.idxmax()[i], gains_df.loc[gains_df.idxmax()[i], labels[i]])
# Out:
# flau_small_c LR50 0.04251138241622687
# flau_base_u Perc25 0.023311382691299065
# flau_base_c Perc5 0.1045125924600614
# flau_large_c Perc25 0.013505760656154608
# cam_base Perc5 0.004093372930987882
# xlm_large All imp dims10 0.03033243486073678
# xlm_base Corr1 0.04742138364779869
# bert_base_u Corr10 0.004125036440251306
# distilbert_base LR10 0.03738752431906622
# bert_base_c Perc1 0.036578915369649745

# %% [markdown]
# Below, you can find the best achieved accuracy and the dimension group that produced it. This value is `InfEnc`.

# %%
for i in range(len(models)):
    print(labels[i], accs_df.idxmax()[i], accs_df.loc[accs_df.idxmax()[i], labels[i]])
# Out:
# flau_small_c LR50 0.9421423661300727
# flau_base_u Perc25 0.6412917134113554
# flau_base_c Perc5 0.6970521072183586
# flau_large_c Perc25 0.952270833235243
# cam_base Perc5 0.5182460731172076
# xlm_large All imp dims10 0.6154896675651392
# xlm_base Corr1 0.5833962264150944
# bert_base_u Corr10 0.5654082633238809
# distilbert_base LR10 0.6845938715953308
# bert_base_c Perc1 0.5723826605058365

# %%
with open('../Data/best_results/number_na_dims.pickle', 'wb') as f:
    pickle.dump(dims, f)

# %%
with open('../Data/best_results/number_na_accs.pickle', 'wb') as f:
    pickle.dump(accs, f)

# %%
with open('../Data/best_results/number_na_medians.pickle', 'wb') as f:
    pickle.dump(medians, f)

# %% [markdown]
# # Conclusion

# %% [markdown]
# (Similar to number of nouns and number of adjectives)
# - FlauBERT small and large show very similar results despite FlauBERT large being 10x larger in terms of paramters
# - DistilBERT shows much better results for number than for gender, alongside with XLM
