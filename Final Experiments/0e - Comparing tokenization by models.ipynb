# %%
import pandas as pd

# %%
import sys
sys.path.append('../Util')

# %%
from we import initiate_model, get_we, create_we_df

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
models = [
    {
        'name': 'flaubert/flaubert_small_cased',
        'label': 'flau_small_c'
    },
    {
    
        'name': 'flaubert/flaubert_base_uncased', 
        'label': 'flau_base_u'

    },
    {
        'name': 'flaubert/flaubert_base_cased',
        'label': 'flau_base_c'
    },
    {
        'name': 'flaubert/flaubert_large_cased',
        'label': 'flau_large_c'
    },
    {
        'name': 'camembert/camembert-base',
        'label': 'cam_base'
    },
    {
        'name': 'xlm-roberta-large',
        'label': 'xlm_large'
    },
    {
    
        'name': 'xlm-roberta-base', 
        'label': 'xlm_base'

    },
    {
        'name': 'bert-base-multilingual-uncased',
        'label': 'bert_base_u'
    },
    {
        'name': 'distilbert-base-multilingual-cased',
        'label': 'distilbert_base'
    },
    {
        'name': 'bert-base-multilingual-cased',
        'label': 'bert_base_c'
    }
    
]

# %% [markdown]
# For all PoS the comparison will be down with the set of the word associated with the PoS from Morphalou.
#
# For each model we'll show the percentage of the words that is tokenized as one word and the percentage of words tokenized in multiple parts.

# %% [markdown]
# # Nouns

# %%
all_nouns = pd.read_csv('../Data/Morphalou/all_nouns_v2.csv', index_col = 0)

# %%
all_nouns = all_nouns[(all_nouns.Number != 'invariable') & (all_nouns.Gender != 'invariable')]

# %%
all_nouns
# Out:
#                    Number     Gender            Lemma
# Word
# a b c            singular  masculine            a b c
#  a demi-mot      singular  masculine       a demi-mot
# a-mi-la          singular  masculine          a-mi-la
# aabam            singular  masculine            aabam
# aalénien         singular  masculine         aalénien
# ...                   ...        ...              ...
# œuvre            singular   feminine            œuvre
# œuvres             plural   feminine            œuvre
# œuvre-testament  singular   feminine  œuvre-testament
# œuvrette         singular   feminine         œuvrette
# œuvrettes          plural   feminine         œuvrette
#
# [170766 rows x 3 columns]

# %% [markdown]
# We can see that there are quite a lot of words inside Morphalou categorized as nouns, which are compositions of several words. We can find only non-complex words among Morphalou nouns:

# %%
all_nouns['len'] = [len(x.split()) for x in all_nouns.index.str.replace('-', ' ')]

# %%
one_word_nouns = all_nouns[all_nouns.len == 1]

# %%
one_word_nouns
# Out:
#              Number     Gender     Lemma  len
# Word
# aabam      singular  masculine     aabam    1
# aalénien   singular  masculine  aalénien    1
# aaléniens    plural  masculine  aalénien    1
# aba        singular  masculine       aba    1
# abaca      singular  masculine     abaca    1
# ...             ...        ...       ...  ...
# œufriers     plural  masculine   œufrier    1
# œuvre      singular   feminine     œuvre    1
# œuvres       plural   feminine     œuvre    1
# œuvrette   singular   feminine  œuvrette    1
# œuvrettes    plural   feminine  œuvrette    1
#
# [162756 rows x 4 columns]

# %%
noun_lens = []

# %%
for i in range(len(models)):
    nouns_df = pd.read_csv(f'../Data/{models[i]["label"]}/all_nouns_we.csv')
    noun_lens.append(len(nouns_df))

# %%
noun_size_comp = pd.DataFrame(index=[m['label'] for m in models])

# %%
noun_size_comp['Noun vocab size'] = noun_lens
noun_size_comp['Percentage of Morphalou vocab'] = noun_size_comp['Noun vocab size'] * 100 / len(one_word_nouns)

# %%
noun_size_comp.sort_values(by='Noun vocab size', ascending=False)
# Out:
#                  Noun vocab size  Percentage of Morphalou vocab
# flau_base_u                17272                      10.612205
# flau_small_c               14091                       8.657745
# flau_base_c                14091                       8.657745
# flau_large_c               14091                       8.657745
# cam_base                    9894                       6.079039
# bert_base_u                 6982                       4.289857
# distilbert_base             4494                       2.761189
# bert_base_c                 4494                       2.761189
# xlm_large                   3982                       2.446607
# xlm_base                    3982                       2.446607

# %% [markdown]
# We can select 20 random nouns from Morphalou vocab to see how they are tokenized differently by different models:

# %%
tokenizations = []

# %%
word_sample = one_word_nouns.index.to_series().sample(n=20)

# %%
for m in models:
    m_tokenizations = []
    model, tokenizer = initiate_model(m['name'])
    for w in word_sample:
        tokenization = [tokenizer.decode(x) for x in tokenizer.encode(w)]
        m_tokenizations.append(tokenization)
    tokenizations.append(m_tokenizations)
# Out:
# Some weights of the model checkpoint at bert-base-multilingual-uncased were not used when initializing BertForMaskedLM: ['cls.seq_relationship.bias', 'cls.seq_relationship.weight']
# - This IS expected if you are initializing BertForMaskedLM from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForMaskedLM from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of the model checkpoint at bert-base-multilingual-cased were not used when initializing BertForMaskedLM: ['cls.seq_relationship.bias', 'cls.seq_relationship.weight']
# - This IS expected if you are initializing BertForMaskedLM from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForMaskedLM from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
def check_not_stop_tokens(s):
    return (s != '<s>') and (s != '</s>') and (s != '[CLS]') and (s != '[SEP]')

# %%
for j in range(len(word_sample)):
    print(f'\nWord: {word_sample[j]}')
    for i in range(len(models)):
        print(f'\tTokenization by {models[i]["name"]}: {list(filter(check_not_stop_tokens, tokenizations[i][j]))}')
# Out:
# Word: crémoirs
# 	Tokenization by flaubert/flaubert_small_cased: ['cré', 'moi', 'rs']
# 	Tokenization by flaubert/flaubert_base_uncased: ['cré', 'moi', 'rs']
# 	Tokenization by flaubert/flaubert_base_cased: ['cré', 'moi', 'rs']
# 	Tokenization by flaubert/flaubert_large_cased: ['cré', 'moi', 'rs']
# 	Tokenization by camembert/camembert-base: ['cré', 'm', 'oirs']
# 	Tokenization by xlm-roberta-large: ['', 'cré', 'mo', 'ir', 's']
# 	Tokenization by xlm-roberta-base: ['', 'cré', 'mo', 'ir', 's']
# 	Tokenization by bert-base-multilingual-uncased: ['cr', '##em', '##oir', '##s']
# 	Tokenization by distilbert-base-multilingual-cased: ['c', '##ré', '##mo', '##irs']
# 	Tokenization by bert-base-multilingual-cased: ['c', '##ré', '##mo', '##irs']
#
# Word: lasciveté
# 	Tokenization by flaubert/flaubert_small_cased: ['las', 'ci', 'veté']
# 	Tokenization by flaubert/flaubert_base_uncased: ['las', 'ci', 'veté']
# 	Tokenization by flaubert/flaubert_base_cased: ['las', 'ci', 'veté']
# 	Tokenization by flaubert/flaubert_large_cased: ['las', 'ci', 'veté']
# 	Tokenization by camembert/camembert-base: ['la', 's', 'ci', 'vet', 'é']
# 	Tokenization by xlm-roberta-large: ['las', 'ci', 've', 'té']
# 	Tokenization by xlm-roberta-base: ['las', 'ci', 've', 'té']
# 	Tokenization by bert-base-multilingual-uncased: ['las', '##ci', '##vete']
# 	Tokenization by distilbert-base-multilingual-cased: ['las', '##ci', '##vet', '##é']
# 	Tokenization by bert-base-multilingual-cased: ['las', '##ci', '##vet', '##é']
#
# Word: anthaxies
# 	Tokenization by flaubert/flaubert_small_cased: ['anth', 'ax', 'ies']
# 	Tokenization by flaubert/flaubert_base_uncased: ['anth', 'axi', 'es']
# 	Tokenization by flaubert/flaubert_base_cased: ['anth', 'ax', 'ies']
# 	Tokenization by flaubert/flaubert_large_cased: ['anth', 'ax', 'ies']
# 	Tokenization by camembert/camembert-base: ['an', 'tha', 'xie', 's']
# 	Tokenization by xlm-roberta-large: ['', 'antha', 'xi', 'es']
# 	Tokenization by xlm-roberta-base: ['', 'antha', 'xi', 'es']
# 	Tokenization by bert-base-multilingual-uncased: ['ant', '##ha', '##xie', '##s']
# 	Tokenization by distilbert-base-multilingual-cased: ['ant', '##ha', '##xies']
# 	Tokenization by bert-base-multilingual-cased: ['ant', '##ha', '##xies']
#
# Word: diégèses
# 	Tokenization by flaubert/flaubert_small_cased: ['di', 'ég', 'èses']
# 	Tokenization by flaubert/flaubert_base_uncased: ['di', 'ég', 'èses']
# 	Tokenization by flaubert/flaubert_base_cased: ['di', 'ég', 'èses']
# 	Tokenization by flaubert/flaubert_large_cased: ['di', 'ég', 'èses']
# 	Tokenization by camembert/camembert-base: ['di', 'ég', 'èse', 's']
# 	Tokenization by xlm-roberta-large: ['di', 'ég', 'èse', 's']
# 	Tokenization by xlm-roberta-base: ['di', 'ég', 'èse', 's']
# 	Tokenization by bert-base-multilingual-uncased: ['die', '##gese', '##s']
# 	Tokenization by distilbert-base-multilingual-cased: ['dié', '##g', '##èse', '##s']
# 	Tokenization by bert-base-multilingual-cased: ['dié', '##g', '##èse', '##s']
#
# Word: elpidites
# 	Tokenization by flaubert/flaubert_small_cased: ['el', 'pi', 'dites']
# 	Tokenization by flaubert/flaubert_base_uncased: ['el', 'pi', 'dites']
# 	Tokenization by flaubert/flaubert_base_cased: ['el', 'pi', 'dites']
# 	Tokenization by flaubert/flaubert_large_cased: ['el', 'pi', 'dites']
# 	Tokenization by camembert/camembert-base: ['el', 'pid', 'ites']
# 	Tokenization by xlm-roberta-large: ['el', 'pidi', 'tes']
# 	Tokenization by xlm-roberta-base: ['el', 'pidi', 'tes']
# 	Tokenization by bert-base-multilingual-uncased: ['el', '##pid', '##ites']
# 	Tokenization by distilbert-base-multilingual-cased: ['el', '##pid', '##ites']
# 	Tokenization by bert-base-multilingual-cased: ['el', '##pid', '##ites']
#
# Word: matassin
# 	Tokenization by flaubert/flaubert_small_cased: ['mat', 'assin']
# 	Tokenization by flaubert/flaubert_base_uncased: ['mata', 'ssin']
# 	Tokenization by flaubert/flaubert_base_cased: ['mat', 'assin']
# 	Tokenization by flaubert/flaubert_large_cased: ['mat', 'assin']
# 	Tokenization by camembert/camembert-base: ['mat', 'assin']
# 	Tokenization by xlm-roberta-large: ['mata', 'ssin']
# 	Tokenization by xlm-roberta-base: ['mata', 'ssin']
# 	Tokenization by bert-base-multilingual-uncased: ['mata', '##ssin']
# 	Tokenization by distilbert-base-multilingual-cased: ['mata', '##ssin']
# 	Tokenization by bert-base-multilingual-cased: ['mata', '##ssin']
#
# Word: sangliot
# 	Tokenization by flaubert/flaubert_small_cased: ['sang', 'li', 'ot']
# 	Tokenization by flaubert/flaubert_base_uncased: ['sang', 'li', 'ot']
# 	Tokenization by flaubert/flaubert_base_cased: ['sang', 'li', 'ot']
# 	Tokenization by flaubert/flaubert_large_cased: ['sang', 'li', 'ot']
# 	Tokenization by camembert/camembert-base: ['sang', 'lio', 't']
# 	Tokenization by xlm-roberta-large: ['sang', 'li', 'ot']
# 	Tokenization by xlm-roberta-base: ['sang', 'li', 'ot']
# 	Tokenization by bert-base-multilingual-uncased: ['sang', '##lio', '##t']
# 	Tokenization by distilbert-base-multilingual-cased: ['sang', '##lio', '##t']
# 	Tokenization by bert-base-multilingual-cased: ['sang', '##lio', '##t']
#
# Word: cachet
# 	Tokenization by flaubert/flaubert_small_cased: ['cachet']
# 	Tokenization by flaubert/flaubert_base_uncased: ['cachet']
# 	Tokenization by flaubert/flaubert_base_cased: ['cachet']
# 	Tokenization by flaubert/flaubert_large_cased: ['cachet']
# 	Tokenization by camembert/camembert-base: ['cachet']
# 	Tokenization by xlm-roberta-large: ['cache', 't']
# 	Tokenization by xlm-roberta-base: ['cache', 't']
# 	Tokenization by bert-base-multilingual-uncased: ['cache', '##t']
# 	Tokenization by distilbert-base-multilingual-cased: ['cache', '##t']
# 	Tokenization by bert-base-multilingual-cased: ['cache', '##t']
#
# Word: libournaises
# 	Tokenization by flaubert/flaubert_small_cased: ['lib', 'our', 'n', 'aises']
# 	Tokenization by flaubert/flaubert_base_uncased: ['li', 'bour', 'n', 'aises']
# 	Tokenization by flaubert/flaubert_base_cased: ['lib', 'our', 'n', 'aises']
# 	Tokenization by flaubert/flaubert_large_cased: ['lib', 'our', 'n', 'aises']
# 	Tokenization by camembert/camembert-base: ['li', 'bour', 'naise', 's']
# 	Tokenization by xlm-roberta-large: ['li', 'bour', 'naise', 's']
# 	Tokenization by xlm-roberta-base: ['li', 'bour', 'naise', 's']
# 	Tokenization by bert-base-multilingual-uncased: ['lib', '##our', '##nais', '##es']
# 	Tokenization by distilbert-base-multilingual-cased: ['lib', '##our', '##nais', '##es']
# 	Tokenization by bert-base-multilingual-cased: ['lib', '##our', '##nais', '##es']
#
# Word: encéphalocèle
# 	Tokenization by flaubert/flaubert_small_cased: ['en', 'cé', 'phal', 'oc', 'èle']
# 	Tokenization by flaubert/flaubert_base_uncased: ['en', 'céphal', 'oc', 'èle']
# 	Tokenization by flaubert/flaubert_base_cased: ['en', 'cé', 'phal', 'oc', 'èle']
# 	Tokenization by flaubert/flaubert_large_cased: ['en', 'cé', 'phal', 'oc', 'èle']
# 	Tokenization by camembert/camembert-base: ['en', 'c', 'épha', 'lo', 'c', 'èle']
# 	Tokenization by xlm-roberta-large: ['en', 'cé', 'pha', 'lo', 'cè', 'le']
# 	Tokenization by xlm-roberta-base: ['en', 'cé', 'pha', 'lo', 'cè', 'le']
# 	Tokenization by bert-base-multilingual-uncased: ['en', '##ce', '##pha', '##lo', '##cel', '##e']
# 	Tokenization by distilbert-base-multilingual-cased: ['en', '##cé', '##pha', '##loc', '##èle']
# 	Tokenization by bert-base-multilingual-cased: ['en', '##cé', '##pha', '##loc', '##èle']
#
# Word: chapelle
# 	Tokenization by flaubert/flaubert_small_cased: ['chapelle']
# 	Tokenization by flaubert/flaubert_base_uncased: ['chapelle']
# 	Tokenization by flaubert/flaubert_base_cased: ['chapelle']
# 	Tokenization by flaubert/flaubert_large_cased: ['chapelle']
# 	Tokenization by camembert/camembert-base: ['chapelle']
# 	Tokenization by xlm-roberta-large: ['chap', 'elle']
# 	Tokenization by xlm-roberta-base: ['chap', 'elle']
# 	Tokenization by bert-base-multilingual-uncased: ['chapelle']
# 	Tokenization by distilbert-base-multilingual-cased: ['chapelle']
# 	Tokenization by bert-base-multilingual-cased: ['chapelle']
#
# Word: syncinésie
# 	Tokenization by flaubert/flaubert_small_cased: ['syn', 'cin', 'ésie']
# 	Tokenization by flaubert/flaubert_base_uncased: ['syn', 'ciné', 'sie']
# 	Tokenization by flaubert/flaubert_base_cased: ['syn', 'cin', 'ésie']
# 	Tokenization by flaubert/flaubert_large_cased: ['syn', 'cin', 'ésie']
# 	Tokenization by camembert/camembert-base: ['syn', 'cin', 'ésie']
# 	Tokenization by xlm-roberta-large: ['syn', 'ci', 'né', 'sie']
# 	Tokenization by xlm-roberta-base: ['syn', 'ci', 'né', 'sie']
# 	Tokenization by bert-base-multilingual-uncased: ['syn', '##cine', '##sie']
# 	Tokenization by distilbert-base-multilingual-cased: ['syn', '##cin', '##ési', '##e']
# 	Tokenization by bert-base-multilingual-cased: ['syn', '##cin', '##ési', '##e']
#
# Word: druse
# 	Tokenization by flaubert/flaubert_small_cased: ['dr', 'use']
# 	Tokenization by flaubert/flaubert_base_uncased: ['dru', 'se']
# 	Tokenization by flaubert/flaubert_base_cased: ['dr', 'use']
# 	Tokenization by flaubert/flaubert_large_cased: ['dr', 'use']
# 	Tokenization by camembert/camembert-base: ['d', 'r', 'use']
# 	Tokenization by xlm-roberta-large: ['dru', 'se']
# 	Tokenization by xlm-roberta-base: ['dru', 'se']
# 	Tokenization by bert-base-multilingual-uncased: ['dr', '##use']
# 	Tokenization by distilbert-base-multilingual-cased: ['dr', '##use']
# 	Tokenization by bert-base-multilingual-cased: ['dr', '##use']
#
# Word: sidérurgistes
# 	Tokenization by flaubert/flaubert_small_cased: ['sidérur', 'g', 'istes']
# 	Tokenization by flaubert/flaubert_base_uncased: ['sidérur', 'g', 'istes']
# 	Tokenization by flaubert/flaubert_base_cased: ['sidérur', 'g', 'istes']
# 	Tokenization by flaubert/flaubert_large_cased: ['sidérur', 'g', 'istes']
# 	Tokenization by camembert/camembert-base: ['', 'sidér', 'ur', 'g', 'istes']
# 	Tokenization by xlm-roberta-large: ['si', 'd', 'ér', 'urg', 'istes']
# 	Tokenization by xlm-roberta-base: ['si', 'd', 'ér', 'urg', 'istes']
# 	Tokenization by bert-base-multilingual-uncased: ['sider', '##urg', '##istes']
# 	Tokenization by distilbert-base-multilingual-cased: ['sid', '##éru', '##rgi', '##stes']
# 	Tokenization by bert-base-multilingual-cased: ['sid', '##éru', '##rgi', '##stes']
#
# Word: avalées
# 	Tokenization by flaubert/flaubert_small_cased: ['aval', 'ées']
# 	Tokenization by flaubert/flaubert_base_uncased: ['aval', 'ées']
# 	Tokenization by flaubert/flaubert_base_cased: ['aval', 'ées']
# 	Tokenization by flaubert/flaubert_large_cased: ['aval', 'ées']
# 	Tokenization by camembert/camembert-base: ['aval', 'ées']
# 	Tokenization by xlm-roberta-large: ['aval', 'ées']
# 	Tokenization by xlm-roberta-base: ['aval', 'ées']
# 	Tokenization by bert-base-multilingual-uncased: ['aval', '##ees']
# 	Tokenization by distilbert-base-multilingual-cased: ['aval', '##ées']
# 	Tokenization by bert-base-multilingual-cased: ['aval', '##ées']
#
# Word: ethnozoologie
# 	Tokenization by flaubert/flaubert_small_cased: ['ethno', 'zo', 'ologie']
# 	Tokenization by flaubert/flaubert_base_uncased: ['ethno', 'zo', 'ologie']
# 	Tokenization by flaubert/flaubert_base_cased: ['ethno', 'zo', 'ologie']
# 	Tokenization by flaubert/flaubert_large_cased: ['ethno', 'zo', 'ologie']
# 	Tokenization by camembert/camembert-base: ['', 'ethno', 'zo', 'ologie']
# 	Tokenization by xlm-roberta-large: ['et', 'h', 'no', 'zo', 'ologie']
# 	Tokenization by xlm-roberta-base: ['et', 'h', 'no', 'zo', 'ologie']
# 	Tokenization by bert-base-multilingual-uncased: ['eth', '##no', '##zoo', '##logie']
# 	Tokenization by distilbert-base-multilingual-cased: ['et', '##hn', '##oz', '##ool', '##ogie']
# 	Tokenization by bert-base-multilingual-cased: ['et', '##hn', '##oz', '##ool', '##ogie']
#
# Word: coacquéreur
# 	Tokenization by flaubert/flaubert_small_cased: ['co', 'acquéreur']
# 	Tokenization by flaubert/flaubert_base_uncased: ['co', 'acquéreur']
# 	Tokenization by flaubert/flaubert_base_cased: ['co', 'acquéreur']
# 	Tokenization by flaubert/flaubert_large_cased: ['co', 'acquéreur']
# 	Tokenization by camembert/camembert-base: ['co', 'acquéreur']
# 	Tokenization by xlm-roberta-large: ['co', 'ac', 'qué', 're', 'ur']
# 	Tokenization by xlm-roberta-base: ['co', 'ac', 'qué', 're', 'ur']
# 	Tokenization by bert-base-multilingual-uncased: ['coa', '##cq', '##uer', '##eur']
# 	Tokenization by distilbert-base-multilingual-cased: ['coa', '##cq', '##ué', '##reur']
# 	Tokenization by bert-base-multilingual-cased: ['coa', '##cq', '##ué', '##reur']
#
# Word: boulodromes
# 	Tokenization by flaubert/flaubert_small_cased: ['bou', 'lo', 'dromes']
# 	Tokenization by flaubert/flaubert_base_uncased: ['boulo', 'dromes']
# 	Tokenization by flaubert/flaubert_base_cased: ['bou', 'lo', 'dromes']
# 	Tokenization by flaubert/flaubert_large_cased: ['bou', 'lo', 'dromes']
# 	Tokenization by camembert/camembert-base: ['bou', 'lo', 'drome', 's']
# 	Tokenization by xlm-roberta-large: ['bo', 'ulo', 'drome', 's']
# 	Tokenization by xlm-roberta-base: ['bo', 'ulo', 'drome', 's']
# 	Tokenization by bert-base-multilingual-uncased: ['bou', '##lod', '##rome', '##s']
# 	Tokenization by distilbert-base-multilingual-cased: ['bou', '##lod', '##rome', '##s']
# 	Tokenization by bert-base-multilingual-cased: ['bou', '##lod', '##rome', '##s']
#
# Word: romantisme
# 	Tokenization by flaubert/flaubert_small_cased: ['romantisme']
# 	Tokenization by flaubert/flaubert_base_uncased: ['romantisme']
# 	Tokenization by flaubert/flaubert_base_cased: ['romantisme']
# 	Tokenization by flaubert/flaubert_large_cased: ['romantisme']
# 	Tokenization by camembert/camembert-base: ['romantisme']
# 	Tokenization by xlm-roberta-large: ['romantis', 'me']
# 	Tokenization by xlm-roberta-base: ['romantis', 'me']
# 	Tokenization by bert-base-multilingual-uncased: ['roman', '##tisme']
# 	Tokenization by distilbert-base-multilingual-cased: ['roman', '##tisme']
# 	Tokenization by bert-base-multilingual-cased: ['roman', '##tisme']
#
# Word: pétouille
# 	Tokenization by flaubert/flaubert_small_cased: ['pé', 'tou', 'ille']
# 	Tokenization by flaubert/flaubert_base_uncased: ['pé', 'tou', 'ille']
# 	Tokenization by flaubert/flaubert_base_cased: ['pé', 'tou', 'ille']
# 	Tokenization by flaubert/flaubert_large_cased: ['pé', 'tou', 'ille']
# 	Tokenization by camembert/camembert-base: ['pét', 'ouille']
# 	Tokenization by xlm-roberta-large: ['pé', 'to', 'uille']
# 	Tokenization by xlm-roberta-base: ['pé', 'to', 'uille']
# 	Tokenization by bert-base-multilingual-uncased: ['pet', '##ou', '##ille']
# 	Tokenization by distilbert-base-multilingual-cased: ['pé', '##tou', '##ille']
# 	Tokenization by bert-base-multilingual-cased: ['pé', '##tou', '##ille']

# %% [markdown]
# # Verbs

# %%
all_verbs = pd.read_csv('../Data/Morphalou/all_verbs_v2.csv', index_col = 0)

# %%
all_verbs
# Out:
#                Number       Tense        Person     Lemma
# Word
# abaissa      singular  simplePast   thirdPerson  abaisser
# abaissai     singular  simplePast   firstPerson  abaisser
# abaissaient    plural   imperfect   thirdPerson  abaisser
# abaissais    singular   imperfect  secondPerson  abaisser
# abaissait    singular   imperfect   thirdPerson  abaisser
# ...               ...         ...           ...       ...
# œuvreront      plural      future   thirdPerson    œuvrer
# œuvrâmes       plural  simplePast   firstPerson    œuvrer
# œuvrâtes       plural  simplePast  secondPerson    œuvrer
# œuvrèrent      plural  simplePast   thirdPerson    œuvrer
# œuvré        singular        past           NaN    œuvrer
#
# [320264 rows x 4 columns]

# %%
verb_lens = []

# %%
for i in range(len(models)):
    verbs_df = pd.read_csv(f'../Data/{models[i]["label"]}/all_verbs_we.csv')
    verb_lens.append(len(verbs_df))

# %%
verb_size_comp = pd.DataFrame(index=[m['label'] for m in models])

# %%
verb_size_comp['Verb vocab size'] = verb_lens
verb_size_comp['Percentage of Morphalou vocab'] = verb_size_comp['Verb vocab size'] * 100 / len(all_verbs)

# %%
verb_size_comp.sort_values(by='Verb vocab size', ascending=False)
# Out:
#                  Verb vocab size  Percentage of Morphalou vocab
# flau_base_u                 6377                       1.991170
# flau_small_c                5425                       1.693915
# flau_base_c                 5425                       1.693915
# flau_large_c                5425                       1.693915
# cam_base                    3852                       1.202758
# bert_base_u                 2353                       0.734706
# xlm_large                   1233                       0.384995
# xlm_base                    1233                       0.384995
# distilbert_base              925                       0.288824
# bert_base_c                  925                       0.288824

# %%
verb_sample = all_verbs.index.to_series().sample(n=20)

# %%
verb_tokenizations = []

# %%
for m in models:
    m_tokenizations = []
    model, tokenizer = initiate_model(m['name'])
    for w in verb_sample:
        tokenization = [tokenizer.decode(x) for x in tokenizer.encode(w)]
        m_tokenizations.append(tokenization)
    verb_tokenizations.append(m_tokenizations)
# Out:
# Some weights of the model checkpoint at bert-base-multilingual-uncased were not used when initializing BertForMaskedLM: ['cls.seq_relationship.bias', 'cls.seq_relationship.weight']
# - This IS expected if you are initializing BertForMaskedLM from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForMaskedLM from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of the model checkpoint at bert-base-multilingual-cased were not used when initializing BertForMaskedLM: ['cls.seq_relationship.bias', 'cls.seq_relationship.weight']
# - This IS expected if you are initializing BertForMaskedLM from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForMaskedLM from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
for j in range(len(verb_sample)):
    print(f'\nWord: {verb_sample[j]}')
    for i in range(len(models)):
        print(f'\tTokenization by {models[i]["name"]}: {list(filter(check_not_stop_tokens, verb_tokenizations[i][j]))}')
# Out:
# Word: déparchâtes
# 	Tokenization by flaubert/flaubert_small_cased: ['dé', 'par', 'châ', 'tes']
# 	Tokenization by flaubert/flaubert_base_uncased: ['dépar', 'châ', 'tes']
# 	Tokenization by flaubert/flaubert_base_cased: ['dé', 'par', 'châ', 'tes']
# 	Tokenization by flaubert/flaubert_large_cased: ['dé', 'par', 'châ', 'tes']
# 	Tokenization by camembert/camembert-base: ['dép', 'arch', 'ât', 'es']
# 	Tokenization by xlm-roberta-large: ['dép', 'arch', 'ât', 'es']
# 	Tokenization by xlm-roberta-base: ['dép', 'arch', 'ât', 'es']
# 	Tokenization by bert-base-multilingual-uncased: ['de', '##par', '##cha', '##tes']
# 	Tokenization by distilbert-base-multilingual-cased: ['dé', '##par', '##ch', '##ât', '##es']
# 	Tokenization by bert-base-multilingual-cased: ['dé', '##par', '##ch', '##ât', '##es']
#
# Word: dépréciés
# 	Tokenization by flaubert/flaubert_small_cased: ['dépréci', 'és']
# 	Tokenization by flaubert/flaubert_base_uncased: ['dépréci', 'és']
# 	Tokenization by flaubert/flaubert_base_cased: ['dépréci', 'és']
# 	Tokenization by flaubert/flaubert_large_cased: ['dépréci', 'és']
# 	Tokenization by camembert/camembert-base: ['dépréci', 'és']
# 	Tokenization by xlm-roberta-large: ['dép', 'ré', 'ci', 'és']
# 	Tokenization by xlm-roberta-base: ['dép', 'ré', 'ci', 'és']
# 	Tokenization by bert-base-multilingual-uncased: ['de', '##pre', '##cies']
# 	Tokenization by distilbert-base-multilingual-cased: ['dé', '##pr', '##éc', '##iés']
# 	Tokenization by bert-base-multilingual-cased: ['dé', '##pr', '##éc', '##iés']
#
# Word: dénivelaient
# 	Tokenization by flaubert/flaubert_small_cased: ['déni', 'vel', 'aient']
# 	Tokenization by flaubert/flaubert_base_uncased: ['déni', 'vel', 'aient']
# 	Tokenization by flaubert/flaubert_base_cased: ['déni', 'vel', 'aient']
# 	Tokenization by flaubert/flaubert_large_cased: ['déni', 'vel', 'aient']
# 	Tokenization by camembert/camembert-base: ['déni', 'vel', 'aient']
# 	Tokenization by xlm-roberta-large: ['dé', 'nivel', 'aient']
# 	Tokenization by xlm-roberta-base: ['dé', 'nivel', 'aient']
# 	Tokenization by bert-base-multilingual-uncased: ['den', '##ivel', '##aient']
# 	Tokenization by distilbert-base-multilingual-cased: ['dé', '##ni', '##vela', '##ient']
# 	Tokenization by bert-base-multilingual-cased: ['dé', '##ni', '##vela', '##ient']
#
# Word: acidifierons
# 	Tokenization by flaubert/flaubert_small_cased: ['aci', 'di', 'fi', 'erons']
# 	Tokenization by flaubert/flaubert_base_uncased: ['aci', 'di', 'fi', 'erons']
# 	Tokenization by flaubert/flaubert_base_cased: ['aci', 'di', 'fi', 'erons']
# 	Tokenization by flaubert/flaubert_large_cased: ['aci', 'di', 'fi', 'erons']
# 	Tokenization by camembert/camembert-base: ['a', 'cid', 'ifier', 'ons']
# 	Tokenization by xlm-roberta-large: ['acid', 'ifier', 'ons']
# 	Tokenization by xlm-roberta-base: ['acid', 'ifier', 'ons']
# 	Tokenization by bert-base-multilingual-uncased: ['acid', '##ifie', '##rons']
# 	Tokenization by distilbert-base-multilingual-cased: ['acid', '##ifier', '##ons']
# 	Tokenization by bert-base-multilingual-cased: ['acid', '##ifier', '##ons']
#
# Word: autoproclamâtes
# 	Tokenization by flaubert/flaubert_small_cased: ['auto', 'proclam', 'â', 'tes']
# 	Tokenization by flaubert/flaubert_base_uncased: ['auto', 'proclam', 'â', 'tes']
# 	Tokenization by flaubert/flaubert_base_cased: ['auto', 'proclam', 'â', 'tes']
# 	Tokenization by flaubert/flaubert_large_cased: ['auto', 'proclam', 'â', 'tes']
# 	Tokenization by camembert/camembert-base: ['auto', 'pro', 'c', 'lam', 'ât', 'es']
# 	Tokenization by xlm-roberta-large: ['auto', 'pro', 'clam', 'ât', 'es']
# 	Tokenization by xlm-roberta-base: ['auto', 'pro', 'clam', 'ât', 'es']
# 	Tokenization by bert-base-multilingual-uncased: ['auto', '##pro', '##cla', '##mates']
# 	Tokenization by distilbert-base-multilingual-cased: ['auto', '##pro', '##cla', '##m', '##ât', '##es']
# 	Tokenization by bert-base-multilingual-cased: ['auto', '##pro', '##cla', '##m', '##ât', '##es']
#
# Word: paginais
# 	Tokenization by flaubert/flaubert_small_cased: ['pa', 'gin', 'ais']
# 	Tokenization by flaubert/flaubert_base_uncased: ['pa', 'gin', 'ais']
# 	Tokenization by flaubert/flaubert_base_cased: ['pa', 'gin', 'ais']
# 	Tokenization by flaubert/flaubert_large_cased: ['pa', 'gin', 'ais']
# 	Tokenization by camembert/camembert-base: ['pa', 'gin', 'ais']
# 	Tokenization by xlm-roberta-large: ['pagina', 'is']
# 	Tokenization by xlm-roberta-base: ['pagina', 'is']
# 	Tokenization by bert-base-multilingual-uncased: ['pagina', '##is']
# 	Tokenization by distilbert-base-multilingual-cased: ['pagina', '##is']
# 	Tokenization by bert-base-multilingual-cased: ['pagina', '##is']
#
# Word: redélogeassiez
# 	Tokenization by flaubert/flaubert_small_cased: ['re', 'dé', 'lo', 'ge', 'assiez']
# 	Tokenization by flaubert/flaubert_base_uncased: ['re', 'dé', 'lo', 'ge', 'assi', 'ez']
# 	Tokenization by flaubert/flaubert_base_cased: ['re', 'dé', 'lo', 'ge', 'assiez']
# 	Tokenization by flaubert/flaubert_large_cased: ['re', 'dé', 'lo', 'ge', 'assiez']
# 	Tokenization by camembert/camembert-base: ['red', 'éloge', 'assi', 'ez']
# 	Tokenization by xlm-roberta-large: ['red', 'é', 'loge', 'as', 'si', 'ez']
# 	Tokenization by xlm-roberta-base: ['red', 'é', 'loge', 'as', 'si', 'ez']
# 	Tokenization by bert-base-multilingual-uncased: ['rede', '##loge', '##ass', '##iez']
# 	Tokenization by distilbert-base-multilingual-cased: ['red', '##él', '##oge', '##ass', '##ie', '##z']
# 	Tokenization by bert-base-multilingual-cased: ['red', '##él', '##oge', '##ass', '##ie', '##z']
#
# Word: stuquerons
# 	Tokenization by flaubert/flaubert_small_cased: ['stu', 'qu', 'erons']
# 	Tokenization by flaubert/flaubert_base_uncased: ['stu', 'querons']
# 	Tokenization by flaubert/flaubert_base_cased: ['stu', 'qu', 'erons']
# 	Tokenization by flaubert/flaubert_large_cased: ['stu', 'qu', 'erons']
# 	Tokenization by camembert/camembert-base: ['s', 'tu', 'que', 'rons']
# 	Tokenization by xlm-roberta-large: ['stu', 'que', 'rons']
# 	Tokenization by xlm-roberta-base: ['stu', 'que', 'rons']
# 	Tokenization by bert-base-multilingual-uncased: ['stu', '##quer', '##ons']
# 	Tokenization by distilbert-base-multilingual-cased: ['st', '##u', '##quer', '##ons']
# 	Tokenization by bert-base-multilingual-cased: ['st', '##u', '##quer', '##ons']
#
# Word: enformait
# 	Tokenization by flaubert/flaubert_small_cased: ['en', 'formait']
# 	Tokenization by flaubert/flaubert_base_uncased: ['en', 'formait']
# 	Tokenization by flaubert/flaubert_base_cased: ['en', 'formait']
# 	Tokenization by flaubert/flaubert_large_cased: ['en', 'formait']
# 	Tokenization by camembert/camembert-base: ['en', 'form', 'ait']
# 	Tokenization by xlm-roberta-large: ['en', 'forma', 'it']
# 	Tokenization by xlm-roberta-base: ['en', 'forma', 'it']
# 	Tokenization by bert-base-multilingual-uncased: ['en', '##forma', '##it']
# 	Tokenization by distilbert-base-multilingual-cased: ['en', '##forma', '##it']
# 	Tokenization by bert-base-multilingual-cased: ['en', '##forma', '##it']
#
# Word: chagrina
# 	Tokenization by flaubert/flaubert_small_cased: ['chagr', 'ina']
# 	Tokenization by flaubert/flaubert_base_uncased: ['chagr', 'ina']
# 	Tokenization by flaubert/flaubert_base_cased: ['chagr', 'ina']
# 	Tokenization by flaubert/flaubert_large_cased: ['chagr', 'ina']
# 	Tokenization by camembert/camembert-base: ['chagrin', 'a']
# 	Tokenization by xlm-roberta-large: ['cha', 'grin', 'a']
# 	Tokenization by xlm-roberta-base: ['cha', 'grin', 'a']
# 	Tokenization by bert-base-multilingual-uncased: ['cha', '##gri', '##na']
# 	Tokenization by distilbert-base-multilingual-cased: ['cha', '##gri', '##na']
# 	Tokenization by bert-base-multilingual-cased: ['cha', '##gri', '##na']
#
# Word: olofâmes
# 	Tokenization by flaubert/flaubert_small_cased: ['olo', 'f', 'âmes']
# 	Tokenization by flaubert/flaubert_base_uncased: ['olo', 'f', 'âmes']
# 	Tokenization by flaubert/flaubert_base_cased: ['olo', 'f', 'âmes']
# 	Tokenization by flaubert/flaubert_large_cased: ['olo', 'f', 'âmes']
# 	Tokenization by camembert/camembert-base: ['', 'olo', 'f', 'âmes']
# 	Tokenization by xlm-roberta-large: ['olo', 'fâ', 'mes']
# 	Tokenization by xlm-roberta-base: ['olo', 'fâ', 'mes']
# 	Tokenization by bert-base-multilingual-uncased: ['olof', '##ame', '##s']
# 	Tokenization by distilbert-base-multilingual-cased: ['ol', '##of', '##âm', '##es']
# 	Tokenization by bert-base-multilingual-cased: ['ol', '##of', '##âm', '##es']
#
# Word: lapidifiassions
# 	Tokenization by flaubert/flaubert_small_cased: ['l', 'api', 'di', 'fi', 'as', 'sions']
# 	Tokenization by flaubert/flaubert_base_uncased: ['lap', 'idi', 'fi', 'as', 'sions']
# 	Tokenization by flaubert/flaubert_base_cased: ['l', 'api', 'di', 'fi', 'as', 'sions']
# 	Tokenization by flaubert/flaubert_large_cased: ['l', 'api', 'di', 'fi', 'as', 'sions']
# 	Tokenization by camembert/camembert-base: ['la', 'pid', 'ifi', 'a', 'ssions']
# 	Tokenization by xlm-roberta-large: ['la', 'pidi', 'fi', 'as', 'sions']
# 	Tokenization by xlm-roberta-base: ['la', 'pidi', 'fi', 'as', 'sions']
# 	Tokenization by bert-base-multilingual-uncased: ['lapi', '##di', '##fia', '##ssion', '##s']
# 	Tokenization by distilbert-base-multilingual-cased: ['lap', '##idi', '##fia', '##ssion', '##s']
# 	Tokenization by bert-base-multilingual-cased: ['lap', '##idi', '##fia', '##ssion', '##s']
#
# Word: glissâtes
# 	Tokenization by flaubert/flaubert_small_cased: ['glis', 's', 'â', 'tes']
# 	Tokenization by flaubert/flaubert_base_uncased: ['gliss', 'â', 'tes']
# 	Tokenization by flaubert/flaubert_base_cased: ['glis', 's', 'â', 'tes']
# 	Tokenization by flaubert/flaubert_large_cased: ['glis', 's', 'â', 'tes']
# 	Tokenization by camembert/camembert-base: ['g', 'lis', 's', 'ât', 'es']
# 	Tokenization by xlm-roberta-large: ['gli', 's', 's', 'ât', 'es']
# 	Tokenization by xlm-roberta-base: ['gli', 's', 's', 'ât', 'es']
# 	Tokenization by bert-base-multilingual-uncased: ['gli', '##ssa', '##tes']
# 	Tokenization by distilbert-base-multilingual-cased: ['gli', '##ss', '##ât', '##es']
# 	Tokenization by bert-base-multilingual-cased: ['gli', '##ss', '##ât', '##es']
#
# Word: enchastelassions
# 	Tokenization by flaubert/flaubert_small_cased: ['ench', 'ast', 'el', 'as', 'sions']
# 	Tokenization by flaubert/flaubert_base_uncased: ['en', 'chas', 'tel', 'as', 'sions']
# 	Tokenization by flaubert/flaubert_base_cased: ['ench', 'ast', 'el', 'as', 'sions']
# 	Tokenization by flaubert/flaubert_large_cased: ['ench', 'ast', 'el', 'as', 'sions']
# 	Tokenization by camembert/camembert-base: ['en', 'ch', 'aste', 'la', 'ssions']
# 	Tokenization by xlm-roberta-large: ['en', 'cha', 'stel', 'as', 'sions']
# 	Tokenization by xlm-roberta-base: ['en', 'cha', 'stel', 'as', 'sions']
# 	Tokenization by bert-base-multilingual-uncased: ['en', '##chas', '##tela', '##ssion', '##s']
# 	Tokenization by distilbert-base-multilingual-cased: ['en', '##chas', '##tela', '##ssion', '##s']
# 	Tokenization by bert-base-multilingual-cased: ['en', '##chas', '##tela', '##ssion', '##s']
#
# Word: mangeai
# 	Tokenization by flaubert/flaubert_small_cased: ['mange', 'ai']
# 	Tokenization by flaubert/flaubert_base_uncased: ['mange', 'ai']
# 	Tokenization by flaubert/flaubert_base_cased: ['mange', 'ai']
# 	Tokenization by flaubert/flaubert_large_cased: ['mange', 'ai']
# 	Tokenization by camembert/camembert-base: ['mange', 'ai']
# 	Tokenization by xlm-roberta-large: ['mange', 'ai']
# 	Tokenization by xlm-roberta-base: ['mange', 'ai']
# 	Tokenization by bert-base-multilingual-uncased: ['mange', '##ai']
# 	Tokenization by distilbert-base-multilingual-cased: ['mange', '##ai']
# 	Tokenization by bert-base-multilingual-cased: ['mange', '##ai']
#
# Word: attablais
# 	Tokenization by flaubert/flaubert_small_cased: ['att', 'ab', 'lais']
# 	Tokenization by flaubert/flaubert_base_uncased: ['atta', 'blais']
# 	Tokenization by flaubert/flaubert_base_cased: ['att', 'ab', 'lais']
# 	Tokenization by flaubert/flaubert_large_cased: ['att', 'ab', 'lais']
# 	Tokenization by camembert/camembert-base: ['att', 'ab', 'lais']
# 	Tokenization by xlm-roberta-large: ['att', 'ab', 'lais']
# 	Tokenization by xlm-roberta-base: ['att', 'ab', 'lais']
# 	Tokenization by bert-base-multilingual-uncased: ['atta', '##bla', '##is']
# 	Tokenization by distilbert-base-multilingual-cased: ['att', '##ab', '##lais']
# 	Tokenization by bert-base-multilingual-cased: ['att', '##ab', '##lais']
#
# Word: surfacturais
# 	Tokenization by flaubert/flaubert_small_cased: ['sur', 'factu', 'rais']
# 	Tokenization by flaubert/flaubert_base_uncased: ['sur', 'factu', 'rais']
# 	Tokenization by flaubert/flaubert_base_cased: ['sur', 'factu', 'rais']
# 	Tokenization by flaubert/flaubert_large_cased: ['sur', 'factu', 'rais']
# 	Tokenization by camembert/camembert-base: ['surf', 'actu', 'rais']
# 	Tokenization by xlm-roberta-large: ['surf', 'a', 'ctura', 'is']
# 	Tokenization by xlm-roberta-base: ['surf', 'a', 'ctura', 'is']
# 	Tokenization by bert-base-multilingual-uncased: ['surf', '##ac', '##tura', '##is']
# 	Tokenization by distilbert-base-multilingual-cased: ['sur', '##fa', '##ctura', '##is']
# 	Tokenization by bert-base-multilingual-cased: ['sur', '##fa', '##ctura', '##is']
#
# Word: amatissent
# 	Tokenization by flaubert/flaubert_small_cased: ['am', 'ati', 'ssent']
# 	Tokenization by flaubert/flaubert_base_uncased: ['am', 'ati', 'ssent']
# 	Tokenization by flaubert/flaubert_base_cased: ['am', 'ati', 'ssent']
# 	Tokenization by flaubert/flaubert_large_cased: ['am', 'ati', 'ssent']
# 	Tokenization by camembert/camembert-base: ['a', 'mat', 'issent']
# 	Tokenization by xlm-roberta-large: ['amat', 'issent']
# 	Tokenization by xlm-roberta-base: ['amat', 'issent']
# 	Tokenization by bert-base-multilingual-uncased: ['amat', '##issent']
# 	Tokenization by distilbert-base-multilingual-cased: ['amat', '##issent']
# 	Tokenization by bert-base-multilingual-cased: ['amat', '##issent']
#
# Word: pochtronnaient
# 	Tokenization by flaubert/flaubert_small_cased: ['po', 'ch', 'tr', 'onnaient']
# 	Tokenization by flaubert/flaubert_base_uncased: ['po', 'ch', 'tr', 'onnaient']
# 	Tokenization by flaubert/flaubert_base_cased: ['po', 'ch', 'tr', 'onnaient']
# 	Tokenization by flaubert/flaubert_large_cased: ['po', 'ch', 'tr', 'onnaient']
# 	Tokenization by camembert/camembert-base: ['po', 'ch', 'tron', 'naient']
# 	Tokenization by xlm-roberta-large: ['po', 'ch', 'tron', 'n', 'aient']
# 	Tokenization by xlm-roberta-base: ['po', 'ch', 'tron', 'n', 'aient']
# 	Tokenization by bert-base-multilingual-uncased: ['poc', '##ht', '##ron', '##nai', '##ent']
# 	Tokenization by distilbert-base-multilingual-cased: ['poc', '##ht', '##ron', '##naie', '##nt']
# 	Tokenization by bert-base-multilingual-cased: ['poc', '##ht', '##ron', '##naie', '##nt']
#
# Word: dansés
# 	Tokenization by flaubert/flaubert_small_cased: ['dan', 'sés']
# 	Tokenization by flaubert/flaubert_base_uncased: ['dan', 'sés']
# 	Tokenization by flaubert/flaubert_base_cased: ['dan', 'sés']
# 	Tokenization by flaubert/flaubert_large_cased: ['dan', 'sés']
# 	Tokenization by camembert/camembert-base: ['dans', 'és']
# 	Tokenization by xlm-roberta-large: ['dans', 'és']
# 	Tokenization by xlm-roberta-base: ['dans', 'és']
# 	Tokenization by bert-base-multilingual-uncased: ['danse', '##s']
# 	Tokenization by distilbert-base-multilingual-cased: ['dans', '##és']
# 	Tokenization by bert-base-multilingual-cased: ['dans', '##és']

# %% [markdown]
# # Adjectives

# %%
all_adjs = pd.read_csv('../Data/Morphalou/all_adjs_v2.csv', index_col = 0)

# %%
all_adjs = all_adjs[(all_adjs.Gender != 'invariable') & (all_adjs.Number != 'invariable')]

# %%
all_adjs
# Out:
#                        Gender    Number             Lemma
# Word
# a-humain            masculine  singular          a-humain
# a-raciste           masculine  singular         a-raciste
# aalénien            masculine  singular          aalénien
# aaléniens           masculine    plural          aalénien
# aalénienne           feminine  singular          aalénien
# ...                       ...       ...               ...
# œstroprogestatives   feminine    plural  œstroprogestatif
# œuvé                masculine  singular              œuvé
# œuvés               masculine    plural              œuvé
# œuvée                feminine  singular              œuvé
# œuvées               feminine    plural              œuvé
#
# [67982 rows x 3 columns]

# %% [markdown]
# Similarly to nouns, we can exclude multi-word adjectives:

# %%
all_adjs['len'] = [len(x.split()) for x in all_adjs.index.str.replace('-', ' ')]

# %%
one_word_adjs = all_adjs[all_adjs.len == 1]

# %%
adj_lens = []

# %%
for i in range(len(models)):
    adjs_df = pd.read_csv(f'../Data/{models[i]["label"]}/all_adjs_we.csv')
    adj_lens.append(len(adjs_df))

# %%
adj_size_comp = pd.DataFrame(index=[m['label'] for m in models])

# %%
adj_size_comp['Adj vocab size'] = adj_lens
adj_size_comp['Percentage of Morphalou vocab'] = adj_size_comp['Adj vocab size'] * 100 / len(one_word_adjs)

# %%
adj_size_comp.sort_values(by='Adj vocab size', ascending=False)
# Out:
#                  Adj vocab size  Percentage of Morphalou vocab
# flau_base_u               10362                      15.867814
# flau_small_c               8797                      13.471257
# flau_base_c                8797                      13.471257
# flau_large_c               8797                      13.471257
# cam_base                   6346                       9.717926
# bert_base_u                2907                       4.451625
# distilbert_base            1610                       2.465468
# bert_base_c                1610                       2.465468
# xlm_large                  1387                       2.123978
# xlm_base                   1387                       2.123978

# %%
adj_sample = one_word_adjs.index.to_series().sample(n=20)

# %%
adj_tokenizations = []

# %%
for m in models:
    m_tokenizations = []
    model, tokenizer = initiate_model(m['name'])
    for w in adj_sample:
        tokenization = [tokenizer.decode(x) for x in tokenizer.encode(w)]
        m_tokenizations.append(tokenization)
    adj_tokenizations.append(m_tokenizations)
# Out:
# Some weights of the model checkpoint at bert-base-multilingual-uncased were not used when initializing BertForMaskedLM: ['cls.seq_relationship.bias', 'cls.seq_relationship.weight']
# - This IS expected if you are initializing BertForMaskedLM from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForMaskedLM from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of the model checkpoint at bert-base-multilingual-cased were not used when initializing BertForMaskedLM: ['cls.seq_relationship.bias', 'cls.seq_relationship.weight']
# - This IS expected if you are initializing BertForMaskedLM from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForMaskedLM from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
for j in range(len(adj_sample)):
    print(f'\nWord: {adj_sample[j]}')
    for i in range(len(models)):
        print(f'\tTokenization by {models[i]["name"]}: {list(filter(check_not_stop_tokens, adj_tokenizations[i][j]))}')
# Out:
# Word: chicaneurs
# 	Tokenization by flaubert/flaubert_small_cased: ['chi', 'can', 'eurs']
# 	Tokenization by flaubert/flaubert_base_uncased: ['chi', 'can', 'eurs']
# 	Tokenization by flaubert/flaubert_base_cased: ['chi', 'can', 'eurs']
# 	Tokenization by flaubert/flaubert_large_cased: ['chi', 'can', 'eurs']
# 	Tokenization by camembert/camembert-base: ['chic', 'an', 'eurs']
# 	Tokenization by xlm-roberta-large: ['chica', 'n', 'eurs']
# 	Tokenization by xlm-roberta-base: ['chica', 'n', 'eurs']
# 	Tokenization by bert-base-multilingual-uncased: ['chica', '##neur', '##s']
# 	Tokenization by distilbert-base-multilingual-cased: ['chica', '##neur', '##s']
# 	Tokenization by bert-base-multilingual-cased: ['chica', '##neur', '##s']
#
# Word: ressuyé
# 	Tokenization by flaubert/flaubert_small_cased: ['res', 'su', 'yé']
# 	Tokenization by flaubert/flaubert_base_uncased: ['res', 'su', 'yé']
# 	Tokenization by flaubert/flaubert_base_cased: ['res', 'su', 'yé']
# 	Tokenization by flaubert/flaubert_large_cased: ['res', 'su', 'yé']
# 	Tokenization by camembert/camembert-base: ['ress', 'uy', 'é']
# 	Tokenization by xlm-roberta-large: ['res', 'su', 'y', 'é']
# 	Tokenization by xlm-roberta-base: ['res', 'su', 'y', 'é']
# 	Tokenization by bert-base-multilingual-uncased: ['res', '##su', '##ye']
# 	Tokenization by distilbert-base-multilingual-cased: ['res', '##su', '##y', '##é']
# 	Tokenization by bert-base-multilingual-cased: ['res', '##su', '##y', '##é']
#
# Word: cérigère
# 	Tokenization by flaubert/flaubert_small_cased: ['c', 'éri', 'gère']
# 	Tokenization by flaubert/flaubert_base_uncased: ['céri', 'gère']
# 	Tokenization by flaubert/flaubert_base_cased: ['c', 'éri', 'gère']
# 	Tokenization by flaubert/flaubert_large_cased: ['c', 'éri', 'gère']
# 	Tokenization by camembert/camembert-base: ['c', 'éri', 'gère']
# 	Tokenization by xlm-roberta-large: ['cé', 'rig', 'ère']
# 	Tokenization by xlm-roberta-base: ['cé', 'rig', 'ère']
# 	Tokenization by bert-base-multilingual-uncased: ['ce', '##rige', '##re']
# 	Tokenization by distilbert-base-multilingual-cased: ['c', '##éri', '##g', '##ère']
# 	Tokenization by bert-base-multilingual-cased: ['c', '##éri', '##g', '##ère']
#
# Word: adoratrices
# 	Tokenization by flaubert/flaubert_small_cased: ['ador', 'atrices']
# 	Tokenization by flaubert/flaubert_base_uncased: ['ador', 'atrices']
# 	Tokenization by flaubert/flaubert_base_cased: ['ador', 'atrices']
# 	Tokenization by flaubert/flaubert_large_cased: ['ador', 'atrices']
# 	Tokenization by camembert/camembert-base: ['', 'ador', 'atrices']
# 	Tokenization by xlm-roberta-large: ['adora', 'trice', 's']
# 	Tokenization by xlm-roberta-base: ['adora', 'trice', 's']
# 	Tokenization by bert-base-multilingual-uncased: ['ado', '##rat', '##rices']
# 	Tokenization by distilbert-base-multilingual-cased: ['ado', '##rat', '##rices']
# 	Tokenization by bert-base-multilingual-cased: ['ado', '##rat', '##rices']
#
# Word: évangélisateur
# 	Tokenization by flaubert/flaubert_small_cased: ['évangél', 'isateur']
# 	Tokenization by flaubert/flaubert_base_uncased: ['évangél', 'isateur']
# 	Tokenization by flaubert/flaubert_base_cased: ['évangél', 'isateur']
# 	Tokenization by flaubert/flaubert_large_cased: ['évangél', 'isateur']
# 	Tokenization by camembert/camembert-base: ['év', 'angé', 'l', 'isateur']
# 	Tokenization by xlm-roberta-large: ['é', 'vang', 'é', 'lis', 'ateur']
# 	Tokenization by xlm-roberta-base: ['é', 'vang', 'é', 'lis', 'ateur']
# 	Tokenization by bert-base-multilingual-uncased: ['evan', '##gel', '##isa', '##teur']
# 	Tokenization by distilbert-base-multilingual-cased: ['év', '##ang', '##él', '##isa', '##teur']
# 	Tokenization by bert-base-multilingual-cased: ['év', '##ang', '##él', '##isa', '##teur']
#
# Word: intriquées
# 	Tokenization by flaubert/flaubert_small_cased: ['intri', 'quées']
# 	Tokenization by flaubert/flaubert_base_uncased: ['intri', 'quées']
# 	Tokenization by flaubert/flaubert_base_cased: ['intri', 'quées']
# 	Tokenization by flaubert/flaubert_large_cased: ['intri', 'quées']
# 	Tokenization by camembert/camembert-base: ['in', 'tri', 'quée', 's']
# 	Tokenization by xlm-roberta-large: ['in', 'tri', 'qué', 'es']
# 	Tokenization by xlm-roberta-base: ['in', 'tri', 'qué', 'es']
# 	Tokenization by bert-base-multilingual-uncased: ['intr', '##ique', '##es']
# 	Tokenization by distilbert-base-multilingual-cased: ['int', '##ri', '##quées']
# 	Tokenization by bert-base-multilingual-cased: ['int', '##ri', '##quées']
#
# Word: macrosociologique
# 	Tokenization by flaubert/flaubert_small_cased: ['macro', 'sociologique']
# 	Tokenization by flaubert/flaubert_base_uncased: ['macro', 'sociologique']
# 	Tokenization by flaubert/flaubert_base_cased: ['macro', 'sociologique']
# 	Tokenization by flaubert/flaubert_large_cased: ['macro', 'sociologique']
# 	Tokenization by camembert/camembert-base: ['macro', 'soci', 'ologique']
# 	Tokenization by xlm-roberta-large: ['macro', 'soci', 'ologique']
# 	Tokenization by xlm-roberta-base: ['macro', 'soci', 'ologique']
# 	Tokenization by bert-base-multilingual-uncased: ['mac', '##ros', '##ocio', '##logique']
# 	Tokenization by distilbert-base-multilingual-cased: ['mac', '##ros', '##oci', '##ologique']
# 	Tokenization by bert-base-multilingual-cased: ['mac', '##ros', '##oci', '##ologique']
#
# Word: dépersonnalisant
# 	Tokenization by flaubert/flaubert_small_cased: ['dé', 'personn', 'alisant']
# 	Tokenization by flaubert/flaubert_base_uncased: ['dé', 'personn', 'alisant']
# 	Tokenization by flaubert/flaubert_base_cased: ['dé', 'personn', 'alisant']
# 	Tokenization by flaubert/flaubert_large_cased: ['dé', 'personn', 'alisant']
# 	Tokenization by camembert/camembert-base: ['dé', 'pers', 'on', 'nal', 'isant']
# 	Tokenization by xlm-roberta-large: ['dé', 'person', 'nal', 'isant']
# 	Tokenization by xlm-roberta-base: ['dé', 'person', 'nal', 'isant']
# 	Tokenization by bert-base-multilingual-uncased: ['de', '##person', '##nali', '##sant']
# 	Tokenization by distilbert-base-multilingual-cased: ['dé', '##person', '##nalis', '##ant']
# 	Tokenization by bert-base-multilingual-cased: ['dé', '##person', '##nalis', '##ant']
#
# Word: affabulateur
# 	Tokenization by flaubert/flaubert_small_cased: ['aff', 'abul', 'ateur']
# 	Tokenization by flaubert/flaubert_base_uncased: ['aff', 'ab', 'ul', 'ateur']
# 	Tokenization by flaubert/flaubert_base_cased: ['aff', 'abul', 'ateur']
# 	Tokenization by flaubert/flaubert_large_cased: ['aff', 'abul', 'ateur']
# 	Tokenization by camembert/camembert-base: ['', 'affa', 'bul', 'ateur']
# 	Tokenization by xlm-roberta-large: ['a', 'ffa', 'bula', 'teur']
# 	Tokenization by xlm-roberta-base: ['a', 'ffa', 'bula', 'teur']
# 	Tokenization by bert-base-multilingual-uncased: ['af', '##fa', '##bula', '##teur']
# 	Tokenization by distilbert-base-multilingual-cased: ['af', '##fa', '##bula', '##teur']
# 	Tokenization by bert-base-multilingual-cased: ['af', '##fa', '##bula', '##teur']
#
# Word: pendant
# 	Tokenization by flaubert/flaubert_small_cased: ['pendant']
# 	Tokenization by flaubert/flaubert_base_uncased: ['pendant']
# 	Tokenization by flaubert/flaubert_base_cased: ['pendant']
# 	Tokenization by flaubert/flaubert_large_cased: ['pendant']
# 	Tokenization by camembert/camembert-base: ['pendant']
# 	Tokenization by xlm-roberta-large: ['pendant']
# 	Tokenization by xlm-roberta-base: ['pendant']
# 	Tokenization by bert-base-multilingual-uncased: ['pendant']
# 	Tokenization by distilbert-base-multilingual-cased: ['pendant']
# 	Tokenization by bert-base-multilingual-cased: ['pendant']
#
# Word: arondinacée
# 	Tokenization by flaubert/flaubert_small_cased: ['ar', 'ond', 'in', 'acée']
# 	Tokenization by flaubert/flaubert_base_uncased: ['ar', 'on', 'din', 'acée']
# 	Tokenization by flaubert/flaubert_base_cased: ['ar', 'ond', 'in', 'acée']
# 	Tokenization by flaubert/flaubert_large_cased: ['ar', 'ond', 'in', 'acée']
# 	Tokenization by camembert/camembert-base: ['a', 'rond', 'ina', 'cée']
# 	Tokenization by xlm-roberta-large: ['a', 'ron', 'dina', 'cé', 'e']
# 	Tokenization by xlm-roberta-base: ['a', 'ron', 'dina', 'cé', 'e']
# 	Tokenization by bert-base-multilingual-uncased: ['aron', '##dina', '##cee']
# 	Tokenization by distilbert-base-multilingual-cased: ['ar', '##ond', '##ina', '##cée']
# 	Tokenization by bert-base-multilingual-cased: ['ar', '##ond', '##ina', '##cée']
#
# Word: zénithaux
# 	Tokenization by flaubert/flaubert_small_cased: ['z', 'éni', 'th', 'aux']
# 	Tokenization by flaubert/flaubert_base_uncased: ['zéni', 'th', 'aux']
# 	Tokenization by flaubert/flaubert_base_cased: ['z', 'éni', 'th', 'aux']
# 	Tokenization by flaubert/flaubert_large_cased: ['z', 'éni', 'th', 'aux']
# 	Tokenization by camembert/camembert-base: ['z', 'éni', 'th', 'aux']
# 	Tokenization by xlm-roberta-large: ['z', 'én', 'ith', 'aux']
# 	Tokenization by xlm-roberta-base: ['z', 'én', 'ith', 'aux']
# 	Tokenization by bert-base-multilingual-uncased: ['zenit', '##hau', '##x']
# 	Tokenization by distilbert-base-multilingual-cased: ['z', '##éni', '##tha', '##ux']
# 	Tokenization by bert-base-multilingual-cased: ['z', '##éni', '##tha', '##ux']
#
# Word: cloîtriers
# 	Tokenization by flaubert/flaubert_small_cased: ['clo', 'î', 'tri', 'ers']
# 	Tokenization by flaubert/flaubert_base_uncased: ['clo', 'î', 'tri', 'ers']
# 	Tokenization by flaubert/flaubert_base_cased: ['clo', 'î', 'tri', 'ers']
# 	Tokenization by flaubert/flaubert_large_cased: ['clo', 'î', 'tri', 'ers']
# 	Tokenization by camembert/camembert-base: ['clo', 'ît', 'rier', 's']
# 	Tokenization by xlm-roberta-large: ['clo', 'ît', 'rier', 's']
# 	Tokenization by xlm-roberta-base: ['clo', 'ît', 'rier', 's']
# 	Tokenization by bert-base-multilingual-uncased: ['cl', '##oit', '##riers']
# 	Tokenization by distilbert-base-multilingual-cased: ['c', '##lo', '##ît', '##riers']
# 	Tokenization by bert-base-multilingual-cased: ['c', '##lo', '##ît', '##riers']
#
# Word: corniculés
# 	Tokenization by flaubert/flaubert_small_cased: ['cor', 'ni', 'cul', 'és']
# 	Tokenization by flaubert/flaubert_base_uncased: ['cor', 'ni', 'culés']
# 	Tokenization by flaubert/flaubert_base_cased: ['cor', 'ni', 'cul', 'és']
# 	Tokenization by flaubert/flaubert_large_cased: ['cor', 'ni', 'cul', 'és']
# 	Tokenization by camembert/camembert-base: ['cor', 'nic', 'ulé', 's']
# 	Tokenization by xlm-roberta-large: ['cor', 'nicu', 'lés']
# 	Tokenization by xlm-roberta-base: ['cor', 'nicu', 'lés']
# 	Tokenization by bert-base-multilingual-uncased: ['corn', '##icu', '##les']
# 	Tokenization by distilbert-base-multilingual-cased: ['corn', '##icu', '##lés']
# 	Tokenization by bert-base-multilingual-cased: ['corn', '##icu', '##lés']
#
# Word: sympathisants
# 	Tokenization by flaubert/flaubert_small_cased: ['sympathisants']
# 	Tokenization by flaubert/flaubert_base_uncased: ['sympathisants']
# 	Tokenization by flaubert/flaubert_base_cased: ['sympathisants']
# 	Tokenization by flaubert/flaubert_large_cased: ['sympathisants']
# 	Tokenization by camembert/camembert-base: ['sympathisants']
# 	Tokenization by xlm-roberta-large: ['sympa', 'this', 'ants']
# 	Tokenization by xlm-roberta-base: ['sympa', 'this', 'ants']
# 	Tokenization by bert-base-multilingual-uncased: ['sy', '##mpat', '##his', '##ants']
# 	Tokenization by distilbert-base-multilingual-cased: ['sy', '##mpa', '##thi', '##sant', '##s']
# 	Tokenization by bert-base-multilingual-cased: ['sy', '##mpa', '##thi', '##sant', '##s']
#
# Word: concoctés
# 	Tokenization by flaubert/flaubert_small_cased: ['concoc', 'tés']
# 	Tokenization by flaubert/flaubert_base_uncased: ['concoc', 'tés']
# 	Tokenization by flaubert/flaubert_base_cased: ['concoc', 'tés']
# 	Tokenization by flaubert/flaubert_large_cased: ['concoc', 'tés']
# 	Tokenization by camembert/camembert-base: ['concocté', 's']
# 	Tokenization by xlm-roberta-large: ['con', 'co', 'c', 'tés']
# 	Tokenization by xlm-roberta-base: ['con', 'co', 'c', 'tés']
# 	Tokenization by bert-base-multilingual-uncased: ['con', '##co', '##ctes']
# 	Tokenization by distilbert-base-multilingual-cased: ['con', '##co', '##ct', '##és']
# 	Tokenization by bert-base-multilingual-cased: ['con', '##co', '##ct', '##és']
#
# Word: homéenne
# 	Tokenization by flaubert/flaubert_small_cased: ['hom', 'éenne']
# 	Tokenization by flaubert/flaubert_base_uncased: ['hom', 'é', 'enne']
# 	Tokenization by flaubert/flaubert_base_cased: ['hom', 'éenne']
# 	Tokenization by flaubert/flaubert_large_cased: ['hom', 'éenne']
# 	Tokenization by camembert/camembert-base: ['', 'hom', 'éenne']
# 	Tokenization by xlm-roberta-large: ['hom', 'é', 'enne']
# 	Tokenization by xlm-roberta-base: ['hom', 'é', 'enne']
# 	Tokenization by bert-base-multilingual-uncased: ['home', '##enne']
# 	Tokenization by distilbert-base-multilingual-cased: ['hom', '##éen', '##ne']
# 	Tokenization by bert-base-multilingual-cased: ['hom', '##éen', '##ne']
#
# Word: biplane
# 	Tokenization by flaubert/flaubert_small_cased: ['bi', 'plane']
# 	Tokenization by flaubert/flaubert_base_uncased: ['bi', 'plane']
# 	Tokenization by flaubert/flaubert_base_cased: ['bi', 'plane']
# 	Tokenization by flaubert/flaubert_large_cased: ['bi', 'plane']
# 	Tokenization by camembert/camembert-base: ['bi', 'plan', 'e']
# 	Tokenization by xlm-roberta-large: ['bi', 'plan', 'e']
# 	Tokenization by xlm-roberta-base: ['bi', 'plan', 'e']
# 	Tokenization by bert-base-multilingual-uncased: ['bi', '##plane']
# 	Tokenization by distilbert-base-multilingual-cased: ['bi', '##plane']
# 	Tokenization by bert-base-multilingual-cased: ['bi', '##plane']
#
# Word: invertébré
# 	Tokenization by flaubert/flaubert_small_cased: ['in', 'vertéb', 'ré']
# 	Tokenization by flaubert/flaubert_base_uncased: ['in', 'verté', 'bré']
# 	Tokenization by flaubert/flaubert_base_cased: ['in', 'vertéb', 'ré']
# 	Tokenization by flaubert/flaubert_large_cased: ['in', 'vertéb', 'ré']
# 	Tokenization by camembert/camembert-base: ['in', 'vert', 'é', 'bré']
# 	Tokenization by xlm-roberta-large: ['invert', 'é', 'bré']
# 	Tokenization by xlm-roberta-base: ['invert', 'é', 'bré']
# 	Tokenization by bert-base-multilingual-uncased: ['in', '##verte', '##bre']
# 	Tokenization by distilbert-base-multilingual-cased: ['in', '##vert', '##é', '##bré']
# 	Tokenization by bert-base-multilingual-cased: ['in', '##vert', '##é', '##bré']
#
# Word: contraversif
# 	Tokenization by flaubert/flaubert_small_cased: ['con', 'traver', 'sif']
# 	Tokenization by flaubert/flaubert_base_uncased: ['con', 'traver', 'sif']
# 	Tokenization by flaubert/flaubert_base_cased: ['con', 'traver', 'sif']
# 	Tokenization by flaubert/flaubert_large_cased: ['con', 'traver', 'sif']
# 	Tokenization by camembert/camembert-base: ['contra', 'vers', 'if']
# 	Tokenization by xlm-roberta-large: ['contra', 'versi', 'f']
# 	Tokenization by xlm-roberta-base: ['contra', 'versi', 'f']
# 	Tokenization by bert-base-multilingual-uncased: ['contra', '##vers', '##if']
# 	Tokenization by distilbert-base-multilingual-cased: ['contra', '##versi', '##f']
# 	Tokenization by bert-base-multilingual-cased: ['contra', '##versi', '##f']

# %% [markdown]
# # Shared vocabulary for all models

# %% [markdown]
# As we can see above, the vocabulary sizes vary among different models. Here we want to have a look into the vocabulary shared by models. For this, we will create 2 groups of models: trained on French corpus only and multi-lingual (trained on multiple languages). We will find the common vocabulary for French corpus models and all models, including French and multi-lingual.

# %%
french_model_ind = list(range(5))

# %% [markdown]
# ### Shared nouns

# %%
shared_vocab_fr = set()

# %%
for i in french_model_ind:
    nouns_df = pd.read_csv(f'../Data/{models[i]["label"]}/all_nouns_we.csv', index_col=0)
    if not shared_fr_vocab:
        shared_vocab_fr.update(nouns_df.index)
    else:
        shared_vocab_fr = shared_fr_vocab.intersection(nouns_df.index)

# %%
print(f'Size of shared vocabulary of French models: {len(shared_vocab_fr)}')
# Out:
# Size of shared vocabulary of French models: 9068

# %% [markdown]
# Below you can find a random sample of 30 nouns from the shared French vocabulary:

# %%
pd.Series(list(shared_vocab_fr)).sample(n=30)
# Out:
# 4487           croate
# 2157            roule
# 4739           tuerie
# 3885      réservation
# 5521            visée
# 3272           carnet
# 4255         standard
# 7232            appui
# 7690         canicule
# 2652       opérateurs
# 8888      psychologie
# 5168            garni
# 8533             fret
# 8868         magasins
# 6542            égaré
# 5462           nickel
# 8999        anecdotes
# 7499             doré
# 3180            types
# 8921       kilomètres
# 7209    organisateurs
# 734       capitaliste
# 8189           vivant
# 5298        rapproché
# 7792            corse
# 6286            lundi
# 1015          entière
# 6724        chapitres
# 7888            water
# 6997             noix
# dtype: object

# %%
shared_vocab_all = set()

# %%
for i in range(len(models)):
    nouns_df = pd.read_csv(f'../Data/{models[i]["label"]}/all_nouns_we.csv', index_col=0)
    if not shared_vocab_all:
        shared_vocab_all.update(nouns_df.index)
    else:
        shared_vocab_all = shared_vocab_all.intersection(nouns_df.index)

# %%
print(f'Size of shared vocabulary of all models: {len(shared_vocab_all)}')
# Out:
# Size of shared vocabulary of all models: 1980

# %% [markdown]
# Here is the sample of 30 nouns from the shared vocabulary among all models:

# %%
pd.Series(list(shared_vocab_all)).sample(n=30)
# Out:
# 685        élément
# 1078        mentor
# 1388           etc
# 80         matière
# 47          profil
# 1363      distance
# 309      documents
# 1199        guerre
# 456        conflit
# 1976         ligne
# 1855          logo
# 840            ben
# 1188         sites
# 485        licence
# 1631        impact
# 1235         basse
# 1489     Cambridge
# 871           bras
# 947       batterie
# 1376     populaire
# 1476       culture
# 616       matériel
# 1231       patient
# 1125          More
# 1468       package
# 1223           ver
# 320     résistance
# 468             TV
# 1769         crime
# 1776      variante
# dtype: object

# %% [markdown]
# ### Shared verbs

# %%
shared_verbs_fr = set()

# %%
for i in french_model_ind:
    verbs_df = pd.read_csv(f'../Data/{models[i]["label"]}/all_verbs_we.csv', index_col=0)
    if not shared_verbs_fr:
        shared_verbs_fr.update(verbs_df.index)
    else:
        shared_verbs_fr = shared_verbs_fr.intersection(verbs_df.index)

# %%
print(f'Number of shared verbs by French models: {len(shared_verbs_fr)}')
# Out:
# Number of shared verbs by French models: 3469

# %%
pd.Series(list(shared_verbs_fr)).sample(n=30)
# Out:
# 1840        parlait
# 2209      combinant
# 2742         épousé
# 199         rajouté
# 812            rasé
# 2450          suffi
# 2282      favoriser
# 513         fournir
# 118         pourrai
# 204         chauffé
# 1146       révélant
# 1550        offerts
# 439      entraînant
# 2782       apparait
# 3428       aspirant
# 3461        enterré
# 2726       renversé
# 1062        désirer
# 1569        serpent
# 2544         tissus
# 2843      distribué
# 1411    sophistiqué
# 83         comptant
# 1883       demeurer
# 345         expulsé
# 1766        discuté
# 398          croire
# 2757        soutenu
# 3325      défendent
# 1410     récompensé
# dtype: object

# %%
shared_verbs_all = set()

# %%
for i in range(len(models)):
    verbs_df = pd.read_csv(f'../Data/{models[i]["label"]}/all_verbs_we.csv', index_col=0)
    if not shared_verbs_all:
        shared_verbs_all.update(verbs_df.index)
    else:
        shared_verbs_all = shared_verbs_all.intersection(verbs_df.index)

# %%
print(f'Number of shared verbs by all models: {len(shared_verbs_all)}')
# Out:
# Number of shared verbs by all models: 343

# %%
pd.Series(list(shared_verbs_all)).sample(n=30)
# Out:
# 258         mater
# 142          veut
# 63            put
# 157        arriva
# 118          aura
# 196            vu
# 154      parcours
# 289      designer
# 111         lancé
# 87         agenda
# 73      rejoindre
# 208          voit
# 101       réalisé
# 322       demanda
# 32      convertir
# 33          faire
# 260    développer
# 318       contenu
# 84          carré
# 7          appelé
# 94       observer
# 286        envoyé
# 238        combat
# 146    intervenir
# 161        porter
# 263       exercer
# 48          débat
# 259       avaient
# 120        partir
# 1           lança
# dtype: object

# %% [markdown]
# ### Shared adjectives

# %%
shared_adj_fr = set()

for i in french_model_ind:
    adj_df = pd.read_csv(f'../Data/{models[i]["label"]}/all_adjs_we.csv', index_col=0)
    if not shared_adj_fr:
        shared_adj_fr.update(adj_df.index)
    else:
        shared_adj_fr = shared_adj_fr.intersection(adj_df.index)

# %%
print(f'Number of shared adjectives by French models: {len(shared_adj_fr)}')
# Out:
# Number of shared adjectives by French models: 5651

# %%
pd.Series(list(shared_adj_fr)).sample(n=30)
# Out:
# 3613            mural
# 5180        affichant
# 5489             pris
# 2076      coéquipiers
# 971            poussé
# 4464        agressive
# 3739        débutants
# 1108         entrevue
# 673          modifiés
# 18      indépendantes
# 3449       dramatique
# 5547     spécialisées
# 3374          réservé
# 3196           carrée
# 2843          notable
# 2735            venus
# 2371         digitale
# 3976         secondes
# 3735          traduit
# 3470      qualitative
# 4624      déterminant
# 700             promu
# 2132          passive
# 4201        préalable
# 5234           promis
# 688         contenant
# 2211      esthétiques
# 4336     impressionné
# 760           adaptée
# 2635             brut
# dtype: object

# %%
shared_adj_all = set()

for i in range(len(models)):
    adj_df = pd.read_csv(f'../Data/{models[i]["label"]}/all_adjs_we.csv', index_col=0)
    if not shared_adj_all:
        shared_adj_all.update(adj_df.index)
    else:
        shared_adj_all = shared_adj_all.intersection(adj_df.index)

# %%
print(f'Number of shared adjectives by all models: {len(shared_adj_all)}')
# Out:
# Number of shared adjectives by all models: 794

# %%
pd.Series(list(shared_adj_all)).sample(n=30)
# Out:
# 88           droits
# 675          expert
# 755      nombreuses
# 511          maître
# 595          active
# 475          député
# 218           sobre
# 24              pro
# 141           chair
# 348           final
# 203           frais
# 103       spectacle
# 726          absent
# 760          établi
# 532        militant
# 543    représentant
# 290         endroit
# 747             off
# 739          propre
# 699             bon
# 317          triste
# 776        probable
# 463           suivi
# 752         diffuse
# 65           perché
# 412     importantes
# 254          invité
# 337     commerciale
# 244             nul
# 356       véritable
# dtype: object
