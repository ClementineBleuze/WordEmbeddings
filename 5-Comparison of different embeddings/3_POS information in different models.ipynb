# %%
import sys
sys.path.append('../Util')

# %%
from evaluation import aabcc, sig_props, correlation, lr, perceptron, kmeans_1dim, \
                     score_comparison, run_tests, report, dimensions_report, repeated_dimensions, \
                    kmeans_multi_dim
from preparation import prepare_dataset, read_datasets

# %%
import pandas as pd
import numpy as np
from scipy.stats import shapiro
import seaborn as sns

# %%
models = [
    {
        'name': 'flaubert/flaubert_small_cased',
        'label': 'flau_small_c'
    },
    {
    
        'name': 'flaubert/flaubert_base_uncased', 
        'label': 'flau_base_u'

    },
    {
        'name': 'flaubert/flaubert_base_cased',
        'label': 'flau_base_c'
    },
    {
        'name': 'flaubert/flaubert_large_cased',
        'label': 'flau_large_c'
    },
    {
        'name': 'camembert/camembert-base',
        'label': 'cam_base'
    }
    
]

# %%
labels = [m['label'] for m in models]

# %% [markdown]
# # Nouns

# %%
we_with_features = read_datasets(
                            path = '../Data',
                            model_labels = labels,
                            file_name = 'all_unique_pos_we.csv'
                    )

# %%
feature_col_count = 6
feature = 'POS'

# %%
normalized_dims = []
feature_vectors = []

# %%
for we in we_with_features:
    we_copy = we.copy()
    we_copy['POS'] = we_copy.POS.apply(lambda x: int(x == 'NOUN'))
    dims, f_vec = prepare_dataset(we_copy, feature_col_count=feature_col_count, feature_name=feature)
    normalized_dims.append(dims)
    feature_vectors.append(f_vec)

# %% [markdown]
# Now we will run our 6 tests (aabcc, sig-props, correlation, logistic regression weights, perceptron weights, Kmeans clustering on one dimension) for each of the models.

# %%
tests = [
    aabcc,
    sig_props,
    correlation,
    lr,
    perceptron,
    kmeans_1dim
]

# %%
all_res = run_tests(tests, normalized_dims, feature_vectors, labels, report_progress=True)
# Out:
# Currently running: AABCC
# 		Model: flau_small_c
# 		Model: flau_base_u
# 		Model: flau_base_c
# 		Model: flau_large_c
# 		Model: cam_base
# Done
# =======================================
# Currently running: SIG_PROPS
# 		Model: flau_small_c
# 		Model: flau_base_u
# 		Model: flau_base_c
# 		Model: flau_large_c
# 		Model: cam_base
# Done
# =======================================
# Currently running: CORRELATION
# 		Model: flau_small_c
# 		Model: flau_base_u
# 		Model: flau_base_c
# 		Model: flau_large_c
# 		Model: cam_base
# Done
# =======================================
# Currently running: LR
# 		Model: flau_small_c
# 		Model: flau_base_u
# 		Model: flau_base_c
# 		Model: flau_large_c
# 		Model: cam_base
# Done
# =======================================
# Currently running: PERCEPTRON
# 		Model: flau_small_c
# 		Model: flau_base_u
# 		Model: flau_base_c
# 		Model: flau_large_c
# 		Model: cam_base
# Done
# =======================================
# Currently running: KMEANS_1DIM
# 		Model: flau_small_c
# 		Model: flau_base_u
# 		Model: flau_base_c
# 		Model: flau_large_c
# 		Model: cam_base
# Done
# =======================================

# %% [markdown]
# Now we can compare the distribution of test results for each test and each model:

# %%
report_df = report(all_res, tests, labels)
report_df
# Out:
#                                Min       Max          Mean           25%  \
# AABCC_flau_small_c           31422     62224  34461.472656  32757.500000
# AABCC_flau_base_u            42112     53989  44938.778646  44023.000000
# AABCC_flau_base_c            31706     35133  32890.979167  32576.500000
# AABCC_flau_large_c           31720     49187  34037.014648  32757.500000
# AABCC_cam_base               21163     22948  21962.825521  21745.750000
# SIG_PROPS_flau_small_c    0.000167  0.122715      0.029502      0.012080
# SIG_PROPS_flau_base_u     0.000039  0.089002      0.015234      0.005653
# SIG_PROPS_flau_base_c     0.000053  0.039942      0.012190      0.004910
# SIG_PROPS_flau_large_c    0.000045  0.093186      0.024106      0.009389
# SIG_PROPS_cam_base        0.000031  0.021332      0.005570      0.002352
# CORRELATION_flau_small_c  0.000625   0.43692      0.115266      0.047788
# CORRELATION_flau_base_u   0.000171  0.228225      0.061659      0.024212
# CORRELATION_flau_base_c   0.000253  0.162151      0.050957      0.021818
# CORRELATION_flau_large_c  0.000348  0.379444      0.098991      0.039718
# CORRELATION_cam_base      0.000124   0.07358      0.020077      0.008966
# LR_flau_small_c           0.001655   3.05384      0.812423      0.380936
# LR_flau_base_u            0.000171  3.204809      0.513896      0.208077
# LR_flau_base_c             0.00753  3.189839      0.628914      0.261220
# LR_flau_large_c           0.000192  2.620366      0.563791      0.232355
# LR_cam_base               0.000455  1.327646      0.354717      0.144785
# PERCEPTRON_flau_small_c   0.012212  0.815949      0.217272      0.082924
# PERCEPTRON_flau_base_u    0.010529  0.629764      0.128606      0.052272
# PERCEPTRON_flau_base_c    0.008934  0.483486      0.115079      0.043810
# PERCEPTRON_flau_large_c   0.008773  0.620376      0.146965      0.055502
# PERCEPTRON_cam_base        0.01022  0.198223      0.057251      0.024813
# KMEANS_1DIM_flau_small_c -0.001545  0.137337      0.013236      0.001245
# KMEANS_1DIM_flau_base_u  -0.007201  0.052776     -0.000345     -0.003279
# KMEANS_1DIM_flau_base_c  -0.008453  0.018629     -0.000679     -0.002522
# KMEANS_1DIM_flau_large_c -0.001175  0.103452      0.009322      0.000795
# KMEANS_1DIM_cam_base     -0.005863  0.012438      0.001081     -0.000524
#
#                                    50%           75%           95%  \
# AABCC_flau_small_c        33478.000000  34893.500000  40001.800000
# AABCC_flau_base_u         44736.500000  45526.000000  47476.500000
# AABCC_flau_base_c         32829.500000  33158.000000  33844.600000
# AABCC_flau_large_c        33335.000000  34390.750000  38543.700000
# AABCC_cam_base            21955.000000  22163.000000  22464.550000
# SIG_PROPS_flau_small_c        0.025333      0.043028      0.073075
# SIG_PROPS_flau_base_u         0.012029      0.021488      0.039344
# SIG_PROPS_flau_base_c         0.010753      0.017720      0.029714
# SIG_PROPS_flau_large_c        0.020202      0.034535      0.060578
# SIG_PROPS_cam_base            0.004721      0.007926      0.013689
# CORRELATION_flau_small_c      0.100333      0.165795      0.271391
# CORRELATION_flau_base_u       0.051056      0.085906      0.155811
# CORRELATION_flau_base_c       0.046274      0.075793      0.113133
# CORRELATION_flau_large_c      0.084328      0.144151      0.243841
# CORRELATION_cam_base          0.017495      0.028613      0.047615
# LR_flau_small_c               0.706902      1.145708      1.936732
# LR_flau_base_u                0.421088      0.737343      1.255055
# LR_flau_base_c                0.514537      0.893314      1.548540
# LR_flau_large_c               0.497695      0.827807      1.308437
# LR_cam_base                   0.309325      0.519612      0.805275
# PERCEPTRON_flau_small_c       0.183696      0.316215      0.510961
# PERCEPTRON_flau_base_u        0.103299      0.182446      0.320574
# PERCEPTRON_flau_base_c        0.095578      0.164330      0.286236
# PERCEPTRON_flau_large_c       0.120904      0.211824      0.367943
# PERCEPTRON_cam_base           0.047773      0.078914      0.134076
# KMEANS_1DIM_flau_small_c      0.006600      0.017258      0.052243
# KMEANS_1DIM_flau_base_u      -0.001926      0.000718      0.009746
# KMEANS_1DIM_flau_base_c      -0.000775      0.000472      0.004987
# KMEANS_1DIM_flau_large_c      0.004271      0.012032      0.036753
# KMEANS_1DIM_cam_base          0.000572      0.002547      0.006234
#
#                                  97.7%         99.9%
# AABCC_flau_small_c        44363.585000  56543.213000
# AABCC_flau_base_u         48809.799000  52685.100000
# AABCC_flau_base_c         34120.154000  34758.704000
# AABCC_flau_large_c        40315.845000  48337.384000
# AABCC_cam_base            22580.077000  22884.339000
# SIG_PROPS_flau_small_c        0.087666      0.116735
# SIG_PROPS_flau_base_u         0.047686      0.073597
# SIG_PROPS_flau_base_c         0.033731      0.038877
# SIG_PROPS_flau_large_c        0.068620      0.091916
# SIG_PROPS_cam_base            0.016404      0.021023
# CORRELATION_flau_small_c      0.331440      0.414864
# CORRELATION_flau_base_u       0.180473      0.220063
# CORRELATION_flau_base_c       0.128677      0.158358
# CORRELATION_flau_large_c      0.269743      0.350034
# CORRELATION_cam_base          0.054755      0.071120
# LR_flau_small_c               2.297925      3.050265
# LR_flau_base_u                1.539189      2.403123
# LR_flau_base_c                1.735726      3.027412
# LR_flau_large_c               1.530741      2.304514
# LR_cam_base                   0.967659      1.325101
# PERCEPTRON_flau_small_c       0.633803      0.799772
# PERCEPTRON_flau_base_u        0.381834      0.586912
# PERCEPTRON_flau_base_c        0.333132      0.482645
# PERCEPTRON_flau_large_c       0.428163      0.608813
# PERCEPTRON_cam_base           0.147644      0.196442
# KMEANS_1DIM_flau_small_c      0.074909      0.120555
# KMEANS_1DIM_flau_base_u       0.015567      0.036551
# KMEANS_1DIM_flau_base_c       0.007184      0.015623
# KMEANS_1DIM_flau_large_c      0.046313      0.088384
# KMEANS_1DIM_cam_base          0.007401      0.012081

# %%
percentile = 99

# %%
dimensions_df = dimensions_report(all_res, tests, labels, percentile)
dimensions_df
# Out:
#                                flau_small_c  \
# AABCC         [159, 346, 31, 305, 212, 409]
# SIG_PROPS    [159, 346, 212, 504, 480, 401]
# CORRELATION  [159, 346, 305, 409, 212, 504]
# LR           [485, 132, 275, 176, 378, 339]
# PERCEPTRON   [378, 159, 409, 305, 303, 462]
# KMEANS_1DIM  [159, 346, 305, 480, 458, 212]
#
#                                           flau_base_u  \
# AABCC        [178, 405, 107, 565, 298, 217, 299, 390]
# SIG_PROPS     [405, 153, 565, 626, 89, 720, 170, 178]
# CORRELATION   [107, 299, 170, 390, 89, 178, 649, 217]
# LR           [405, 203, 238, 763, 383, 159, 385, 499]
# PERCEPTRON   [405, 383, 170, 299, 672, 390, 238, 435]
# KMEANS_1DIM   [565, 626, 89, 720, 299, 390, 298, 748]
#
#                                         flau_base_c  \
# AABCC         [234, 75, 87, 119, 80, 366, 382, 705]
# SIG_PROPS     [55, 345, 608, 687, 50, 76, 367, 426]
# CORRELATION  [234, 366, 76, 152, 705, 688, 87, 608]
# LR           [47, 57, 650, 248, 345, 476, 572, 754]
# PERCEPTRON   [454, 564, 417, 106, 162, 345, 87, 55]
# KMEANS_1DIM   [80, 87, 720, 38, 564, 417, 745, 366]
#
#                                                   flau_large_c  \
# AABCC        [437, 57, 207, 458, 988, 800, 914, 831, 966, 4...
# SIG_PROPS    [207, 988, 437, 458, 354, 800, 914, 966, 57, 6...
# CORRELATION  [437, 458, 207, 988, 800, 57, 479, 354, 914, 5...
# LR           [82, 614, 968, 525, 1016, 482, 642, 978, 363, ...
# PERCEPTRON   [437, 88, 44, 988, 1016, 549, 914, 413, 961, 2...
# KMEANS_1DIM  [437, 458, 57, 207, 988, 800, 956, 479, 694, 9...
#
#                                              cam_base
# AABCC          [574, 315, 436, 291, 517, 88, 69, 626]
# SIG_PROPS    [602, 536, 217, 579, 176, 100, 243, 694]
# CORRELATION   [48, 602, 436, 517, 695, 360, 176, 475]
# LR           [525, 271, 602, 436, 697, 696, 206, 486]
# PERCEPTRON   [723, 517, 436, 573, 251, 271, 695, 726]
# KMEANS_1DIM   [251, 174, 475, 250, 48, 320, 357, 166]

# %%
repeated_dimensions_df = repeated_dimensions(dimensions_df, labels)

# %%
repeated_dimensions_df
# Out:
#                                                          1 test  \
# flau_small_c  [31, 132, 159, 176, 212, 275, 303, 305, 339, 3...
# flau_base_u   [89, 107, 153, 159, 170, 178, 203, 217, 238, 2...
# flau_base_c   [38, 47, 50, 55, 57, 75, 76, 80, 87, 106, 119,...
# flau_large_c  [44, 57, 82, 88, 207, 253, 354, 363, 413, 437,...
# cam_base      [48, 69, 88, 100, 166, 174, 176, 206, 217, 243...
#
#                                                         2 tests  \
# flau_small_c           [159, 212, 305, 346, 378, 409, 480, 504]
# flau_base_u   [89, 107, 170, 178, 217, 238, 298, 299, 383, 3...
# flau_base_c   [55, 76, 80, 87, 234, 345, 366, 417, 564, 608,...
# flau_large_c  [44, 57, 207, 354, 437, 458, 479, 800, 914, 95...
# cam_base           [48, 176, 251, 271, 436, 475, 517, 602, 695]
#
#                                                    3 tests  \
# flau_small_c                     [159, 212, 305, 346, 409]
# flau_base_u             [89, 170, 178, 299, 390, 405, 565]
# flau_base_c                                 [87, 345, 366]
# flau_large_c  [57, 207, 437, 458, 479, 800, 914, 966, 988]
# cam_base                                   [436, 517, 602]
#
#                                          4 tests               5 tests 6 tests
# flau_small_c                [159, 212, 305, 346]                 [159]      []
# flau_base_u                      [299, 390, 405]                    []      []
# flau_base_c                                 [87]                    []      []
# flau_large_c  [57, 207, 437, 458, 800, 914, 988]  [207, 437, 458, 988]      []
# cam_base                                   [436]                    []      []

# %%
ari_scores_df = pd.DataFrame(columns = ['All_dims', '1_dim_best', 
                                        '1_test_dims', '2_test_dims',
                                        '3_test_dims', '4_test_dims',
                                        '5_test_dims', '6_test_dims'
                                       ])

# %%
for i in range(len(labels)):
    model = labels[i]
    n_dims = len(all_res[0][i])
    ari_scores_df.loc[model] = {
        'All_dims' : kmeans_multi_dim(normalized_dims[i], list(range(n_dims)), feature_vectors[i]), 
        '1_dim_best': all_res[-1][i][0][1], 
        '1_test_dims': kmeans_multi_dim(normalized_dims[i], repeated_dimensions_df.loc[model]['1 test'], feature_vectors[i]), 
        '2_test_dims': kmeans_multi_dim(normalized_dims[i], repeated_dimensions_df.loc[model]['2 tests'], feature_vectors[i]),
        '3_test_dims': kmeans_multi_dim(normalized_dims[i], repeated_dimensions_df.loc[model]['3 tests'], feature_vectors[i]),
        '4_test_dims': kmeans_multi_dim(normalized_dims[i], repeated_dimensions_df.loc[model]['4 tests'], feature_vectors[i]),
        '5_test_dims': kmeans_multi_dim(normalized_dims[i], repeated_dimensions_df.loc[model]['5 tests'], feature_vectors[i]),
        '6_test_dims': kmeans_multi_dim(normalized_dims[i], repeated_dimensions_df.loc[model]['6 tests'], feature_vectors[i]),
    }

# %%
ari_scores_df
# Out:
#               All_dims  1_dim_best  1_test_dims  2_test_dims  3_test_dims  \
# flau_small_c  0.204495    0.137337     0.353523     0.317189     0.267117
# flau_base_u   0.058136    0.052776     0.056432     0.056031     0.055691
# flau_base_c   0.003036    0.018629     0.007435     0.006505     0.006510
# flau_large_c  0.218357    0.103452     0.405854     0.347859     0.357100
# cam_base     -0.004846    0.012438    -0.004846    -0.003285    -0.000429
#
#               4_test_dims  5_test_dims 6_test_dims
# flau_small_c     0.240862     0.137337        None
# flau_base_u      0.019856          NaN        None
# flau_base_c      0.014710          NaN        None
# flau_large_c     0.314346     0.251932        None
# cam_base        -0.002846          NaN        None

# %% [markdown]
# # Adjectives

# %% [markdown]
# We can now repeat the experiment for Adjectives.

# %%
we_with_features = read_datasets(
                            path = '../Data',
                            model_labels = labels,
                            file_name = 'all_unique_pos_we.csv'
                    )

# %%
normalized_dims = []
feature_vectors = []

# %%
for we in we_with_features:
    we_copy = we.copy()
    we_copy['POS'] = we_copy.POS.apply(lambda x: int(x == 'ADJ'))
    dims, f_vec = prepare_dataset(we_copy, feature_col_count=feature_col_count, feature_name=feature)
    normalized_dims.append(dims)
    feature_vectors.append(f_vec)

# %%
all_res_adj = run_tests(tests, normalized_dims, feature_vectors, labels, report_progress=True)
# Out:
# Currently running: AABCC
# 		Model: flau_small_c
# 		Model: flau_base_u
# 		Model: flau_base_c
# 		Model: flau_large_c
# 		Model: cam_base
# Done
# =======================================
# Currently running: SIG_PROPS
# 		Model: flau_small_c
# 		Model: flau_base_u
# 		Model: flau_base_c
# 		Model: flau_large_c
# 		Model: cam_base
# Done
# =======================================
# Currently running: CORRELATION
# 		Model: flau_small_c
# 		Model: flau_base_u
# 		Model: flau_base_c
# 		Model: flau_large_c
# 		Model: cam_base
# Done
# =======================================
# Currently running: LR
# 		Model: flau_small_c
# 		Model: flau_base_u
# 		Model: flau_base_c
# 		Model: flau_large_c
# 		Model: cam_base
# Done
# =======================================
# Currently running: PERCEPTRON
# 		Model: flau_small_c
# 		Model: flau_base_u
# 		Model: flau_base_c
# 		Model: flau_large_c
# 		Model: cam_base
# Done
# =======================================
# Currently running: KMEANS_1DIM
# 		Model: flau_small_c
# 		Model: flau_base_u
# 		Model: flau_base_c
# 		Model: flau_large_c
# 		Model: cam_base
# Done
# =======================================

# %%
report_adj_df = report(all_res_adj, tests, labels)
report_adj_df
# Out:
#                                Min       Max          Mean           25%  \
# AABCC_flau_small_c           67517    116682  74219.800781  70414.750000
# AABCC_flau_base_u            86652    102300  91842.483073  90369.250000
# AABCC_flau_base_c            66346     75657  70441.923177  69441.500000
# AABCC_flau_large_c           66222    148059  74493.316406  70467.500000
# AABCC_cam_base               46417     54038  49939.473958  49083.000000
# SIG_PROPS_flau_small_c    0.000009  0.091713      0.026460      0.011059
# SIG_PROPS_flau_base_u     0.000012  0.047029      0.011390      0.004669
# SIG_PROPS_flau_base_c     0.000001  0.026337      0.007266      0.002938
# SIG_PROPS_flau_large_c     0.00005  0.105988      0.023894      0.008887
# SIG_PROPS_cam_base        0.000009  0.061796      0.011837      0.004805
# CORRELATION_flau_small_c  0.000027  0.307693      0.082417      0.034467
# CORRELATION_flau_base_u   0.000041  0.143072      0.036587      0.015098
# CORRELATION_flau_base_c   0.000004  0.089091      0.024524      0.010219
# CORRELATION_flau_large_c  0.000149  0.311201      0.077727      0.029248
# CORRELATION_cam_base      0.000031  0.090352      0.031117      0.014756
# LR_flau_small_c              0.003  2.914037      0.744101      0.333077
# LR_flau_base_u             0.00058  2.396098      0.490472      0.203723
# LR_flau_base_c            0.001412  3.452393      0.570070      0.217335
# LR_flau_large_c            0.00004  2.098017      0.504765      0.216349
# LR_cam_base               0.000018  1.674943      0.351619      0.130632
# PERCEPTRON_flau_small_c   0.009997  0.052294      0.030340      0.025771
# PERCEPTRON_flau_base_u    0.009772  0.040059      0.023520      0.020103
# PERCEPTRON_flau_base_c    0.009921  0.036894      0.022756      0.019519
# PERCEPTRON_flau_large_c   0.007639  0.036783      0.018898      0.015970
# PERCEPTRON_cam_base       0.008603  0.039786      0.021997      0.018600
# KMEANS_1DIM_flau_small_c -0.004773  0.047637      0.005073      0.000096
# KMEANS_1DIM_flau_base_u  -0.031527  0.041566     -0.004814     -0.009646
# KMEANS_1DIM_flau_base_c  -0.017605  0.016548     -0.001522     -0.004089
# KMEANS_1DIM_flau_large_c -0.007356  0.063562      0.003833     -0.000074
# KMEANS_1DIM_cam_base     -0.027449  0.039739     -0.004973     -0.009875
#
#                                    50%           75%           95%  \
# AABCC_flau_small_c        72196.000000  76050.000000  85736.350000
# AABCC_flau_base_u         91592.000000  93039.500000  95614.500000
# AABCC_flau_base_c         70422.000000  71351.500000  72812.800000
# AABCC_flau_large_c        72306.000000  75965.750000  88761.950000
# AABCC_cam_base            49961.000000  50756.250000  51921.250000
# SIG_PROPS_flau_small_c        0.020236      0.039120      0.065640
# SIG_PROPS_flau_base_u         0.009695      0.015912      0.028070
# SIG_PROPS_flau_base_c         0.006483      0.010718      0.017617
# SIG_PROPS_flau_large_c        0.019882      0.034717      0.058813
# SIG_PROPS_cam_base            0.009778      0.016549      0.030752
# CORRELATION_flau_small_c      0.065909      0.121829      0.202720
# CORRELATION_flau_base_u       0.031490      0.051805      0.088416
# CORRELATION_flau_base_c       0.021897      0.035181      0.058148
# CORRELATION_flau_large_c      0.064491      0.114717      0.192836
# CORRELATION_cam_base          0.029598      0.045556      0.065822
# LR_flau_small_c               0.684205      1.038817      1.808071
# LR_flau_base_u                0.425360      0.704224      1.209923
# LR_flau_base_c                0.461632      0.803025      1.393254
# LR_flau_large_c               0.422713      0.752818      1.231687
# LR_cam_base                   0.287465      0.518470      0.881100
# PERCEPTRON_flau_small_c       0.030001      0.034947      0.041410
# PERCEPTRON_flau_base_u        0.023306      0.026929      0.032123
# PERCEPTRON_flau_base_c        0.022628      0.025897      0.031181
# PERCEPTRON_flau_large_c       0.018758      0.021948      0.025953
# PERCEPTRON_cam_base           0.021849      0.025432      0.030069
# KMEANS_1DIM_flau_small_c      0.001681      0.007179      0.021756
# KMEANS_1DIM_flau_base_u      -0.004966     -0.000342      0.006814
# KMEANS_1DIM_flau_base_c      -0.001267      0.000806      0.006060
# KMEANS_1DIM_flau_large_c      0.001275      0.005420      0.016890
# KMEANS_1DIM_cam_base         -0.006157     -0.002194      0.011704
#
#                                  97.7%          99.9%
# AABCC_flau_small_c        91324.681000  109479.455000
# AABCC_flau_base_u         97137.745000  102173.445000
# AABCC_flau_base_c         73520.361000   75584.902000
# AABCC_flau_large_c        94135.615000  115856.300000
# AABCC_cam_base            52642.436000   53715.860000
# SIG_PROPS_flau_small_c        0.072256       0.090863
# SIG_PROPS_flau_base_u         0.031708       0.044465
# SIG_PROPS_flau_base_c         0.020575       0.026227
# SIG_PROPS_flau_large_c        0.068721       0.102470
# SIG_PROPS_cam_base            0.036127       0.060482
# CORRELATION_flau_small_c      0.226914       0.286085
# CORRELATION_flau_base_u       0.098055       0.133871
# CORRELATION_flau_base_c       0.069001       0.086059
# CORRELATION_flau_large_c      0.217588       0.301707
# CORRELATION_cam_base          0.071218       0.088108
# LR_flau_small_c               2.103644       2.794304
# LR_flau_base_u                1.445660       2.087612
# LR_flau_base_c                1.743187       2.591073
# LR_flau_large_c               1.398109       2.056806
# LR_cam_base                   1.003299       1.536979
# PERCEPTRON_flau_small_c       0.042869       0.050583
# PERCEPTRON_flau_base_u        0.034061       0.039764
# PERCEPTRON_flau_base_c        0.032697       0.036152
# PERCEPTRON_flau_large_c       0.027148       0.034262
# PERCEPTRON_cam_base           0.032372       0.038567
# KMEANS_1DIM_flau_small_c      0.031083       0.047070
# KMEANS_1DIM_flau_base_u       0.011277       0.032003
# KMEANS_1DIM_flau_base_c       0.008261       0.015924
# KMEANS_1DIM_flau_large_c      0.024795       0.056075
# KMEANS_1DIM_cam_base          0.021472       0.039094

# %%
dimensions_adj_df = dimensions_report(all_res_adj, tests, labels, percentile)
dimensions_adj_df
# Out:
#                                flau_small_c  \
# AABCC         [478, 50, 100, 250, 387, 439]
# SIG_PROPS    [478, 158, 464, 224, 220, 281]
# CORRELATION   [478, 464, 220, 50, 250, 439]
# LR           [100, 510, 260, 138, 485, 315]
# PERCEPTRON     [451, 25, 136, 21, 174, 259]
# KMEANS_1DIM  [478, 250, 464, 220, 158, 314]
#
#                                           flau_base_u  \
# AABCC        [203, 423, 719, 671, 247, 526, 172, 320]
# SIG_PROPS     [320, 746, 565, 153, 43, 572, 172, 449]
# CORRELATION   [320, 746, 43, 423, 449, 719, 203, 275]
# LR            [391, 495, 91, 379, 203, 159, 691, 752]
# PERCEPTRON    [327, 216, 703, 272, 158, 305, 56, 255]
# KMEANS_1DIM  [565, 423, 719, 526, 203, 752, 643, 374]
#
#                                           flau_base_c  \
# AABCC        [260, 191, 407, 603, 349, 336, 498, 363]
# SIG_PROPS    [581, 185, 336, 301, 727, 485, 571, 331]
# CORRELATION   [581, 234, 485, 336, 571, 330, 77, 185]
# LR            [724, 754, 492, 273, 27, 670, 178, 485]
# PERCEPTRON    [108, 570, 599, 188, 46, 513, 652, 190]
# KMEANS_1DIM  [351, 555, 557, 571, 764, 491, 431, 567]
#
#                                                   flau_large_c  \
# AABCC        [741, 458, 890, 92, 436, 617, 953, 346, 797, 6...
# SIG_PROPS    [741, 436, 890, 948, 92, 354, 458, 617, 1005, ...
# CORRELATION  [741, 436, 652, 92, 458, 792, 948, 890, 1005, ...
# LR           [82, 80, 298, 978, 292, 423, 196, 304, 1006, 9...
# PERCEPTRON   [286, 100, 6, 461, 991, 848, 497, 709, 295, 50...
# KMEANS_1DIM  [741, 436, 346, 877, 953, 618, 792, 787, 1005,...
#
#                                              cam_base
# AABCC          [341, 559, 68, 633, 97, 194, 620, 758]
# SIG_PROPS      [100, 714, 309, 119, 272, 467, 430, 3]
# CORRELATION    [473, 356, 309, 764, 119, 125, 714, 3]
# LR           [622, 674, 529, 323, 750, 683, 187, 437]
# PERCEPTRON     [470, 297, 84, 623, 36, 303, 743, 587]
# KMEANS_1DIM   [119, 100, 714, 309, 52, 272, 717, 467]

# %%
repeated_dimensions_adj_df = repeated_dimensions(dimensions_adj_df, labels)
repeated_dimensions_adj_df
# Out:
#                                                          1 test  \
# flau_small_c  [21, 25, 50, 100, 136, 138, 158, 174, 220, 224...
# flau_base_u   [43, 56, 91, 153, 158, 159, 172, 203, 216, 247...
# flau_base_c   [27, 46, 77, 108, 178, 185, 188, 190, 191, 234...
# flau_large_c  [6, 50, 80, 82, 92, 100, 196, 286, 292, 295, 2...
# cam_base      [3, 36, 52, 68, 84, 97, 100, 119, 125, 187, 19...
#
#                                                         2 tests  \
# flau_small_c            [50, 100, 158, 220, 250, 439, 464, 478]
# flau_base_u   [43, 172, 203, 320, 423, 449, 526, 565, 719, 7...
# flau_base_c                           [185, 336, 485, 571, 581]
# flau_large_c  [92, 346, 436, 458, 617, 652, 685, 741, 787, 7...
# cam_base                      [3, 100, 119, 272, 309, 467, 714]
#
#                                      3 tests          4 tests 5 tests 6 tests
# flau_small_c            [220, 250, 464, 478]            [478]      []      []
# flau_base_u             [203, 320, 423, 719]            [203]      []      []
# flau_base_c                  [336, 485, 571]               []      []      []
# flau_large_c  [92, 436, 458, 741, 890, 1005]  [436, 458, 741]      []      []
# cam_base                     [119, 309, 714]               []      []      []

# %%
ari_scores_adj_df = pd.DataFrame(columns = ['All_dims', '1_dim_best', 
                                        '1_test_dims', '2_test_dims',
                                        '3_test_dims', '4_test_dims',
                                        '5_test_dims', '6_test_dims'
                                       ])

# %%
for i in range(len(labels)):
    model = labels[i]
    n_dims = len(all_res[0][i])
    ari_scores_adj_df.loc[model] = {
        'All_dims' : kmeans_multi_dim(normalized_dims[i], list(range(n_dims)), feature_vectors[i]), 
        '1_dim_best': all_res_adj[-1][i][0][1], 
        '1_test_dims': kmeans_multi_dim(normalized_dims[i], repeated_dimensions_adj_df.loc[model]['1 test'], feature_vectors[i]), 
        '2_test_dims': kmeans_multi_dim(normalized_dims[i], repeated_dimensions_adj_df.loc[model]['2 tests'], feature_vectors[i]),
        '3_test_dims': kmeans_multi_dim(normalized_dims[i], repeated_dimensions_adj_df.loc[model]['3 tests'], feature_vectors[i]),
        '4_test_dims': kmeans_multi_dim(normalized_dims[i], repeated_dimensions_adj_df.loc[model]['4 tests'], feature_vectors[i]),
        '5_test_dims': kmeans_multi_dim(normalized_dims[i], repeated_dimensions_adj_df.loc[model]['5 tests'], feature_vectors[i]),
        '6_test_dims': kmeans_multi_dim(normalized_dims[i], repeated_dimensions_adj_df.loc[model]['6 tests'], feature_vectors[i]),
    }

# %%
ari_scores_adj_df
# Out:
#               All_dims  1_dim_best  1_test_dims  2_test_dims  3_test_dims  \
# flau_small_c  0.002331    0.047637     0.229939     0.143326     0.152073
# flau_base_u   0.042316    0.041566     0.041396     0.043724    -0.012930
# flau_base_c  -0.001864    0.016548    -0.000760    -0.007756    -0.003591
# flau_large_c  0.008652    0.063562     0.229324     0.217511     0.154221
# cam_base      0.038898    0.039739     0.038898     0.038898     0.038898
#
#               4_test_dims 5_test_dims 6_test_dims
# flau_small_c     0.047637        None        None
# flau_base_u      0.019960        None        None
# flau_base_c           NaN        None        None
# flau_large_c     0.118495        None        None
# cam_base              NaN        None        None

# %% [markdown]
# # Verb

# %%
we_with_features = read_datasets(
                            path = '../Data',
                            model_labels = labels,
                            file_name = 'all_unique_pos_we.csv'
                    )

# %%
normalized_dims = []
feature_vectors = []

# %%
for we in we_with_features:
    we_copy = we.copy()
    we_copy['POS'] = we_copy.POS.apply(lambda x: int(x == 'VERB'))
    dims, f_vec = prepare_dataset(we_copy, feature_col_count=feature_col_count, feature_name=feature)
    normalized_dims.append(dims)
    feature_vectors.append(f_vec)

# %%
all_res_verb = run_tests(tests, normalized_dims, feature_vectors, labels, report_progress=True)
# Out:
# Currently running: AABCC
# 		Model: flau_small_c
# 		Model: flau_base_u
# 		Model: flau_base_c
# 		Model: flau_large_c
# 		Model: cam_base
# Done
# =======================================
# Currently running: SIG_PROPS
# 		Model: flau_small_c
# 		Model: flau_base_u
# 		Model: flau_base_c
# 		Model: flau_large_c
# 		Model: cam_base
# Done
# =======================================
# Currently running: CORRELATION
# 		Model: flau_small_c
# 		Model: flau_base_u
# 		Model: flau_base_c
# 		Model: flau_large_c
# 		Model: cam_base
# Done
# =======================================
# Currently running: LR
# 		Model: flau_small_c
# 		Model: flau_base_u
# 		Model: flau_base_c
# 		Model: flau_large_c
# 		Model: cam_base
# Done
# =======================================
# Currently running: PERCEPTRON
# 		Model: flau_small_c
# 		Model: flau_base_u
# 		Model: flau_base_c
# 		Model: flau_large_c
# 		Model: cam_base
# Done
# =======================================
# Currently running: KMEANS_1DIM
# 		Model: flau_small_c
# 		Model: flau_base_u
# 		Model: flau_base_c
# 		Model: flau_large_c
# 		Model: cam_base
# Done
# =======================================

# %%
report_verb_df = report(all_res_verb, tests, labels)
report_verb_df
# Out:
#                                Min       Max          Mean           25%  \
# AABCC_flau_small_c           56618    432205  73529.255859  61191.250000
# AABCC_flau_base_u            77283    119847  84454.726562  81676.000000
# AABCC_flau_base_c            55855     76388  60633.950521  59266.000000
# AABCC_flau_large_c           56563    184790  66699.136719  60450.750000
# AABCC_cam_base               40245     46731  43079.819010  42316.000000
# SIG_PROPS_flau_small_c     0.00006   0.15667      0.036321      0.014243
# SIG_PROPS_flau_base_u     0.000044  0.101841      0.019183      0.008115
# SIG_PROPS_flau_base_c      0.00003  0.063043      0.014980      0.006210
# SIG_PROPS_flau_large_c    0.000015  0.114607      0.027534      0.011064
# SIG_PROPS_cam_base        0.000016  0.082911      0.015429      0.005850
# CORRELATION_flau_small_c  0.000182  0.494238      0.118987      0.048395
# CORRELATION_flau_base_u   0.000148  0.246833      0.065113      0.028451
# CORRELATION_flau_base_c   0.000103  0.206133      0.052782      0.023025
# CORRELATION_flau_large_c  0.000049  0.362081      0.094765      0.038346
# CORRELATION_cam_base      0.000053  0.121998      0.043356      0.019663
# LR_flau_small_c            0.00114   2.96633      0.664894      0.262038
# LR_flau_base_u            0.002761  3.634756      0.584170      0.226939
# LR_flau_base_c            0.000624  2.516208      0.679886      0.292800
# LR_flau_large_c           0.000232  2.088389      0.483315      0.196976
# LR_cam_base               0.000383  1.399853      0.381351      0.156714
# PERCEPTRON_flau_small_c   0.012934   0.13874      0.047131      0.032742
# PERCEPTRON_flau_base_u    0.009108  0.043414      0.023587      0.019430
# PERCEPTRON_flau_base_c    0.008004  0.039249      0.022392      0.018919
# PERCEPTRON_flau_large_c   0.007688  0.032017      0.018510      0.015688
# PERCEPTRON_cam_base        0.00829  0.035267      0.022168      0.018767
# KMEANS_1DIM_flau_small_c -0.010318  0.134604      0.008780      0.000374
# KMEANS_1DIM_flau_base_u  -0.030296  0.078872     -0.007209     -0.014563
# KMEANS_1DIM_flau_base_c  -0.041566  0.022624     -0.006160     -0.011320
# KMEANS_1DIM_flau_large_c -0.008132  0.061557      0.004421     -0.000029
# KMEANS_1DIM_cam_base     -0.039873  0.037875      0.008784      0.003446
#
#                                    50%           75%            95%  \
# AABCC_flau_small_c        66039.000000  73983.500000  106147.850000
# AABCC_flau_base_u         83441.500000  85818.250000   91737.450000
# AABCC_flau_base_c         60272.500000  61502.000000   64367.650000
# AABCC_flau_large_c        62853.000000  68127.250000   85199.500000
# AABCC_cam_base            43040.500000  43796.250000   45008.950000
# SIG_PROPS_flau_small_c        0.030042      0.049572       0.091745
# SIG_PROPS_flau_base_u         0.016329      0.026877       0.049064
# SIG_PROPS_flau_base_c         0.013132      0.021634       0.036272
# SIG_PROPS_flau_large_c        0.023146      0.039744       0.067482
# SIG_PROPS_cam_base            0.012136      0.022020       0.039316
# CORRELATION_flau_small_c      0.099912      0.165614       0.292101
# CORRELATION_flau_base_u       0.056620      0.093249       0.157214
# CORRELATION_flau_base_c       0.047275      0.077008       0.118169
# CORRELATION_flau_large_c      0.079938      0.138715       0.229164
# CORRELATION_cam_base          0.039185      0.063769       0.093630
# LR_flau_small_c               0.535360      0.953890       1.759549
# LR_flau_base_u                0.472633      0.841016       1.408636
# LR_flau_base_c                0.560435      0.964377       1.678643
# LR_flau_large_c               0.396250      0.707086       1.172270
# LR_cam_base                   0.320326      0.552707       0.941972
# PERCEPTRON_flau_small_c       0.042425      0.056211       0.088648
# PERCEPTRON_flau_base_u        0.023534      0.027217       0.033088
# PERCEPTRON_flau_base_c        0.022182      0.025871       0.031383
# PERCEPTRON_flau_large_c       0.018338      0.021151       0.025262
# PERCEPTRON_cam_base           0.022089      0.025508       0.030630
# KMEANS_1DIM_flau_small_c      0.003150      0.010825       0.039209
# KMEANS_1DIM_flau_base_u      -0.009135     -0.002022       0.012939
# KMEANS_1DIM_flau_base_c      -0.005014     -0.000571       0.005609
# KMEANS_1DIM_flau_large_c      0.001743      0.006634       0.019444
# KMEANS_1DIM_cam_base          0.009269      0.015630       0.024764
#
#                                   97.7%          99.9%
# AABCC_flau_small_c        145883.126000  349786.832000
# AABCC_flau_base_u          96849.361000  118383.564000
# AABCC_flau_base_c          65500.513000   74314.032000
# AABCC_flau_large_c        100355.377000  159673.152000
# AABCC_cam_base             45518.925000   46550.755000
# SIG_PROPS_flau_small_c         0.108142       0.155204
# SIG_PROPS_flau_base_u          0.056502       0.088556
# SIG_PROPS_flau_base_c          0.040554       0.059150
# SIG_PROPS_flau_large_c         0.078372       0.105655
# SIG_PROPS_cam_base             0.047554       0.080253
# CORRELATION_flau_small_c       0.354433       0.475001
# CORRELATION_flau_base_u        0.180121       0.239506
# CORRELATION_flau_base_c        0.136347       0.203614
# CORRELATION_flau_large_c       0.260115       0.349736
# CORRELATION_cam_base           0.103990       0.121967
# LR_flau_small_c                2.051476       2.829502
# LR_flau_base_u                 1.695148       2.663234
# LR_flau_base_c                 2.014825       2.511402
# LR_flau_large_c                1.358604       1.907466
# LR_cam_base                    1.092756       1.361351
# PERCEPTRON_flau_small_c        0.105148       0.137193
# PERCEPTRON_flau_base_u         0.035194       0.039543
# PERCEPTRON_flau_base_c         0.032983       0.038613
# PERCEPTRON_flau_large_c        0.027581       0.030996
# PERCEPTRON_cam_base            0.032032       0.035193
# KMEANS_1DIM_flau_small_c       0.051637       0.126480
# KMEANS_1DIM_flau_base_u        0.020434       0.062498
# KMEANS_1DIM_flau_base_c        0.009213       0.021511
# KMEANS_1DIM_flau_large_c       0.024763       0.058942
# KMEANS_1DIM_cam_base           0.029122       0.036744

# %%
dimensions_verb_df = dimensions_report(all_res_verb, tests, labels, percentile)
dimensions_verb_df
# Out:
#                                flau_small_c  \
# AABCC        [480, 182, 401, 159, 310, 192]
# SIG_PROPS     [310, 480, 401, 159, 504, 89]
# CORRELATION   [310, 480, 401, 159, 89, 504]
# LR            [378, 56, 434, 192, 154, 432]
# PERCEPTRON     [192, 480, 89, 318, 56, 504]
# KMEANS_1DIM    [310, 480, 89, 159, 401, 29]
#
#                                           flau_base_u  \
# AABCC        [299, 107, 390, 649, 217, 383, 224, 121]
# SIG_PROPS     [405, 89, 720, 626, 390, 121, 383, 748]
# CORRELATION   [390, 299, 107, 89, 748, 649, 217, 121]
# LR           [405, 146, 565, 726, 170, 763, 465, 476]
# PERCEPTRON   [533, 341, 417, 523, 483, 659, 402, 238]
# KMEANS_1DIM  [565, 390, 299, 383, 720, 626, 744, 589]
#
#                                          flau_base_c  \
# AABCC         [87, 705, 80, 688, 285, 152, 472, 443]
# SIG_PROPS      [50, 688, 705, 55, 152, 472, 687, 87]
# CORRELATION     [688, 87, 705, 152, 80, 472, 50, 76]
# LR           [492, 57, 248, 294, 650, 136, 451, 403]
# PERCEPTRON    [169, 164, 723, 753, 346, 107, 157, 3]
# KMEANS_1DIM    [417, 412, 87, 80, 481, 385, 66, 324]
#
#                                                   flau_large_c  \
# AABCC        [800, 473, 925, 172, 932, 437, 207, 793, 988, ...
# SIG_PROPS    [932, 925, 886, 800, 927, 793, 343, 479, 988, ...
# CORRELATION  [932, 925, 800, 479, 853, 333, 927, 793, 886, ...
# LR           [777, 793, 490, 803, 591, 249, 909, 398, 846, ...
# PERCEPTRON   [89, 848, 817, 296, 475, 423, 36, 465, 62, 204...
# KMEANS_1DIM  [932, 886, 479, 437, 2, 800, 253, 605, 925, 66...
#
#                                              cam_base
# AABCC        [185, 433, 589, 303, 438, 334, 102, 405]
# SIG_PROPS    [100, 714, 309, 467, 217, 579, 272, 430]
# CORRELATION   [243, 694, 217, 486, 53, 579, 740, 524]
# LR            [285, 546, 436, 549, 90, 575, 238, 754]
# PERCEPTRON   [266, 523, 135, 501, 741, 755, 451, 183]
# KMEANS_1DIM    [357, 174, 21, 224, 75, 475, 320, 251]

# %%
repeated_dimensions_verb_df = repeated_dimensions(dimensions_adj_df, labels)
repeated_dimensions_verb_df
# Out:
#                                                          1 test  \
# flau_small_c  [21, 25, 50, 100, 136, 138, 158, 174, 220, 224...
# flau_base_u   [43, 56, 91, 153, 158, 159, 172, 203, 216, 247...
# flau_base_c   [27, 46, 77, 108, 178, 185, 188, 190, 191, 234...
# flau_large_c  [6, 50, 80, 82, 92, 100, 196, 286, 292, 295, 2...
# cam_base      [3, 36, 52, 68, 84, 97, 100, 119, 125, 187, 19...
#
#                                                         2 tests  \
# flau_small_c            [50, 100, 158, 220, 250, 439, 464, 478]
# flau_base_u   [43, 172, 203, 320, 423, 449, 526, 565, 719, 7...
# flau_base_c                           [185, 336, 485, 571, 581]
# flau_large_c  [92, 346, 436, 458, 617, 652, 685, 741, 787, 7...
# cam_base                      [3, 100, 119, 272, 309, 467, 714]
#
#                                      3 tests          4 tests 5 tests 6 tests
# flau_small_c            [220, 250, 464, 478]            [478]      []      []
# flau_base_u             [203, 320, 423, 719]            [203]      []      []
# flau_base_c                  [336, 485, 571]               []      []      []
# flau_large_c  [92, 436, 458, 741, 890, 1005]  [436, 458, 741]      []      []
# cam_base                     [119, 309, 714]               []      []      []

# %%
ari_scores_verb_df = pd.DataFrame(columns = ['All_dims', '1_dim_best', 
                                        '1_test_dims', '2_test_dims',
                                        '3_test_dims', '4_test_dims',
                                        '5_test_dims', '6_test_dims'
                                       ])

# %%
for i in range(len(labels)):
    model = labels[i]
    n_dims = len(all_res[0][i])
    ari_scores_verb_df.loc[model] = {
        'All_dims' : kmeans_multi_dim(normalized_dims[i], list(range(n_dims)), feature_vectors[i]), 
        '1_dim_best': all_res_verb[-1][i][0][1], 
        '1_test_dims': kmeans_multi_dim(normalized_dims[i], repeated_dimensions_verb_df.loc[model]['1 test'], feature_vectors[i]), 
        '2_test_dims': kmeans_multi_dim(normalized_dims[i], repeated_dimensions_verb_df.loc[model]['2 tests'], feature_vectors[i]),
        '3_test_dims': kmeans_multi_dim(normalized_dims[i], repeated_dimensions_verb_df.loc[model]['3 tests'], feature_vectors[i]),
        '4_test_dims': kmeans_multi_dim(normalized_dims[i], repeated_dimensions_verb_df.loc[model]['4 tests'], feature_vectors[i]),
        '5_test_dims': kmeans_multi_dim(normalized_dims[i], repeated_dimensions_verb_df.loc[model]['5 tests'], feature_vectors[i]),
        '6_test_dims': kmeans_multi_dim(normalized_dims[i], repeated_dimensions_verb_df.loc[model]['6 tests'], feature_vectors[i]),
    }

# %%
ari_scores_verb_df
# Out:
#               All_dims  1_dim_best  1_test_dims  2_test_dims  3_test_dims  \
# flau_small_c  0.216043    0.134604    -0.017419     0.009879    -0.010338
# flau_base_u   0.092836    0.078872     0.083638     0.080721     0.000039
# flau_base_c  -0.003136    0.022624    -0.000140    -0.005372    -0.003969
# flau_large_c  0.080811    0.061557    -0.010414    -0.013342    -0.007812
# cam_base     -0.039838    0.037875    -0.039838    -0.039838    -0.039838
#
#               4_test_dims 5_test_dims 6_test_dims
# flau_small_c     0.000523        None        None
# flau_base_u     -0.015872        None        None
# flau_base_c           NaN        None        None
# flau_large_c    -0.005329        None        None
# cam_base              NaN        None        None
