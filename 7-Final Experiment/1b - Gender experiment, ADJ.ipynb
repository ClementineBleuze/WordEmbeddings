# %%
import sys
sys.path.append('../Util')
import pickle
import os

# %%
from IPython.display import Image

# %%
from evaluation import correlation, lr, perceptron, get_anova_dims, get_mi_dims
from preparation import prepare_dataset, read_datasets

# %%
from we import get_we, initiate_model

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from scipy.stats import f_oneway

# %%
from sklearn.metrics import mean_absolute_error, accuracy_score
from sklearn.manifold import TSNE
from sklearn.preprocessing import MinMaxScaler, QuantileTransformer

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
models = [
    {
        'name': 'flaubert/flaubert_small_cased',
        'label': 'flau_small_c'
    },
    {
    
        'name': 'flaubert/flaubert_base_uncased', 
        'label': 'flau_base_u'

    },
    {
        'name': 'flaubert/flaubert_base_cased',
        'label': 'flau_base_c'
    },
    {
        'name': 'flaubert/flaubert_large_cased',
        'label': 'flau_large_c'
    },
    {
        'name': 'camembert/camembert-base',
        'label': 'cam_base'
    },
    {
        'name': 'xlm-roberta-large',
        'label': 'xlm_large'
    },
    {
    
        'name': 'xlm-roberta-base', 
        'label': 'xlm_base'

    },
    {
        'name': 'bert-base-multilingual-uncased',
        'label': 'bert_base_u'
    },
    {
        'name': 'distilbert-base-multilingual-cased',
        'label': 'distilbert_base'
    },
    {
        'name': 'bert-base-multilingual-cased',
        'label': 'bert_base_c'
    }
    
]

# %%
labels = [m['label'] for m in models]

# %%
we_with_features = read_datasets(
                            path = '../Data',
                            model_labels = labels,
                            file_name = 'all_adjs_we.csv'
                    )

# %%
we_with_features[-1].head()
# Out:
#                    0         1         2         3         4         5  \
# Word
# abandonné   0.530145  0.060065  0.007523  0.990865  0.430226  0.009984
# absent      0.531874  0.058954  0.008474  0.992320  0.430201  0.009588
# absolue     0.530525  0.059162  0.006882  0.991010  0.430248  0.010904
# accessible  0.533019  0.059168  0.008158  0.993498  0.430884  0.008257
# accompagné  0.528270  0.059300  0.005714  0.989006  0.430188  0.010091
#
#                    6         7         8         9  ...       761       762  \
# Word                                                ...
# abandonné   0.979131  0.978007  0.169568  0.868192  ...  0.032520  0.537425
# absent      0.979643  0.978505  0.169001  0.868324  ...  0.030967  0.538838
# absolue     0.978860  0.978440  0.167912  0.868436  ...  0.031620  0.535794
# accessible  0.979684  0.978070  0.167863  0.868585  ...  0.027722  0.534105
# accompagné  0.980515  0.978253  0.171316  0.867668  ...  0.035285  0.540979
#
#                  763       764       765       766       767      Gender  \
# Word
# abandonné   0.982741  0.068059  0.106907  0.257188  0.765370   masculine
# absent      0.983681  0.068282  0.106521  0.258556  0.765498   masculine
# absolue     0.983176  0.068435  0.106496  0.259584  0.765379    feminine
# accessible  0.983887  0.067770  0.107722  0.258436  0.763149  invariable
# accompagné  0.982319  0.070023  0.107055  0.257919  0.768394   masculine
#
#               Number       Lemma
# Word
# abandonné   singular   abandonné
# absent      singular      absent
# absolue     singular      absolu
# accessible  singular  accessible
# accompagné  singular  accompagné
#
# [5 rows x 771 columns]

# %%
# There are 3 extra feautres in addition to embedding dimensions in the file: number, gender, lemma
feature_col_count = 3

# Feature to investigate in this notebook
feature = 'Gender'

# %% [markdown]
# # Adjectivess

# %%
pos = ['ADJ']

# %% [markdown]
# Split each model into train and test:

# %%
X_adj_train = []
y_adj_train = []

X_adj_test = []
y_adj_test = []

# %%
for we in we_with_features:
    xtr, xtst, ytr, ytst = prepare_dataset(dataset=we[(we.Gender != 'invariable') & (we.Number != 'invariable')],
                                           feature_col_count=feature_col_count,
                                           feature_name=feature,
                                           normalize=False,
                                           encode=True,
                                           encode_as1='feminine',
                                           split=True,
                                           balance=True)
    X_adj_train.append(xtr)
    X_adj_test.append(xtst)
    
    y_adj_train.append(ytr)
    y_adj_test.append(ytst)

# %%
dataset_sizes = pd.DataFrame(index=labels)
dataset_sizes['Train size'] = [len(x) for x in X_adj_train]
dataset_sizes['Test size'] = [len(x) for x in X_adj_test]
dataset_sizes
# Out:
#                  Train size  Test size
# flau_small_c           4235       1059
# flau_base_u            4950       1238
# flau_base_c            4235       1059
# flau_large_c           4235       1059
# cam_base               2345        587
# xlm_large               366         92
# xlm_base                366         92
# bert_base_u             838        210
# distilbert_base         636        160
# bert_base_c             636        160

# %% [markdown]
# ## Non-independent dims

# %% [markdown]
# ANOVA test with p-value < 0.01:

# %%
anova_dims = [get_anova_dims(X_adj_train[i], y_adj_train[i]) for i in range(len(models))]

# %%
mi_dims = [get_mi_dims(X_adj_train[i], y_adj_train[i]) for i in range(len(models))]

# %%
non_ind_dims = [list(set(anova_dims[i]).intersection(mi_dims[i])) for i in range(len(models))]

# %% [markdown]
# Stats about the number of dimensions for each model:

# %%
non_ind_df = pd.DataFrame(index=labels, columns=['ANOVA', 'MI', 'Total non independent'])

# %%
non_ind_df['ANOVA'] = [len(x) for x in anova_dims]
non_ind_df['MI'] = [len(x) for x in mi_dims]
non_ind_df['Total non independent'] = [len(x) for x in non_ind_dims]

# %%
non_ind_df
# Out:
#                  ANOVA   MI  Total non independent
# flau_small_c       369  372                    294
# flau_base_u        220  410                    134
# flau_base_c        336  445                    221
# flau_large_c       797  731                    626
# cam_base           134  449                     85
# xlm_large           10  526                      7
# xlm_base            33  416                     21
# bert_base_u          2  347                      2
# distilbert_base    212  462                    152
# bert_base_c          1  465                      1

# %%
dims = {}

# %%
for i in range(len(models)):
    dims[labels[i]] = {}
    dims[labels[i]]['All dims'] = X_adj_train[i].columns
    dims[labels[i]]['ANOVA'] = anova_dims[i]
    dims[labels[i]]['MI'] = mi_dims[i]
    dims[labels[i]]['All non ind'] = non_ind_dims[i]

# %% [markdown]
# ## Important dims

# %% [markdown]
# We can test different $\alpha$ values: 1%, 5%, 10%, 25%, 50%, 75%.

# %%
alphas = [1, 5, 10, 25, 50, 75]

# %% [markdown]
# Train Logistic Regression on train set for each model:

# %%
lr_res = [lr(X_adj_train[i], y_adj_train[i]) for i in range(len(models))]

# %% [markdown]
# Train Perceptron 10 times and get average weights:

# %%
perceptron_res = [perceptron(X_adj_train[i], y_adj_train[i]) for i in range(len(models))]

# %% [markdown]
# Compute correlation to the gender vector:

# %%
corr_res = [correlation(X_adj_train[i], y_adj_train[i]) for i in range(len(models))]

# %%
for i in range(len(models)):
    for alpha in alphas:
        num_imp_dims = len(X_adj_test[i].columns)*alpha//100
        lr_dims = [str(x[0]) for x in lr_res[i][:num_imp_dims]]
        perc_dims = [str(x[0]) for x in perceptron_res[i][:num_imp_dims]]
        corr_dims = [str(x[0]) for x in corr_res[i][:num_imp_dims]]
        dims[labels[i]][f'LR{alpha}'] = lr_dims
        dims[labels[i]][f'Perc{alpha}'] = perc_dims
        dims[labels[i]][f'Corr{alpha}'] = corr_dims
        dims[labels[i]][f'All imp dims{alpha}'] = list(set(lr_dims).intersection(perc_dims).intersection(corr_dims))

# %% [markdown]
# ## Compute medians

# %%
medians = {}

# %%
for i in range(len(models)):
    medians[labels[i]] = {}
    for dim_group in dims[labels[i]].keys():
        medians[labels[i]][dim_group] = {}
        dim_list = dims[labels[i]][dim_group]
        # Median of dimensions where feature vector is equal to 0
        median_0 = X_adj_train[i][y_adj_train[i] == 0][dim_list].median()
        # Median of dimensions where feature vector is equal to 1
        median_1 = X_adj_train[i][y_adj_train[i] == 1][dim_list].median()
        
        medians[labels[i]][dim_group]['0'] = median_0
        medians[labels[i]][dim_group]['1'] = median_1

# %%
dim_lens = {}

for model in dims.keys():
    dim_lens[model] = {}
    for dim_group in dims[model].keys():
        dim_lens[model][dim_group] = len(dims[model][dim_group])

# %%
pd.DataFrame(dim_lens)
# Out:
#                 flau_small_c  flau_base_u  flau_base_c  flau_large_c  \
# All dims                 512          768          768          1024
# ANOVA                    369          220          336           797
# MI                       372          410          445           731
# All non ind              294          134          221           626
# LR1                        5            7            7            10
# Perc1                      5            7            7            10
# Corr1                      5            7            7            10
# All imp dims1              1            0            0             0
# LR5                       25           38           38            51
# Perc5                     25           38           38            51
# Corr5                     25           38           38            51
# All imp dims5             15           10            4            11
# LR10                      51           76           76           102
# Perc10                    51           76           76           102
# Corr10                    51           76           76           102
# All imp dims10            26           21           20            35
# LR25                     128          192          192           256
# Perc25                   128          192          192           256
# Corr25                   128          192          192           256
# All imp dims25            76           69           68           108
# LR50                     256          384          384           512
# Perc50                   256          384          384           512
# Corr50                   256          384          384           512
# All imp dims50           159          178          183           290
# LR75                     384          576          576           768
# Perc75                   384          576          576           768
# Corr75                   384          576          576           768
# All imp dims75           290          372          369           536
#
#                 cam_base  xlm_large  xlm_base  bert_base_u  distilbert_base  \
# All dims             768       1024       768          768              768
# ANOVA                134         10        33            2              212
# MI                   449        526       416          347              462
# All non ind           85          7        21            2              152
# LR1                    7         10         7            7                7
# Perc1                  7         10         7            7                7
# Corr1                  7         10         7            7                7
# All imp dims1          0          1         0            0                0
# LR5                   38         51        38           38               38
# Perc5                 38         51        38           38               38
# Corr5                 38         51        38           38               38
# All imp dims5          2          6         7            3                7
# LR10                  76        102        76           76               76
# Perc10                76        102        76           76               76
# Corr10                76        102        76           76               76
# All imp dims10         9         14        12            7               14
# LR25                 192        256       192          192              192
# Perc25               192        256       192          192              192
# Corr25               192        256       192          192              192
# All imp dims25        34         66        50           36               50
# LR50                 384        512       384          384              384
# Perc50               384        512       384          384              384
# Corr50               384        512       384          384              384
# All imp dims50       123        182       138          125              168
# LR75                 576        768       576          576              576
# Perc75               576        768       576          576              576
# Corr75               576        768       576          576              576
# All imp dims75       332        466       353          331              365
#
#                 bert_base_c
# All dims                768
# ANOVA                     1
# MI                      465
# All non ind               1
# LR1                       7
# Perc1                     7
# Corr1                     7
# All imp dims1             0
# LR5                      38
# Perc5                    38
# Corr5                    38
# All imp dims5             0
# LR10                     76
# Perc10                   76
# Corr10                   76
# All imp dims10            4
# LR25                    192
# Perc25                  192
# Corr25                  192
# All imp dims25           31
# LR50                    384
# Perc50                  384
# Corr50                  384
# All imp dims50          128
# LR75                    576
# Perc75                  576
# Corr75                  576
# All imp dims75          328

# %% [markdown]
# ## Compute predictions

# %%
y_preds = {}

# %%
for i in range(len(models)):
    y_preds[labels[i]] = {}
    for dim_group in dims[labels[i]].keys():
        dim_list = dims[labels[i]][dim_group]
        mae0 = X_adj_test[i][dim_list].apply(lambda x: mean_absolute_error(medians[labels[i]][dim_group]['0'], x), axis=1)
        mae1 = X_adj_test[i][dim_list].apply(lambda x: mean_absolute_error(medians[labels[i]][dim_group]['1'], x), axis=1)
        # If MSE for sample 0 is lower than for sample 1, the label should be 0. So we need to convert False to 0.
        y_preds[labels[i]][dim_group] = (mae0 > mae1).apply(int)

# %% [markdown]
# ## Compute accuracies

# %%
accs = {}

# %%
for i in range(len(models)):
    accs[labels[i]] = {}
    for dim_group in dims[labels[i]].keys():
        y_true = y_adj_test[i]
        y_pred = y_preds[labels[i]][dim_group]
        if any(y_pred):
            acc = accuracy_score(y_true, y_pred)
        else:
            acc = 0
        accs[labels[i]][dim_group] = acc

# %%
accs_df = pd.DataFrame(accs)
accs_df
# Out:
#                 flau_small_c  flau_base_u  flau_base_c  flau_large_c  \
# All dims            0.932956     0.506462     0.589235      0.915958
# ANOVA               0.931067     0.517771     0.593957      0.913126
# MI                  0.931067     0.511309     0.593012      0.918791
# All non ind         0.932011     0.519386     0.591124      0.916903
# LR1                 0.723324     0.527464     0.539188      0.691218
# Perc1               0.732767     0.544426     0.594901      0.799811
# Corr1               0.714825     0.528271     0.599622      0.777148
# All imp dims1       0.604344     0.000000     0.000000      0.000000
# LR5                 0.855524     0.553312     0.580737      0.866856
# Perc5               0.875354     0.550889     0.627951      0.877243
# Corr5               0.874410     0.537964     0.612842      0.876298
# All imp dims5       0.853636     0.536349     0.541076      0.788480
# LR10                0.914070     0.542811     0.620397      0.898017
# Perc10              0.911237     0.543619     0.643059      0.905571
# Corr10              0.898961     0.535541     0.597734      0.901794
# All imp dims10      0.870633     0.542811     0.600567      0.868744
# LR25                0.938621     0.526656     0.647781      0.928234
# Perc25              0.933900     0.542003     0.655335      0.931067
# Corr25              0.929178     0.523425     0.598678      0.907460
# All imp dims25      0.920680     0.540388     0.642115      0.912181
# LR50                0.944287     0.512116     0.618508      0.926346
# Perc50              0.949953     0.524233     0.634561      0.931067
# Corr50              0.929178     0.514540     0.590179      0.913126
# All imp dims50      0.933900     0.533118     0.621341      0.926346
# LR75                0.942398     0.503231     0.597734      0.912181
# Perc75              0.939566     0.504847     0.610009      0.926346
# Corr75              0.929178     0.508885     0.589235      0.912181
# All imp dims75      0.945231     0.512116     0.621341      0.922568
#
#                 cam_base  xlm_large  xlm_base  bert_base_u  distilbert_base  \
# All dims        0.528109   0.500000  0.521739     0.495238          0.58125
# ANOVA           0.528109   0.532609  0.532609     0.500000          0.58125
# MI              0.528109   0.576087  0.543478     0.490476          0.58125
# All non ind     0.528109   0.554348  0.554348     0.500000          0.58125
# LR1             0.521295   0.586957  0.500000     0.480952          0.55625
# Perc1           0.475298   0.565217  0.543478     0.500000          0.59375
# Corr1           0.514480   0.532609  0.554348     0.490476          0.58125
# All imp dims1   0.000000   0.554348  0.000000     0.000000          0.00000
# LR5             0.526405   0.543478  0.500000     0.495238          0.63125
# Perc5           0.531516   0.597826  0.456522     0.500000          0.61250
# Corr5           0.524702   0.576087  0.521739     0.500000          0.56875
# All imp dims5   0.522998   0.554348  0.467391     0.514286          0.56250
# LR10            0.528109   0.510870  0.521739     0.495238          0.63125
# Perc10          0.528109   0.510870  0.467391     0.495238          0.60625
# Corr10          0.528109   0.554348  0.500000     0.495238          0.56875
# All imp dims10  0.519591   0.586957  0.532609     0.509524          0.60625
# LR25            0.528109   0.532609  0.510870     0.500000          0.60625
# Perc25          0.528109   0.532609  0.510870     0.495238          0.58750
# Corr25          0.528109   0.521739  0.576087     0.500000          0.57500
# All imp dims25  0.529813   0.510870  0.489130     0.495238          0.60625
# LR50            0.528109   0.532609  0.532609     0.495238          0.59375
# Perc50          0.528109   0.521739  0.543478     0.495238          0.58750
# Corr50          0.528109   0.521739  0.532609     0.495238          0.58125
# All imp dims50  0.528109   0.521739  0.532609     0.495238          0.60000
# LR75            0.528109   0.521739  0.565217     0.495238          0.58750
# Perc75          0.528109   0.510870  0.532609     0.495238          0.58750
# Corr75          0.528109   0.521739  0.521739     0.495238          0.58125
# All imp dims75  0.528109   0.532609  0.554348     0.495238          0.60000
#
#                 bert_base_c
# All dims            0.51875
# ANOVA               0.53750
# MI                  0.51250
# All non ind         0.53750
# LR1                 0.56250
# Perc1               0.55000
# Corr1               0.53750
# All imp dims1       0.00000
# LR5                 0.52500
# Perc5               0.52500
# Corr5               0.51875
# All imp dims5       0.00000
# LR10                0.52500
# Perc10              0.51875
# Corr10              0.51875
# All imp dims10      0.55625
# LR25                0.52500
# Perc25              0.51875
# Corr25              0.51875
# All imp dims25      0.53750
# LR50                0.52500
# Perc50              0.51875
# Corr50              0.52500
# All imp dims50      0.52500
# LR75                0.52500
# Perc75              0.51875
# Corr75              0.52500
# All imp dims75      0.52500

# %% [markdown]
# We can show what is the accuracy gain for each dimension test comparison to using all dimensions:

# %%
gains_df = (accs_df - accs_df.loc['All dims'])
gains_df
# Out:
#                 flau_small_c  flau_base_u  flau_base_c  flau_large_c  \
# All dims            0.000000     0.000000     0.000000      0.000000
# ANOVA              -0.001889     0.011309     0.004721     -0.002833
# MI                 -0.001889     0.004847     0.003777      0.002833
# All non ind        -0.000944     0.012924     0.001889      0.000944
# LR1                -0.209632     0.021002    -0.050047     -0.224740
# Perc1              -0.200189     0.037964     0.005666     -0.116147
# Corr1              -0.218130     0.021809     0.010387     -0.138810
# All imp dims1      -0.328612    -0.506462    -0.589235     -0.915958
# LR5                -0.077432     0.046850    -0.008499     -0.049103
# Perc5              -0.057602     0.044426     0.038716     -0.038716
# Corr5              -0.058546     0.031502     0.023607     -0.039660
# All imp dims5      -0.079320     0.029887    -0.048159     -0.127479
# LR10               -0.018886     0.036349     0.031161     -0.017941
# Perc10             -0.021719     0.037157     0.053824     -0.010387
# Corr10             -0.033994     0.029079     0.008499     -0.014164
# All imp dims10     -0.062323     0.036349     0.011331     -0.047214
# LR25                0.005666     0.020194     0.058546      0.012276
# Perc25              0.000944     0.035541     0.066100      0.015109
# Corr25             -0.003777     0.016963     0.009443     -0.008499
# All imp dims25     -0.012276     0.033926     0.052880     -0.003777
# LR50                0.011331     0.005654     0.029273      0.010387
# Perc50              0.016997     0.017771     0.045326      0.015109
# Corr50             -0.003777     0.008078     0.000944     -0.002833
# All imp dims50      0.000944     0.026656     0.032106      0.010387
# LR75                0.009443    -0.003231     0.008499     -0.003777
# Perc75              0.006610    -0.001616     0.020774      0.010387
# Corr75             -0.003777     0.002423     0.000000     -0.003777
# All imp dims75      0.012276     0.005654     0.032106      0.006610
#
#                 cam_base  xlm_large  xlm_base  bert_base_u  distilbert_base  \
# All dims        0.000000   0.000000  0.000000     0.000000          0.00000
# ANOVA           0.000000   0.032609  0.010870     0.004762          0.00000
# MI              0.000000   0.076087  0.021739    -0.004762          0.00000
# All non ind     0.000000   0.054348  0.032609     0.004762          0.00000
# LR1            -0.006814   0.086957 -0.021739    -0.014286         -0.02500
# Perc1          -0.052811   0.065217  0.021739     0.004762          0.01250
# Corr1          -0.013629   0.032609  0.032609    -0.004762          0.00000
# All imp dims1  -0.528109   0.054348 -0.521739    -0.495238         -0.58125
# LR5            -0.001704   0.043478 -0.021739     0.000000          0.05000
# Perc5           0.003407   0.097826 -0.065217     0.004762          0.03125
# Corr5          -0.003407   0.076087  0.000000     0.004762         -0.01250
# All imp dims5  -0.005111   0.054348 -0.054348     0.019048         -0.01875
# LR10            0.000000   0.010870  0.000000     0.000000          0.05000
# Perc10          0.000000   0.010870 -0.054348     0.000000          0.02500
# Corr10          0.000000   0.054348 -0.021739     0.000000         -0.01250
# All imp dims10 -0.008518   0.086957  0.010870     0.014286          0.02500
# LR25            0.000000   0.032609 -0.010870     0.004762          0.02500
# Perc25          0.000000   0.032609 -0.010870     0.000000          0.00625
# Corr25          0.000000   0.021739  0.054348     0.004762         -0.00625
# All imp dims25  0.001704   0.010870 -0.032609     0.000000          0.02500
# LR50            0.000000   0.032609  0.010870     0.000000          0.01250
# Perc50          0.000000   0.021739  0.021739     0.000000          0.00625
# Corr50          0.000000   0.021739  0.010870     0.000000          0.00000
# All imp dims50  0.000000   0.021739  0.010870     0.000000          0.01875
# LR75            0.000000   0.021739  0.043478     0.000000          0.00625
# Perc75          0.000000   0.010870  0.010870     0.000000          0.00625
# Corr75          0.000000   0.021739  0.000000     0.000000          0.00000
# All imp dims75  0.000000   0.032609  0.032609     0.000000          0.01875
#
#                 bert_base_c
# All dims            0.00000
# ANOVA               0.01875
# MI                 -0.00625
# All non ind         0.01875
# LR1                 0.04375
# Perc1               0.03125
# Corr1               0.01875
# All imp dims1      -0.51875
# LR5                 0.00625
# Perc5               0.00625
# Corr5               0.00000
# All imp dims5      -0.51875
# LR10                0.00625
# Perc10              0.00000
# Corr10              0.00000
# All imp dims10      0.03750
# LR25                0.00625
# Perc25              0.00000
# Corr25              0.00000
# All imp dims25      0.01875
# LR50                0.00625
# Perc50              0.00000
# Corr50              0.00625
# All imp dims50      0.00625
# LR75                0.00625
# Perc75              0.00000
# Corr75              0.00625
# All imp dims75      0.00625

# %% [markdown]
# Here are the dimension groups and the accuracy gain this dimension group provides over all dimensions:

# %%
for i in range(len(models)):
    print(labels[i], gains_df.idxmax()[i], gains_df.loc[gains_df.idxmax()[i], labels[i]])
# Out:
# flau_small_c Perc50 0.016997167138810165
# flau_base_u LR5 0.04684975767366717
# flau_base_c Perc25 0.06610009442870635
# flau_large_c Perc25 0.01510859301227574
# cam_base Perc5 0.0034071550255536653
# xlm_large Perc5 0.09782608695652173
# xlm_base Corr25 0.05434782608695654
# bert_base_u All imp dims5 0.01904761904761898
# distilbert_base LR5 0.04999999999999993
# bert_base_c LR1 0.043749999999999956

# %%
for i in range(len(models)):
    print(labels[i], accs_df.idxmax()[i], accs_df.loc[accs_df.idxmax()[i], labels[i]])
# Out:
# flau_small_c Perc50 0.9499527856468366
# flau_base_u LR5 0.5533117932148627
# flau_base_c Perc25 0.6553352219074599
# flau_large_c Perc25 0.931067044381492
# cam_base Perc5 0.5315161839863713
# xlm_large Perc5 0.5978260869565217
# xlm_base Corr25 0.5760869565217391
# bert_base_u All imp dims5 0.5142857142857142
# distilbert_base LR5 0.63125
# bert_base_c LR1 0.5625

# %%
if 'gender_adj.pickle' not in os.listdir('../Data/best_results/'):
    best_res = {}
    for label in labels:
        best_res[label] = {}
        best_res[label]['best_dim_set'] = []
        best_res[label]['best_dims'] = []
        best_res[label]['accs'] = []
        best_res[label]['gains'] = []
        best_res[label]['medians_0'] = []
        best_res[label]['medians_1'] = []


else:
    with open('../Data/best_results/gender_adj.pickle', 'rb') as f:
        best_res = pickle.load(f)

# %%
for i in range(len(models)):
    best_res[labels[i]]['best_dim_set'].append(gains_df.idxmax()[i])
    best_res[labels[i]]['best_dims'].append(dims[labels[i]][gains_df.idxmax()[i]])
    best_res[labels[i]]['accs'].append(accs_df.loc[accs_df.idxmax()[i], labels[i]])
    best_res[labels[i]]['gains'].append(gains_df.loc[gains_df.idxmax()[i], labels[i]])
    best_res[labels[i]]['medians_0'].append(medians[labels[i]][accs_df.idxmax()[i]]['0'])
    best_res[labels[i]]['medians_1'].append(medians[labels[i]][accs_df.idxmax()[i]]['1'])

# %%
with open('../Data/best_results/gender_adj.pickle', 'wb') as f:
    pickle.dump(best_res, f)

# %% [markdown]
# # Conclusion

# %% [markdown]
# 1. We can note that smaller models (FlauBERT-small and DistilBERT) might be performing on par or better than their bigger counterparts (FlauBERT large and mBERT-base).
# 3. Once again, a bigger vocabulary size doesn't seem to be correlated with the observed accuracy: CamemBERT having a vocabulary 4 times bigger than DistilBERT, however, showing a lower accuracy.
# 4. A lot of models (FlauBERT, XLM, DistilBERT) show higher accuracies for adjectives, despite small vocabulary size.
