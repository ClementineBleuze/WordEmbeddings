# %%
import sys
sys.path.append('../Util')
import pickle
import os

# %%
from evaluation import correlation, lr, perceptron, get_anova_dims, get_mi_dims
from preparation import prepare_dataset, read_datasets

# %%
from we import get_we, initiate_model

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from scipy.stats import f_oneway

# %%
from sklearn.metrics import mean_absolute_error, accuracy_score
from sklearn.manifold import TSNE
from sklearn.preprocessing import MinMaxScaler, QuantileTransformer

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
models = [
    {
        'name': 'flaubert/flaubert_small_cased',
        'label': 'flau_small_c'
    },
    {
    
        'name': 'flaubert/flaubert_base_uncased', 
        'label': 'flau_base_u'

    },
    {
        'name': 'flaubert/flaubert_base_cased',
        'label': 'flau_base_c'
    },
    {
        'name': 'flaubert/flaubert_large_cased',
        'label': 'flau_large_c'
    },
    {
        'name': 'camembert/camembert-base',
        'label': 'cam_base'
    },
    {
        'name': 'xlm-roberta-large',
        'label': 'xlm_large'
    },
    {
    
        'name': 'xlm-roberta-base', 
        'label': 'xlm_base'

    },
    {
        'name': 'bert-base-multilingual-uncased',
        'label': 'bert_base_u'
    },
    {
        'name': 'distilbert-base-multilingual-cased',
        'label': 'distilbert_base'
    },
    {
        'name': 'bert-base-multilingual-cased',
        'label': 'bert_base_c'
    }
    
]

# %%
labels = [m['label'] for m in models]

# %%
we_with_features = read_datasets(
                            path = '../Data',
                            model_labels = labels,
                            file_name = 'all_unique_pos_we.csv'
                    )

# %%
we_with_features[-1].head()
# Out:
#                 0         1         2         3         4         5         6  \
# Word
# 2D       0.909603  0.551025  0.436937  0.789782  0.311517  0.417476  0.629341
# 3D       0.901779  0.549880  0.427826  0.797102  0.313900  0.419226  0.623478
# aa       0.899570  0.555891  0.418186  0.805754  0.319232  0.412976  0.618457
# abandon  0.898879  0.556306  0.417821  0.805256  0.318463  0.412505  0.618276
# abbaye   0.895888  0.554461  0.420659  0.799339  0.322441  0.418141  0.618820
#
#                 7         8         9  ...       764       765       766  \
# Word                                   ...
# 2D       0.913722  0.349834  0.838988  ...  0.285154  0.057887  0.030874
# 3D       0.916539  0.355807  0.844714  ...  0.287610  0.054251  0.018604
# aa       0.914183  0.367882  0.845985  ...  0.287883  0.057476  0.013614
# abandon  0.914983  0.367654  0.846577  ...  0.288183  0.057827  0.014050
# abbaye   0.921033  0.367005  0.845904  ...  0.293985  0.057312  0.012175
#
#               767      Number     Gender    Lemma   POS  Tense  Person
# Word
# 2D       0.310204  invariable   feminine       2D  NOUN    NaN     NaN
# 3D       0.305226  invariable   feminine       3D  NOUN    NaN     NaN
# aa       0.290463  invariable  masculine       aa  NOUN    NaN     NaN
# abandon  0.290994    singular  masculine  abandon  NOUN    NaN     NaN
# abbaye   0.298473    singular   feminine   abbaye  NOUN    NaN     NaN
#
# [5 rows x 774 columns]

# %%
# There are 6 extra feautres in addition to embedding dimensions in the file: number, gender, lemma, pos, tense, person
feature_col_count = 6

# Feature to investigate in this notebook
feature = 'Gender'

# %% [markdown]
# # Adjectivess

# %%
pos = ['ADJ', 'NOUN']

# %% [markdown]
# Split each model into train and test:

# %%
X_na_train = []
y_na_train = []

X_na_test = []
y_na_test = []

# %%
for we in we_with_features:
    xtr, xtst, ytr, ytst = prepare_dataset(dataset=we[(we.Gender != 'invariable') & \
                                                      (we.Number != 'invariable') & (we.POS.isin(pos))],
                                           feature_col_count=feature_col_count,
                                           feature_name=feature,
                                           normalize=False,
                                           encode=True,
                                           encode_as1='feminine',
                                           split=True,
                                           balance=True)
    X_na_train.append(xtr)
    X_na_test.append(xtst)
    
    y_na_train.append(ytr)
    y_na_test.append(ytst)

# %%
dataset_sizes = pd.DataFrame(index=labels)
dataset_sizes['Train size'] = [len(x) for x in X_na_train]
dataset_sizes['Test size'] = [len(x) for x in X_na_test]
dataset_sizes
# Out:
#                  Train size  Test size
# flau_small_c           7166       1792
# flau_base_u            9180       2296
# flau_base_c            7166       1792
# flau_large_c           7166       1792
# cam_base               4825       1207
# xlm_large              1580        396
# xlm_base               1580        396
# bert_base_u            3076        770
# distilbert_base        2108        528
# bert_base_c            2108        528

# %% [markdown]
# ## Non-independent dims

# %% [markdown]
# ANOVA test with p-value < 0.01:

# %%
anova_dims = [get_anova_dims(X_na_train[i], y_na_train[i]) for i in range(len(models))]

# %%
mi_dims = [get_mi_dims(X_na_train[i], y_na_train[i]) for i in range(len(models))]

# %%
non_ind_dims = [list(set(anova_dims[i]).intersection(mi_dims[i])) for i in range(len(models))]

# %% [markdown]
# Stats about the number of dimensions for each model:

# %%
non_ind_df = pd.DataFrame(index=labels, columns=['ANOVA', 'MI', 'Total non independent'])

# %%
non_ind_df['ANOVA'] = [len(x) for x in anova_dims]
non_ind_df['MI'] = [len(x) for x in mi_dims]
non_ind_df['Total non independent'] = [len(x) for x in non_ind_dims]

# %%
non_ind_df
# Out:
#                  ANOVA   MI  Total non independent
# flau_small_c       340  328                    240
# flau_base_u        252  593                    197
# flau_base_c        320  420                    202
# flau_large_c       785  740                    621
# cam_base           334  524                    245
# xlm_large          234  574                    148
# xlm_base           565  477                    371
# bert_base_u         15  548                     11
# distilbert_base    203  447                    130
# bert_base_c          2  462                      1

# %%
dims = {}

# %%
for i in range(len(models)):
    dims[labels[i]] = {}
    dims[labels[i]]['All dims'] = X_na_train[i].columns
    dims[labels[i]]['ANOVA'] = anova_dims[i]
    dims[labels[i]]['MI'] = mi_dims[i]
    dims[labels[i]]['All non ind'] = non_ind_dims[i]

# %% [markdown]
# ## Important dims

# %% [markdown]
# We can test different $\alpha$ values: 1%, 5%, 10%, 25%, 50%, 75%.

# %%
alphas = [1, 5, 10, 25, 50, 75]

# %% [markdown]
# Train Logistic Regression on train set for each model:

# %%
lr_res = [lr(X_na_train[i], y_na_train[i]) for i in range(len(models))]

# %% [markdown]
# Train Perceptron 10 times and get average weights:

# %%
perceptron_res = [perceptron(X_na_train[i], y_na_train[i]) for i in range(len(models))]

# %% [markdown]
# Compute correlation to the gender vector:

# %%
corr_res = [correlation(X_na_train[i], y_na_train[i]) for i in range(len(models))]

# %%
for i in range(len(models)):
    for alpha in alphas:
        num_imp_dims = len(X_na_test[i].columns)*alpha//100
        lr_dims = [str(x[0]) for x in lr_res[i][:num_imp_dims]]
        perc_dims = [str(x[0]) for x in perceptron_res[i][:num_imp_dims]]
        corr_dims = [str(x[0]) for x in corr_res[i][:num_imp_dims]]
        dims[labels[i]][f'LR{alpha}'] = lr_dims
        dims[labels[i]][f'Perc{alpha}'] = perc_dims
        dims[labels[i]][f'Corr{alpha}'] = corr_dims
        dims[labels[i]][f'All imp dims{alpha}'] = list(set(lr_dims).intersection(perc_dims).intersection(corr_dims))

# %% [markdown]
# ## Compute medians

# %%
medians = {}

# %%
for i in range(len(models)):
    medians[labels[i]] = {}
    for dim_group in dims[labels[i]].keys():
        medians[labels[i]][dim_group] = {}
        dim_list = dims[labels[i]][dim_group]
        # Median of dimensions where feature vector is equal to 0
        median_0 = X_na_train[i][y_na_train[i] == 0][dim_list].median()
        # Median of dimensions where feature vector is equal to 1
        median_1 = X_na_train[i][y_na_train[i] == 1][dim_list].median()
        
        medians[labels[i]][dim_group]['0'] = median_0
        medians[labels[i]][dim_group]['1'] = median_1

# %%
dim_lens = {}

for model in dims.keys():
    dim_lens[model] = {}
    for dim_group in dims[model].keys():
        dim_lens[model][dim_group] = len(dims[model][dim_group])

# %%
pd.DataFrame(dim_lens)
# Out:
#                 flau_small_c  flau_base_u  flau_base_c  flau_large_c  \
# All dims                 512          768          768          1024
# ANOVA                    340          252          320           785
# MI                       328          593          420           740
# All non ind              240          197          202           621
# LR1                        5            7            7            10
# Perc1                      5            7            7            10
# Corr1                      5            7            7            10
# All imp dims1              1            1            0             2
# LR5                       25           38           38            51
# Perc5                     25           38           38            51
# Corr5                     25           38           38            51
# All imp dims5              6            4            7            10
# LR10                      51           76           76           102
# Perc10                    51           76           76           102
# Corr10                    51           76           76           102
# All imp dims10            15           10           15            27
# LR25                     128          192          192           256
# Perc25                   128          192          192           256
# Corr25                   128          192          192           256
# All imp dims25            59           55           59            88
# LR50                     256          384          384           512
# Perc50                   256          384          384           512
# Corr50                   256          384          384           512
# All imp dims50           138          159          187           251
# LR75                     384          576          576           768
# Perc75                   384          576          576           768
# Corr75                   384          576          576           768
# All imp dims75           258          367          390           518
#
#                 cam_base  xlm_large  xlm_base  bert_base_u  distilbert_base  \
# All dims             768       1024       768          768              768
# ANOVA                334        234       565           15              203
# MI                   524        574       477          548              447
# All non ind          245        148       371           11              130
# LR1                    7         10         7            7                7
# Perc1                  7         10         7            7                7
# Corr1                  7         10         7            7                7
# All imp dims1          0          0         1            0                0
# LR5                   38         51        38           38               38
# Perc5                 38         51        38           38               38
# Corr5                 38         51        38           38               38
# All imp dims5          1          2         5            7                4
# LR10                  76        102        76           76               76
# Perc10                76        102        76           76               76
# Corr10                76        102        76           76               76
# All imp dims10         2          7         8           16               17
# LR25                 192        256       192          192              192
# Perc25               192        256       192          192              192
# Corr25               192        256       192          192              192
# All imp dims25        32         38        30           54               59
# LR50                 384        512       384          384              384
# Perc50               384        512       384          384              384
# Corr50               384        512       384          384              384
# All imp dims50       129        165        96          157              164
# LR75                 576        768       576          576              576
# Perc75               576        768       576          576              576
# Corr75               576        768       576          576              576
# All imp dims75       334        434       298          360              370
#
#                 bert_base_c
# All dims                768
# ANOVA                     2
# MI                      462
# All non ind               1
# LR1                       7
# Perc1                     7
# Corr1                     7
# All imp dims1             0
# LR5                      38
# Perc5                    38
# Corr5                    38
# All imp dims5             0
# LR10                     76
# Perc10                   76
# Corr10                   76
# All imp dims10            1
# LR25                    192
# Perc25                  192
# Corr25                  192
# All imp dims25           23
# LR50                    384
# Perc50                  384
# Corr50                  384
# All imp dims50          112
# LR75                    576
# Perc75                  576
# Corr75                  576
# All imp dims75          328

# %% [markdown]
# ## Compute predictions

# %%
y_preds = {}

# %%
for i in range(len(models)):
    y_preds[labels[i]] = {}
    for dim_group in dims[labels[i]].keys():
        dim_list = dims[labels[i]][dim_group]
        mae0 = X_na_test[i][dim_list].apply(lambda x: mean_absolute_error(medians[labels[i]][dim_group]['0'], x), axis=1)
        mae1 = X_na_test[i][dim_list].apply(lambda x: mean_absolute_error(medians[labels[i]][dim_group]['1'], x), axis=1)
        # If MSE for sample 0 is lower than for sample 1, the label should be 0. So we need to convert False to 0.
        y_preds[labels[i]][dim_group] = (mae0 > mae1).apply(int)

# %% [markdown]
# ## Compute accuracies

# %%
accs = {}

# %%
for i in range(len(models)):
    accs[labels[i]] = {}
    for dim_group in dims[labels[i]].keys():
        y_true = y_na_test[i]
        y_pred = y_preds[labels[i]][dim_group]
        if any(y_pred):
            acc = accuracy_score(y_true, y_pred)
        else:
            acc = 0
        accs[labels[i]][dim_group] = acc

# %%
accs_df = pd.DataFrame(accs)
accs_df
# Out:
#                 flau_small_c  flau_base_u  flau_base_c  flau_large_c  \
# All dims            0.720424     0.530923     0.634487      0.872768
# ANOVA               0.721540     0.556185     0.637835      0.872768
# MI                  0.715402     0.543554     0.636719      0.878906
# All non ind         0.720424     0.550087     0.639509      0.877790
# LR1                 0.600446     0.544861     0.546875      0.632254
# Perc1               0.626116     0.557491     0.583705      0.762277
# Corr1               0.627790     0.533972     0.580915      0.751116
# All imp dims1       0.582031     0.537892     0.000000      0.607143
# LR5                 0.698661     0.534843     0.592076      0.740513
# Perc5               0.728795     0.585801     0.613839      0.848772
# Corr5               0.696429     0.558798     0.626116      0.831473
# All imp dims5       0.638951     0.552265     0.577009      0.693638
# LR10                0.753906     0.544861     0.619420      0.831473
# Perc10              0.770647     0.574042     0.661830      0.866629
# Corr10              0.701451     0.554443     0.638393      0.844866
# All imp dims10      0.676339     0.554878     0.590960      0.800781
# LR25                0.789621     0.540070     0.634487      0.870536
# Perc25              0.800781     0.569686     0.669085      0.887835
# Corr25              0.711496     0.545732     0.628348      0.864955
# All imp dims25      0.757812     0.566202     0.633371      0.848214
# LR50                0.763393     0.540941     0.652344      0.882812
# Perc50              0.768973     0.554007     0.657366      0.896205
# Corr50              0.723214     0.548345     0.642299      0.876674
# All imp dims50      0.767299     0.568815     0.664621      0.878906
# LR75                0.737165     0.533972     0.630580      0.879464
# Perc75              0.742746     0.548780     0.650112      0.888393
# Corr75              0.722098     0.539634     0.636161      0.872768
# All imp dims75      0.767299     0.548345     0.654576      0.883371
#
#                 cam_base  xlm_large  xlm_base  bert_base_u  distilbert_base  \
# All dims        0.545153   0.575758  0.540404     0.505195         0.651515
# ANOVA           0.545153   0.583333  0.540404     0.503896         0.655303
# MI              0.545153   0.578283  0.540404     0.496104         0.642045
# All non ind     0.544325   0.588384  0.540404     0.509091         0.642045
# LR1             0.549296   0.555556  0.545455     0.490909         0.530303
# Perc1           0.536868   0.613636  0.520202     0.490909         0.606061
# Corr1           0.545982   0.626263  0.547980     0.528571         0.630682
# All imp dims1   0.000000   0.000000  0.555556     0.000000         0.000000
# LR5             0.540182   0.621212  0.540404     0.510390         0.632576
# Perc5           0.532726   0.608586  0.532828     0.505195         0.657197
# Corr5           0.545153   0.611111  0.530303     0.500000         0.653409
# All imp dims5   0.531069   0.618687  0.537879     0.497403         0.594697
# LR10            0.541011   0.595960  0.535354     0.511688         0.662879
# Perc10          0.545982   0.608586  0.535354     0.497403         0.687500
# Corr10          0.546810   0.590909  0.532828     0.503896         0.666667
# All imp dims10  0.525269   0.611111  0.522727     0.500000         0.634470
# LR25            0.543496   0.580808  0.545455     0.496104         0.662879
# Perc25          0.545153   0.593434  0.542929     0.500000         0.666667
# Corr25          0.545153   0.580808  0.542929     0.503896         0.664773
# All imp dims25  0.545153   0.618687  0.530303     0.505195         0.674242
# LR50            0.545153   0.578283  0.542929     0.501299         0.647727
# Perc50          0.544325   0.578283  0.540404     0.507792         0.666667
# Corr50          0.545153   0.583333  0.542929     0.506494         0.643939
# All imp dims50  0.544325   0.578283  0.542929     0.503896         0.649621
# LR75            0.545153   0.580808  0.540404     0.503896         0.659091
# Perc75          0.545153   0.578283  0.540404     0.505195         0.655303
# Corr75          0.545153   0.573232  0.540404     0.502597         0.642045
# All imp dims75  0.545153   0.580808  0.540404     0.502597         0.664773
#
#                 bert_base_c
# All dims           0.558712
# ANOVA              0.558712
# MI                 0.560606
# All non ind        0.558712
# LR1                0.553030
# Perc1              0.537879
# Corr1              0.539773
# All imp dims1      0.000000
# LR5                0.554924
# Perc5              0.553030
# Corr5              0.543561
# All imp dims5      0.000000
# LR10               0.558712
# Perc10             0.556818
# Corr10             0.547348
# All imp dims10     0.505682
# LR25               0.558712
# Perc25             0.562500
# Corr25             0.553030
# All imp dims25     0.545455
# LR50               0.556818
# Perc50             0.558712
# Corr50             0.556818
# All imp dims50     0.553030
# LR75               0.554924
# Perc75             0.560606
# Corr75             0.556818
# All imp dims75     0.558712

# %% [markdown]
# We can show what is the accuracy gain for each dimension test comparison to using all dimensions:

# %%
gains_df = (accs_df - accs_df.loc['All dims'])
gains_df
# Out:
#                 flau_small_c  flau_base_u  flau_base_c  flau_large_c  \
# All dims            0.000000     0.000000     0.000000      0.000000
# ANOVA               0.001116     0.025261     0.003348      0.000000
# MI                 -0.005022     0.012631     0.002232      0.006138
# All non ind         0.000000     0.019164     0.005022      0.005022
# LR1                -0.119978     0.013937    -0.087612     -0.240513
# Perc1              -0.094308     0.026568    -0.050781     -0.110491
# Corr1              -0.092634     0.003049    -0.053571     -0.121652
# All imp dims1      -0.138393     0.006969    -0.634487     -0.265625
# LR5                -0.021763     0.003920    -0.042411     -0.132254
# Perc5               0.008371     0.054878    -0.020647     -0.023996
# Corr5              -0.023996     0.027875    -0.008371     -0.041295
# All imp dims5      -0.081473     0.021341    -0.057478     -0.179129
# LR10                0.033482     0.013937    -0.015067     -0.041295
# Perc10              0.050223     0.043118     0.027344     -0.006138
# Corr10             -0.018973     0.023519     0.003906     -0.027902
# All imp dims10     -0.044085     0.023955    -0.043527     -0.071987
# LR25                0.069196     0.009146     0.000000     -0.002232
# Perc25              0.080357     0.038763     0.034598      0.015067
# Corr25             -0.008929     0.014808    -0.006138     -0.007812
# All imp dims25      0.037388     0.035279    -0.001116     -0.024554
# LR50                0.042969     0.010017     0.017857      0.010045
# Perc50              0.048549     0.023084     0.022879      0.023438
# Corr50              0.002790     0.017422     0.007812      0.003906
# All imp dims50      0.046875     0.037892     0.030134      0.006138
# LR75                0.016741     0.003049    -0.003906      0.006696
# Perc75              0.022321     0.017857     0.015625      0.015625
# Corr75              0.001674     0.008711     0.001674      0.000000
# All imp dims75      0.046875     0.017422     0.020089      0.010603
#
#                 cam_base  xlm_large  xlm_base  bert_base_u  distilbert_base  \
# All dims        0.000000   0.000000  0.000000     0.000000         0.000000
# ANOVA           0.000000   0.007576  0.000000    -0.001299         0.003788
# MI              0.000000   0.002525  0.000000    -0.009091        -0.009470
# All non ind    -0.000829   0.012626  0.000000     0.003896        -0.009470
# LR1             0.004143  -0.020202  0.005051    -0.014286        -0.121212
# Perc1          -0.008285   0.037879 -0.020202    -0.014286        -0.045455
# Corr1           0.000829   0.050505  0.007576     0.023377        -0.020833
# All imp dims1  -0.545153  -0.575758  0.015152    -0.505195        -0.651515
# LR5            -0.004971   0.045455  0.000000     0.005195        -0.018939
# Perc5          -0.012428   0.032828 -0.007576     0.000000         0.005682
# Corr5           0.000000   0.035354 -0.010101    -0.005195         0.001894
# All imp dims5  -0.014085   0.042929 -0.002525    -0.007792        -0.056818
# LR10           -0.004143   0.020202 -0.005051     0.006494         0.011364
# Perc10          0.000829   0.032828 -0.005051    -0.007792         0.035985
# Corr10          0.001657   0.015152 -0.007576    -0.001299         0.015152
# All imp dims10 -0.019884   0.035354 -0.017677    -0.005195        -0.017045
# LR25           -0.001657   0.005051  0.005051    -0.009091         0.011364
# Perc25          0.000000   0.017677  0.002525    -0.005195         0.015152
# Corr25          0.000000   0.005051  0.002525    -0.001299         0.013258
# All imp dims25  0.000000   0.042929 -0.010101     0.000000         0.022727
# LR50            0.000000   0.002525  0.002525    -0.003896        -0.003788
# Perc50         -0.000829   0.002525  0.000000     0.002597         0.015152
# Corr50          0.000000   0.007576  0.002525     0.001299        -0.007576
# All imp dims50 -0.000829   0.002525  0.002525    -0.001299        -0.001894
# LR75            0.000000   0.005051  0.000000    -0.001299         0.007576
# Perc75          0.000000   0.002525  0.000000     0.000000         0.003788
# Corr75          0.000000  -0.002525  0.000000    -0.002597        -0.009470
# All imp dims75  0.000000   0.005051  0.000000    -0.002597         0.013258
#
#                 bert_base_c
# All dims           0.000000
# ANOVA              0.000000
# MI                 0.001894
# All non ind        0.000000
# LR1               -0.005682
# Perc1             -0.020833
# Corr1             -0.018939
# All imp dims1     -0.558712
# LR5               -0.003788
# Perc5             -0.005682
# Corr5             -0.015152
# All imp dims5     -0.558712
# LR10               0.000000
# Perc10            -0.001894
# Corr10            -0.011364
# All imp dims10    -0.053030
# LR25               0.000000
# Perc25             0.003788
# Corr25            -0.005682
# All imp dims25    -0.013258
# LR50              -0.001894
# Perc50             0.000000
# Corr50            -0.001894
# All imp dims50    -0.005682
# LR75              -0.003788
# Perc75             0.001894
# Corr75            -0.001894
# All imp dims75     0.000000

# %% [markdown]
# Here are the dimension groups and the accuracy gain this dimension group provides over all dimensions:

# %%
for i in range(len(models)):
    print(labels[i], gains_df.idxmax()[i], gains_df.loc[gains_df.idxmax()[i], labels[i]])
# Out:
# flau_small_c Perc25 0.0803571428571429
# flau_base_u Perc5 0.054878048780487854
# flau_base_c Perc25 0.0345982142857143
# flau_large_c Perc50 0.0234375
# cam_base LR1 0.0041425020712511085
# xlm_large Corr1 0.0505050505050505
# xlm_base All imp dims1 0.015151515151515138
# bert_base_u Corr1 0.023376623376623384
# distilbert_base Perc10 0.03598484848484851
# bert_base_c Perc25 0.0037878787878787845

# %%
for i in range(len(models)):
    print(labels[i], accs_df.idxmax()[i], accs_df.loc[accs_df.idxmax()[i], labels[i]])
# Out:
# flau_small_c Perc25 0.80078125
# flau_base_u Perc5 0.585801393728223
# flau_base_c Perc25 0.6690848214285714
# flau_large_c Perc50 0.8962053571428571
# cam_base LR1 0.5492957746478874
# xlm_large Corr1 0.6262626262626263
# xlm_base All imp dims1 0.5555555555555556
# bert_base_u Corr1 0.5285714285714286
# distilbert_base Perc10 0.6875
# bert_base_c Perc25 0.5625

# %%
if 'gender_na.pickle' not in os.listdir('../Data/best_results/'):
    best_res = {}
    for label in labels:
        best_res[label] = {}
        best_res[label]['best_dim_set'] = []
        best_res[label]['best_dims'] = []
        best_res[label]['accs'] = []
        best_res[label]['gains'] = []
        best_res[label]['medians_0'] = []
        best_res[label]['medians_1'] = []


else:
    with open('../Data/best_results/gender_na.pickle', 'rb') as f:
        best_res = pickle.load(f)

# %%
for i in range(len(models)):
    best_res[labels[i]]['best_dim_set'].append(gains_df.idxmax()[i])
    best_res[labels[i]]['best_dims'].append(dims[labels[i]][gains_df.idxmax()[i]])
    best_res[labels[i]]['accs'].append(accs_df.loc[accs_df.idxmax()[i], labels[i]])
    best_res[labels[i]]['gains'].append(gains_df.loc[gains_df.idxmax()[i], labels[i]])
    best_res[labels[i]]['medians_0'].append(medians[labels[i]][accs_df.idxmax()[i]]['0'])
    best_res[labels[i]]['medians_1'].append(medians[labels[i]][accs_df.idxmax()[i]]['1'])

# %%
with open('../Data/best_results/gender_na.pickle', 'wb') as f:
    pickle.dump(best_res, f)

# %% [markdown]
# # Conclusion

# %% [markdown]
# 1. The results for both nouns and adjectives show the same trends: out of french models, FlauBERT shows better results, out of multilingual models - XLM large and DistilBERT.
# 2. For all models, the accuracy is improved when a subset of dimensions is selected instead of all dimensions.
